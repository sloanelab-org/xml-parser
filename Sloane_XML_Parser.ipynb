# %% [markdown]
# # Sloane Lab XML Parser

# %% [markdown]
# This notebook parses the TEI XML files from the Enlightenment Architectures project, extracts the data that we want to import into the Sloane Lab knowledge base, and checks if there are any errors or inconsistencies.

# %% [markdown]
# #### Import libraries

# %%
# -*- coding: future_fstrings -*-
import os
import re
import sys
import urllib
import pandas as pd
from viapy import api
import matplotlib.pyplot as plt
from matplotlib import *
from bs4 import BeautifulSoup as Soup

# %matplotlib inline

# %% [markdown]
# #### XML File path

# %%
# XML file path
XML_PATH = 'data/miscellanea.xml'

# %% [markdown]
# #### Function to handle catalogue numbers

# %%
# Function to transform the catalogue number to an integer
def cat_to_int(catnum):
    catnum = re.search('\d+', catnum)
    if catnum:
        return int(catnum.group(0))
    return None

# %% [markdown]
# #### Load all catalogues and their entries

# %%
# List of catalogues
cats = []

# Open the XML file
with open(XML_PATH) as xml_file:

    # Read the file
    xml = xml_file.read()
    
    # Parse the file
    parsed_xml = Soup(xml, 'lxml')
    
    # Create empty list of people
    people_list = []
    
    # Create empty list of places
    place_list = []
    
    # For each person in the XML list...
    for person in parsed_xml.find('listperson').find_all('person'):

        # Create dictionary with person's internal ID
        person_dict = {'id': person['xml:id']}
        
        # Find the person's external IDs
        person_ids = person.find_all('idno')
        
        # For each external ID...
        for person_id in person_ids:

            # If the type of ID is VIAF...
            if person_id['type'] == 'viaf':
                
                # Add VIAF ID to person dictionary
                person_dict['viaf'] = person_id.text 
 
            # Otherwise, print person
            else:
                print(person)
            
        # Add the dictionary to the list
        people_list.append(person_dict)
    
    # For each place in the XML list...
    for place in parsed_xml.find('listplace').find_all('place'):
        
        # Create dictionary with place's internal ID
        place_dict = {'id': place['xml:id']}

        # Find the person's external IDs
        place_ids = place.find_all('idno')
        
        # For each external ID...
        for place_id in place_ids:
            
            # If the type of ID is VIAF...
            if place_id['type'] == 'viaf':
            
                # Add VIAF ID to place dictionary
                place_dict['viaf'] = place_id.text

            # If the type of ID is GEO...
            elif place_id['type'] == 'geo':
                
                try:
                    # Extract latitude and longitude
                    lat, lon = place_id.text.split(',')
                
                    # Add latitude to place dictionary
                    place_dict['lat'] = float(lat.strip())
                
                    # Add longitude to place dictionary
                    place_dict['lon'] = float(lon.strip())
                except:
                    print(place)
                
            # Otherwise, print place
            else:
                print(place)
            
        # Add the dictionary to the list
        place_list.append(place_dict)

    # Find all catalogues in the manuscript
    catalogues = parsed_xml.find_all('div2')
    
    # For each catalogue...
    for catalogue in catalogues:
        
        # Create catalogue dictionary
        cat_dict = {}
        
        # Create list of entries
        cat_dict['entries'] = []
        
        # Get catalogue title
        cat_dict['title'] = catalogue.find('label').text
        
        # Find all entries in the catalogue
        entries = catalogue.find_all('div3')
    
        # For each entry...
        for entry in entries:
            
            # Get number of entry
            catnum = entry.find('ea:catnum').get_text() if entry.find('ea:catnum') else None
            
            # Get people
            people = entry.find_all('persname')
            
            # Get places
            places = entry.find_all('placename')
            
            # Create entry dictionary
            entry_dict = {
                'num_str': ' '.join(catnum.split()) if catnum else None,
                'num_int': cat_to_int(catnum) if catnum else None,
                'text': ' '.join(entry.text.split()),
                'people': [{'id': x['ref'].strip('#') if 'ref' in x.attrs else None, 'name': ' '.join(x.text.split())} for x in people] if people else None,
                'places': [{'id': x['ref'].strip('#') if 'ref' in x.attrs else None, 'name': ' '.join(x.text.split())} for x in places] if places else None
            }
        
            # Append entry to entry list
            cat_dict['entries'].append(entry_dict)
        
        # Append catalogue to catalogue list
        cats.append(cat_dict)
# Out:
# <place xml:id="Eichstadt">
# <placename>Eichstadt</placename>
# <idno type="viaf">124967002</idno>
# <idno type="geo"> 124967002</idno>
# </place>
# <place xml:id="Hispaniola">
# <placename>Hispaniola</placename>
# <placename>wreck on the coast of Espanola</placename>
# <idno type="viaf">242111207</idno>
# <idno type="geo"> failed</idno>
# </place>
# <place xml:id="Katzenelnbogen">
# <placename>Country of Catzellenbogen &amp; belonging to the Landgrave of Hesse cassell,
#               northward of Mayence</placename>
# <idno type="viaf">129154192</idno>
# <idno type="geo"> 50.26745,†7.97322</idno>
# </place>
# <place xml:id="Lapland">
# <placename>Lapland</placename>
# <idno type="viaf">140666509 </idno>
# <idno type="geo"> 67.616229 26.761877</idno>
# </place>
# <place xml:id="Manila">
# <placename>Maniglia in the East Indies </placename>
# <idno type="viaf">128902416</idno>
# <idno type="geo"> 14.6042,†120.9822</idno>
# </place>
# <place xml:id="Melo_Island">
# <placename>Melo Island</placename>
# <idno type="geo"> 11.03333,†-15.21667</idno>
# </place>
# <place xml:id="New_England">
# <placename>New England</placename>
# <placename>N England</placename>
# <idno type="geo"> 44,†-71</idno>
# </place>
# <place xml:id="River_Craven">
# <placename>river above Ingleton in Craven</placename>
# <idno type="viaf">138642187</idno>
# <idno type="geo"> 54.15392,†-2.46849</idno>
# </place>
# <place xml:id="Santa_Maria_Campeche">
# <placename>Sta Maria near Campeche</placename>
# <idno type="viaf">136049224</idno>
# <idno type="geo"> 18.83333,†-90.25</idno>
# </place>
# <place xml:id="Surentum">
# <placename>Surentum</placename>
# <idno type="viaf">154773300</idno>
# <idno type="geo"> 47.51,†6.8</idno>
# </place>
# <place xml:id="Wolfenbuettel">
# <placename>Asse in Wolfembatle</placename>
# <placename>Wolfem =butle</placename>
# <idno type="viaf">140714405</idno>
# <idno type="geo"> 52.16442,†10.54095</idno>
# </place>

# %% [markdown]
# #### How many people in the list?

# %%
len(people_list)
# Out:
# 2799

# %% [markdown]
# #### How many places in the list?

# %%
len(place_list)
# Out:
# 555

# %% [markdown]
# #### How many catalogues?

# %%
# Print number of catalogues
len(cats)
# Out:
# 9

# %% [markdown]
# #### What are their titles?

# %%
# Print all catalogue titles
[x['title'].strip() for x in cats]
# Out:
# ['Miscellanies.',
#  'Antiquities.',
#  'Impressions of Seals &c.',
#  'Index. inSigilla, Sigillorum. Impressiones, &c.',
#  'Pictures &c.',
#  'Mathematicall instruments &c',
#  'Index to the Mathematical Instruments.',
#  'Agate handles &c.',
#  'Agate cups botles spoons &c.']

# %% [markdown]
# #### What are their lengths?

# %%
# Compute catalogue lengths
for x in cats:
    x['length'] = len(x['entries'])

[x['length'] for x in cats]
# Out:
# [2335, 1376, 290, 332, 450, 60, 105, 261, 364]

# %% [markdown]
# #### Transform the list of catalogues into a dataframe

# %%
cat_df = pd.DataFrame(cats)
cat_df
# Out:
#                                              entries  length  \
# 0  [{'places': [{'id': 'East_Indies', 'name': 'Ea...    2335
# 1  [{'places': None, 'num_str': '-700.', 'num_int...    1376
# 2  [{'places': [{'id': 'Scotland', 'name': 'Scotl...     290
# 3  [{'places': None, 'num_str': None, 'num_int': ...     332
# 4  [{'places': None, 'num_str': '-1.', 'num_int':...     450
# 5  [{'places': None, 'num_str': '1.', 'num_int': ...      60
# 6  [{'places': None, 'num_str': None, 'num_int': ...     105
# 7  [{'places': None, 'num_str': '1.', 'num_int': ...     261
# 8  [{'places': None, 'num_str': '1.', 'num_int': ...     364
#
#                                              title
# 0                                    Miscellanies.
# 1                                     Antiquities.
# 2                         Impressions of Seals &c.
# 3  Index. inSigilla, Sigillorum. Impressiones, &c.
# 4                                     Pictures &c.
# 5                     Mathematicall instruments &c
# 6       \nIndex to the Mathematical Instruments.\n
# 7                                Agate handles &c.
# 8                     Agate cups botles spoons &c.

# %% [markdown]
# #### Display the lengths of the catalogues

# %%
plt.figure(figsize=(14,6))
plt.xticks(range(30), rotation='vertical')
plt.bar(cat_df['title'],cat_df['length'])
plt.show()

# %% [markdown]
# #### First catalogue: Miscellanies

# %%
# Check first catalogue
cats[0]
# Out:
# {'entries': [{'num_int': 1799,
#    'num_str': '-1799.',
#    'people': [{'id': 'Mr._Amyand', 'name': 'Mr. Amyand'}],
#    'places': [{'id': 'East_Indies', 'name': 'East Indies'}],
#    'text': '-1799. A bow said to be made of a bone from East Indies given to me by Mr. Amyand 252.'},
#   {'num_int': 1800,
#    'num_str': '-1800.',
#    'people': None,
#    'places': None,
#    'text': '-1800. Arrows from the same. Id. 252.'},
#   {'num_int': 1801,
#    'num_str': '-1801.',
#    'people': [{'id': 'James_Theobalds_Esqr', 'name': 'Mr. Theobalds'}],
#    'places': [{'id': 'Norway', 'name': 'Norway'}],
#    'text': '-1801. A trumpet from Norway made of 2 pieces of wood about 5 foot long in form of a trumpet fastened by birch tree bark from Mr. Theobalds. 245.'},
#   {'num_int': 1802,
#    'num_str': '-1802.',
#    'people': None,
#    'places': None,
#    'text': '-1802. A Chinese womans shoe. 299 b 24'},
#   {'num_int': 1803,
#    'num_str': '-1803.',
#    'people': None,
#    'places': None,
#    'text': '-1803. A chinese womans girdle wt. her handkerchiefs & purses. 226 24'},
#   {'num_int': 1804,
#    'num_str': '-1804.',
#    'people': None,
#    'places': None,
#    'text': '-1804. A Chinese tobacco pipe enameld. 245.'},
#   {'num_int': 1805,
#    'num_str': '-1805.',
#    'people': None,
#    'places': None,
#    'text': '-1805. A chinese scratcher wt. a handle & hand. 163 25'},
#   {'num_int': 1806,
#    'num_str': '-1806.',
#    'people': [{'id': 'Mr_Roberts', 'name': 'Mr. Roberts'}],
#    'places': None,
#    'text': '-1806. Large severall figured pieces of blew glasse taken from the bottom of the fire place of a furnace given me by Mr. Roberts. 216 b 30 C'},
#   {'num_int': 1807,
#    'num_str': '-1807.',
#    'people': [{'id': 'MrMC', 'name': 'Mr. Mc. Cormick'}],
#    'places': [{'id': 'Lisbon', 'name': 'Lisbon'}],
#    'text': '-1807. A leather boracho or bottle wherein is carried wine on a journey wt. a wooden Cork or stopple & a horn mouth to drink out of it. from Mr. Mc. Cormick a surgeon who brought it from Lisbon. 199 a c 19 N'},
#   {'num_int': 1808,
#    'num_str': '-1808.',
#    'people': None,
#    'places': [{'id': 'Lisbon', 'name': 'Lisbone'}],
#    'text': '-1808. An arteficiall spike or ear of barley made of wire by the nuns at Lisbone from the same 199 a'},
#   {'num_int': 1809,
#    'num_str': '-1809.',
#    'people': [{'id': 'Alexander_Stuart', 'name': 'Dr. Stuart'}],
#    'places': [{'id': 'Malacca', 'name': 'Malacca'}],
#    'text': '-1809. A weapon . dagger wt. wch. the Malayese run a muck in Malacca made of 2 antelopes horns shed at both ends wt. iron given to me by Dr. Stuart. 252.'},
#   {'num_int': 1810,
#    'num_str': '1810.',
#    'people': None,
#    'places': [{'id': 'China', 'name': 'China'}],
#    'text': '1810. A sort of glew used in medicine of wch. de Halde hath given an acct. in his books of China. 244. 26. Cab.'},
#   {'num_int': 1811,
#    'num_str': '1811.',
#    'people': None,
#    'places': None,
#    'text': '1811. A pebble of a yellowish colour on wch. are painted sevll. heads from Maukia. 244 26 Cab.'},
#   {'num_int': 1812,
#    'num_str': '1812.',
#    'people': [{'id': 'MrMC', 'name': 'Mr. Mc. Cormick'}],
#    'places': [{'id': 'Lisbon', 'name': 'Lisbon'},
#     {'id': 'Brasil', 'name': 'Brasile'}],
#    'text': '1812. A small leather bottle from Lisbon so elastick as when the air is forcd thrown out to fill its selfe wt. water the upper part screwd of made of _ _ _ _ from Brasile. It is used to squirt water the upper pt. screwd on in Carnevale times by frollicksom people. Glister pipes are made of it. from Mr. Mc. Cormick. 199. 27'},
#   {'num_int': 1813,
#    'num_str': '-1813.',
#    'people': [{'id': 'Mr._Hodson', 'name': 'Mr. Hodsun'}],
#    'places': [{'id': 'China', 'name': 'China'}],
#    'text': '-1813. A sheet of white paper 21 foot long & 4 1/2 broad from China by Mr. Hodsun. 199 a'},
#   {'num_int': 1814,
#    'num_str': '-1814.',
#    'people': None,
#    'places': None,
#    'text': '-1814. A pair of grown womans shoe Id. 199 e 24'},
#   {'num_int': 1815,
#    'num_str': '-1815.',
#    'people': None,
#    'places': None,
#    'text': '-1815. A tinder box wt. tinder from the same. 199 a 25'},
#   {'num_int': 1816,
#    'num_str': '-1816.',
#    'people': [{'id': 'Mr._Launce', 'name': 'Mr. Launce'}],
#    'places': [{'id': 'Guinea', 'name': 'Guinea'}],
#    'text': '-1816. Sticks for cleaning the teeth from Guinea by Mr. Launce. 199 a 27 C'},
#   {'num_int': 1817,
#    'num_str': '-1817.',
#    'people': None,
#    'places': None,
#    'text': '-1817. A fetish shell worn abt. the ancles of the Gaders at Drownd Id. lphoadghs. 303 M'},
#   {'num_int': 1818,
#    'num_str': '-1818.',
#    'people': None,
#    'places': [{'id': 'Malabar', 'name': 'Malabar'}],
#    'text': '-1818. Area mine pro callgrid used by the Indians brazed on a stove wt water for sore eyes in Malabar given me by ____ 199 a'},
#   {'num_int': 1819,
#    'num_str': '-1819.',
#    'people': None,
#    'places': [{'id': 'England', 'name': 'England'}],
#    'text': '-1819. A hollow trunk canes & spears of wood for fishing ? from a England. CXLIX.'},
#   {'num_int': 1,
#    'num_str': '1.',
#    'people': None,
#    'places': [{'id': 'London', 'name': 'London'}],
#    'text': '1. A parcell of knives with bone hafts burnt in the fire of London. ✓ < 245 216.f3'},
#   {'num_int': 2,
#    'num_str': '2.',
#    'people': None,
#    'places': None,
#    'text': '2. A brush of Ostridges feathers. ✓ < 226'},
#   {'num_int': 3,
#    'num_str': '3.',
#    'people': None,
#    'places': None,
#    'text': '3. A piece of the keel of a ship eat by the worms. ✓ < 199 d 231 e'},
#   {'num_int': 4,
#    'num_str': '4.',
#    'people': None,
#    'places': [{'id': 'Coromandel', 'name': 'Coromandel'}],
#    'text': '4. A shoe from Coromandel ✓ < 226. 25 X'},
#   {'num_int': 5,
#    'num_str': '5.',
#    'people': None,
#    'places': None,
#    'text': '5. The same. ✓ < 226. 25.'},
#   {'num_int': 6,
#    'num_str': '6.',
#    'people': None,
#    'places': None,
#    'text': '6. An ivory instrument - - 0. 1. 0 ✓ < 245'},
#   {'num_int': 7,
#    'num_str': '___7.',
#    'people': [{'id': 'Jean_De_Fontaney', 'name': 'father Fontenay'}],
#    'places': [{'id': 'China', 'name': 'China'}],
#    'text': '___7. A sword from China worn there by father Fontenay who gave it me. The Chinese wear swords with their hilts towards their backs. ✓ < 245 a'},
#   {'num_int': 8,
#    'num_str': '8.',
#    'people': None,
#    'places': [{'id': 'Persia', 'name': 'Persian'}],
#    'text': '8. A Persian sword ? 245. Another ye same. 252.'},
#   {'num_int': 9,
#    'num_str': '___9.',
#    'people': [{'id': 'James_Cunningham', 'name': 'Mr. Cunningham'}],
#    'places': [{'id': 'Tonkin', 'name': 'Tunquin'}],
#    'text': '___9. A hatt from Tunquin where it belonged to the Queen. It is made of 2 Talipot leaves on the upper side & cane underneath. It was sent me by Mr. Cunningham. 226. C ✓ X'},
#   {'num_int': 10,
#    'num_str': '10.',
#    'people': None,
#    'places': None,
#    'text': "10. A case containing of turn'd ivory. 246."},
#   {'num_int': 11,
#    'num_str': '11.',
#    'people': None,
#    'places': None,
#    'text': '11. Another. 246'},
#   {'num_int': 12,
#    'num_str': '12.',
#    'people': [{'id': 'Daniel_Waldo', 'name': 'Dr. Waldo'}],
#    'places': [{'id': 'China', 'name': 'China'},
#     {'id': 'Suratte', 'name': 'Suratte'}],
#    'text': '12. An instrument or whisk for cleaning of pictures in China ware. of an Indian Cows tail with a mother of pearl handle from Dr. Waldo at Suratte. Vis Quadrupe No. 1408 - - 1. 6. 226. X'},
#   {'num_int': 1820,
#    'num_str': '-1820.',
#    'people': [{'id': 'Capt_Walker', 'name': 'Capt. Walker'}],
#    'places': [{'id': 'New_England', 'name': 'New England'}],
#    'text': "-1820. A very large bow & arrows from New England by Capt. Walker. Fleches d'Amerique Biron p. 279. 235 244 CL"},
#   {'num_int': 1821,
#    'num_str': '-1821.',
#    'people': None,
#    'places': None,
#    'text': '-1821. Another different. Id. 244 C. < CLI.'},
#   {'num_int': 1822,
#    'num_str': '-1822',
#    'people': [{'id': 'Capt_Walker', 'name': 'Capt. Walker'}],
#    'places': [{'id': 'Berbice', 'name': 'Berbices'},
#     {'id': 'Surinam', 'name': 'Surinam'},
#     {'id': 'West_Indies', 'name': 'West Indies'}],
#    'text': '-1822 A large flat roundish earthen ware Jarr of an ah ash colour made by the Indians at Berbices near Surinam befor the coming of the Europeans into the West Indies from Capt. Walker. CLXII.'},
#   {'num_int': 1823,
#    'num_str': '-1823.',
#    'people': None,
#    'places': [{'id': 'Surinam', 'name': 'Surinam'}],
#    'text': '-1823. An Indian womans flapp , wt. beads which wch. they wear befor them having no cloaths in the hott countrys. Id. from Surinam. 199. e. 19 V.'},
#   {'num_int': 1824,
#    'num_str': '-1824.',
#    'people': None,
#    'places': None,
#    'text': '-1824. Two Indian tobacco pipes Id. O. 245 ✓ 20 L.'},
#   {'num_int': 1825,
#    'num_str': '-1825',
#    'people': None,
#    'places': None,
#    'text': '-1825 ___________ black & white . Id. O 245 ✓'},
#   {'num_int': 1826,
#    'num_str': '-1826.',
#    'people': None,
#    'places': None,
#    'text': '-1826. Indian hatchett of a dark nephritick stone thought to be hammers. 245. a'},
#   {'num_int': 1827,
#    'num_str': '-1827.',
#    'people': None,
#    'places': None,
#    'text': '-1827. _________ wt. white veins. Id. 245. a'},
#   {'num_int': 1828,
#    'num_str': '-1828.',
#    'people': None,
#    'places': None,
#    'text': '-1828. A Calabash carved by the Indians in imitation of a scull wt. its sutures. Id. 238. C < XIII'},
#   {'num_int': 1829,
#    'num_str': '-1829.',
#    'people': None,
#    'places': None,
#    'text': '-1829. A small carved calabash. Id. for making spoons of'},
#   {'num_int': 1830,
#    'num_str': '-1830.',
#    'people': None,
#    'places': [{'id': 'Guinea', 'name': 'Guinea'}],
#    'text': '-1830. A Capashears knife from Guinea. Id. S. B 245. a CLXIIII.'},
#   {'num_int': 1831,
#    'num_str': '-1831.',
#    'people': [{'id': 'Isaac_Waldron_Esqr', 'name': 'Isaac Waldron Esqr'}],
#    'places': [{'id': 'Bristol', 'name': 'hope near Bristol'},
#     {'id': 'Bristol', 'name': 'Bristol'}],
#    'text': '-1831. A piece of some instrument of musick found at Meriat. hope near Bristol in some plowed land on a spott where King Philipp lived & undoubtedly was made befor any tools were invented there gave me by Isaac Waldron Esqr Bristol March. 19. 1735/6 Id. 245 ✓ 28 b.'},
#   {'num_int': 1832,
#    'num_str': '-1832.',
#    'people': None,
#    'places': None,
#    'text': '-1832. A piece of wood representing a Negro boys head. Id. 245. X ✓ 19 O'},
#   {'num_int': 1833,
#    'num_str': '-1833.',
#    'people': None,
#    'places': [{'id': 'Guinea', 'name': 'Guinea'}],
#    'text': '-1833. A Guinea spoon. Id. 244. 19. O.'},
#   {'num_int': 1834,
#    'num_str': '-1834.',
#    'people': None,
#    'places': None,
#    'text': '-1834. A bullet lodged in a spruce fur tree grown out & found in a ships mast. Id. 245.✓ 19. O'},
#   {'num_int': 1835,
#    'num_str': '-1835.',
#    'people': [{'id': 'Abraham_Waldron', 'name': 'Abraham Waldron'}],
#    'places': None,
#    'text': "-1835. An Indian Stone pestle to beat in a wooden trough made of wood burnt & hollowed by their hatchets) Indian corn to make Rocelure belong'd to Abraham Waldron? Id. 5 CLXV 4"},
#   {'num_int': 13,
#    'num_str': '13.',
#    'people': None,
#    'places': [{'id': 'China', 'name': 'China'}],
#    'text': "13. A hatt of the Patriarch of China made of canes splitt on the __ outside & lin'd wt. plantain leaves. 226. d < X"},
#   {'num_int': 14,
#    'num_str': '14.',
#    'people': None,
#    'places': [{'id': 'Isles_Scotland', 'name': 'Isles of Scotland'}],
#    'text': '14. A two handed sword from the Isles of Scotland. 245.'},
#   {'num_int': 15,
#    'num_str': '15.',
#    'people': None,
#    'places': [{'id': 'Turkey', 'name': 'Turkey'}],
#    'text': '15. A bow from Turkey? 245.'},
#   {'num_int': 16,
#    'num_str': '__16.',
#    'people': None,
#    'places': [{'id': 'Brasil', 'name': 'Brasile'},
#     {'id': 'Brasil', 'name': 'Brasile'}],
#    'text': '__16. A bow of Brasile wood with 3 arrows of Small canes headed wt. Brasile wood bearded.__ - -0. 10. 0. 245.'},
#   {'num_int': 17,
#    'num_str': '17.',
#    'people': None,
#    'places': None,
#    'text': '17. A cane arrow , headed wt. hard __ wood --- -- 0. 0. 6 245.'},
#   {'num_int': 18,
#    'num_str': '18.',
#    'people': None,
#    'places': None,
#    'text': '18. A dart to strike fish with. ----- 0. 1. 0.'},
#   {'num_int': 19,
#    'num_str': '19.',
#    'people': None,
#    'places': None,
#    'text': '19. Another larger?'},
#   {'num_int': 20,
#    'num_str': '20.',
#    'people': [{'id': 'William_Courten', 'name': 'Mr. Courtens'}],
#    'places': None,
#    'text': '20. A crab tree clubb or mace very large & much knotted , with Mr. Courtens arms on the top of it. < 238. 245'},
#   {'num_int': 21,
#    'num_str': '21.',
#    'people': None,
#    'places': [{'id': 'Brasil', 'name': 'Brasile'}],
#    'text': '21. A mace of Brasile wood, wrought on the broad end by the Indians Baton. --- --0. 5. 0 252. X'},
#   {'num_int': 22,
#    'num_str': '__22.',
#    'people': None,
#    'places': None,
#    'text': '__22. One of the same larger. 245. X'},
#   {'num_int': 23,
#    'num_str': '23.',
#    'people': None,
#    'places': None,
#    'text': '23. A hollow machine made of canes for are a swing? Squeezing the juice out of limes &c. invented by the Indian Caribes. Vid. Labat. 246.'},
#   {'num_int': 24,
#    'num_str': '24.',
#    'people': None,
#    'places': [{'id': 'Borneo', 'name': 'Borneo'}],
#    'text': '24. A Chinese wooden arrow headed wt. iron adjusted wt. birch bark, wt. ye. wing feathers of the feasant of Borneo. 245'},
#   {'num_int': 1836,
#    'num_str': '-1836.',
#    'people': None,
#    'places': None,
#    'text': '-1836. A small Indian basket made of black white & orange coloured shavings or splinters of wood. Id. CLX. VI'},
#   {'num_int': 1837,
#    'num_str': '-1837.',
#    'people': None,
#    'places': [{'id': 'Japan', 'name': 'Japan'}],
#    'text': '-1837. An Japan pagoda wt. the Idol standing on a flower &c lacquer shrine with folding doors. figure in gilt 113 H 7 1/2 ✓ 246. 199 246 26 A.W.F. 1854'},
#   {'num_int': 1838,
#    'num_str': '-1838.',
#    'people': [{'id': 'George_Edwards, Mr._Edwards', 'name': 'Mr. Edwards'}],
#    'places': [{'id': 'Hudson_Bay', 'name': 'Hudsons Bay'}],
#    'text': '-1838. A bolt made of unicorns horn on wch. are rudely engraved boats canoes &c. fastened wt. a cord fish skin - From Hudsons Bay by Mr. Edwards. 244 28 C'},
#   {'num_int': 1839,
#    'num_str': '-1839.',
#    'people': None,
#    'places': None,
#    'text': '-1839. A lesser one Id 244 28. C'},
#   {'num_int': 1840,
#    'num_str': '-1840.',
#    'people': None,
#    'places': None,
#    'text': '-1840. A childs spoon made of horn. Id. O. 245 ✓ 19. O'},
#   {'num_int': 1841,
#    'num_str': '-1841.',
#    'people': None,
#    'places': None,
#    'text': '-1841. An ornament to be hung before the breast. Id. O 245 ✓ 28. C'},
#   {'num_int': 1842,
#    'num_str': '-1842.',
#    'people': None,
#    'places': None,
#    'text': '-1842. A piece of wood to cover the eyes & part of the nose to be fastened to the head by beaver straps wt. 2 chinks in the wood to see through. Id < 226 244 28. C.'},
#   {'num_int': 1843,
#    'num_str': '-1843.',
#    'people': [{'id': 'Richard_Middleton_Massey', 'name': 'Dr. Massy'}],
#    'places': [{'id': 'Hudson_Bay', 'name': 'Hudsons bay'}],
#    'text': '-1843. A necklace made of a sweet smelling grasse from Hudsons bay by the natives who have of them made into bracelets by Dr. Massy an cyperus or Gr. Mariæ an for ornament or remedy? 244.'},
#   {'num_int': 1844,
#    'num_str': '-1844.',
#    'people': [{'id': 'George_Edwards, Mr._Edwards', 'name': 'Mr. Edwards'}],
#    'places': [{'id': 'Hudson_Bay', 'name': 'Hudsons bay'}],
#    'text': '-1844. A fisgegg from Hudsons bay to catch salmon made of two long bearded bones sett at the end of a sharp wo- oden pole all fastened wt. fish gutts. from Mr. Edwards. CLXXI'},
#   {'num_int': 1845,
#    'num_str': '-1845.',
#    'people': [{'id': 'Peter_Collinson', 'name': 'Mr. Collinson'}],
#    'places': [{'id': 'Carolina', 'name': 'Carolina'}],
#    'text': '-1845. A stick made of the sorrell tree in Carolina painted wt. brown lines. from Mr. Collinson. LXXII'},
#   {'num_int': 1846,
#    'num_str': '-1846.',
#    'people': None,
#    'places': [{'id': 'Canada', 'name': 'Canada'}],
#    'text': '-1846. A dagger of a beryll sett in a wooden haft from Canada Vid. Aldrovand. Mus. Metall. p 157. 209 19. e 28. C.'},
#   {'num_int': 1847,
#    'num_str': '-1847.',
#    'people': [{'id': 'Matthew_Gosset', 'name': 'Monsr. Gosset'}],
#    'places': [{'id': 'Ireland', 'name': 'Ireland'}],
#    'text': '-1847. An odd figured punch ladle made of yew wood by Monsr. Gosset in Ireland & given to me by him. 244. 19. O'},
#   {'num_int': 1848,
#    'num_str': '-1848.',
#    'people': None,
#    'places': None,
#    'text': '-1848. A snuff pan wt. a point at the end for clearing the snuff box of the same wood spotted . Id 244 19. O.'},
#   {'num_int': 1849,
#    'num_str': '-1849.',
#    'people': None,
#    'places': None,
#    'text': '-1849. An extinguisher of the same. Id. 245 19. O.'},
#   {'num_int': 1850,
#    'num_str': '-1850.',
#    'people': None,
#    'places': None,
#    'text': '-1850. Vid. Antiq. 781.'},
#   {'num_int': 1851,
#    'num_str': '-1851.',
#    'people': [{'id': 'Cromwell_Mortimer', 'name': 'Dr. Mortimer'}],
#    'places': None,
#    'text': '-1851. A china whitish tea dish wt. the gold fish painted on it from Dr. Mortimer 5'},
#   {'num_int': 25,
#    'num_str': '25.',
#    'people': None,
#    'places': None,
#    'text': '25. The same headed with a hollow horn to make a noise in flying throh the air. 252'},
#   {'num_int': 26,
#    'num_str': '26.',
#    'people': None,
#    'places': [{'id': 'Turkey', 'name': 'Turky'}],
#    'text': '26. An ordinary arrow an of Turky. 252'},
#   {'num_int': 27,
#    'num_str': '27.',
#    'people': None,
#    'places': None,
#    'text': '27. An Indian fan for cooling the air? 226. B <'},
#   {'num_int': 28,
#    'num_str': '28.',
#    'people': None,
#    'places': None,
#    'text': '28. Another. B < 226.'},
#   {'num_int': 29,
#    'num_str': '29.',
#    'people': None,
#    'places': None,
#    'text': "29. A Targett painted over, & as it were emboss'd, ovall. 245 199."},
#   {'num_int': 30,
#    'num_str': '30.',
#    'people': None,
#    'places': None,
#    'text': '30. A Targett of Manati hide, round. 252 X'},
#   {'num_int': 31,
#    'num_str': '31.',
#    'people': None,
#    'places': None,
#    'text': '31. A fann of Straw. 226.'},
#   {'num_int': 32,
#    'num_str': '32.',
#    'people': None,
#    'places': None,
#    'text': '32. A straw or bent cap. 246.'},
#   {'num_int': 33,
#    'num_str': '33.',
#    'people': None,
#    'places': [{'id': 'China', 'name': 'China'}],
#    'text': '33. A small common arrow, used in China wt. the crossbow. (put into No. 710.) 245. 253'},
#   {'num_int': 34,
#    'num_str': '34.',
#    'people': None,
#    'places': None,
#    'text': '34. Another. 245'},
#   {'num_int': 35,
#    'num_str': '35.',
#    'people': None,
#    'places': None,
#    'text': '35. Another. 245 28. C'},
#   {'num_int': 36,
#    'num_str': '36.',
#    'people': None,
#    'places': None,
#    'text': '36. A brush of the fibrous roots of__ 226.'},
#   {'num_int': 37,
#    'num_str': '37.',
#    'people': None,
#    'places': None,
#    'text': '37. Indian waved or flaming dagger 0. 8. 0 with a horn handle 4th __ - - -0. 8. 0 252.'},
#   {'num_int': 38,
#    'num_str': '38.',
#    'people': None,
#    'places': None,
#    'text': '38. The same larger with a fish skin handle. 245. a <'},
#   {'num_int': 39,
#    'num_str': '39.',
#    'people': None,
#    'places': None,
#    'text': "39. A double branch'd head of a Spear flam'd or waved. 245."},
#   {'num_int': 40,
#    'num_str': '40.',
#    'people': None,
#    'places': None,
#    'text': '40. A Highland Scotch Sken or dagger wt. a wooden haft. 252. X'},
#   {'num_int': 41,
#    'num_str': '41.',
#    'people': None,
#    'places': None,
#    'text': '41. The same wt. a bone haft. 252.'},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': "5* Les maisons des particuliers, vont construites dans un certain ordre d'architecture qui leur est propre. Le qui surprend, c' est qu'ils n'ont point d'autre outil que des haches de pierre pour couper le bois, & le mettre en œu œuvre. Lettres Edifiantes XXV. Recueil page. 124. Paraguay P. Jean Patrice Fernandez 5a"},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': '5** enim terra nihil profert, quia non est Stercorata. Nic. Durand of Paraquaria p. 163. 5b'},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': "Pierres des Amazones. Condamine. Relat. abregee d'un Voyage de Ld Amerique Meridionale p. 104 et p. 140. for curing the Stone Nephritic colic & epilepsy"},
#   {'num_int': 1852,
#    'num_str': '-1852.',
#    'people': [{'id': 'Mr._Gordon', 'name': 'Mr. Gordon'}],
#    'places': [{'id': 'Mexico', 'name': 'Mexico'}],
#    'text': '-1852. A tobacco pouch or purse made of maiz & some tinsel ribbon in wch. are pipes made of tobacco cutt small for smoking inclosed in small tubuli made of the covering or spathe of the maiz seeds. From Mr. Gordon who had it from Mexico. 199. e 25. 163. 209 X'},
#   {'num_int': 1853,
#    'num_str': '-1853.',
#    'people': None,
#    'places': None,
#    'text': '-1853. Whole leaves of tobacco rouled up for smoking to both those silver pipes are adjusted sometimes for holding them during the time of smoking Id. 199 b 25 163. 209'},
#   {'num_int': 1854,
#    'num_str': '-1854.',
#    'people': None,
#    'places': [{'id': 'China', 'name': 'China'}],
#    'text': '-1854. Artificiall phalenae leaves &c. made in China for wearing in the hair. Id. 201'},
#   {'num_int': 1855,
#    'num_str': '-1855',
#    'people': None,
#    'places': [{'id': 'West_Indies', 'name': 'W. Indies'}],
#    'text': '-1855 Two pendants , a ring & some pyrites of wch. they are made from the Spanish W. Indies. 199 e 163'},
#   {'num_int': 1856,
#    'num_str': '-1856.',
#    'people': [{'id': 'Richard_Middleton_Massey', 'name': 'Dr. Massy'}],
#    'places': [{'id': 'Hudson_Bay', 'name': 'Hudsons bay'}],
#    'text': '-1856. Stocking Shoes Boots wt. a great top such as fisherman use made of Deer whale or fish skins from Hudsons bay by Dr. Massy. CCXVI'},
#   {'num_int': 1857,
#    'num_str': '-1857.',
#    'people': [{'id': 'Dr_Douce', 'name': 'Dr. Douce'}],
#    'places': None,
#    'text': '-1857. A crese or Indian dagger used by the Malays in a wooden Scabbard and an ebony handle in laid wt. gold plates. from Dr. Douce. 191'},
#   {'num_int': 1858,
#    'num_str': '-1858.',
#    'people': None,
#    'places': [{'id': 'East_Indies', 'name': 'E. India'}],
#    'text': '-1858. An E. India hubble buble for cooling of wine &c wt. the bottle. CCXXXIII'},
#   {'num_int': 1859,
#    'num_str': '-1859.',
#    'people': [{'id': 'Duke_of_Bourbon', 'name': 'Duke of Bourbons'}],
#    'places': None,
#    'text': '-1859. The Duke of Bourbonsmedal in gold in a blew chagrin case given by himselfe to me 161'},
#   {'num_int': 1860,
#    'num_str': '-1860',
#    'people': [{'id': 'Philip_2nd_of_Spain', 'name': 'Philip. 2d'}],
#    'places': [{'id': 'Spain', 'name': 'Spaine'}],
#    'text': '-1860 A small coconut carvd wt. a peacock, spread eagle, heart &c. Soi de Leonor, sister to Philip. 2d. of Spaine set in gold- philagreen. 199 161'},
#   {'num_int': 1861,
#    'num_str': '-1861',
#    'people': [{'id': 'Mrs_Edwards, Mrs._Edwards', 'name': 'Mrs. Edwards'},
#     {'id': 'Hans_Sloane', 'name': 'Sr. Hans'},
#     {'id': 'J_Empson', 'name': 'J Empson'}],
#    'places': [{'id': 'Nuremberg', 'name': 'Nurinberg'}],
#    'text': "-1861 A gold snuff box curiously embossd wt. - sorts of alloy as the Nurinberg gold of the magistrates of that city given to me by Mrs. Edwards. enter'd by mistake given by Sr. Hans to me J Empson. 161"},
#   {'num_int': 1862,
#    'num_str': '-1862',
#    'people': [{'id': 'Lord_Sondes', 'name': 'Ld Sondes'},
#     {'id': 'Christian_Zincke', 'name': 'Mr. Zink'},
#     {'id': 'Lady_Sondes', 'name': 'Lady Sondes'},
#     {'id': 'Hans_Sloane', 'name': 'Sr. Hans'},
#     {'id': 'Robert_Southwell', 'name': 'Mr. Southwell'}],
#    'places': None,
#    'text': "-1862 A gold snuffe box wt. a bloodstone top & enameld picture of Ld Sondes on the inside by Mr. Zink curiously graved & embossd given to me by Lady Sondes. enter'd by mistake given by Sr. Hans to Mr. Southwell 161"},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': '6'},
#   {'num_int': 42,
#    'num_str': '42.',
#    'people': None,
#    'places': None,
#    'text': '42. An Ebony handle. k 245.'},
#   {'num_int': 43,
#    'num_str': '43.',
#    'people': None,
#    'places': None,
#    'text': '43. An Indian hatchett sett in wood It is a greenish stone or lapis nephriticus & 0. 5. 0. Aldrovand Mus. Metall. p. 158. Dampier Voy vol 1. P. 85 ✓ 245. a S. B'},
#   {'num_int': 44,
#    'num_str': '44.',
#    'people': None,
#    'places': [{'id': 'Guinea', 'name': 'Guinea'}],
#    'text': '44. An ivory hollow case for the penis. It is used in Guinea by the Negros when they travell in the woods putting the penis into it & it into their girdles to keep that part from being hurt by the thorns. b 245. X'},
#   {'num_int': 45,
#    'num_str': '-45.',
#    'people': None,
#    'places': [{'id': 'Jamaica', 'name': 'Jamaica'}],
#    'text': '-45. A ladle made of a Calabash for taking water from the Jarrs, made by the Indians, in Jamaica. 238.'},
#   {'num_int': 46,
#    'num_str': '-46.',
#    'people': None,
#    'places': None,
#    'text': '-46. A cup made of the same the rind being tinctured reddish 238.'},
#   {'num_int': 47,
#    'num_str': '-47.',
#    'people': None,
#    'places': None,
#    'text': '-47. A Chinese organ made of pipes of cane of severall lengths. Vid de Hald. tom 3. Page. 267. Flutes compose de plusieurs tuyaux a quelque rapport a notre orgue. 245. X'},
#   {'num_int': 48,
#    'num_str': '-48.',
#    'people': None,
#    'places': [{'id': 'Virginia', 'name': 'Virginia'}],
#    'text': '-48. 19 J A Virginia belt. 245.'},
#   {'num_int': 49,
#    'num_str': '-49.',
#    'people': None,
#    'places': None,
#    'text': '-49. The same with 24: 245'},
#   {'num_int': 50,
#    'num_str': '-50.',
#    'people': None,
#    'places': None,
#    'text': '-50. A Cane arrow headed wt. Iron. 252.'},
#   {'num_int': 51,
#    'num_str': '-51.',
#    'people': None,
#    'places': None,
#    'text': '-51. The same with a different flatt head. 252.'},
#   {'num_int': 52,
#    'num_str': '-52.',
#    'people': None,
#    'places': [{'id': 'Turkey', 'name': 'Turkish'}],
#    'text': '-52. A Turkish bow. 252.'},
#   {'num_int': 53,
#    'num_str': '-53.',
#    'people': None,
#    'places': None,
#    'text': '-53. A clyster pipe with what necessary for the giving ones selfe a tobacco clyster. 0. 7. 6. 20 L.'},
#   {'num_int': 1863,
#    'num_str': '-1863.',
#    'people': [{'id': 'Mr_Styleman', 'name': 'Mr. Styleman'}],
#    'places': None,
#    'text': '-1863. A Chinese womans shoe brought from there by Mr. Styleman given me by his wife 199 e 163 24'},
#   {'num_int': 1864,
#    'num_str': '-1864.',
#    'people': None,
#    'places': None,
#    'text': "-1864. A pair of gloves belong'd to the same woman. 199 e 163 209. 24"},
#   {'num_int': 1865,
#    'num_str': '-1865.',
#    'people': None,
#    'places': None,
#    'text': '-1865. A case wherein is a knife, fork, ear picker & ear tickles from the Same. 199. C. 163 25'},
#   {'num_int': 1866,
#    'num_str': '-1866.',
#    'people': [{'id': 'Mr._Bell', 'name': 'Mr. Bell'}],
#    'places': None,
#    'text': '-1866. A rice or Alabaster box wt. a Chinese picture on it. by Mr. Bell. 163. A.W.F. 1853 Steatite. in form of a seated figure wh: forms lid. low relief. L. 2 5/8. S B. X'},
#   {'num_int': 1867,
#    'num_str': '1867.',
#    'people': [{'id': 'Capt_Christopher_Middleton', 'name': 'Capt. Midleton.'}],
#    'places': [{'id': 'Hudson_Bay', 'name': 'Hudsons bay'},
#     {'id': 'Greenland', 'name': 'Greenland'}],
#    'text': '1867. A Canoa from Hudsons bay or Greenland wt. some instruments belonging to it. given to me by Capt. Midleton. CCXIII'},
#   {'num_int': 1868,
#    'num_str': '-1868.',
#    'people': None,
#    'places': None,
#    'text': '-1868. A pair of shoes made of fish skin belonging to the- Inhabitants of that Countrey 226. 20 S.'},
#   {'num_int': 1869,
#    'num_str': '-1869.',
#    'people': [{'id': 'Mr_Hoofnail', 'name': 'Mr. Hoofnail'}],
#    'places': [{'id': 'Fountain_Court_Strand',
#      'name': 'fountain court in the strand'}],
#    'text': '-1869. A box containing the sevll. sorts of foyles to be used in setting under I wells or pretious stones or chrystalls, & glasse to counter feit them given to me by Mr. Hoofnail in fountain court in the strand Jeweller. 216 d 27 C X'},
#   {'num_int': 1870,
#    'num_str': '-1870.',
#    'people': None,
#    'places': None,
#    'text': '-1870. A snuff box made of a Bergamot orange rind. 216 a 19 J.'},
#   {'num_int': 1871,
#    'num_str': '-1871.',
#    'people': [{'id': 'Mrs_Hepheshebah_Parker',
#      'name': 'Mrs. Hepheshebah Parker'}],
#    'places': [{'id': 'Croydon', 'name': 'Croydon'}],
#    'text': "-1871. A pincushion made by Mrs. Hepheshebah Parker near Croydon of sevll. coloured silks & Brocade & sowed wt. the silks of the same colour by her who had great convulsions in the small pox & lost her sight by them Being her physitian I have seen strange convulsions on her temples wch. would rise to a great heighth in them I had sevll. letters from her wrote in her own hand wch. was a good one. When I tryed her wt. silks of sevll. colours she never miss'd telling me their true colours by tasting & smelling to them. The same she would tell of the sevll. colours by tasting & then smelling to them. I tryed her wt a flour of bellis minor from my garden wch had white & red petals & by tasting & smelling to ym. she declard their sevll. colours. 216 d 29 a"},
#   {'num_int': 1872,
#    'num_str': '-1872.',
#    'people': [{'id': 'Dr_Labe', 'name': 'Dr. Labe'}],
#    'places': None,
#    'text': '-1872. Sal Lactis vaccini chrystallini from Dr. Labe. Made use of in consumptions Hectics &c. the medicine is dear. 216 d 19 k'},
#   {'num_int': 1873,
#    'num_str': '-1873.',
#    'people': None,
#    'places': None,
#    'text': '-1873. Doses of a lunarg provider of one grain to vomit wt. a lump of solary for the same purpose likely vitium antimon. 216 d'},
#   {'num_int': 1874,
#    'num_str': '-1874.',
#    'people': [{'id': 'Mrs_Stephens', 'name': 'Mrs. Stephens'}],
#    'places': None,
#    'text': '-1874. Powder of Mrs. Stephens for dissolving the stones? 216 19 k'},
#   {'num_int': 1875,
#    'num_str': '-1875.',
#    'people': None,
#    'places': None,
#    'text': '-1875. Serpentine Stone great button for tying the bretches 216 d'},
#   {'num_int': 1876,
#    'num_str': '-1876.',
#    'people': [{'id': 'James_Petiver', 'name': 'Pet.'}],
#    'places': None,
#    'text': '-1876. Maiden pipes. Pet. 20 K'},
#   {'num_int': 1877,
#    'num_str': '1877.',
#    'people': None,
#    'places': [{'id': 'East_Indies', 'name': 'E Indies'}],
#    'text': '1877. Moxa a sort of down taken off an herb like a Artemisia w ch. they use for the cure of the gout in the E Indies by burning it on the place affected. wt. the pustules. 25'},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': '7'},
#   {'num_int': 54,
#    'num_str': '-54.',
#    'people': None,
#    'places': None,
#    'text': '-54. A barbary Scourge wt. wch. the slaves are beaten made of the of a palm tree. 245 226 29 b X'},
#   {'num_int': 55,
#    'num_str': '-55.',
#    'people': [{'id': 'David_Krieg', 'name': 'Dr. Krieg'}],
#    'places': [{'id': 'Livonia', 'name': 'Livonia'}],
#    'text': '-55. A Livonia Cittern sent me by Dr. Krieg, made of 2 pieces of wood, the one hollowed of firr, the other flatt & holes in it of oak. 245 b'},
#   {'num_int': 56,
#    'num_str': '-56.',
#    'people': None,
#    'places': [{'id': 'Jamaica', 'name': 'Jamaica'}],
#    'text': '-56. Jamaica Strum Strum or musicall instrumt. made of an oblong - hollowed piece of wood with a crosse hole in the side, strings of a scandent herbs caulis. b 245. X'},
#   {'num_int': 57,
#    'num_str': '-57.',
#    'people': None,
#    'places': None,
#    'text': '-57. The same made of a cucurbita lagenaria coverd wt. Skin- holed in the side b 245.'},
#   {'num_int': 58,
#    'num_str': '-58.',
#    'people': None,
#    'places': None,
#    'text': '-58. One of another from, wt. a bell in it. 245. b'},
#   {'num_int': 59,
#    'num_str': '-59.',
#    'people': None,
#    'places': [{'id': 'Barbary', 'name': 'Barbary'}],
#    'text': '-59. 20 S. A pair of Barbary shoes. S.B. \uf050 226. 20 S XXX'},
#   {'num_int': 60,
#    'num_str': '60.',
#    'people': None,
#    'places': None,
#    'text': '60. Chinese figure -1G. Lying 2. 3. 0. 251 300 26'},
#   {'num_int': 61,
#    'num_str': '61.',
#    'people': None,
#    'places': None,
#    'text': '61. 26 Another - - - - 2. 3. 0. 300. 300'},
#   {'num_int': 62,
#    'num_str': '62.',
#    'people': None,
#    'places': None,
#    'text': '62. Another 116 - - - female fig seated - - - H. 3 1/4 in 2. 3. 0. C 251 26 O. A.W.F 1853.'},
#   {'num_int': 63,
#    'num_str': '63.',
#    'people': None,
#    'places': None,
#    'text': '63. Another - - - - 2. 3. 0. 251 26 ?'},
#   {'num_int': 64,
#    'num_str': '-64.',
#    'people': [{'id': 'James_Cunningham', 'name': 'Mr.- Cunningham'}],
#    'places': [{'id': 'Japan', 'name': 'Japan'}],
#    'text': '-64. A Chinese compasse sent me by Mr.- Cunningham in a Japan box. 199 C. 25'},
#   {'num_int': 1878,
#    'num_str': '-1878.',
#    'people': None,
#    'places': None,
#    'text': '-1878. A Brasse small crucifix. 216 d'},
#   {'num_int': 1879,
#    'num_str': '-1879.',
#    'people': None,
#    'places': None,
#    'text': '-1879. Sevll. religious figures Carvd in ivory in sevll. compartmts. in a long plate likely belonging to some chappell. ü 216 d. 29 b. X'},
#   {'num_int': 1880,
#    'num_str': '-1880.',
#    'people': [{'id': 'Mr._Pycolas', 'name': 'Mr. Pycolas'},
#     {'id': 'Vale_Vicor', 'name': 'Vale. Vicor'}],
#    'places': None,
#    'text': '-1880. Æsculapius & Hygiena incisd in a Chrystall wt. a- looking glasse plate behind it making it look- embossd given to me by Mr. Pycolas & made by Vale. Vicor. 161.'},
#   {'num_int': 1881,
#    'num_str': '-1881.',
#    'people': None,
#    'places': [{'id': 'China', 'name': 'China'}],
#    'text': '-1881. White paint from. China? Sope of Melo? 216 d 24'},
#   {'num_int': 1882,
#    'num_str': '-1882.',
#    'people': None,
#    'places': None,
#    'text': '-1882. A Chinese printing letter in white earthen ware. 216 d 24'},
#   {'num_int': 1883,
#    'num_str': '-1883',
#    'people': None,
#    'places': None,
#    'text': '-1883 A pr of chinese nippers. 209 161 25 204 309'},
#   {'num_int': 1884,
#    'num_str': '1884.',
#    'people': None,
#    'places': [{'id': 'New_England', 'name': 'N England'}],
#    'text': '1884. The largest wampumbeg necklace or money from N England. white . 199 e 161'},
#   {'num_int': 1885,
#    'num_str': '1885.',
#    'people': None,
#    'places': None,
#    'text': '1885. The midling sized white & black . Do. 199 e 28 b 166'},
#   {'num_int': 1886,
#    'num_str': '1886.',
#    'people': None,
#    'places': None,
#    'text': '1886. A lesser sort black & white . Do. 269 160 209.'},
#   {'num_int': 1887,
#    'num_str': '1887.',
#    'people': None,
#    'places': None,
#    'text': '1887. The least sort all white . Do. 199 e 160'},
#   {'num_int': 1888,
#    'num_str': '1888.',
#    'people': None,
#    'places': None,
#    'text': '1888. A necklace of blew hollow four square glasse long pieces or for an armilla. 199 e 168 21. O.'},
#   {'num_int': 1889,
#    'num_str': '-1889.',
#    'people': None,
#    'places': None,
#    'text': '-1889. Beads or pater nosters for use in prayers made of the seeds of Canna Indica. 1613'},
#   {'num_int': 1890,
#    'num_str': '1890.',
#    'people': None,
#    'places': None,
#    'text': '1890. A necklace of Brown conche veneris wt. false pearl between & short strings to hang on the neck. 1613 28 C'},
#   {'num_int': 1891,
#    'num_str': '1891.',
#    'people': None,
#    'places': None,
#    'text': '1891. Short strings to hang over the breast of white Concha Veneris. 199 e 28. C.'},
#   {'num_int': 1892,
#    'num_str': '-1892.',
#    'people': [{'id': 'Moses', 'name': 'Marcus Moses'}],
#    'places': None,
#    'text': '-1892. A modell of the green diamond brought from the diamond mines in Golconda by Marcus Moses valued at 20000. 40.000? ff 182. X'},
#   {'num_int': 1893,
#    'num_str': '-1893.',
#    'people': None,
#    'places': None,
#    'text': '-1893. A sphericall body made up of Black yellow & red wax & one made for taking of impressions of seals. (Paste.) 216 d 20 M.'},
#   {'num_int': 1894,
#    'num_str': '-1894.',
#    'people': None,
#    'places': None,
#    'text': '-1894. Black glasse or enamel. 216 20 S.'},
#   {'num_int': 1895,
#    'num_str': '-1895.',
#    'people': [{'id': 'James_Petiver', 'name': 'Pet'}],
#    'places': None,
#    'text': '-1895. Wax naked figures in filbert shells. Pet 216 20 M'},
#   {'num_int': 1896,
#    'num_str': '1896.',
#    'people': None,
#    'places': [{'id': 'Scotland', 'name': 'Scotland'}],
#    'text': '1896. Elfs arrows from Scotland arrowheads an silex veratule forma Worm mus. P. 85. 163. 20 b.'},
#   {'num_int': 1897,
#    'num_str': '-1897.',
#    'people': None,
#    'places': None,
#    'text': '-1897. A piece of glasse of various colours. 201 O 209.'},
#   {'num_int': 1898,
#    'num_str': '1898.',
#    'people': None,
#    'places': None,
#    'text': '1898. A bead made of a various coloured palm fruit. 163 27 C 209.'},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': '8'},
#   {'num_int': 65,
#    'num_str': '65.',
#    'people': None,
#    'places': None,
#    'text': '65. A very thin wooden ladle. 245.'},
#   {'num_int': 66,
#    'num_str': '66.',
#    'people': None,
#    'places': None,
#    'text': '66. pieces of the same broke. k. 245. 19 f'},
#   {'num_int': 67,
#    'num_str': '67.',
#    'people': None,
#    'places': None,
#    'text': '67. A box spoon from Buda. 216. a 19. O'},
#   {'num_int': 68,
#    'num_str': '68.',
#    'people': None,
#    'places': None,
#    'text': '68. A wreathed flatt chrystall glasse bottle broken at the mouth. 300 251. 30'},
#   {'num_int': 69,
#    'num_str': '69.',
#    'people': None,
#    'places': None,
#    'text': '69. A blew & white china saucer. 183 251.'},
#   {'num_int': 70,
#    'num_str': '70.',
#    'people': None,
#    'places': None,
#    'text': '70. The same. 183 251.'},
#   {'num_int': 71,
#    'num_str': '71.',
#    'people': None,
#    'places': None,
#    'text': '71. A China saucer, blew & red .'},
#   {'num_int': 72,
#    'num_str': '72.',
#    'people': None,
#    'places': None,
#    'text': '72. A blew & white china bason. \uf050 199 251.'},
#   {'num_int': 73,
#    'num_str': '73.',
#    'people': None,
#    'places': None,
#    'text': '73. The same. \uf050 199 251.'},
#   {'num_int': 74,
#    'num_str': '74.',
#    'people': None,
#    'places': None,
#    'text': '74. A chrystall glasse cup & cover in the top of wch. is a yellow thread. 300 251. 30 only cover AWF.'},
#   {'num_int': 75,
#    'num_str': '75.',
#    'people': None,
#    'places': None,
#    'text': '75. The top 251. 30'},
#   {'num_int': 76,
#    'num_str': '76.',
#    'people': None,
#    'places': None,
#    'text': '76. A plain cover. 251.'},
#   {'num_int': 77,
#    'num_str': '77.',
#    'people': None,
#    'places': None,
#    'text': '77. A blew & white china Bason. 251.'},
#   {'num_int': 78,
#    'num_str': '78.',
#    'people': None,
#    'places': [{'id': 'Japan', 'name': 'Japan'}],
#    'text': '78. A Japan bottle. \uf050 251. 24 C S B.'},
#   {'num_int': 79,
#    'num_str': '79.',
#    'people': None,
#    'places': [{'id': 'Surinam', 'name': 'Surinam'}],
#    'text': '79. A Calabash from Surinam painted - - - - 0. 0. 6. 216. f3'},
#   {'num_int': 80,
#    'num_str': '80.',
#    'people': None,
#    'places': None,
#    'text': "80. A great Enamel'd cup whereon are enamel'd the arms of all the members of the Empire. 300 30 C."},
#   {'num_int': 81,
#    'num_str': '81.',
#    'people': None,
#    'places': [{'id': 'China', 'name': 'China'}],
#    'text': '81. A China ink pott. 251. 30 C'},
#   {'num_int': 82,
#    'num_str': '82.',
#    'people': None,
#    'places': None,
#    'text': '82. A Coco-nutt cupp. 245. 238 \uf050 199'},
#   {'num_int': 83,
#    'num_str': '83.',
#    'people': None,
#    'places': [{'id': 'China', 'name': 'China'}],
#    'text': '83. A blew & white China bason. 199.'},
#   {'num_int': 84,
#    'num_str': '84.',
#    'people': None,
#    'places': None,
#    'text': '84. A Saucer of the same.'},
#   {'num_int': 1899,
#    'num_str': '1899.',
#    'people': None,
#    'places': None,
#    'text': '1899. A head cutt on a plum b stone 209. 163. 27 C 209'},
#   {'num_int': 1900,
#    'num_str': '-1900',
#    'people': None,
#    'places': None,
#    'text': '-1900 A piece vid Ducatoon. of 8 taken up from the Spainish wreckd galeon on the N. side of Espanola covered wt. worm shells & corallin matter all over. 189'},
#   {'num_int': 1901,
#    'num_str': '-1901.',
#    'people': None,
#    'places': [{'id': 'Jamaica', 'name': 'Jama'}],
#    'text': '-1901. A Spanish piece calld a quartillo found in Jama. 189'},
#   {'num_int': 1902,
#    'num_str': '-1902.',
#    'people': None,
#    'places': [{'id': 'Malaga', 'name': 'Malaga'}],
#    'text': '-1902. A _________ rasor or knife wt. these words & flowers etched on it Fecha en Malaga A.D. 1710. por Andres Lopes Mt ro 199. b 25 216 h.'},
#   {'num_int': 1903,
#    'num_str': '-1903.',
#    'people': None,
#    'places': None,
#    'text': '-1903. Blew red & white broken bead on sevll Strata on glasse or enamel. 199 c 20. I.'},
#   {'num_int': 1904,
#    'num_str': '-1904.',
#    'people': None,
#    'places': [{'id': 'Jamaica', 'name': 'Jamaica'}],
#    'text': '-1904. A comb & comb case made of tortoise shell wt. a case of the same whereon are engraved the arms of Jamaica A plantain tree & two ananast. made in 16 7 75. ✓ 199. c 216 f. 27 a.'},
#   {'num_int': 1905,
#    'num_str': '-1905.',
#    'people': None,
#    'places': None,
#    'text': '-1905. The head of a cane of gum anime? ✓ 199 c. 216 f.'},
#   {'num_int': 1906,
#    'num_str': '-1906.',
#    'people': None,
#    'places': [{'id': 'Thames', 'name': 'Thames'}],
#    'text': '-1906. A piece of greenish ordinary glasse taken up on the side of the Thames where among the gravell by being tumbled about its surface was rounded & rough as ordinary pebbles polished on one side. ✓ 199 c. 216 f. 20. I'},
#   {'num_int': 1907,
#    'num_str': '1907.',
#    'people': None,
#    'places': None,
#    'text': '1907. An ancient gray Stone hatchet wt. notches to be fixed to its handle called by some thunder stones. markd formerly 277. 199 d 216 f.'},
#   {'num_int': 1908,
#    'num_str': '1908.',
#    'people': None,
#    'places': None,
#    'text': '1908. A piece of Roman brick or tile? markd formerly 257. ✓ 199 c 19 K.'},
#   {'num_int': 1909,
#    'num_str': '-1909.',
#    'people': None,
#    'places': None,
#    'text': '-1909. A Sword or large knife haft of Unicorns horn markd 100. 191 216 f.'},
#   {'num_int': 1910,
#    'num_str': '1910.',
#    'people': None,
#    'places': None,
#    'text': "1910. A piece of Stone or flint calcin'd in a log of firewood mark'd 1379. 216 199 d"},
#   {'num_int': 1911,
#    'num_str': '1911.',
#    'people': None,
#    'places': [{'id': 'Scotland', 'name': 'Scotland'}],
#    'text': '1911. The hemisphericall part of an ancient fibula from Scotland in silver. Vid. Montfancons monumens du Roi tom 1. pag. 14. pl. 5. fig. 4 199. c. 216 f. 27 a'},
#   {'num_int': 1912,
#    'num_str': '1912.',
#    'people': None,
#    'places': None,
#    'text': '1912. One of the chrystall hemisphericall ornaments for horses markd 239. 199 c 216 f'},
#   {'num_int': 1913,
#    'num_str': '1913.',
#    'people': None,
#    'places': None,
#    'text': '1913. Another whitish clouded chrystall or Cornelian markd 273. 199 c 216 f'},
#   {'num_int': 1914,
#    'num_str': '1914.',
#    'people': None,
#    'places': None,
#    'text': '1914. Sevll. woods of the growth of English gardens made into the form of a book, as. 1. lilac the red wood, 3 mulberry the yellow on the back laburnum the brownish , 10 yew & box (made by John Cannon cabinet maker in St. Martins lane. 12 sumach, 4 Aprecock 5 arbor Inde, 6 walnut tree 7 Acacia 8 white strypes lacarlk black pear tree 9. back strings holly 216 f'},
#   {'num_int': 1915,
#    'num_str': '-1915.',
#    'people': None,
#    'places': None,
#    'text': '-1915. part of the tripes or skin of some animal work by the Gutts Hottentots on their ancles & then eaten markd formerly. 439. 216 f'},
#   {'num_int': 1916,
#    'num_str': '-1916.',
#    'people': [{'id': 'Richard_Middleton_Massey', 'name': 'Dr. Massy'}],
#    'places': [{'id': 'China', 'name': 'China'}],
#    'text': '-1916. Glew: Ai & vw from China? used there as a medicine made of an asses skin steeped for 7 months in a well famous Dr. Massy. 216 19 f 199 d'},
#   {'num_int': 1917,
#    'num_str': '-1917.',
#    'people': None,
#    'places': None,
#    'text': '-1917. A Newberry lozenge for the heart burn. 19 f'},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': '9'},
#   {'num_int': 85,
#    'num_str': '85.',
#    'people': None,
#    'places': [{'id': 'China', 'name': 'China'}],
#    'text': '85. A China 251. 25.'},
#   {'num_int': 86,
#    'num_str': '86.',
#    'people': None,
#    'places': None,
#    'text': '86. A Christall glasse cup. 251. 300 30.'},
#   {'num_int': 87,
#    'num_str': '87.',
#    'people': None,
#    'places': None,
#    'text': '87. Its cover. 251. 200 30.'},
#   {'num_int': 88,
#    'num_str': '88.',
#    'people': None,
#    'places': [{'id': 'China', 'name': 'China'}],
#    'text': '88. A blew & white China saucer. ✓ 183 251 30.'},
#   {'num_int': 89,
#    'num_str': '89.',
#    'people': None,
#    'places': None,
#    'text': '89. Coffee cup of the same. 30'},
#   {'num_int': 90,
#    'num_str': '90.',
#    'people': None,
#    'places': None,
#    'text': '90. The same.'},
#   {'num_int': 91,
#    'num_str': '91.',
#    'people': None,
#    'places': [{'id': 'China', 'name': 'China'}],
#    'text': '91. A white & blew China saccer. 183. 251'},
#   {'num_int': 92,
#    'num_str': '92.',
#    'people': None,
#    'places': None,
#    'text': '92. A white & blew coffee cup.'},
#   {'num_int': 93,
#    'num_str': '93.',
#    'people': None,
#    'places': None,
#    'text': '93. A Christall glasse cup gilt. 251. 19 M 30'},
#   {'num_int': 94,
#    'num_str': '94.',
#    'people': None,
#    'places': None,
#    'text': "94. A Japann'd bottle S.B. ✓ 199 251 24 C."},
#   {'num_int': 95,
#    'num_str': '95.',
#    'people': None,
#    'places': None,
#    'text': "95. A wreath'd chrystall glasse bottle. H. 8 2/10. 300 A.W.F. 1855 30."},
#   {'num_int': 96,
#    'num_str': '? 96.',
#    'people': None,
#    'places': None,
#    'text': '? 96. A large piece of Chrystalls- growing together.'},
#   {'num_int': 97,
#    'num_str': '? 97.',
#    'people': None,
#    'places': None,
#    'text': '? 97. Lignum Campechianum species quaedam Brasil. de Laet. cat. p. 213. Loggwood. 237.'},
#   {'num_int': 98,
#    'num_str': '?98.',
#    'people': None,
#    'places': None,
#    'text': '?98. Lignum insulæ Bonaire Belgis stock vish - hout. Es. ib. p. 213. 237.'},
#   {'num_int': 99,
#    'num_str': '?99.',
#    'people': None,
#    'places': None,
#    'text': '?99. Pseudo santalum croceum. cat. Jam. p. 213. 237.'},
#   {'num_int': 100,
#    'num_str': '?100.',
#    'people': None,
#    'places': None,
#    'text': '?100. Brasil? d. < 237'},
#   {'num_int': 101,
#    'num_str': '?101.',
#    'people': None,
#    'places': None,
#    'text': '?101. Lignum merdam olens? 237 32. A.'},
#   {'num_int': 102,
#    'num_str': '? 102.',
#    'people': None,
#    'places': [{'id': 'Jamaica', 'name': 'Jamaica'}],
#    'text': '? 102. Green or Jamaica ebony. 237 246 a 32. E'},
#   {'num_int': 103,
#    'num_str': '?-103.',
#    'people': None,
#    'places': None,
#    'text': '?-103. Very large sea feather wt out crust.'},
#   {'num_int': 1918,
#    'num_str': '-1918.',
#    'people': None,
#    'places': None,
#    'text': '-1918. A musket bullet which being shott at a mark on a door went thro & killd a young man on the other side by shattering his thigh bone. ✓ 199 c. 216f 27 a'},
#   {'num_int': 1919,
#    'num_str': '-1919.',
#    'people': None,
#    'places': None,
#    'text': '-1919. Crocus metallorum?....... 199 c. 216f 20. J.'},
#   {'num_int': 1920,
#    'num_str': '-1920.',
#    'people': None,
#    'places': None,
#    'text': '-1920. A Cornelian ring? ✓ 199 c 216f 20. J.'},
#   {'num_int': 1921,
#    'num_str': '-1921.',
#    'people': [{'id': 'Mr_Collier', 'name': 'Mr. Collier'}],
#    'places': [{'id': 'Jerusalem', 'name': 'Jerusalem'}],
#    'text': '-1921. Jerusalem sope from Mr. Collier. ✓ 199 d 216f'},
# ...
#    'text': '-529. Packs of China cards given me by Mr. Robert Walker. 209 25 X'},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': '49'},
#   {'num_int': 530,
#    'num_str': '-530.',
#    'people': None,
#    'places': [{'id': 'Tourn', 'name': 'Tourn'}],
#    'text': "-530. Savon de Prusse que des Religieuses font a Tourn qu'elles apellent creme de Savon. 99."},
#   {'num_int': 531,
#    'num_str': '-531.',
#    'people': None,
#    'places': [{'id': 'Jaffa', 'name': 'Joppa'}],
#    'text': '-531. Sope from Joppa. P. 99.'},
#   {'num_int': 532,
#    'num_str': '-532.',
#    'people': None,
#    'places': [{'id': 'Melo_Island', 'name': 'Melo Island'}],
#    'text': '-532. Sope of Melo Island. P.'},
#   {'num_int': 533,
#    'num_str': '-533.',
#    'people': None,
#    'places': None,
#    'text': "-533. A Substance voided by the anus of one who had taken calcin'd corall ? (Calculus Intestinabi?) 32 234. h-"},
#   {'num_int': 534,
#    'num_str': '-534.',
#    'people': None,
#    'places': None,
#    'text': '-534. A Substance taken out of gum. Ammoniac ? a pill ? 166'},
#   {'num_int': 535,
#    'num_str': '-535.',
#    'people': None,
#    'places': None,
#    'text': '-535. Huile du Sacre e du roy Jaques 2d. 324 e 27 C'},
#   {'num_int': 536,
#    'num_str': '-536.',
#    'people': None,
#    'places': None,
#    'text': '-536. The Sceleton of the head & trunc of the body in lead : P. 216 a 19 f'},
#   {'num_int': 537,
#    'num_str': '-537.',
#    'people': None,
#    'places': None,
#    'text': '-537. Glasse or past in imitation of a Chrysolite of a greenish yellow colour. 324. e'},
#   {'num_int': 538,
#    'num_str': '-538.',
#    'people': None,
#    'places': None,
#    'text': '-538. A musicall ball of brasse in the hollow of which are placed some things that make a musicall sound. ---} 1. 6. 0. X'},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': '50'},
#   {'num_int': 539,
#    'num_str': '-539.',
#    'people': None,
#    'places': [{'id': 'East_Indies', 'name': 'East India'}],
#    'text': '-539. An East India cane lanthorne --- 0. 5. 0. 245.'},
#   {'num_int': 540,
#    'num_str': '-540.',
#    'people': [{'id': 'Colonel_Laws', 'name': 'Coll. Laws'}],
#    'places': [{'id': 'Campeche', 'name': 'Campeche'},
#     {'id': 'Jamaica', 'name': 'Jamaica'}],
#    'text': '-540. A leather purse embroidered together with the figure of a hand in horn? fastened to it to be worn to prevent thunder in the mines of Sta. Maria near Campeche in New Spain taken from the Indians by the English of Jamaica from the Spainyards when they took those mines & given me by Coll. Laws. 199. b 29 C X'},
#   {'num_int': 541,
#    'num_str': '-541.',
#    'people': None,
#    'places': None,
#    'text': "-541. A girdle to be worn by a child to prevent the effects of thunder at which these hangs a Silver ? purse A medall of our Saviour, a nut= megg , a 2 hands enamell'd wt. pearl about it, A picture of the Virgin- Mary a crosse in Alabaster & a hand in Jett. From the same. 199. b. 29 a"},
#   {'num_int': 542,
#    'num_str': '-542.',
#    'people': None,
#    'places': None,
#    'text': '-542. Another girdle for the same purpose & brought from the same place at wch hang, a in metall gold ? a pair of sizars a nutmegg & the figure of the sun, a knife, the picture of the Virgin Mary a bell, an ewer, a plate, a comb, a crosse a hand in christall a box wt. wax figures of our saviour & St. Antony? a fork, a piece of Spainish gold , a plate of chr i ystall , a plate, ewer 199 b. 29 a'},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': '51'},
#   {'num_int': 542,
#    'num_str': '-542.',
#    'people': None,
#    'places': None,
#    'text': '-542. pendent? the moon a Spoon & a hand in jett holding the moon.'},
#   {'num_int': 543,
#    'num_str': '-543.',
#    'people': [{'id': 'Mrs_Sadler', 'name': 'Mrs. Sadler'}],
#    'places': [{'id': 'Guinea', 'name': 'Guinea'},
#     {'id': 'Jamaica', 'name': 'Jamaica'}],
#    'text': '-543. A Guinea smallest deers foot made into a tobacco stopper by being tipld with gold - vid 1027 . sent me by Mrs. Sadler from Jamaica. Cervus Juvencus, perpussilus Guineensis Seba. tom. 1. Tab. 43. P. 70. 199 a 161 e 246 27 a'},
#   {'num_int': 544,
#    'num_str': '-544.',
#    'people': None,
#    'places': None,
#    'text': '-544. A medicine used for the cure of the Kings evill. 246. i'},
#   {'num_int': 545,
#    'num_str': '-545.',
#    'people': None,
#    'places': None,
#    'text': '-545. Crocus ☔ comburend & diligenter Lavand. pro collyrio. 216. b. 19 K.'},
#   {'num_int': 546,
#    'num_str': '-546.',
#    'people': None,
#    'places': [{'id': 'Mount_Mill_St_Bartholomew', 'name': 'Mounts mill'}],
#    'text': "-546. The singed hair of the woman kill'd by by thunder 1691. at Mounts mill. 216 b. 19 g"},
#   {'num_int': 547,
#    'num_str': '-547.',
#    'people': None,
#    'places': None,
#    'text': '-547. Part of a pair of britches singed by thunder? 216 b. 19 g'},
#   {'num_int': 548,
#    'num_str': '-548.',
#    'people': None,
#    'places': None,
#    'text': '-548. A medicine of bole , Alum , & vitriol for owtward use in hemorhages ? 99 26 x'},
#   {'num_int': 549,
#    'num_str': '549.',
#    'people': None,
#    'places': None,
#    'text': '549. An Indian apron , of coarse Thread , whites black & red , wove Carpet-wise wth figures of a Man on Horse back. 244 19 R'},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': '52'},
#   {'num_int': 550,
#    'num_str': '-550.',
#    'people': None,
#    'places': None,
#    'text': '-550. An ivory tobacco clyster pipe for conveying the fume into the gutts for curing the colick. 216. c. 20 L.'},
#   {'num_int': 551,
#    'num_str': '-551.',
#    'people': None,
#    'places': None,
#    'text': '-551. An Indian tobacco pipe. 245.'},
#   {'num_int': 552,
#    'num_str': '-552.',
#    'people': None,
#    'places': None,
#    'text': '-552. A pair of Chinese Scales with its weights & an abacus upon it. L. 10 1/2 in ✓ 245. b. 244 25 S B A.W.F. 1853.'},
#   {'num_int': 553,
#    'num_str': '-553.',
#    'people': None,
#    'places': None,
#    'text': '-553. One of their Larger weights - of brasse. 245. b. 244 25'},
#   {'num_int': 554,
#    'num_str': '-554.',
#    'people': None,
#    'places': None,
#    'text': '-554. Another Smaller. S. B ✓ 245. b. 244 25'},
#   {'num_int': 555,
#    'num_str': '-555.',
#    'people': None,
#    'places': None,
#    'text': '-555. Another. S. B ✓ 245. b. 244 25'},
#   {'num_int': 556,
#    'num_str': '-556.',
#    'people': None,
#    'places': None,
#    'text': '-556. Another. S. B ✓ 245. b. 244 25'},
#   {'num_int': 557,
#    'num_str': '-557.',
#    'people': None,
#    'places': None,
#    'text': '-557. Another. S. B ✓ 245. b. 244 25'},
#   {'num_int': 558,
#    'num_str': '-558.',
#    'people': None,
#    'places': None,
#    'text': '-558. Another. S. B ✓ 245. b. 244 25'},
#   {'num_int': 559,
#    'num_str': '-559.',
#    'people': [{'id': 'Mr_Gore', 'name': 'Mr. Gore'}],
#    'places': [{'id': 'East_Indies', 'name': 'E. India'}],
#    'text': '-559. A medecine for agues brought from E. India from a Banian Dr. by Mr. Gore 7 graines poudered to be taken 3 mornings in a Spoonfull of broath, posset drink, or rose water - tryed & proved by Mr. 245. b. 244 25'},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': '53'},
#   {'num_int': 560,
#    'num_str': '-560.',
#    'people': None,
#    'places': None,
#    'text': '-560. A double bead white , yellow blew & red? 99'},
#   {'num_int': 561,
#    'num_str': '-561.',
#    'people': None,
#    'places': None,
#    'text': '-561. A Coco nutt of the small kind brown yellow & white Stained. 199. b 27 C.'},
#   {'num_int': 562,
#    'num_str': '-562.',
#    'people': None,
#    'places': [{'id': 'China', 'name': 'China'}],
#    'text': '-562. A pott made of a past to put burn perfumes in in China. pierced vase. a house & figures within branch work. H. 5in. Steatite. 216 300 251. 26. A.W.F. 1853.'},
#   {'num_int': 563,
#    'num_str': '-563.',
#    'people': None,
#    'places': None,
#    'text': '-563. The Same.'},
#   {'num_int': 564,
#    'num_str': '-564.',
#    'people': [{'id': 'Mr_Orchard', 'name': 'Mr. Orchard'}],
#    'places': [{'id': 'China', 'name': 'China'}],
#    'text': '-564. A China belt , given me by Mr. Orchard. 199 a'},
#   {'num_int': 565,
#    'num_str': '-565.',
#    'people': None,
#    'places': None,
#    'text': '-565. A very Large box comb naeaw inlayed wt. ivory. ---} - 0. 10. 9.'},
#   {'num_int': 566,
#    'num_str': '-566.',
#    'people': [{'id': 'John_Pinfold', 'name': 'Mr. Pinfold'}],
#    'places': None,
#    'text': '-566. 2 Glasse rings made in imitation of Cornelian from Mr. Pinfold.'},
#   {'num_int': 567,
#    'num_str': '-567.',
#    'people': None,
#    'places': None,
#    'text': '-567. A fork of mother of pearl shell. 187'},
#   {'num_int': 568,
#    'num_str': '-568.',
#    'people': [{'id': 'Patrick_Adair', 'name': 'Dr. Adair'}],
#    'places': [{'id': 'East_Indies', 'name': 'East Indies'}],
#    'text': '-568. An East India baskett , from the East Indies by Dr. Adair. wt. 245.'},
#   {'num_int': 569,
#    'num_str': '-569.',
#    'people': None,
#    'places': None,
#    'text': '-569. A carved nautilus broken wt 0. 5 L 303. C'},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': '54'},
#   {'num_int': 570,
#    'num_str': '-570.',
#    'people': [{'id': 'Edmund_Chishull', 'name': 'Mr. Chichele'}],
#    'places': [{'id': 'Turkey', 'name': 'Turkish'}],
#    'text': '-570. The pipe of a long Turkish tobacco pipe made of wood turned. given me by Mr. Chichele.'},
#   {'num_int': 571,
#    'num_str': '-571.',
#    'people': None,
#    'places': None,
#    'text': '-571. The white bole of the same -. of earth. ✓ < 245. 246'},
#   {'num_int': 572,
#    'num_str': '-572',
#    'people': None,
#    'places': None,
#    'text': "-572 A long thin piece of wood like a lath long broad shaped like a knife with a handle which one of the Indian Kings thrust down his throat.'Tis used as a remedy to cause vomiting as a proang tho it did not cause him to - vomit. S. B (published, Bushnell) 245. b 244 X"},
#   {'num_int': 573,
#    'num_str': '-573.',
#    'people': [{'id': 'Mr_Middleton', 'name': 'Mr. Middleton'}],
#    'places': None,
#    'text': '-573. A Cord o made of hemp & porcupines quills died from the Iroquois by the Indian Kings given me by Mr. Middleton , for tying their prisoners. published Bushnell 245. b 244 19 J X'},
#   {'num_int': 574,
#    'num_str': '-574.',
#    'people': None,
#    'places': None,
#    'text': '-574. The Same of a courser Sort wt out the quills. 252. 19 J.'},
#   {'num_int': 575,
#    'num_str': '-575.',
#    'people': None,
#    'places': None,
#    'text': '-575. A wooden arrow wt. a triangular bone head to it.'},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': '55'},
#   {'num_int': 576,
#    'num_str': '-576.',
#    'people': None,
#    'places': None,
#    'text': "-576. A pair of Chinese shoes for women whose feet are diminish'd by art that they may not walk- abroad. 245. b. 244 20 S. S B X"},
#   {'num_int': 577,
#    'num_str': '-577.',
#    'people': None,
#    'places': None,
#    'text': '-577. A Chinese chopstick or fork of ebony wt. 2 of which they eat their meat. 209 25'},
#   {'num_int': 578,
#    'num_str': '-578.',
#    'people': None,
#    'places': None,
#    'text': '-578. Another. 209 25'},
#   {'num_int': 579,
#    'num_str': '-579.',
#    'people': [{'id': 'Sir_Charles_Wager', 'name': 'Sr. Charles Wager'},
#     {'id': 'Richard_Mead', 'name': 'Dr. Mead'}],
#    'places': [{'id': 'Darien', 'name': 'Darien'}],
#    'text': '-579. A silver instrument to be fastened to the end of the penis to keep that part from hurt by the bryars & thorns in Darien brought from thence by Sr. Charles Wager & given me by Dr. Mead. 58. X'},
#   {'num_int': 580,
#    'num_str': '-580.',
#    'people': [{'id': 'Mr_Bernard', 'name': 'Mr. Bernard'}],
#    'places': [{'id': 'Scotland', 'name': 'Scotland'}],
#    'text': '-580. A piece of a dish a target covered wt. gilt leather taken up out of the Spainish galeon that was Shipwrackd in 1588. on the coast of Scotland about 100 years after when it was covered in part with a thin crust from the sea water given me by Mr. Bernard who had it of 245.'},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': '56'},
#   {'num_int': 581,
#    'num_str': '-581.',
#    'people': None,
#    'places': None,
#    'text': '-581. A piece of hollow brasse wt. an incrustation in it from the same. 245. a. 4 19 f'},
#   {'num_int': 582,
#    'num_str': '-582.',
#    'people': None,
#    'places': [{'id': 'East_Indies', 'name': 'East Indies'}],
#    'text': '-582. A long Spear with a flaming point & ferill of brasse , and a rest for keeping steady their hands when they discharge their bowes in the East Indies. The spear is made of the Areca palm tree & painted .-----} 00. 07. 06. 252.'},
#   {'num_int': 583,
#    'num_str': '-583.',
#    'people': None,
#    'places': None,
#    'text': '-583. Another Spear or Javelin of the same palm, or some other wood wt out the head & rest----} -00. 02. 6. 252.'},
#   {'num_int': 584,
#    'num_str': '-584.',
#    'people': None,
#    'places': [{'id': 'Java', 'name': 'Java'},
#     {'id': 'Makassar', 'name': 'Macassar'}],
#    'text': "-584. A Spear or Javelin from Java or Macassar of black wood , hollow for shooting poyson'd arrows--} 252."},
#   {'num_int': 585,
#    'num_str': '-585.',
#    'people': None,
#    'places': None,
#    'text': '-585. A quiver made of the joint of a bambo wt. 9 small arrowes whole & & broken to shoot thro, the trunk. Lignum levissimum hollowed 245. X'},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': '57'},
#   {'num_int': 586,
#    'num_str': '-586.',
#    'people': [{'id': 'Alexander_Brown', 'name': 'Alexr. Brown'}],
#    'places': None,
#    'text': '-586. Another quiver wt. 8 arrowes 2 of them intire Larger then the precedent, the one end being headed & besmeared wt. poyson, the other having a piece of Lignum levissimum fastened to it, There is like wise a hollow small joint of a cane likely to contain poyson & a pencill made of a triangular hollow stalk likely of some cyperus , the hairs of it are like small ostridges feathers. These three last out of the collection of Alexr. Brown. 245.'},
#   {'num_int': 587,
#    'num_str': '-587.',
#    'people': None,
#    'places': None,
#    'text': '-587. An Indian bow , the string of wch. is made of the outward part of a cane , There are 4 small coco nuts fastened to it to make a noise. } 0. 1. 0. 245. b'},
#   {'num_int': 588,
#    'num_str': '-588.',
#    'people': None,
#    'places': [{'id': 'Guinea', 'name': 'Guinea'}],
#    'text': '-588. A girdle made of canes for dyed, from Guinea. made into brown , black, red , & yellow Ropes fastened together. 245. k 244 19 J'},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': '58'},
#   {'num_int': 589,
#    'num_str': '-589.',
#    'people': None,
#    'places': None,
#    'text': '-589. Another girdle from the same. 245. k 244'},
#   {'num_int': 590,
#    'num_str': '-590.',
#    'people': None,
#    'places': [{'id': 'Guinea', 'name': 'Guinea'}],
#    'text': '-590. A n Indian bracelet wt. rattles to it cut out of the elephants tooth ( Ivory.) wore upon the arms Guinea } 0. 5. 00. Marked C.H.R. i 245. 244 25'},
#   {'num_int': 591,
#    'num_str': '-591.',
#    'people': None,
#    'places': None,
#    'text': '-591. Another.---- 0. 5. 0. 199. e 201 25'},
#   {'num_int': 592,
#    'num_str': '-592.',
#    'people': None,
#    'places': [{'id': 'Guinea', 'name': 'Guinea'}],
#    'text': '-592. A bracelet or necklace made of that concha Veneris called in Guinea gowries being cutt in the backs & adjusted in 3 rowes. 199 e 164'},
#   {'num_int': 593,
#    'num_str': '-593.',
#    'people': [{'id': 'Mr_Maidstone, Mr._Maidstone', 'name': 'Mr. Maidstone'}],
#    'places': None,
#    'text': '-593. A Chinese organ to be held in the hand & plaid upon given me by Mr. Maidstone. 245. X'},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': '59'},
#   ...],
#  'title': 'Miscellanies.'}

# %% [markdown]
# #### What is the title?

# %%
# Print title of first catalogue
cats[0]['title']
# Out:
# 'Miscellanies.'

# %% [markdown]
# #### How many catalogue entries in Miscellanies?

# %%
# Print number of entries in first catalogue
len(cats[0]['entries'])
# Out:
# 2335

# %% [markdown]
# #### What is the first entry?

# %%
# Print first entry
cats[0]['entries'][0]
# Out:
# {'num_int': 1799,
#  'num_str': '-1799.',
#  'people': [{'id': 'Mr._Amyand', 'name': 'Mr. Amyand'}],
#  'places': [{'id': 'East_Indies', 'name': 'East Indies'}],
#  'text': '-1799. A bow said to be made of a bone from East Indies given to me by Mr. Amyand 252.'}

# %% [markdown]
# #### Put all the data in a dataframe

# %%
# Create dataframe from first catalogue
df = pd.DataFrame(cats[0]['entries'])

# Set visualisation options
pd.set_option('precision', 0)

# Print the dataframe
df

# Drop nulls
df = df.dropna(subset=['num_int'])

# Sort by entry number
df = df.sort_values(by=['num_int'])

# Print the dataframe
df
# Out:
#       num_int        num_str  \
# 245         1         No. 1.
# 21          1             1.
# 22          2             2.
# 23          3             3.
# 24          4             4.
# 25          5             5.
# 26          6             6.
# 27          7          ___7.
# 28          8             8.
# 29          9          ___9.
# 30         10            10.
# 31         11            11.
# 32         12            12.
# 49         13            13.
# 50         14            14.
# 51         15            15.
# 52         16          __16.
# 53         17            17.
# 54         18            18.
# 55         19            19.
# 56         20            20.
# 57         21            21.
# 58         22          __22.
# 59         23            23.
# 60         24            24.
# 77         25            25.
# 78         26            26.
# 79         27            27.
# 80         28            28.
# 81         29            29.
# 82         30            30.
# 83         31            31.
# 84         32            32.
# 85         33            33.
# 86         34            34.
# 87         35            35.
# 88         36            36.
# 89         37            37.
# 90         38            38.
# 91         39            39.
# 92         40            40.
# 93         41            41.
# 109        42            42.
# 110        43            43.
# 111        44            44.
# 112        45           -45.
# 113        46           -46.
# 114        47           -47.
# 115        48           -48.
# 116        49           -49.
# 117        50           -50.
# 118        51           -51.
# 119        52           -52.
# 120        53           -53.
# 137        54           -54.
# 138        55           -55.
# 139        56           -56.
# 140        57           -57.
# 141        58           -58.
# 142        59           -59.
# 143        60            60.
# 144        61            61.
# 145        62            62.
# 146        63            63.
# 147        64           -64.
# 170        65            65.
# 171        66            66.
# 172        67            67.
# 173        68            68.
# 174        69            69.
# 175        70            70.
# 176        71            71.
# 177        72            72.
# 178        73            73.
# 179        74            74.
# 180        75            75.
# 181        76            76.
# 182        77            77.
# 183        78            78.
# 184        79            79.
# 185        80            80.
# 186        81            81.
# 187        82            82.
# 188        83            83.
# 189        84            84.
# 210        85            85.
# 211        86            86.
# 212        87            87.
# 213        88            88.
# 214        89            89.
# 215        90            90.
# 216        91            91.
# 217        92            92.
# 218        93            93.
# 219        94            94.
# 220        95            95.
# 221        96          ? 96.
# 222        97          ? 97.
# 223        98           ?98.
# 224        99           ?99.
# 225       100          ?100.
# 226       101          ?101.
# 227       102         ? 102.
# 228       103         ?-103.
# 247       104         ? 104.
# 248       105         ? 105.
# 249       106           106.
# 250       107           107.
# 251       108           108.
# 252       109           109.
# 253       110           110.
# 254       111           111.
# 255       112          -112.
# 256       113          -113.
# 257       114          -114.
# 258       115          -115.
# 259       116          -116.
# 260       117          -117.
# 261       118          -118.
# 262       119          -119.
# 289       120          -120.
# 290       121           121.
# 291       122          -122.
# 292       123           123.
# 293       124           124.
# 294       125           125.
# 295       126           126.
# 296       127           127.
# 297       128           128.
# 298       129          -129.
# 299       130           130.
# 300       131          -131.
# 301       132          -132.
# 302       133           133.
# 320       134           134.
# 321       135          -135.
# 322       136           136.
# 323       137           137.
# 324       138           138.
# 325       139           139.
# 326       140           140.
# 327       141           141.
# 328       142           142.
# 329       143           143.
# 330       144           144.
# 331       145           145.
# 332       146           146.
# 333       147           147.
# 334       148           148.
# 358       149           149.
# 359       150           150.
# 360       151           151.
# 361       152           152.
# 362       153           153.
# 363       154           154.
# 364       155           155.
# 365       156           156.
# 366       157           157.
# 367       158           158.
# 368       159           159.
# 369       160           160.
# 370       161           161.
# 371       162           162.
# 372       163           163.
# 390       164           164.
# 391       165          -165.
# 392       166          -166.
# 393       167           167.
# 394       168            168
# 395       169           169.
# 396       170           170.
# 397       171           171.
# 398       172           172.
# 399       173           173.
# 400       174           174.
# 401       175          -175.
# 402       176          -176.
# 403       177          -177.
# 404       178          -178.
# 417       179          -179.
# 418       180          -180.
# 419       181          -181.
# 420       182          -182.
# 421       183          -183.
# 422       184          -184.
# 423       185          -185.
# 424       186          -186.
# 425       187          -187.
# 426       188          -188.
# 427       189          -189.
# 442       190           190.
# 443       191           191.
# 444       192           192.
# 445       193           193.
# 446       194           194.
# 447       195           195.
# 448       196           196.
# 449       197           197.
# 450       198           198.
# 451       199           199.
# 452       200           200.
# 453       201           201.
# 454       202           202.
# 455       203           203.
# 472       204           204*
# 471       204           204.
# 473       205            205
# 474       206           206.
# 475       207           207.
# 476       208           208.
# 477       209           209.
# 478       210           210.
# 492       211           211.
# 493       212           212.
# 494       213          -213.
# 495       214          -214.
# 496       215          -215.
# 497       216          -216.
# 498       217          -217.
# 499       218          -218.
# 500       219           219.
# 501       220           220.
# 502       221          -221.
# 503       222          -222.
# 504       223          -223.
# 505       224          -224.
# 517       225           225.
# 518       226           226.
# 519       227           227.
# 520       228           228.
# 521       229           229.
# 522       230          -230.
# 523       231          -231.
# 524       232          -232.
# 525       233          -233.
# 526       234           234.
# 539       235           235.
# 540       236           236.
# 541       237           237.
# 542       238           238.
# 543       239           239.
# 544       240           240.
# 545       241           241.
# 546       242           242.
# 547       243           243.
# 548       244           244.
# 549       245           245.
# 550       246           246.
# 560       247          -247.
# 561       248           248.
# 562       249           249.
# 563       250           250.
# 564       251           251.
# 565       252           252.
# 566       253           253.
# 567       254          -254.
# 568       255          -255.
# 569       256          -256.
# 570       257          -257.
# 571       258           258.
# 578       259           259.
# 579       260           260.
# 580       261           261.
# 581       262           262.
# 582       263           263.
# 583       264           264.
# 584       265           265.
# 585       266          -266.
# 586       267          -267.
# 587       268           268.
# 588       269           269.
# 589       270           270.
# 599       271          -271.
# 600       272           272.
# 601       273           273.
# 602       274           274.
# 603       275           275.
# 604       276           276.
# 605       277           277.
# 606       278           278.
# 607       279           279.
# 608       280           280.
# 619       281           281.
# 620       282           282.
# 621       283           283.
# 622       284           284.
# 623       285           285.
# 624       286           286.
# 625       287          -287.
# 626       288           288.
# 627       289           289.
# 637       290          -290.
# 638       291          -291.
# 639       292          -292.
# 640       293          -293.
# 641       294          -294.
# 642       295          -295.
# 643       296           296.
# 644       297          -297.
# 654       298          -298.
# 655       299          -299.
# 656       300          -300.
# 657       301          -301.
# 658       302          -302.
# 659       303          -303.
# 660       304          -304.
# 661       305          -305.
# 662       306           306.
# 663       307          -307.
# 664       308           308.
# 665       309           309.
# 673       310          -310.
# 674       311          -311.
# 675       312           312.
# 676       313          -313.
# 677       314          -314.
# 678       315          -315.
# 679       316          -316.
# 680       317          -317.
# 681       318          -318.
# 682       319           -319
# 683       320          -320.
# 691       321          -321.
# 692       322           322.
# 693       323          -323.
# 694       324          -324.
# 695       325          -325.
# 696       326          -326.
# 697       327          -327.
# 698       328           328.
# 700       329           329.
# 701       330           330.
# 702       331          -331.
# 703       332          -332.
# 704       333          -333.
# 705       334          -334.
# 706       335          -335.
# 707       336          -336.
# 708       337           337.
# 709       338           338.
# 711       339          -339.
# 712       340           -340
# 713       341           341.
# 714       342           342.
# 715       343           343.
# 716       344           344.
# 717       345           345.
# 718       346           346.
# 719       347           347.
# 720       348          -348.
# 721       349          -349.
# 722       350           350.
# 724       351           351.
# 725       352           352.
# 726       353           353.
# 727       354           354.
# 728       355           355.
# 729       356           356.
# 730       357           357.
# 731       358           358.
# 732       359           359.
# 733       360           360.
# 734       361           361.
# 735       362           362.
# 736       363           363.
# 738       364           364.
# 739       365           365.
# 740       366           366.
# 741       367           367.
# 742       368           368.
# 743       369           369.
# 744       370           370.
# 745       371          -371.
# 746       372          -372.
# 747       373          -373.
# 748       374          -374.
# 749       375          -375.
# 750       376          -376.
# 751       377          -377.
# 753       378          -378.
# 754       379          -379.
# 755       380          -380.
# 756       381          -381.
# 757       382          -382.
# 758       383           383.
# 759       384           384.
# 760       385           385.
# 761       385          385*.
# 763       386          386*.
# 762       386           386.
# 764       387           387.
# 765       388           388.
# 766       389           389.
# 767       390           390.
# 769       391          -391.
# 770       392          -392.
# 771       393          -393.
# 772       394          -394.
# 773       395          -395.
# 774       396          -396.
# 1178      396            396
# 775       397          -397.
# 776       398          -398.
# 777       399          -399.
# 778       400          -400.
# 779       401          -401.
# 780       402          -402.
# 782       403          -403.
# 783       404          -404.
# 784       405          -405.
# 785       406          -406.
# 786       407          -407.
# 787       408          -408.
# 788       409          -409.
# 789       410           -410
# 790       411          -411.
# 793       412          -412.
# 794       413          -413.
# 795       414          -414.
# 796       415          -415.
# 797       416          -416.
# 798       417          -417.
# 799       418          -418.
# 800       419          -419.
# 802       420           420.
# 803       421           421.
# 804       422           422.
# 805       423          -423.
# 806       424           424.
# 807       425           425.
# 808       426           426.
# 809       427           427.
# 810       427          427*.
# 811       428           428.
# 812       429           429.
# 814       430           430.
# 815       431           431.
# 816       432           432.
# 817       433           433.
# 818       434          -434.
# 819       435           435.
# 820       436           436.
# 821       437           437.
# 822       438          -438.
# 823       439          -439.
# 824       440          -440.
# 825       441          -441.
# 827       442          -442.
# 828       443          -443.
# 829       444           444.
# 830       445           445.
# 831       446           446.
# 832       447           447.
# 833       448          -448.
# 834       449           449.
# 835       450          -450.
# 836       451          -451.
# 838       452          -452.
# 839       453           453.
# 840       454          -454.
# 841       455          -455.
# 842       456          -456.
# 843       457          -457.
# 844       458          -458.
# 845       459          -459.
# 846       460           -460
# 847       461          -461.
# 849       462          -462.
# 850       463           463.
# 851       464          -464.
# 852       465          -465.
# 853       466          -466.
# 854       467          -467.
# 855       468          -468.
# 856       469          -469.
# 858       470           470.
# 859       471           471.
# 860       472          -472.
# 861       473          -473.
# 862       474          -474.
# 863       475          -475.
# 864       476           476.
# 865       477          -477.
# 867       478          -478.
# 868       479          -479.
# 869       480          -480.
# 870       481          -481.
# 871       482          -482.
# 872       483          -483.
# 873       484        484 483
# 874       485      -485. 484
# 875       486           486.
# 877       487           487.
# 878       488           488.
# 879       489           489.
# 880       490           490.
# 881       491          -491.
# 882       492           492.
# 883       493          -493.
# 884       494          -494.
# 885       495          -495.
# 887       496          -496.
# 888       497          -497.
# 889       498          -498.
# 890       499          -499.
# 891       500          -500.
# 893       501          -501.
# 894       502          -502.
# 895       503          -503.
# 896       504          -504.
# 897       505          -505.
# 898       506          -506.
# 899       507          -507.
# 900       508          -508.
# 902       509          -509.
# 903       510           -510
# 904       511          -511.
# 905       512          -512.
# 906       513          -513.
# 907       514          -514.
# 908       515          -515.
# 909       516          -516.
# 910       517          -517.
# 912       518          -518.
# 913       519          -519.
# 914       520          -520.
# 915       521          -521.
# 916       522          -522.
# 917       523          -523.
# 918       524          -524.
# 919       525          -525.
# 920       526          -526.
# 921       527          -527.
# 922       528          -528.
# 923       529          -529.
# 925       530          -530.
# 926       531          -531.
# 927       532          -532.
# 928       533          -533.
# 929       534          -534.
# 930       535          -535.
# 931       536          -536.
# 932       537          -537.
# 933       538          -538.
# 935       539          -539.
# 936       540          -540.
# 937       541          -541.
# 938       542          -542.
# 940       542          -542.
# 941       543          -543.
# 942       544          -544.
# 943       545          -545.
# 944       546          -546.
# 945       547          -547.
# 946       548          -548.
# 947       549           549.
# 949       550          -550.
# 950       551          -551.
# 951       552          -552.
# 952       553          -553.
# 953       554          -554.
# 954       555          -555.
# 955       556          -556.
# 956       557          -557.
# 957       558          -558.
# 958       559          -559.
# 960       560          -560.
# 961       561          -561.
# 962       562          -562.
# 963       563          -563.
# 964       564          -564.
# 965       565          -565.
# 966       566          -566.
# 967       567          -567.
# 968       568          -568.
# 969       569          -569.
# 971       570          -570.
# 972       571          -571.
# 973       572           -572
# 974       573          -573.
# 975       574          -574.
# 976       575          -575.
# 978       576          -576.
# 979       577          -577.
# 980       578          -578.
# 981       579          -579.
# 982       580          -580.
# 984       581          -581.
# 985       582          -582.
# 986       583          -583.
# 987       584          -584.
# 988       585          -585.
# 990       586          -586.
# 991       587          -587.
# 992       588          -588.
# 994       589          -589.
# 995       590          -590.
# 996       591          -591.
# 997       592          -592.
# 998       593          -593.
# 1000      594          -594.
# 1001      595          -595.
# 1002      596          -596.
# 1003      597          -597.
# 1004      598          -598.
# 1005      599          -599.
# 1006      600          -600.
# 1008      601          -601.
# 1009      602          -602.
# 1010      603          -603.
# 1011      604          -604.
# 1012      605          -605.
# 1013      606          -606.
# 1014      607          -607.
# 1015      608          -608.
# 1017      609          -609.
# 1018      610          -610.
# 1019      611          -611.
# 1020      612          -612.
# 1021      613          -613.
# 1022      614          -614.
# 1023      615          -615.
# 1024      616          -616.
# 1025      617          -617.
# 1027      618          -618.
# 1028      619          -619.
# 1029      620          -620.
# 1030      621          -621.
# 1031      622          -622.
# 1032      623          -623.
# 1033      624          -624.
# 1035      625          -625.
# 1036      626          -626.
# 1037      627          -627.
# 1038      628          -628.
# 1039      629          -629.
# 1040      630          -630.
# 1041      631          -631.
# 1042      632          -632.
# 1044      633          -633.
# 1045      634          -634.
# 1046      635          -635.
# 1047      636          -636.
# 1048      637          -637.
# 1049      638          -638.
# 1051      639          -639.
# 1052      640          -640.
# 1053      641          -641.
# 1054      642          -642.
# 1055      643          -643.
# 1056      644          -644.
# 1057      645          -645.
# 1058      646          -646.
# 1060      647          -647.
# 1061      648          -648.
# 1062      649          -649.
# 1063      650          -650.
# 1064      651          -651.
# 1065      652          -652.
# 1066      653            653
# 1069      654          -654.
# 1070      655          -655.
# 1071      656          -656.
# 1072      657          -657.
# 1073      658          -658.
# 1074      659          -659.
# 1075      660          -660.
# 1076      661          -661.
# 1078      662          -662.
# 1079      663          -663.
# 1080      664          -664.
# 1081      665          -665.
# 1082      666          -666.
# 1083      667          -667.
# 1084      668          -668.
# 1085      669          -669.
# 1087      670          -670.
# 1088      671          -671.
# 1089      672          -672.
# 1090      673          -673.
# 1091      674          -674.
# 1092      675          -675.
# 1093      676          -676.
# 1094      677          -677.
# 1095      678          -678.
# 1097      679          -679.
# 1098      680          -680.
# 1099      681          -681.
# 1100      682          -682.
# 1101      683          -683.
# 1102      684          -684.
# 1103      685          -685.
# 1104      686          -686.
# 1105      687          -687.
# 1107      688          -688.
# 1108      689          -689.
# 1109      690          -690.
# 1110      691          -691.
# 1111      692          -692.
# 1112      693          -693.
# 1113      694          -694.
# 1114      695          -695.
# 1117      696           696.
# 1118      697           697.
# 1119      698          -698.
# 1120      699          -699.
# 1121      700          -700.
# 1122      701          -701.
# 1123      702          -702.
# 1124      703          -703.
# 1126      704          -704.
# 1127      705          -705.
# 1128      706          -706.
# 1129      707          -707.
# 1130      708          -708.
# 1131      709          -709.
# 1133      710          -710.
# 1134      711          -711.
# 1135      712          -712.
# 1136      713          -713.
# 1137      714          -714.
# 1138      715          -715.
# 1139      716          -716.
# 1140      717          -717.
# 1141      718          -718.
# 1142      719          -719.
# 1144      720          -720.
# 1145      721          -721.
# 1146      722          -722.
# 1147      723          -723.
# 1148      724          -724.
# 1149      725          -725.
# 1151      726          -726.
# 1152      727          -727.
# 1153      728          -728.
# 1154      729          -729.
# 1155      730           730.
# 1156      731           731.
# 1157      732          -732.
# 1158      733          -733.
# 1160      734          -734.
# 1161      735           735.
# 1162      736          -736.
# 1163      737          -737.
# 1164      738          -738.
# 1165      739          -739.
# 1166      740          -740.
# 1168      741          -741.
# 1169      742          -742.
# 1170      743           743.
# 1171      744           744.
# 1172      745           745.
# 1173      746           746.
# 1174      747           747.
# 1175      748           748.
# 1177      749           749.
# 1179      750          -750.
# 1180      751          -751.
# 1181      752          -752.
# 1182      753          -753.
# 1183      754          -754.
# 1185      755          -755.
# 1186      756          -756.
# 1187      757          -757.
# 1188      758          -758.
# 1189      759          -759.
# 1190      760          -760.
# 1191      761          -761.
# 1193      762          -762.
# 1194      763          -763.
# 1195      764          -764.
# 1196      765          -765.
# 1197      766          -766.
# 1198      767          -767.
# 1199      768          -768.
# 1200      769          -769.
# 1201      770          -770.
# 1203      771          -771.
# 1204      772          -772.
# 1205      773          -773.
# 1206      774          -774.
# 1207      775          -775.
# 1208      776          -776.
# 1209      777          -777.
# 1210      778          -778.
# 1211      779          -779.
# 1213      780      -780. 789
# 1214      781          -781.
# 1215      782          -782.
# 1216      783          -783.
# 1217      784          -784.
# 1218      785          -785.
# 1220      786          -786.
# 1221      787          -787.
# 1222      788           788.
# 1223      789          -789.
# 1224      790          -790.
# 1225      791          -791.
# 1226      792          -792.
# 1227      793          -793.
# 1228      794          -794.
# 1230      795           795.
# 1231      796           796.
# 1232      797           797.
# 1233      798          -798.
# 1234      799           799.
# 1235      800          -800.
# 1236      801          -801.
# 1237      802          -802.
# 1238      803          -803.
# 1239      804          -804.
# 1241      805           805.
# 1242      806           806.
# 1243      807           807.
# 1244      808           808.
# 1245      809          -809.
# 1246      810          -810.
# 1247      811           811.
# 1248      812          -812.
# 1249      813          -813.
# 1250      814          -814.
# 1252      815          -815.
# 1253      816          -816.
# 1254      817          -817.
# 1255      818          -818.
# 1256      819          -819.
# 1257      820          -820.
# 1258      821          -821.
# 1259      822          -822.
# 1260      823          -823.
# 1261      824          -824.
# 1262      825           825.
# 1264      826          -826.
# 1265      827          -827.
# 1266      828           828.
# 1267      829          -829.
# 1268      830           830.
# 1269      831          -831.
# 1270      832           832.
# 1271      833          -833.
# 1272      834          -834.
# 1273      835          -835.
# 1275      836          -836.
# 1276      837          -837.
# 1277      838          -838.
# 1278      839          -839.
# 1279      840          -840.
# 1280      841          -841.
# 1282      842          -842.
# 1283      843          -843.
# 1284      844          -844.
# 1285      845          -845.
# 1286      846          -846.
# 1287      847          -847.
# 1288      848          -848.
# 1290      849          -849.
# 1291      850          -850.
# 1292      851          -851.
# 1293      852          -852.
# 1294      853          -853.
# 1295      854          -854.
# 1296      855          -855.
# 1298      856          -856.
# 1299      857          -857.
# 1300      858          -858.
# 1301      859          -859.
# 1302      860          -860.
# 1303      861          -861.
# 1304      862          -862.
# 1307      863          -863.
# 1308      864          -864.
# 1309      865          -865.
# 1310      866          -866.
# 1311      867          -867.
# 1312      868          -868.
# 1313      869          -869.
# 1314      870          -870.
# 1316      871          -871.
# 1317      872          -872.
# 1318      873          -873.
# 1319      874          -874.
# 1320      875          -875.
# 1321      876          -876.
# 1322      877          -877.
# 1324      878          -878.
# 1325      879          -879.
# 1326      880           880.
# 1327      881          -881.
# 1328      882          -882.
# 1329      883          -883.
# 1330      884          -884.
# 1332      885          -885.
# 1333      886          -886.
# 1334      887          -887.
# 1335      888          -888.
# 1336      889          -889.
# 1337      890          -890.
# 1338      891          -891.
# 1339      892          -892.
# 1340      893          -893.
# 1341      894          -894.
# 1342      895          -895.
# 1344      896          -896.
# 1345      897          -897.
# 1346      898          -898.
# 1347      899          -899.
# 1348      900          -900.
# 1349      901          -901.
# 1350      902          -902.
# 1351      903          -903.
# 1352      904          -904.
# 1353      905          -905.
# 1354      906          -906.
# 1355      907          -907.
# 1356      908          -908.
# 1371      909          -909.
# 1358      909          -909.
# 1372      910          -910.
# 1359      910          -910.
# 1373      911        -911. *
# 1360      911          -911.
# 1374      912        -912. *
# 1361      912          -912.
# 1362      913          -913.
# 1375      913       -913. **
# 1363      914          -914.
# 1376      914  -914 * . 714.
# 1377      915        -915. *
# 1364      915          -915.
# 1365      916          -916.
# 1378      916         916. *
# 1379      916        -916. *
# 1366      917          -917.
# 1380      917        -917. *
# 1367      918          -918.
# 1381      918        -918. *
# 1368      919           -919
# 1384      919        -919. *
# 1385      920        -920. *
# 1369      920           -920
# 1386      921          -921.
# 1387      922           922.
# 1388      923          -923.
# 1389      924          -924.
# 1390      925          -925.
# 1391      926          -926.
# 1392      927          -927.
# 1393      928          -928.
# 1395      929          -929.
# 1396      930          -930.
# 1397      931          -931.
# 1398      932          -932.
# 1399      933          -933.
# 1400      934          -934.
# 1401      935          -935.
# 1402      936          -936.
# 1403      937          -937.
# 1404      938          -938.
# 1405      939          -939.
# 1406      940          -940.
# 1408      941          -941.
# 1409      942          -942.
# 1410      943          -943.
# 1411      944          -944.
# 1412      945          -945.
# 1413      946          -946.
# 1414      947          -947.
# 1415      948          -948.
# 1416      949          -949.
# 1417      950          -950.
# 1418      951          -951.
# 1419      952          -952.
# 1420      953          -953.
# 1421      954          -954.
# 1422      955          -955.
# 1423      956          -956.
# 1424      957          -957.
# 1425      958          -958.
# 1426      959          -959.
# 1427      960          -960.
# 1428      961          -961.
# 1430      962          -962.
# 1431      963          -963.
# 1432      964          -964.
# 1433      965          -965.
# 1434      966          -966.
# 1435      967          -967.
# 1436      968          -968.
# 1437      969          -969.
# 1438      970          -970.
# 1439      971          -971.
# 1440      972          -972.
# 1442      973          -973.
# 1443      974          -974.
# 1444      975          -975.
# 1445      976          -976.
# 1446      977          -977.
# 1447      978          -978.
# 1448      979          -979.
# 1449      980          -980.
# 1450      981          -981.
# 1451      982          -982.
# 1452      983          -983.
# 1453      984          -984.
# 1454      985          -985.
# 1455      986          -986.
# 1457      987          -987.
# 1458      988          -988.
# 1459      989          -989.
# 1460      990          -990.
# 1461      991          -991.
# 1462      992           992.
# 1463      993          -993.
# 1464      994          -994.
# 1465      995          -995.
# 1466      996          -996.
# 1467      997          -997.
# 1469      998          -998.
# 1470      999          -999.
# 1471     1000         -1000.
# 1472     1001          -1001
# 1473     1002          1002.
# 1474     1003         -1003.
# 1475     1004         -1004.
# 1476     1005         -1005.
# 1477     1006         -1006.
# 1478     1007         -1007.
# 1479     1008         -1008.
# 1481     1009         -1009.
# 1482     1010         -1010.
# 1483     1011         -1011.
# 1484     1012         -1012.
# 1485     1013         -1013.
# 1486     1014         -1014.
# 1487     1015         -1015.
# 1488     1016         -1016.
# 1489     1017         -1017.
# 1490     1018         -1018.
# 1491     1019         -1019.
# 1492     1020         -1020.
# 1493     1021         -1021.
# 1494     1022         -1022.
# 1497     1023         -1023.
# 1498     1024         -1024.
# 1499     1025         -1025.
# 1495     1025          1025.
# 1500     1026         -1026.
# 1501     1027          1027.
# 1502     1028         -1028.
# 1503     1029         -1029.
# 1504     1030         -1030.
# 1505     1031         -1031.
# 1506     1032         -1032.
# 1507     1033         -1033.
# 1509     1034         -1034.
# 1510     1035         -1035.
# 1511     1036         -1036.
# 1512     1037         -1037.
# 1513     1038         -1038.
# 1514     1039         -1039.
# 1515     1040         -1040.
# 1516     1041         -1041.
# 1518     1042         -1042.
# 1519     1043         -1043.
# 1520     1044         -1044.
# 1521     1045          1045.
# 1522     1046         -1046.
# 1523     1047         -1047.
# 1524     1048         -1048.
# 1525     1049         -1049.
# 1526     1050         -1050.
# 1527     1051         -1051.
# 1528     1052         -1052.
# 1529     1053         -1053.
# 1530     1054         -1054.
# 1531     1055         -1055.
# 1532     1056         -1056.
# 1533     1057         -1057.
# 1534     1058         -1058.
# 1535     1059         -1059.
# 1536     1060         -1060.
# 1539     1061         -1061.
# 1540     1062         -1062.
# 1541     1063         -1063.
# 1542     1064         -1064.
# 1543     1065         -1065.
# 1544     1066   -1066. -1065
# 1545     1067   -1067. -1066
# 1546     1068         -1068.
# 1547     1069         -1069.
# 1548     1070         -1070.
# 1549     1071         -1071.
# 1550     1072         -1072.
# 1551     1073         -1073.
# 1552     1073          1073.
# 1554     1074         -1074.
# 1555     1075         -1075.
# 1556     1076         -1076.
# 1557     1077         -1077.
# 1558     1078         -1078.
# 1559     1079         -1079.
# 1560     1080         -1080.
# 1561     1081         -1081.
# 1562     1082         -1082.
# 1564     1083         -1083.
# 1565     1084         -1084.
# 1566     1085         -1085.
# 1567     1086         -1086.
# 1568     1087         -1087.
# 1569     1088         -1088.
# 1570     1089         -1089.
# 1571     1090         -1090.
# 1572     1091         -1091.
# 1573     1092         -1092.
# 1575     1093       -1093 *.
# 1574     1093         -1093.
# 1576     1094         -1094.
# 1577     1095         -1095.
# 1578     1096         -1096.
# 1579     1097         -1097.
# 1580     1098         -1098.
# 1581     1099         -1099.
# 1582     1100         -1100.
# 1584     1101         -1101.
# 1585     1102         -1102.
# 1586     1103         -1103.
# 1587     1104         -1104.
# 1588     1105         -1105.
# 1589     1106         -1106.
# 1590     1107         -1107.
# 1591     1108         -1108.
# 1592     1109         -1109.
# 1593     1110         -1110.
# 1594     1111         -1111.
# 1595     1112         -1112.
# 1596     1113         -1113.
# 1597     1114         -1114.
# 1598     1115         -1115.
# 1599     1116         -1116.
# 1600     1117         -1117.
# 1601     1118         -1118.
# 1602     1119         -1119.
# 1603     1120         -1120.
# 1604     1121         -1121.
# 1605     1122         -1122.
# 1606     1123         -1123.
# 1608     1124         -1124.
# 1609     1125         -1125.
# 1610     1126         -1126.
# 1611     1127         -1127.
# 1612     1128         -1128.
# 1613     1129         -1129.
# 1614     1130         -1130.
# 1615     1131         -1131.
# 1616     1132         -1132.
# 1617     1133         -1133.
# 1618     1134         -1134.
# 1619     1135         -1135.
# 1620     1136         -1136.
# 1621     1137         -1137.
# 1622     1138         -1138.
# 1623     1139         -1139.
# 1624     1140         -1140.
# 1625     1141         -1141.
# 1628     1142         -1142.
# 1629     1143         -1143.
# 1630     1144         -1144.
# 1631     1145         -1145.
# 1632     1146         -1146.
# 1633     1147         -1147.
# 1634     1148         -1148.
# 1635     1149         -1149.
# 1636     1150         -1150.
# 1637     1151         -1151.
# 1638     1152         -1152.
# 1639     1153         -1153.
# 1640     1154         -1154.
# 1641     1155         -1155.
# 1642     1156         -1156.
# 1643     1157         -1157.
# 1644     1158         -1158.
# 1645     1159         -1159.
# 1647     1160         -1160.
# 1648     1161         -1161.
# 1649     1162         -1162.
# 1650     1163         -1163.
# 1651     1164         -1164.
# 1652     1165         -1165.
# 1653     1166         -1166.
# 1654     1167         -1167.
# 1655     1168         -1168.
# 1656     1169         -1169.
# 1657     1170         -1170.
# 1658     1171         -1171.
# 1659     1172         -1172.
# 1660     1173         -1173.
# 1661     1174         -1174.
# 1662     1175          -1175
# 1664     1176         -1176.
# 1665     1177         -1177.
# 1666     1178         -1178.
# 1667     1179         -1179.
# 1668     1180         -1180.
# 1669     1181         -1181.
# 1670     1182         -1182.
# 1671     1183         -1183.
# 1672     1184         -1184.
# 1673     1185         -1185.
# 1674     1186         -1186.
# 1675     1187         -1187.
# 1676     1188         -1188.
# 1678     1189         -1189.
# 1679     1190         -1190.
# 1680     1191         -1191.
# 1681     1192  -1192. -1191.
# 1682     1193         -1193.
# 1683     1194  -1194. -1193.
# 1684     1195         -1195.
# 1685     1196         -1196.
# 1686     1197         -1197.
# 1687     1198         -1198.
# 1688     1199         -1199.
# 1689     1200         -1200.
# 1690     1201         -1201.
# 1691     1202         -1202.
# 1692     1203         -1203.
# 1694     1204         -1204.
# 1695     1205         -1205.
# 1696     1206         -1206.
# 1697     1207         -1207.
# 1698     1208         -1208.
# 1699     1209         -1209.
# 1700     1210         -1210.
# 1701     1211         -1211.
# 1702     1212         -1212.
# 1703     1213         -1213.
# 1704     1214    -1214. 1213
# 1705     1215         -1215.
# 1706     1216         -1216.
# 1707     1217         -1217.
# 1709     1218         -1218.
# 1710     1219         -1219.
# 1711     1220         -1220.
# 1712     1221         -1221.
# 1713     1222         -1222.
# 1714     1223         -1223.
# 1715     1224         -1224.
# 1716     1225         -1225.
# 1717     1226         -1226.
# 1718     1227         -1227.
# 1719     1228         -1228.
# 1720     1229         -1229.
# 1721     1230         -1230.
# 1722     1231         -1231.
# 1724     1232         -1232.
# 1725     1233         -1233.
# 1726     1234         -1234.
# 1727     1235         -1235.
# 1728     1236         -1236.
# 1729     1237         -1237.
# 1730     1238         -1238.
# 1731     1239         -1239.
# 1732     1240         -1240.
# 1733     1241         -1241.
# 1734     1242         -1242.
# 1735     1243         -1243.
# 1736     1244         -1244.
# 1737     1245         -1245.
# 1738     1246         -1246.
# 1740     1247       -1247. 5
# 1741     1248         -1248.
# 1742     1249         -1249.
# 1743     1250          -1250
# 1744     1251         -1251.
# 1745     1252         -1252.
# 1746     1253         -1253.
# 1747     1254         -1254.
# 1748     1255         -1255.
# 1749     1256         -1256.
# 1750     1257         -1257.
# 1751     1258         -1258.
# 1752     1259         -1259.
# 1753     1260         -1260.
# 1754     1261         -1261.
# 1755     1262         -1262.
# 1756     1263         -1263.
# 1757     1264         -1264.
# 1759     1265         -1265.
# 1760     1266         -1266.
# 1761     1267         -1267.
# 1762     1268         -1268.
# 1763     1269         -1269.
# 1764     1270         -1270.
# 1765     1271         -1271.
# 1766     1272         -1272.
# 1767     1273         -1273.
# 1768     1274         -1274.
# 1769     1275         -1275.
# 1772     1276          1276.
# 1773     1277         -1277.
# 1774     1278         -1278.
# 1775     1279         -1279.
# 1776     1280         -1280.
# 1777     1281         -1281.
# 1778     1282         -1282.
# 1780     1283         -1283.
# 1781     1284         -1284.
# 1782     1285         -1285.
# 1783     1286         -1286.
# 1784     1287         -1287.
# 1785     1288         -1288.
# 1786     1289         -1289.
# 1787     1290         -1290.
# 1788     1291         -1291.
# 1789     1292         -1292.
# 1790     1293         -1293.
# 1791     1294         -1294.
# 1792     1295         -1295.
# 1793     1296         -1296.
# 1794     1297         -1297.
# 1795     1298         -1298.
# 1796     1299         -1299.
# 1797     1300         -1300.
# 1798     1301         -1301.
# 1799     1302         -1302.
# 1800     1303         -1303.
# 1801     1304         -1304.
# 1802     1305         -1305.
# 1803     1306         -1306.
# 1805     1307         -1307.
# 1806     1308         -1308.
# 1807     1309         -1309.
# 1808     1310         -1310.
# 1809     1311         -1311.
# 1810     1312         -1312.
# 1811     1313         -1313.
# 1812     1314         -1314.
# 1813     1315         -1315.
# 1814     1316         -1316.
# 1815     1317         -1317.
# 1816     1318         -1318.
# 1817     1319         -1319.
# 1818     1320         -1320.
# 1819     1321         -1321.
# 1820     1322         -1322.
# 1821     1323         -1323.
# 1822     1324         -1324.
# 1823     1325         -1325.
# 1824     1326         -1326.
# 1825     1327         -1327.
# 1826     1328         -1328.
# 1827     1329         -1329.
# 1828     1330         -1330.
# 1829     1331         -1331.
# 1832     1332         -1332.
# 1833     1333         -1333.
# 1834     1334         -1334.
# 1835     1335         -1335.
# 1836     1336         -1336.
# 1837     1337         -1337.
# 1838     1338         -1338.
# 1839     1339         -1339.
# 1840     1340         -1340.
# 1841     1341         -1341.
# 1842     1342         -1342.
# 1843     1343         -1343.
# 1844     1344         -1344.
# 1845     1345         -1345.
# 1846     1346         -1346.
# 1848     1347         -1347.
# 1849     1348         -1348.
# 1850     1349         -1349.
# 1851     1350         -1350.
# 1852     1351         -1351.
# 1853     1352         -1352.
# 1854     1353         -1353.
# 1855     1354         -1354.
# 1856     1355         -1355.
# 1857     1356         -1356.
# 1858     1357         -1357.
# 1859     1358         -1358.
# 1860     1359         -1359.
# 1861     1360         -1360.
# 1862     1361         -1361.
# 1863     1362         -1362.
# 1864     1363         -1363.
# 1865     1364         -1364.
# 1866     1365         -1365.
# 1867     1366         -1366.
# 1868     1367          1367.
# 1870     1368         -1368.
# 1871     1369         -1369.
# 1872     1370         -1370.
# 1873     1371         -1371.
# 1874     1372         -1372.
# 1875     1373         -1373.
# 1876     1374         -1374.
# 1877     1375         -1375.
# 1878     1376         -1376.
# 1879     1377         -1377.
# 1880     1378         -1378.
# 1881     1379         -1379.
# 1882     1380         -1380.
# 1883     1381         -1381.
# 1884     1382         -1382.
# 1885     1383         -1383.
# 1886     1384         -1384.
# 1887     1385         -1385.
# 1888     1386         -1386.
# 1890     1387         -1387.
# 1891     1388         -1388.
# 1892     1389         -1389.
# 1893     1390         -1390.
# 1894     1391         -1391.
# 1895     1392         -1392.
# 1896     1393         -1393.
# 1897     1394         -1394.
# 1898     1395         -1395.
# 1899     1396         -1396.
# 1900     1397         -1397.
# 1901     1398         -1398.
# 1902     1399         -1399.
# 1903     1400         -1400.
# 1904     1401         -1401.
# 1905     1402         -1402.
# 1906     1403         -1403.
# 1907     1404       -1404. 3
# 1908     1405         -1405.
# 1909     1406         -1406.
# 1910     1407         -1407.
# 1911     1408         -1408.
# 1912     1409         -1409.
# 1913     1410         -1410.
# 1914     1411         -1411.
# 1915     1412         -1412.
# 1916     1413         -1413.
# 1917     1414         -1414.
# 1918     1415         -1415.
# 1919     1416         -1416.
# 1922     1417         -1417.
# 1923     1418         -1418.
# 1924     1419         -1419.
# 1925     1420         -1420.
# 1926     1421         -1421.
# 1927     1422         -1422.
# 1928     1423         -1423.
# 1929     1424         -1424.
# 1930     1425         -1425.
# 1931     1426         -1426.
# 1932     1427         -1427.
# 1933     1428         -1428.
# 1934     1429         -1429.
# 1935     1430         -1430.
# 1936     1431         -1431.
# 1937     1432         -1432.
# 1938     1433         -1433.
# 1939     1434         -1434.
# 1940     1435         -1435.
# 1941     1436         -1436.
# 1942     1437         -1437.
# 1943     1438         -1438.
# 1944     1439         -1439.
# 1945     1440         -1440.
# 1946     1441         -1441.
# 1947     1442         -1442.
# 1950     1443         -1443.
# 1951     1444         -1444.
# 1952     1445         -1445.
# 1953     1446         -1446.
# 1954     1447         -1447.
# 1955     1448         -1448.
# 1956     1449         -1449.
# 1957     1450         -1450.
# 1958     1451         -1451.
# 1959     1452         -1452.
# 1960     1453         -1453.
# 1961     1454         -1454.
# 1948     1455           1455
# 1962     1455         -1455.
# 1963     1456         -1456.
# 1964     1457         -1457.
# 1965     1458         -1458.
# 1966     1459         -1459.
# 1967     1460         -1460.
# 1968     1461         -1461.
# 1969     1462         -1462.
# 1970     1463         -1463.
# 1971     1464         -1464.
# 1972     1465         -1465.
# 1973     1466         -1466.
# 1974     1467         -1467.
# 1975     1468         -1468.
# 1977     1469         -1469.
# 1978     1470         -1470.
# 1979     1471         -1471.
# 1980     1472         -1472.
# 1981     1473         -1473.
# 1982     1474         -1474.
# 1983     1475         -1475.
# ...
# 122   -1864. A pair of gloves belong'd to the same w...
# 123   -1865. A case wherein is a knife, fork, ear pi...
# 124   -1866. A rice or Alabaster box wt. a Chinese p...
# 125   1867. A Canoa from Hudsons bay or Greenland wt...
# 126   -1868. A pair of shoes made of fish skin belon...
# 127   -1869. A box containing the sevll. sorts of fo...
# 128   -1870. A snuff box made of a Bergamot orange r...
# 129   -1871. A pincushion made by Mrs. Hepheshebah P...
# 130   -1872. Sal Lactis vaccini chrystallini from Dr...
# 131   -1873. Doses of a lunarg provider of one grain...
# 132   -1874. Powder of Mrs. Stephens for dissolving ...
# 133   -1875. Serpentine Stone great button for tying...
# 134                      -1876. Maiden pipes. Pet. 20 K
# 135   1877. Moxa a sort of down taken off an herb li...
# 148               -1878. A Brasse small crucifix. 216 d
# 149   -1879. Sevll. religious figures Carvd in ivory...
# 150   -1880. Æsculapius & Hygiena incisd in a Chryst...
# 151   -1881. White paint from. China? Sope of Melo? ...
# 152   -1882. A Chinese printing letter in white eart...
# 153   -1883 A pr of chinese nippers. 209 161 25 204 309
# 154   1884. The largest wampumbeg necklace or money ...
# 155   1885. The midling sized white & black . Do. 19...
# 156   1886. A lesser sort black & white . Do. 269 16...
# 157      1887. The least sort all white . Do. 199 e 160
# 158   1888. A necklace of blew hollow four square gl...
# 159   -1889. Beads or pater nosters for use in praye...
# 160   1890. A necklace of Brown conche veneris wt. f...
# 161   1891. Short strings to hang over the breast of...
# 162   -1892. A modell of the green diamond brought f...
# 163   -1893. A sphericall body made up of Black yell...
# 164            -1894. Black glasse or enamel. 216 20 S.
# 165   -1895. Wax naked figures in filbert shells. Pe...
# 166   1896. Elfs arrows from Scotland arrowheads an ...
# 167   -1897. A piece of glasse of various colours. 2...
# 168   1898. A bead made of a various coloured palm f...
# 190   1899. A head cutt on a plum b stone 209. 163. ...
# 191   -1900 A piece vid Ducatoon. of 8 taken up from...
# 192   -1901. A Spanish piece calld a quartillo found...
# 193   -1902. A _________ rasor or knife wt. these wo...
# 194   -1903. Blew red & white broken bead on sevll S...
# 195   -1904. A comb & comb case made of tortoise she...
# 196   -1905. The head of a cane of gum anime? ✓ 199 ...
# 197   -1906. A piece of greenish ordinary glasse tak...
# 198   1907. An ancient gray Stone hatchet wt. notche...
# 199   1908. A piece of Roman brick or tile? markd fo...
# 200   -1909. A Sword or large knife haft of Unicorns...
# 201   1910. A piece of Stone or flint calcin'd in a ...
# 202   1911. The hemisphericall part of an ancient fi...
# 203   1912. One of the chrystall hemisphericall orna...
# 204   1913. Another whitish clouded chrystall or Cor...
# 205   1914. Sevll. woods of the growth of English ga...
# 206   -1915. part of the tripes or skin of some anim...
# 207   -1916. Glew: Ai & vw from China? used there as...
# 208   -1917. A Newberry lozenge for the heart burn. ...
# 229   -1918. A musket bullet which being shott at a ...
# 230   -1919. Crocus metallorum?....... 199 c. 216f 2...
# 231        -1920. A Cornelian ring? ✓ 199 c 216f 20. J.
# 232   -1921. Jerusalem sope from Mr. Collier. ✓ 199 ...
# 233   -1922. Incrustations from the wreck'd ship? ma...
# 234   -1923. A copper 1601. crucifix. ✓ 199 b 216f 29 C
# 235         -1924. A snafle bridle bitt 216f 216f 199 d
# 236   -1925. Sevll. very small written pieces graved...
# 237   -1926. Sevll. coloured glasses. ✓ 199 b 216f 2...
# 238   -1927. A semicircular old China ware scolloped...
# 239   -1928. The bottom of a hayrick wch. had taken ...
# 240            -1929. Blew glasse or scoriæ. 216 a 30 C
# 241   -1930. The head of an arrow from N. England us...
# 242   -1931. Sevll. deaths heads & sceletons enameld...
# 243   -1932. a knife & Steel for coletting it on the...
# 277   1933. No. 22. A Contrivance belonging to a Dri...
# 278   1933. No. 25. A Fosset to blow up Seal Skin wi...
# 279     1933. No. 26. The same as 20 n. 244. 28 C. S B.
# 280   1933. No. 27. An Ornament hanging at a woman's...
# 281   1933. No. 28. An Ornament for the Nose. S.B n....
# 285    1933. No. 33. For Children to play with. n. 244.
# 283               1933. No. 30. The same as 25. n. 244.
# 284   1933. No. 32. In the Paper is a stone belongin...
# 276                 1933. No. 21. Do. n. 244. 28 C. S B
# 286                      1933. No. 34. A Lance. n. 244.
# 287   1933. No. 35. The same as 29. (Cæetera non des...
# 282   1933. No. 29. An Ivory Idoll. (or Fish-Bone.) ...
# 275   1933. No. 20. A Tooth , but of what Creature I...
# 274              1933. No. 18. A Harpoon. n. 244. 28 C.
# 273   1933. No. 17. The same as no. 5. S. B. n. 244....
# 244   -1933. An Indian basket made of twiggs by the ...
# 263   1933. No. 7. A Swivell for a fishing Line. S. ...
# 265   1933. No. 9. An Ornament hanging at their brea...
# 266       1933. No. 10. A Comb. ✓ S B n. 244. 28. C S B
# 267   1933. No. 11. A Pipe, which they use in skinni...
# 264           1933. No. 8. The same. S. B n. 244. 28. C
# 269   1933. No. 13. A sort of Button on their breast...
# 270   1933. No. 14. made fast to the fishing Lines. ...
# 271   1933. No. 15. A Harpoon sheath'd with wood, fo...
# 272   1933. No. 16. An Ornament for the breast. n. 2...
# 268   1933. No. 12. The butt-end of a Harpoon Staff....
# 303   -1934. Salt ous of water produced by melting I...
# 304   -1935. A piece of flowered weaved staffe made ...
# 305   -1936. A sort of flail or Bludgeon? used in Mu...
# 306   -1937. Tea root carv'd by the Chinese into sev...
# 307   -1938. A Mercuriall thermometer made by Mr. Be...
# 308   -1939. A crayfish, lizard & fly in metall made...
# 309          -1940. Hard sope from Smyrna? 216. a 19. f
# 310                 -1941. Another sort of it? 216 19 m
# 311   -1942. A piece of a vine sarment growing thro ...
# 312   -1943 A Broacha from Spain, it is a swines ski...
# 313   -1944. An India hatt made of the Lantor palm l...
# 314   -1945. A west Indian Kings crown made of the f...
# 315                         -1946. A large Javelin. 252
# 316   -1947. A necklace of small pieces of red coral...
# 317                      1948. ol. lign Sartal. citrin.
# 318                                 1949. ol. cinnamon?
# 335        1950. Ol. ex vad. arboris cinnamon? 181 67 H
# 336                       1951. __ markd 153. 181 >67 E
# 337           1952 ___ red & white on another. 181 67 F
# 338                       1953. ___ markd 967. 181 67 G
# 339                               1954. Sedimentum? 181
# 340                        1955. ___ markd 912 181 67 D
# 341                             1956. ___ 611. 181 67 D
# 342                         1957. Petroleum? 234 b 67 C
# 343                                1958. Id? 234 b 67 E
# 344                                1959. Id? 234 b 67 E
# 345                                1960. Id? 234 b 67 E
# 346                                        1961. 246. o
# 347                            1962. marked 400. 246. o
# 348                              1963. ____ 171? 246. o
# 349                                        1964. 246. o
# 350                                        1965. 246. o
# 351   1966. A coat of the runaway rebellious Negros ...
# 352                     1967. Of the same finenesse 239
# 353   1968. Britches of the same coarser as also his...
# 354   1969. His Knapsack to be carried over his shou...
# 355   1970. Pulvis, Quo Turcæ et Persæ ungues et bar...
# 356   1971. Oèl Tschai. Est Extractum foliorum Theœ,...
# 373   1972. Pur Tschai. Sin. Est Extractum foliorum ...
# 374   1973. Ho jom. Lanugo Artemisiæcu Gossypio et N...
# 375   1974. Sera (a Lock) minutissima, quales Rustic...
# 376   1975. Mercurius dulcis Sinensis. From Do. No. ...
# 377   1976. Four Pastills, or small perfumed Tapers,...
# 378             -1977. Chineshish Ink. P. 209 163 24 P.
# 379   1978. Samadri bead stones mark'd 31. P. Large ...
# 380   -1979. Sal ex aqua minerali Chiltenham. & terr...
# 381     -1980. Suffimentum Surucum. from Dr. Amman. 244
# 382   -1981. A false pink colourd pearl. for a penda...
# 383   -1982. A wooden lock & key from Devonshire giv...
# 384   -1983. A chaine made of. cherry stones. 216. c...
# 385   -1984. A busto medall like of Sr. Isaac Newton...
# 386   -1985. A busto of Sr. Isaac Newton in plaister...
# 387   -1986. A Busto of the Poet Virgil in plaister ...
# 388   -1987. A mask in plaister of Paris taken of th...
# 405   1989. A China plate whereon are enameld four s...
# 406   -1990. An earthen standish for pens ink & sand...
# 407   1991. An Instrument of painted Leather , proba...
# 408   1992. Another somewhat of ye same form, made o...
# 409   1993. An Instrument or weapon? (an for ye whal...
# 410   1994. Part of ye wood or Handle of an East Ind...
# 411   1995. A Creese, or Dagger or Poignard, the Bla...
# 412   1996. A Tobacco-pipe Boll of black Stone or ha...
# 413   1997. A Tobacco pipe Boll of grey Earth wrough...
# 414   1998. A Tobacco pipe, the Boll of red Earth sp...
# 428   1999. A Purse of brown tan'd Leather , on a fo...
# 429   2000. A Necklace, or Garter of Leather and par...
# 430   2001. An octangular plate of Crystal-Glass mar...
# 431   2002. 26. A Chinese figure in Alabaster or Pas...
# 432   2003. another Do. Sitting, with a Chaplet of B...
# 433   -2004. A larger Chinese stillyed of a black wo...
# 434   -2005. Cloath made in China of paper wove & pa...
# 435   2006. The impression of a red wax seal taken f...
# 436   2007. A turbinated small shell made into an ea...
# 437   2008. Auricules, white thorn flowers, a tulip ...
# 438   2009. A mask of Charles 2d face from Mr. Killi...
# 439                  2010. _________ , Oliver Cromwell.
# 440                   2011. Wrestlers in Plaister form.
# 456   2012. An Instrument or Whisk for cleaning Pict...
# 457   2013. A new invented weather machine from Nure...
# 458   2014. A busto of Q. Elizabeth in gold wt. a pe...
# 459   2015. An Indian apron formerly 920. made of bu...
# 460   2016. Two bustos on mother of pearle. 209 163....
# 461   2017. A modell of a wheel for ---- Dr. Hook? 2...
# 462   2018. A knife & fork the handles said to be of...
# 463   2019. A Dragon made of a rays skin from Hollan...
# 464   2020. Agards pills for the gout one pill every...
# 465   2021. A trumpet in Guinea used by the inhabita...
# 466   2022. A block of box whereon is engraved Ascyr...
# 467   2023. A spoon made of the great E. India green...
# 468   2024. ________ open mouthd Concha Persia from ...
# 469                                 2025. Another. 28 b
# 479   2026. pills famous for curing the stone an Mat...
# 480   2027. A stone said to be a bufonites but is a ...
# 481   2028. a bone boke in for the hair wt. the bust...
# 482   2029. The bole of a tobacco pipe or Calumet fr...
# 483                  2030. The same dyed yellow. C. 245
# 484          2031. Indian spoons made of shells? 216. n
# 485   2032. Glasse from the bottom of a tile limekil...
# 486   2033. An ancient Battle ax the handle in laid ...
# 487   2034. St. Hubard wt. a Stage on his horn 216 a...
# 488   2035. A pane fass h ioned piece of Iron hollow...
# 489   2036. The delf Potters Glaze being a mixture o...
# 490   2037. This was some Indian Instru= ment ye hol...
# 507   2038. The head of an arrow made of white sparr...
# 508   2039. Part of an dart arrow found in a cave in...
# 509   2040. a Cradle wt. a pair of Shoes from Hudson...
# 510   2041. A Leather , Stocking adorn'd wt. the cla...
# 511                                2042. Another. < 245
# 512       2043. A belt adorn'd wt. the same. < 245 19J.
# 513   2044. A purse made of 2 feet of 2 sorts of wat...
# 514   2045. Indian scalp from Hudsons Bay adorn'd bi...
# 515   2046. A Shovell head of oak found 40 Foot deep...
# 527     2046. & broad end from, Mr. Mason see No. 1783.
# 528   2047 6 An artificall spike of Barley in copper...
# 529   2048. Ten sevll :habits tending to the Religio...
# 530   2049 Sevll : flowers made of Shells from Cornw...
# 531   2050 A brasse plate wt. Chinese charaters W&t ...
# 532   2051. A Guinea purse stain'd wt. bars of an or...
# 533           2052. brown colour'd Plaister < 199C 19 m
# 534   2053. A piece of amber wt. a Lyon carv'd on it...
# 535   2054. The figure of Three Children carv'd in I...
# 536   2055. Mr. Dandridges white Gun-powder composed...
# 537   ?2056 A Brume made of the adiant um m aurum ma...
# 551   2057. A Hygromëter made in the Garmany in the ...
# 552   2058. A Harlequins sword the handle of wch : i...
# 553          2059 St : George in Copper. and b 26o 19 g
# 554              2060. A small silver tunnel. < 199. C.
# 555   2061. A Heart in yellow amber in wch. is this ...
# 556   2062 Silver coins eight nine pieces call Araiu...
# 557   2063. Four pieces of wt : sevll : small mark's...
# 558   2064 Round copper coins wt. square holes in th...
# 572   2064. Serves to String them by vid Navarette t...
# 573   2065. A nest of Olagans or Thirty Basketts mad...
# 574                    2066 A Chaire made of Bambo Cane
# 575   2067. 9 Pieces of Pots used by the Indians. Th...
# 590   2068. wt : the Clay. I suppose to strengthen y...
# 576   2068. Two others. This I gather'd on our sea c...
# 591   2069. A pair of Stockings of Beavers skin prep...
# 592   2070. The skin of a Martin adorn'd wt. Porcupi...
# 593   2071. Casts of sevll : medal in Plaister of Pa...
# 594   2072. Several pieces of carv'd Ivory likely ta...
# 595   2073. Part of a Necklace made of the fruit of ...
# 596   2074. Three Roman Imperiall Medals cut 199. d ...
# 597   2075. Seal & Impressions. Ancient & modern 199...
# 609   2076. Shoes of the Inhabitants of Malabar 226 ...
# 610                       2077. Mathemactical Tables.&c
# 611   2078 two pieces Glass of bottom of a Pot from ...
# 612   2079. A Preparation made of the Flesh of wild ...
# 613   2080. Bay berry soap from new England tis Mr. ...
# 614                   2081. Shell work by Miss Stanley.
# 615   2082. 2082. a Japan'd Trunck inlaid wt. Mother...
# 616   2083. A walking Cane made of Tortoise shell. w...
# 617        2084. The same made of a Ray tail. Vid Antea
# 628          2085. Spiritus ----- vid Antea. 181. 27 J.
# 629   2086. A glasse or Past made of Chalk & Clay by...
# 630   2087. N Beads or a Necklace made of the Lachry...
# 631   2088 2087 A Last made of a gray stone by the I...
# 632   2089. A Tomhawk. A Stone abt. 9 inches longer ...
# 633         2090 A piece of an Earthen or Stone Vessel.
# 634   ✓ 2091. A Tobacco Box made of ye Bark. of the ...
# 635   2092. A Hygrometer Vid Antea vid Antea of a ne...
# 645   2093. A Couching Needle wth. it its case vid. ...
# 646   2094. An obscene Chinese Fan given me by Mr. B...
# 647   2095. Starch made of Potatoes by chemical art ...
# 648   2096 An Indian Hatchet made of white sparr Fro...
# 649   2097. A piece of an ancient plaister'd Wall? M...
# 650   2098 An Ivory cane head carved wt. a Crucifix ...
# 651   2099. A very long turkish tobacco . Pipe made ...
# 652   2100. 2000 A pair of very fine embroider'd tur...
# 666   2101. A Frame containing two Medalls of the Du...
# 667   2102. Clemens XII. P. M. in Wax. framed. given...
# 668   2103. A Knitting-Needle-Case wt. a Chain to it...
# 669   2104. An Idol or Infant Jesus from Flanders Id...
# 670   2105. The Habet of the Queen of Mada= =gascar ...
# 671   2106. A Mas'k worn by the North American India...
# 684   2107. An Indian Musical Instrument made of Bam...
# 686   2108 A wooden image from Jamaica, given by Jam...
# 687   2109 An intire Electrical apparatus. Presented...
# 688   2110 A nest of twenty three Pearl Sieves broug...
# 689   2111 The Representation of a Battle cut in Vel...

# %% [markdown]
# #### Find duplicate entries

# %%
# Find duplicates
df.duplicated(subset=['num_int']).value_counts()
# Out:
# False    2109
# True       56
# dtype: int64

# %% [markdown]
# #### Print the duplicates

# %%
pd.set_option ('display.max_rows', None)
df[df.duplicated(subset=['num_int'])]
# Out:
#       num_int        num_str  \
# 21          1             1.
# 471       204           204.
# 761       385          385*.
# 762       386           386.
# 1178      396            396
# 810       427          427*.
# 940       542          -542.
# 1358      909          -909.
# 1359      910          -910.
# 1360      911          -911.
# 1361      912          -912.
# 1375      913       -913. **
# 1376      914  -914 * . 714.
# 1364      915          -915.
# 1378      916         916. *
# 1379      916        -916. *
# 1380      917        -917. *
# 1381      918        -918. *
# 1384      919        -919. *
# 1369      920           -920
# 1495     1025          1025.
# 1552     1073          1073.
# 1574     1093         -1093.
# 1962     1455         -1455.
# 2002     1492         -1492.
# 2073     1556         -1556.
# 2161     1635          -1635
# 2329     1799         -1799.
# 278      1933  1933. No. 25.
# 279      1933  1933. No. 26.
# 280      1933  1933. No. 27.
# 281      1933  1933. No. 28.
# 285      1933  1933. No. 33.
# 283      1933  1933. No. 30.
# 284      1933  1933. No. 32.
# 276      1933  1933. No. 21.
# 286      1933  1933. No. 34.
# 287      1933  1933. No. 35.
# 282      1933  1933. No. 29.
# 275      1933  1933. No. 20.
# 274      1933  1933. No. 18.
# 273      1933  1933. No. 17.
# 244      1933         -1933.
# 263      1933   1933. No. 7.
# 265      1933   1933. No. 9.
# 266      1933  1933. No. 10.
# 267      1933  1933. No. 11.
# 264      1933   1933. No. 8.
# 269      1933  1933. No. 13.
# 270      1933  1933. No. 14.
# 271      1933  1933. No. 15.
# 272      1933  1933. No. 16.
# 268      1933  1933. No. 12.
# 527      2046          2046.
# 572      2064          2064.
# 576      2068          2068.
#
#                                                  people  \
# 21                                                 None
# 471                                                None
# 761                                                None
# 762                                                None
# 1178                                               None
# 810                                                None
# 940                                                None
# 1358                                               None
# 1359    [{'id': 'Martin_Lister', 'name': 'Dr. Lister'}]
# 1360                                               None
# 1361    [{'id': 'Martin_Lister', 'name': 'Dr. Lister'}]
# 1375   [{'id': 'James_Petiver', 'name': 'Mr. Petiver'}]
# 1376                                               None
# 1364                                               None
# 1378                                               None
# 1379  [{'id': 'Mr_Stallwood', 'name': 'Mr. Stallwood'}]
# 1380           [{'id': 'James_Petiver', 'name': 'Pet'}]
# 1381                                               None
# 1384      [{'id': 'Mr_Johnson', 'name': 'Mr. Johnson'}]
# 1369                                               None
# 1495                                               None
# 1552                                               None
# 1574                                               None
# 1962                                               None
# 2002                                               None
# 2073                                               None
# 2161  [{'id': 'Nehemiah_Grew', 'name': 'Dr. Grews'},...
# 2329                                               None
# 278                                                None
# 279                                                None
# 280                                                None
# 281                                                None
# 285                                                None
# 283                                                None
# 284                                                None
# 276                                                None
# 286                                                None
# 287                                                None
# 282                                                None
# 275                                                None
# 274                                                None
# 273                                                None
# 244   [{'id': 'Mr_Alexr_Light', 'name': 'Mr. Alexr L...
# 263                                                None
# 265                                                None
# 266                                                None
# 267                                                None
# 264                                                None
# 269                                                None
# 270                                                None
# 271                                                None
# 272                                                None
# 268                                                None
# 527          [{'id': 'Mr._Mason', 'name': 'Mr. Mason'}]
# 572          [{'id': 'Navarette', 'name': 'Navarette'}]
# 576                                                None
#
#                                                  places  \
# 21                 [{'id': 'London', 'name': 'London'}]
# 471                [{'id': 'Canada', 'name': 'Canada'}]
# 761                                                None
# 762                                                None
# 1178           [{'id': 'Virginia', 'name': 'Virginia'}]
# 810                                                None
# 940                                                None
# 1358                                               None
# 1359                                               None
# 1360                                               None
# 1361                                               None
# 1375                                               None
# 1376                 [{'id': 'Spain', 'name': 'Spain'}]
# 1364                                               None
# 1378                                               None
# 1379         [{'id': 'Whitehall', 'name': 'Whitehall'}]
# 1380                                               None
# 1381                                               None
# 1384                                               None
# 1369                                               None
# 1495                                               None
# 1552                                               None
# 1574                                               None
# 1962           [{'id': 'Reculver', 'name': 'Reculver'}]
# 2002                                               None
# 2073                                               None
# 2161                                               None
# 2329                                               None
# 278                                                None
# 279                                                None
# 280                                                None
# 281                                                None
# 285                                                None
# 283                                                None
# 284                                                None
# 276                                                None
# 286                                                None
# 287                                                None
# 282                                                None
# 275                                                None
# 274                                                None
# 273                                                None
# 244   [{'id': 'Hudson_Strait', 'name': 'Hudsons stre...
# 263                                                None
# 265                                                None
# 266                                                None
# 267                                                None
# 264                                                None
# 269                                                None
# 270                                                None
# 271                                                None
# 272                                                None
# 268                                                None
# 527                                                None
# 572                                                None
# 576       [{'id': 'Susquehanna', 'name': 'Susquehama'}]
#
#                                                    text
# 21    1. A parcell of knives with bone hafts burnt i...
# 471   204. Crin d'Orignac or hair of wt. wch. dyed t...
# 761   385*. Another in a blew Jacket & yellow Hat: y...
# 762   386. Another. a Harlequin: part of ye Head bro...
# 1178  396 A black b wt. the tips of the wings scalet...
# 810   427*. A turd in wax work in a straw work'd box...
# 940   -542. pendent? the moon a Spoon & a hand in je...
# 1358  -909. Yellow glasse. made of lead ?- from the ...
# 1359  -910. Vitrum sublimatum ti. Cinna= =bar Vitrif...
# 1360  -911. Pieces of cast burning glasses from the ...
# 1361  -912. A Piece of a pott made of terra Lemnia. ...
# 1375  -913. ** Goan balls or Lapis de goan made by M...
# 1376           -914 * . 714. Red wooll. From Spain? Id.
# 1364  -915. A severall flies shrimps & lizard made o...
# 1378         916. * Tinctura anti phthisica 234 b. 67 J
# 1379  -916. * The hind part of the a head of in whit...
# 1380                -917. * Oleum Macis. Pet. 181. 67 g
# 1381  -918. * Oleum ricins purgans St. Helena. Id. 1...
# 1384  -919. * A china quadrangular stand Mr. Johnson...
# 1369  -920 An apron made of beads from the same. 244...
# 1495  1025. Explanation of the weights The german Es...
# 1552  1073. Carved figure in wood inclosed in foldin...
# 1574  -1093. A fann of a leaf of the palm Lantor , p...
# 1962  -1455. An ancient brasse head from Reculver? H...
# 2002  -1492. A plate of the same sort of china ware ...
# 2073  -1556. A tripus of tin on which it is to be pl...
# 2161  -1635 Substances remaining from Experiments of...
# 2329  -1799. A Hatt made of canes of Sev.ll colours ...
# 278   1933. No. 25. A Fosset to blow up Seal Skin wi...
# 279     1933. No. 26. The same as 20 n. 244. 28 C. S B.
# 280   1933. No. 27. An Ornament hanging at a woman's...
# 281   1933. No. 28. An Ornament for the Nose. S.B n....
# 285    1933. No. 33. For Children to play with. n. 244.
# 283               1933. No. 30. The same as 25. n. 244.
# 284   1933. No. 32. In the Paper is a stone belongin...
# 276                 1933. No. 21. Do. n. 244. 28 C. S B
# 286                      1933. No. 34. A Lance. n. 244.
# 287   1933. No. 35. The same as 29. (Cæetera non des...
# 282   1933. No. 29. An Ivory Idoll. (or Fish-Bone.) ...
# 275   1933. No. 20. A Tooth , but of what Creature I...
# 274              1933. No. 18. A Harpoon. n. 244. 28 C.
# 273   1933. No. 17. The same as no. 5. S. B. n. 244....
# 244   -1933. An Indian basket made of twiggs by the ...
# 263   1933. No. 7. A Swivell for a fishing Line. S. ...
# 265   1933. No. 9. An Ornament hanging at their brea...
# 266       1933. No. 10. A Comb. ✓ S B n. 244. 28. C S B
# 267   1933. No. 11. A Pipe, which they use in skinni...
# 264           1933. No. 8. The same. S. B n. 244. 28. C
# 269   1933. No. 13. A sort of Button on their breast...
# 270   1933. No. 14. made fast to the fishing Lines. ...
# 271   1933. No. 15. A Harpoon sheath'd with wood, fo...
# 272   1933. No. 16. An Ornament for the breast. n. 2...
# 268   1933. No. 12. The butt-end of a Harpoon Staff....
# 527     2046. & broad end from, Mr. Mason see No. 1783.
# 572   2064. Serves to String them by vid Navarette t...
# 576   2068. Two others. This I gather'd on our sea c...

# %% [markdown]
# #### Now let's look at people

# %%
# Find all mentions of people
[x for x in df.explode('people')['people'] if x]
# Out:
# [{'id': 'Mr._Amyand', 'name': 'Mr. Amyand'},
#  {'id': 'James_Theobalds_Esqr', 'name': 'Mr. Theobalds'},
#  {'id': 'Mr_Roberts', 'name': 'Mr. Roberts'},
#  {'id': 'MrMC', 'name': 'Mr. Mc. Cormick'},
#  {'id': 'Alexander_Stuart', 'name': 'Dr. Stuart'},
#  {'id': 'MrMC', 'name': 'Mr. Mc. Cormick'},
#  {'id': 'Mr._Hodson', 'name': 'Mr. Hodsun'},
#  {'id': 'Mr._Launce', 'name': 'Mr. Launce'},
#  {'id': 'Jean_De_Fontaney', 'name': 'father Fontenay'},
#  {'id': 'James_Cunningham', 'name': 'Mr. Cunningham'},
#  {'id': 'Daniel_Waldo', 'name': 'Dr. Waldo'},
#  {'id': 'Capt_Walker', 'name': 'Capt. Walker'},
#  {'id': 'Capt_Walker', 'name': 'Capt. Walker'},
#  {'id': 'Isaac_Waldron_Esqr', 'name': 'Isaac Waldron Esqr'},
#  {'id': 'Abraham_Waldron', 'name': 'Abraham Waldron'},
#  {'id': 'William_Courten', 'name': 'Mr. Courtens'},
#  {'id': 'George_Edwards, Mr._Edwards', 'name': 'Mr. Edwards'},
#  {'id': 'Richard_Middleton_Massey', 'name': 'Dr. Massy'},
#  {'id': 'George_Edwards, Mr._Edwards', 'name': 'Mr. Edwards'},
#  {'id': 'Peter_Collinson', 'name': 'Mr. Collinson'},
#  {'id': 'Matthew_Gosset', 'name': 'Monsr. Gosset'},
#  {'id': 'Cromwell_Mortimer', 'name': 'Dr. Mortimer'},
#  {'id': 'Mr._Gordon', 'name': 'Mr. Gordon'},
#  {'id': 'Richard_Middleton_Massey', 'name': 'Dr. Massy'},
#  {'id': 'Dr_Douce', 'name': 'Dr. Douce'},
#  {'id': 'Duke_of_Bourbon', 'name': 'Duke of Bourbons'},
#  {'id': 'Philip_2nd_of_Spain', 'name': 'Philip. 2d'},
#  {'id': 'Mrs_Edwards, Mrs._Edwards', 'name': 'Mrs. Edwards'},
#  {'id': 'Hans_Sloane', 'name': 'Sr. Hans'},
#  {'id': 'J_Empson', 'name': 'J Empson'},
#  {'id': 'Lord_Sondes', 'name': 'Ld Sondes'},
#  {'id': 'Christian_Zincke', 'name': 'Mr. Zink'},
#  {'id': 'Lady_Sondes', 'name': 'Lady Sondes'},
#  {'id': 'Hans_Sloane', 'name': 'Sr. Hans'},
#  {'id': 'Robert_Southwell', 'name': 'Mr. Southwell'},
#  {'id': 'Mr_Styleman', 'name': 'Mr. Styleman'},
#  {'id': 'Mr._Bell', 'name': 'Mr. Bell'},
#  {'id': 'Capt_Christopher_Middleton', 'name': 'Capt. Midleton.'},
#  {'id': 'Mr_Hoofnail', 'name': 'Mr. Hoofnail'},
#  {'id': 'Mrs_Hepheshebah_Parker', 'name': 'Mrs. Hepheshebah Parker'},
#  {'id': 'Dr_Labe', 'name': 'Dr. Labe'},
#  {'id': 'Mrs_Stephens', 'name': 'Mrs. Stephens'},
#  {'id': 'James_Petiver', 'name': 'Pet.'},
#  {'id': 'David_Krieg', 'name': 'Dr. Krieg'},
#  {'id': 'James_Cunningham', 'name': 'Mr.- Cunningham'},
#  {'id': 'Mr._Pycolas', 'name': 'Mr. Pycolas'},
#  {'id': 'Vale_Vicor', 'name': 'Vale. Vicor'},
#  {'id': 'Moses', 'name': 'Marcus Moses'},
#  {'id': 'James_Petiver', 'name': 'Pet'},
#  {'id': 'Richard_Middleton_Massey', 'name': 'Dr. Massy'},
#  {'id': 'Mr_Collier', 'name': 'Mr. Collier'},
#  {'id': 'Dr_Douce', 'name': 'Dr. Douce'},
#  {'id': 'Mr_Alexr_Light', 'name': 'Mr. Alexr Light'},
#  {'id': 'Mrs_Bernard', 'name': 'Mrs. Bernard'},
#  {'id': 'Mrs_Hayes', 'name': 'Mrs. Hayes'},
#  {'id': 'Daniel_Waldo', 'name': 'Dr. Waldo'},
#  {'id': 'Mr_Lapthorn', 'name': 'Mr. Lapthorn'},
#  {'id': 'Mr_Lapthorn', 'name': 'Mr. Lapthorn'},
#  {'id': 'Jean_De_Fontaney', 'name': 'Father Fontenay'},
#  {'id': 'Mr_Doyly', 'name': 'Mr. Doyly'},
#  {'id': 'Capt_Christopher_Middleton', 'name': 'Capt Christophr. Middleton'},
#  {'id': 'Mr._Bewley', 'name': 'Mr. Bewley'},
#  {'id': 'Rene_Reaumur', 'name': 'Mr. Reaumur'},
#  {'id': 'Philip_Miller', 'name': 'Mr. Millar'},
#  {'id': 'Johann_Amman', 'name': 'Dr. Amman'},
#  {'id': 'Johann_Amman', 'name': 'Dr. Amman'},
#  {'id': 'Cromwell_Mortimer', 'name': 'Dr. Mortimer'},
#  {'id': 'Mr_Padmore', 'name': 'Mr. Padmore'},
#  {'id': 'Isaac_Newton', 'name': 'Sr. Isaac Newton'},
#  {'id': 'Batty_Langley', 'name': 'Mr. Batty Langley'},
#  {'id': 'Matthew_Maty', 'name': 'Dr. Maty'},
#  {'id': 'Isaac_Newton', 'name': 'Sr. Isaac Newton'},
#  {'id': 'Charles_Morton', 'name': 'Dr. Morton'},
#  {'id': 'Charles_II', 'name': 'King Charles 2d'},
#  {'id': 'Mr_Killegrew', 'name': 'Kilegrew'},
#  {'id': 'Matthew_Maty', 'name': 'Dr. Maty'},
#  {'id': 'Francois_Duquesnoy', 'name': 'Francisco Fiamengo'},
#  {'id': 'Mr._Beddevoles', 'name': 'Mr. Beddevoles'},
#  {'id': 'Mr._Marshall', 'name': 'Mr. Marshall'},
#  {'id': 'James_Wilson', 'name': 'Mr. Wilson'},
#  {'id': 'John_Melling', 'name': 'Mr. Mellin'},
#  {'id': 'Johannes_van_Musschenbroek', 'name': 'Mr. Musschenbroock'},
#  {'id': 'King3', 'name': 'Prince of Orange'},
#  {'id': 'Mr_Desmarets', 'name': 'Mr. Desmarets'},
#  {'id': 'William_Bentinck', 'name': 'Mr. Bentinck'},
#  {'id': 'King_James_2nd, King_James', 'name': 'K. James'},
#  {'id': 'Francis_Hauksbee', 'name': 'Mr. Hawksbee'},
#  {'id': 'Arthur_Charlett', 'name': 'Dr. Charlett'},
#  {'id': 'John_Pinfold', 'name': 'Mr. Pinfold'},
#  {'id': 'Giuseppe_Campani', 'name': 'Campani'},
#  {'id': 'Mr_Lenoy', 'name': 'Mr. Lenoy'},
#  {'id': 'Mr_Haynes', 'name': 'Mr. Haynes'},
#  {'id': 'Mrs._Waters', 'name': 'Mrs. Waters'},
#  {'id': 'Charles_II', 'name': 'Charles 2d'},
#  {'id': 'Mr_Killegrew', 'name': 'Mr. Killigrew'},
#  {'id': 'Oliver_Cromwell', 'name': 'Oliver Cromwell'},
#  {'id': 'James_Wilson', 'name': 'Mr. Wilson'},
#  {'id': 'Stephen_Gray', 'name': 'Mr. Ste Gray'},
#  {'id': 'Gio_Bapt_Verle', 'name': 'Verle'},
#  {'id': 'Mr_Villarmont', 'name': 'Mr. Villarmont'},
#  {'id': 'Queen_Elizabeth_I', 'name': 'Q. Elizabeth'},
#  {'id': 'Robert_Hooke', 'name': 'Dr. Hook'},
#  {'id': 'Mr._Adams', 'name': 'Mr. Adams'},
#  {'id': 'John_Ranby', 'name': 'Mr. Ranby'},
#  {'id': 'Thomas_Stack', 'name': 'Dr. Stack'},
#  {'id': 'Mr_Paine', 'name': 'Mr. Paine'},
#  {'id': 'John_Bartram', 'name': 'Dr. Bartram'},
#  {'id': 'James_Cunningham', 'name': 'Mr. Cunning = =ham'},
#  {'id': 'John_Bartram', 'name': 'Dr. Bartram'},
#  {'id': 'Mr._Cotts', 'name': 'Mr. Cotts'},
#  {'id': 'Mr_Handisyd', 'name': 'Mr. Handisyd'},
#  {'id': 'Mr_Handisyde', 'name': 'Mr. Handisyde'},
#  {'id': 'Mr._Mason', 'name': 'Mr. Mason'},
#  {'id': 'Mrs_Edwards, Mrs._Edwards', 'name': 'Mrs. Edwards'},
#  {'id': 'George_Bell', 'name': 'Mr Bell'},
#  {'id': 'Mr._Dandridge', 'name': 'Mr. Dandridge'},
#  {'id': 'Capt_Hebden_', 'name': 'Capt: Hebden'},
#  {'id': 'Charles_I', 'name': 'King Charles'},
#  {'id': 'William_Courten', 'name': 'Mr. Courtens'},
#  {'id': 'Navarette', 'name': 'Navarette'},
#  {'id': 'Capt_Christopher_Middleton', 'name': 'Capt : Middleton'},
#  {'id': 'John_Bartram', 'name': 'Mr. Bartram'},
#  {'id': 'Robert_Hooke', 'name': 'Dr. Hook'},
#  {'id': 'Jean_De_Fontaney', 'name': 'Fa. Fountenay'},
#  {'id': 'Mr_Wright', 'name': 'Mr. Wright'},
#  {'id': 'Mr_Seregold', 'name': 'Mr. Seregold'},
#  {'id': 'James_Cunningham', 'name': 'Mr. Cunningham'},
#  {'id': 'John_Winthrop', 'name': 'Mr. Winthorp'},
#  {'id': 'Miss_Stanley', 'name': 'Miss Stanley'},
#  {'id': 'Patrick_Adair', 'name': 'Dr. Adair'},
#  {'id': 'Joannes_Henricus_Hampe', 'name': 'Dr. Hamp'},
#  {'id': 'Mr_Wildy', 'name': 'Mr. Wildy'},
#  {'id': 'Patrick_Adair', 'name': 'Dr. Adair'},
#  {'id': 'Mr._Bell', 'name': 'Mr. Bell'},
#  {'id': 'Joannes_Henricus_Hampe', 'name': 'Dr. Hampe'},
#  {'id': 'Mr._Clark', 'name': 'Mr. Clark'},
#  {'id': 'Thomas_Stack', 'name': 'Dr. Stack'},
#  {'id': '_Mr_Brown', 'name': 'Mr. Brown'},
#  {'id': 'Duke_of_Cumberland', 'name': 'Duke of Cumberland'},
#  {'id': 'Isaac_Newton', 'name': 'Sr. Isaac Newton'},
#  {'id': 'Pope_Alexander_VIII', 'name': 'Pope Alexander VIII'},
#  {'id': 'John_Jackson', 'name': 'Mr. John Jackson'},
#  {'id': 'Isaac_Newton', 'name': 'Sr. Isaac Newton'},
#  {'id': 'Pope_Clement_XII', 'name': 'Clemens XII'},
#  {'id': 'Mr_Scott', 'name': 'Mr. Scott'},
#  {'id': 'Mr_Hawkeens', 'name': 'Mr. Hawkeens'},
#  {'id': 'Mr_Fairweather', 'name': 'Mr. Fairweather'},
#  {'id': 'George_Edwards', 'name': 'Mr. Geo Edwards'},
#  {'id': 'Mr_Maidstone, Mr._Maidstone', 'name': 'Mr. Maidstone'},
#  {'id': 'James_Theobalds_Esqr', 'name': 'James Theobalds'},
#  {'id': 'William_Watson', 'name': 'Mr. William Watson'},
#  {'id': 'Charles_II', 'name': 'King Charles the Second'},
#  {'id': 'William_Hanbury, William_Hanbury', 'name': 'Willm. Hanbury Esqr'},
#  {'id': 'Jean_Huber', 'name': 'Mr. Hubert'},
#  {'id': 'Duke_of_Grafton', 'name': 'Duke of Graffton'},
#  {'id': 'Jean_De_Fontaney', 'name': 'Father Fontaney'},
#  {'id': 'Frederick_Slare', 'name': 'Dr. Slare'},
#  {'id': 'John_Conyers', 'name': 'Mr. Conyers'},
#  {'id': 'Robert_Boyle', 'name': 'Mr. Boyle'},
#  {'id': 'Robert_Hooke', 'name': 'Dr. Hook'},
#  {'id': 'Caspar_Antonio', 'name': 'Gaspard Antonio'},
#  {'id': 'Robert_Hooke', 'name': 'Dr. Hook'},
#  {'id': 'William_von_Schroder', 'name': 'monsr. Schroter'},
#  {'id': 'Robert_Moray', 'name': 'S r. Rob. Moray'},
#  {'id': 'Lord_Colerane', 'name': 'Lord Coler= =ane'},
#  {'id': 'William_Courten', 'name': 'Mr. Courten'},
#  {'id': 'Robert_Hooke', 'name': 'Dr. Hook'},
#  {'id': 'Monsr_Villette', 'name': 'Monsr. Villette'},
#  {'id': 'Pierre_Silvestre', 'name': 'Dr. Silvestre'},
#  {'id': 'Mr._Staphorst', 'name': 'Staphorst'},
#  {'id': 'James_Petiver', 'name': 'Mr. Petiver'},
#  {'id': 'Father_Visdelon', 'name': 'Father Visdelon'},
#  {'id': 'Beauvilliers', 'name': 'Beauvilliers'},
#  {'id': 'Lady_Kent', 'name': 'Lady Kent'},
#  {'id': 'Mr_Carmichael', 'name': 'Mr. Carmichael'},
#  {'id': 'William_Sherard', 'name': 'Dr. Sherard'},
#  {'id': 'Charles_Leigh', 'name': 'Dr. Leigh'},
#  {'id': 'Patrick_Adair', 'name': 'Dr. Adair'},
#  {'id': 'Patrick_Adair', 'name': 'Dr. Adair'},
#  {'id': 'James_Cunningham', 'name': 'Mr. Cunningham'},
#  {'id': 'Robert_Hooke', 'name': 'Dr. Hook'},
#  {'id': 'Jean_De_Fontaney', 'name': 'Father Fontaney'},
#  {'id': 'Dampier', 'name': 'Mr. Dampier'},
#  {'id': 'John_Conyers', 'name': 'Mr. Conyers'},
#  {'id': 'Alexander_Stuart', 'name': 'Dr. Stuart'},
#  {'id': 'Alexander_Stuart', 'name': 'Dr. Stuart'},
#  {'id': 'Charles_Montagu', 'name': 'Lord Halifax'},
#  {'id': 'Duke_Marlborough', 'name': 'Duke of Marlborough'},
#  {'id': 'Mr_Robert_Walker', 'name': 'Mr. Robert Walker'},
#  {'id': 'Colonel_Laws', 'name': 'Coll. Laws'},
#  {'id': 'Mrs_Sadler', 'name': 'Mrs. Sadler'},
#  {'id': 'Mr_Gore', 'name': 'Mr. Gore'},
#  {'id': 'Mr_Orchard', 'name': 'Mr. Orchard'},
#  {'id': 'John_Pinfold', 'name': 'Mr. Pinfold'},
#  {'id': 'Patrick_Adair', 'name': 'Dr. Adair'},
#  {'id': 'Edmund_Chishull', 'name': 'Mr. Chichele'},
#  {'id': 'Mr_Middleton', 'name': 'Mr. Middleton'},
#  {'id': 'Sir_Charles_Wager', 'name': 'Sr. Charles Wager'},
#  {'id': 'Richard_Mead', 'name': 'Dr. Mead'},
#  {'id': 'Mr_Bernard', 'name': 'Mr. Bernard'},
#  {'id': 'Alexander_Brown', 'name': 'Alexr. Brown'},
#  {'id': 'Mr_Maidstone, Mr._Maidstone', 'name': 'Mr. Maidstone'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Brown'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Brown'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Brown'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Brown'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Brown'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Br'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Brown'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Brown'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Brown'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Brown'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Brown'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Brown'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Brown'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Br'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Brown'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Brown'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Br'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Br'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Br'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Brown'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Brown'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Brown'},
#  {'id': 'Alexander_Brown', 'name': 'Alex. Brown'},
#  {'id': 'Alexander_Brown', 'name': 'Mr. Alexr. Brown'},
#  {'id': 'Alexander_Brown', 'name': 'Alexr. Brown'},
#  {'id': 'Alexander_Brown', 'name': 'Al. Br.'},
#  {'id': 'Alexander_Brown', 'name': 'Al. Br.'},
#  {'id': 'Alexander_Brown', 'name': 'AL B.'},
#  {'id': 'Alexander_Brown', 'name': 'Alexr. Br.'},
#  {'id': 'Alexander_Brown', 'name': 'Al. Br.'},
#  {'id': 'James_Wilson', 'name': 'Mr. Wilson'},
#  {'id': 'Alexander_Brown', 'name': 'Alexr. Brown'},
#  {'id': 'James_Wilson', 'name': 'Mr. Wilson'},
#  {'id': 'Hoffsted_van_Essen', 'name': 'Hoffsted van Essen'},
#  {'id': 'Alexander_Brown', 'name': 'Alexr. Brown'},
#  {'id': 'Alexander_Brown', 'name': 'Alexr. Brown'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Br.'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Brown'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Brown'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Br'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Br.'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Br'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Br'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Br'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Br'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Br'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Brown'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Br'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Br'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Br.'},
#  {'id': 'Mrrown', 'name': 'Mr. S. Br.'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Br.'},
#  {'id': 'Dr_Browne', 'name': 'Dr. Browne'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Brown'},
#  {'id': 'George_Cheyne', 'name': 'Dr. Cheyne'},
#  {'id': 'Dr._Brown', 'name': 'Dr. Brown'},
#  {'id': 'Dr_Groenfield', 'name': 'Dr. Groenfield'},
#  {'id': 'James_Petiver', 'name': 'Mr. Petiver'},
#  {'id': 'Mr_Hodges', 'name': 'Mr. Hodges'},
#  {'id': 'Mr_James', 'name': 'Mr. James'},
#  {'id': 'Ambrose_Godfrey-Hanckwitz', 'name': 'Mr. Godfrey'},
#  {'id': 'Joy', 'name': 'Joys'},
#  {'id': 'William_Dunker', 'name': 'Mr. Wm. Dunker'},
#  {'id': 'John_Rawdon', 'name': 'Sr. John Ra'},
#  {'id': 'Mr_Maidstone, Mr._Maidstone', 'name': 'Mr. Maidstone'},
#  {'id': 'Patrick_Adair', 'name': 'Dr. Adair'},
#  {'id': 'Hans_Holbein', 'name': 'Holbein'},
#  {'id': 'Queen_Elizabeth_I', 'name': 'Queen Eliz= =abeth'},
#  {'id': 'Martha_Cooper', 'name': 'Martha Cooper'},
#  {'id': 'William_Courten', 'name': 'Sr. Wm. Courtens'},
#  {'id': 'Sr_Streynsham_Masters', 'name': 'Sr. Streynsham Masters'},
#  {'id': 'Thomas_Tennison', 'name': 'Archbishop of Canterbury'},
#  {'id': 'Duke_of_Monmouth', 'name': 'Duke of Monmouth'},
#  {'id': 'Thomas_Tennison',
#   'name': 'Thomas Tennison Lord. Archbishop of Canter= bury'},
#  {'id': 'Caspar_Antonio', 'name': 'Caspar Antonio'},
#  {'id': 'Dr._Hobbs', 'name': 'Dr. Hobbs'},
#  {'id': 'Mr._Homberg', 'name': 'Mr. Homberg'},
#  {'id': 'Claude_Geoffroy1', 'name': 'Mr. Geoffroy'},
#  {'id': 'Mr._Robinson', 'name': 'Mr. Robinson'},
#  {'id': 'Daniel_Waldo', 'name': 'Dr. Waldo'},
#  {'id': 'Gilbert_Heathcote', 'name': 'Mr. Heathcote'},
#  {'id': 'Gilbert_Heathcote', 'name': 'Mr. Heathcote'},
#  {'id': 'Nicolas_Waites', 'name': 'Sr. Nicolas Waite'},
#  {'id': 'Daniel_Waldo', 'name': 'Dr. Waldo'},
#  {'id': 'Daniel_Waldo', 'name': 'Dr. Waldo'},
#  {'id': 'Daniel_Waldo', 'name': 'Dr. Waldo'},
#  {'id': 'Daniel_Waldo', 'name': 'Dr. Waldo'},
#  {'id': 'Gilbert_Heathcote', 'name': 'Mr. Heathcote'},
#  {'id': 'Daniel_Waldo', 'name': 'Dr. Waldo'},
#  {'id': 'Jean_Rodoplhe_Lavater, Dr._Lavater', 'name': 'Dr. Lavater'},
#  {'id': 'Mr_Burnett', 'name': 'Mr. Burnett'},
#  {'id': 'Mr._Cowper', 'name': 'Mr. Cowper'},
#  {'id': 'Francis_Aston', 'name': 'Mr. Aston'},
#  {'id': 'Jean_Rodolphe_Perronet', 'name': 'Mr. Perronet'},
#  {'id': 'Mr_Gilberts', 'name': 'Mr. Gilberts'},
#  {'id': 'Martin_Lister', 'name': 'Dr. Lister'},
#  {'id': 'William_Cowper2', 'name': 'Wm. Lord Cowper'},
#  {'id': 'Robert_Harley', 'name': 'Earl of Oxford'},
#  {'id': 'Mr_Roberts', 'name': 'Mr. Roberts'},
#  {'id': 'Albertus_Seba', 'name': 'Albertus Seba'},
#  {'id': 'Martin_Lister', 'name': 'Dr. Lister'},
#  {'id': 'Martin_Lister', 'name': 'Dr. Lister'},
#  {'id': 'Martin_Lister', 'name': 'Dr. Lister'},
#  {'id': 'Johann_Georg_Steigertahl', 'name': 'Dr. Steigertahl'},
#  {'id': 'Mrs._Trenchfield', 'name': 'Mrs. Trenchfield'},
#  {'id': 'James_Petiver', 'name': 'Mr. Petiver'},
#  {'id': 'Gilbert_Heathcote', 'name': 'Mr. Heathcote'},
#  {'id': 'James_Petiver', 'name': 'Mr. Petiver'},
#  {'id': 'James_Petiver', 'name': 'Mr. Petiver'},
#  {'id': 'Mr._Moults', 'name': 'Mr. Moults'},
#  {'id': 'Mr_Stallwood', 'name': 'Mr. Stallwood'},
#  {'id': 'James_Petiver', 'name': 'Pet'},
#  {'id': 'Mr_Johnson', 'name': 'Mr. Johnson'},
#  {'id': 'Mr._Ott', 'name': 'Mr. Ott'},
#  {'id': 'James_Petiver', 'name': 'Pet'},
#  {'id': 'James_Petiver', 'name': 'Pet'},
#  {'id': 'Charles_Cadogan', 'name': 'Ld Cadogan'},
#  {'id': 'James_Petiver', 'name': 'Pet'},
#  {'id': 'Joy', 'name': 'Joy'},
#  {'id': 'James_Petiver', 'name': 'Pet'},
#  {'id': 'James_Petiver', 'name': 'James Petiver'},
#  {'id': 'Mr_Alsop', 'name': 'Mr. Alsop'},
#  {'id': 'James_Petiver', 'name': 'Pet'},
#  {'id': 'James_Petiver', 'name': 'Pet.'},
#  {'id': 'James_Petiver', 'name': 'Pet'},
#  {'id': 'John_Bagford', 'name': 'Bagford'},
#  {'id': 'James_Petiver', 'name': 'Pet'},
#  {'id': 'James_Petiver', 'name': 'Pet.'},
#  {'id': 'James_Petiver', 'name': 'Pet'},
#  {'id': 'Thomas_Simon', 'name': 'Symmonds'},
#  {'id': 'Riley', 'name': 'Riley'},
#  {'id': 'Mrs_Byde', 'name': 'Mrs. Byde'},
#  {'id': 'Frederick_Slare', 'name': 'Dr. Slare'},
#  {'id': 'George_Harris', 'name': 'George Harris'},
#  {'id': 'James_Petiver', 'name': 'Pet'},
#  {'id': 'Prince_of_Hesse', 'name': 'prince of Hesses'},
#  {'id': 'John_Conduitt', 'name': 'Mr. Conduit'},
#  {'id': 'Baron_Botmar', 'name': 'Baron Botmar'},
#  {'id': 'Johann_Georg_Steigertahl', 'name': 'Dr. Steigertahl'},
#  {'id': 'Duke_of_Chandos', 'name': 'Duke of Chandois'},
#  {'id': 'John_Conduitt', 'name': 'Mr. Conduit'},
#  {'id': 'Dr_Bokelman', 'name': 'Dr. Bokelman'},
#  {'id': 'Dr_Bokelman', 'name': 'Dr. Bokelman'},
#  {'id': 'Mrs_Heathcote', 'name': 'Mrs. Heathcotes'},
#  {'id': 'Mr._Serocold', 'name': 'Mr. Serocold'},
#  {'id': 'HenrySr.', 'name': 'Mr. Barham'},
#  {'id': 'Richard_Middleton_Massey', 'name': 'Dr. Massy'},
#  {'id': 'Elihu_Yale', 'name': 'Mr. Yale'},
#  {'id': 'Robert_Houston', 'name': 'Dr. Houston'},
#  {'id': 'Elihu_Yale', 'name': 'Yale'},
#  {'id': 'Mr_Van_Mildert', 'name': 'Mr. van Mildert'},
#  {'id': 'Mr_Harvey', 'name': 'Mr. Harvey'},
#  {'id': 'Dr._Kempfer', 'name': 'Dr. Kempfer'},
#  {'id': 'Johann_Georg_Steigertahl', 'name': 'Dr. Steigertahl'},
#  {'id': 'Dr._Kempfer', 'name': 'Dr. Kempfer'},
#  {'id': 'Dr._Kempfer', 'name': 'Kempfer'},
#  {'id': 'Abraham_Cyprianus', 'name': 'Dr. Cyprianus'},
#  {'id': 'Dr._Kempfer', 'name': 'Dr. Kempfer'},
#  {'id': 'Mr._Hill', 'name': 'Mr. Hill'},
#  {'id': 'Mr_Dupuys', 'name': 'Mr. Dupuys'},
#  {'id': 'John_Covel', 'name': 'Dr. Covell'},
#  {'id': 'Mr_Dupuys', 'name': 'Mr. Dupuys'},
#  {'id': 'John_Covel', 'name': 'Dr. Covell'},
#  {'id': 'Mr_Dupuys', 'name': 'Mr. Dupuys'},
#  {'id': 'Mrs_Astall', 'name': 'Mrs. Astall'},
#  {'id': 'Mr_Dupuys', 'name': 'Mr. Dupuys'},
#  {'id': 'Mr_Dupuys', 'name': 'Mr. Dupuys'},
#  {'id': 'Caspar_Antonio', 'name': 'Caspar Antonio'},
#  {'id': 'John_Covel', 'name': 'Dr. Covell'},
#  {'id': 'Mr._Bell', 'name': 'Mr. Bell'},
#  {'id': 'Mr._Bell', 'name': 'Mr. Bell'},
#  {'id': 'Mr._Bell', 'name': 'Mr. Bell'},
#  {'id': 'Gio_Bapt_Verle', 'name': 'Gio. Bapt. Verle'},
#  {'id': 'Dr._Kempfer', 'name': 'Dr. Kempfer'},
#  {'id': 'Dr._Kempfer', 'name': 'Dr. Kempfer'},
#  {'id': 'Dr._Kempfer', 'name': 'Dr. Kempfer'},
#  {'id': 'Dr._Kempfer', 'name': 'Dr. Kempfer'},
#  {'id': 'Edward_Hawkins', 'name': 'Mr. Hawkins'},
#  {'id': 'King3', 'name': 'King William the 3d'},
#  {'id': 'George_I', 'name': 'King George ye 1st'},
#  {'id': 'Lady_Darlington', 'name': 'Lady Darlington'},
#  {'id': 'Benjamin_Franklin', 'name': 'Mr. Franklin'},
#  {'id': 'Mark_Catesby', 'name': 'Mr. Catesby'},
#  {'id': 'Claude_Geoffroy1', 'name': 'Mr. Geoffroy'},
#  {'id': 'Benjamin_Franklin', 'name': 'Mr. Francklyn'},
#  {'id': 'Mr._Hennepin', 'name': 'Mr. Hennepin'},
#  {'id': 'Francis_Nicholson', 'name': 'Coll. Nicholson'},
#  {'id': 'Robert_Houston', 'name': 'Dr. Houston'},
#  {'id': 'James_Theobalds_Esqr', 'name': 'Mr. Theobalds'},
#  {'id': 'Francis_Nicholson', 'name': 'Coll. Nicholson'},
#  {'id': 'Nicolas_Waites', 'name': 'Sr. Nicholas Waite'},
#  {'id': 'Dr._Kempfer', 'name': 'Dr. Kempfer'},
#  {'id': 'James_Theobalds_Esqr', 'name': 'Mr. Theobalds'},
#  {'id': 'Johann_Georg_Steigertahl', 'name': 'Dr Steigertahl'},
#  {'id': 'JohnFul', 'name': 'Mr. Fuller'},
#  {'id': 'Mr._Campbell', 'name': 'Mr. Campbell'},
#  {'id': 'John_Covel', 'name': 'Dr. Covell'},
#  {'id': 'Roger_Gale', 'name': 'Mr. Gale'},
#  {'id': 'Baron_Rostgard', 'name': 'Baron Rostgards'},
#  {'id': 'John_Covel', 'name': 'Dr. Covell.'},
#  {'id': 'William_Courten', 'name': 'Mr. Courten'},
#  {'id': 'Mr_Skinner', 'name': 'Mr. Skinner'},
#  {'id': 'Charles_Lockyer', 'name': 'Mr. Lockyer'},
#  {'id': 'Dr_Hubbert', 'name': 'Dr. Hubbert'},
#  {'id': 'Dr_Hubbert', 'name': 'Dr. Hubert'},
#  {'id': 'Mr_Elking', 'name': 'Mr. Elking'},
#  {'id': 'Thomas_Pitt', 'name': 'Mr. Pitt'},
#  {'id': 'Cromwell_Mortimer', 'name': 'Dr. Mortimer'},
#  {'id': 'Mr._Harris', 'name': 'Mr. Harris'},
#  {'id': 'Dr_Burnett', 'name': 'Dr. Burnett'},
#  {'id': 'Roger_Gale', 'name': 'Mr. Gale'},
#  {'id': 'Dr_Hoffman', 'name': 'Dr. Hoffman'},
#  {'id': 'Henry_Plumptre', 'name': 'Dr. Plumptree'},
#  {'id': 'Mr_John_Heathcote', 'name': 'Mr. John Heathcote'},
#  {'id': 'Mrs_Shepherd', 'name': 'Mrs. Shepherd'},
#  {'id': 'Mr._Clerk', 'name': 'Mr. Clerk'},
#  {'id': 'Mrs_Dering, Mrs._Dering', 'name': 'Mrs. Dering'},
#  {'id': 'Mr._Clerk', 'name': 'Mr. Clerk'},
#  {'id': 'Governor_Bennet', 'name': 'governor Bennet'},
#  {'id': 'Mr._Bell', 'name': 'Mr. Bell'},
#  {'id': 'Mr_Elking', 'name': 'Mr. Elking'},
#  {'id': 'Mr._Clerk', 'name': 'Mr. Clerk'},
#  {'id': 'Dr_Varin', 'name': 'Dr. Varin'},
#  {'id': 'Mr_Fabre', 'name': 'Mr. Fabre'},
#  {'id': 'Mr_Padmore', 'name': 'Mr. PBadmore'},
#  {'id': 'James_Petiver', 'name': 'Pet'},
#  {'id': 'James_Wilson', 'name': 'Mr. Wilson'},
#  {'id': 'Mr_Lyell', 'name': 'Mr. Lyell'},
#  {'id': 'D_Woodward', 'name': 'Dr. Woodwards'},
#  {'id': 'Edmund_Chishull', 'name': 'Mr. Chishull'},
#  {'id': 'D_Woodward', 'name': 'Dr. Woodwd'},
#  {'id': 'Mrs_Smith', 'name': 'Mrs. Smith'},
#  {'id': 'James_Petiver', 'name': 'Mr. Petiver'},
#  {'id': 'James_Petiver', 'name': 'Mr. Petiver'},
#  {'id': 'Mr_Walduck', 'name': 'Mr. Walduck'},
#  {'id': 'James_Petiver', 'name': 'Pet'},
#  {'id': 'James_Petiver', 'name': 'Pet'},
#  {'id': 'James_Petiver', 'name': 'Pet'},
#  {'id': 'Mr_Standish', 'name': 'Mr. Standish'},
#  {'id': 'James_Petiver', 'name': 'Pet'},
#  {'id': 'Capt_Walduck', 'name': 'Capt. Walduck'},
#  {'id': 'James_Petiver', 'name': 'Pet.'},
#  {'id': 'John_Ranby', 'name': 'Mr. Ranby'},
#  {'id': 'Mr._Barrets', 'name': 'Mr. Barrets'},
#  {'id': 'John_Ranby', 'name': 'Mr. Ranby'},
#  {'id': 'Daniel_Waldo', 'name': 'Dr. Waldo'},
#  {'id': 'Mr._Dering', 'name': 'Mr. Dering'},
#  {'id': 'Daniel_Waldo', 'name': 'Dr. Waldo'},
#  {'id': 'Mr._Jones', 'name': 'Mr. Jones'},
#  {'id': 'Thomas_Knowlton', 'name': 'Mr. Knowlton'},
#  {'id': 'John_Ranby', 'name': 'Mr. Ranby'},
#  {'id': 'Mr_Maidstone, Mr._Maidstone', 'name': 'Mr. Maidstone'},
#  {'id': 'Duke_of_Argyle', 'name': 'Duke of Argyle'},
#  {'id': 'Mr_Maidstone', 'name': 'Mr. Maidston'},
#  {'id': 'Queen_Anne', 'name': 'Q. Anne'},
#  {'id': 'Robert_Southwell', 'name': 'Mr. Southwell'},
#  {'id': 'Mr_Maidstone, Mr._Maidstone', 'name': 'Mr. Maidstone'},
#  {'id': 'Mr_Purnell', 'name': 'Mr. Purnell'},
#  {'id': 'Mr_Maidstone', 'name': 'Mr. Maidston'},
#  {'id': 'John_Thomas_Woolhouse', 'name': 'Mr. Woolhouse'},
#  {'id': 'Dr._Mausafia', 'name': 'Dr. Mausafia'},
#  {'id': 'Dr_Battely', 'name': 'Dr. Battely'},
#  {'id': 'Mr_Nichols', 'name': 'Mr. Nichols'},
#  {'id': 'Mrs_Steigertahl', 'name': 'Mrs. Steigertahl'},
#  {'id': 'Paul_Lucas', 'name': 'Paul Lucas'},
#  {'id': 'Charles_Lennox_Duke_of_Richmond, James_Stuart_Duke_of_Richmond',
#   'name': 'Duke of Richmond'},
#  {'id': 'Ambrose_Godfrey-Hanckwitz', 'name': 'Mr. Godfry'},
#  {'id': 'Ambrose_Godfrey-Hanckwitz', 'name': 'Mr. Godfry'},
#  {'id': 'Mr._Wild', 'name': 'Mr. Wild'},
#  {'id': 'Governr_Jennings', 'name': 'Governr. Jennings'},
#  {'id': 'Erik_Benzelius', 'name': 'Ericus Benzelius'},
#  {'id': 'William_Houstoun', 'name': 'Mr. Houstoun'},
#  {'id': 'Mr_Maidstone, Mr._Maidstone', 'name': 'Mr. Maidstone'},
#  {'id': 'Thomas_Short', 'name': 'Dr. Short'},
#  {'id': 'Thomas_Short', 'name': 'Dr. Short'},
#  {'id': 'Thomas_Short', 'name': 'Dr. Short'},
#  {'id': 'Mr._Bradley', 'name': 'Mr. Bradley'},
#  {'id': 'Thomas_Short', 'name': 'Dr. Short'},
#  {'id': 'Mr_Talbot', 'name': 'Mr. Talbot'},
#  {'id': 'Isaaci_Barrow', 'name': 'Mr. Barrow'},
#  {'id': 'Dr._Clifton', 'name': 'Dr. Clifton'},
#  {'id': 'Ambrose_Godfrey-Hanckwitz', 'name': 'Mr. Godfrey'},
#  {'id': 'Duke_of_Newcastle', 'name': 'Duke of Newcastle'},
#  {'id': 'Nehemiah_Grew', 'name': 'Dr. Grews'},
#  {'id': 'Duke_of_Newcastle', 'name': 'Duke of Newcastle'},
#  {'id': 'Nehemiah_Grew', 'name': 'Dr. Grew'},
#  {'id': 'Duke_of_Newcastle', 'name': 'Duke of Newcastle'},
#  {'id': 'Mr._Godfroy', 'name': 'Mr. Godfroy Junr'},
#  {'id': 'Mr._Bell', 'name': 'Mr. Bell'},
#  {'id': 'Mr._Graham', 'name': 'Mr. Graham Junr'},
#  {'id': 'Charles_I', 'name': 'K. Charles the first'},
#  {'id': 'Mr_Lascelles', 'name': 'Mr. Lascelles'},
#  {'id': 'Mr._Kenly', 'name': 'Mr. Kenly'},
#  {'id': 'Abbe_Bernardo_Sterbini', 'name': 'Abbe Sterbini'},
#  {'id': 'James_Petiver', 'name': 'Pet.'},
#  {'id': 'James_Petiver', 'name': 'Pet'},
#  {'id': 'Henry_Newman', 'name': 'Mr. Newman'},
#  {'id': 'Peter_Collinson', 'name': 'Mr. Collinson'},
#  {'id': 'Peirce_Dod', 'name': 'Dr. Dodd'},
#  {'id': 'Mrs_Marshall', 'name': 'Mrs. Marshall'},
#  {'id': 'Mr_Nash', 'name': 'Mr. Nash'},
#  {'id': 'Mr_Sainthill', 'name': 'Mr. Sainthill'},
#  {'id': 'Richard_Middleton_Massey', 'name': 'Dr. Massey'},
#  {'id': 'Revd_Mr_Scott', 'name': 'Revd Mr. Scott'},
#  {'id': 'Charles_Maitland', 'name': 'Mr. Maitland'},
#  {'id': 'Abbe_Bernardo_Sterbini', 'name': 'Abbe Sterbinis'},
#  {'id': 'Mr._Bell', 'name': 'Mr. Bell'},
#  {'id': 'Mr._Bell', 'name': 'Mr. Bell'},
#  {'id': 'FrancisBuccleuch', 'name': 'Duke of Buclugh'},
#  {'id': 'Daniel_Waldo', 'name': 'Dr. Waldo'},
#  {'id': 'Mr_Green', 'name': 'Mr. Green'},
#  {'id': 'Mr_Gilbert', 'name': 'Mr. Gilbert'},
#  {'id': 'JohnFul', 'name': 'Mr. Fuller'},
#  {'id': 'John_Ranby', 'name': 'Mr. Ranby'},
#  {'id': 'Elihu_Yale', 'name': 'Mr Governr. Yale'},
#  {'id': 'Mr_Muhleman', 'name': 'Mr. Muhleman'},
#  {'id': 'Richard_Middleton_Massey', 'name': 'Dr. Massy'},
#  {'id': 'John_Winthrop', 'name': 'Mr. Wynthorp'},
#  {'id': 'Papenau', 'name': 'Papenau'},
#  {'id': 'John_Winthrop', 'name': 'Winthrop Esqr'},
#  {'id': 'John_Winthrop', 'name': 'Mr. Winthorp'},
#  {'id': 'Mr_Roberts', 'name': 'Mr. Roberts'},
#  {'id': 'John_Winthrop, Mr._Winthorpe', 'name': 'Mr. Winthorpe'},
#  {'id': 'John_Winthrop', 'name': 'Mr. Winthorp'},
#  {'id': 'Richard_Middleton_Massey', 'name': 'Dr. Massey'},
#  {'id': 'Mr._Hodson', 'name': 'Mr. Hodson'},
#  {'id': 'James_Hodgson', 'name': 'Mr. Hodgson'},
#  {'id': 'Johann_Amman', 'name': 'Dr. Amann'},
#  {'id': 'Capt_Jenkens', 'name': 'Mr. Captn Jenkins'},
#  {'id': 'Capt_Jenkens', 'name': 'Mr. Jenkins'},
#  {'id': 'Mr._Clerk', 'name': 'Mr. Clerk'},
#  {'id': 'Queen_Elizabeth_I', 'name': 'Queen Elizabeths'},
#  {'id': 'Mr._Laurie', 'name': 'Mr. Laurie'},
#  {'id': 'Mr._Laurie', 'name': 'Mr. Laurie'},
#  {'id': 'Philip_Miller', 'name': 'Mr. Philipp Miller'},
#  {'id': 'Mr._Mason', 'name': 'Mr. Mason'},
#  {'id': 'Mr_Cotteret', 'name': 'Mr. Cotteret'},
#  {'id': 'Rene_Reaumur', 'name': 'Mr. Reaumar'},
#  {'id': 'Mr_Seguier', 'name': 'Mr. Seguiver'},
#  {'id': 'Mr_Grubb', 'name': 'Mr. Grubb'},
#  {'id': 'Mr._Cox', 'name': 'Mr. Cox'},
#  {'id': 'Richard_Middleton_Massey', 'name': 'Dr. Massy'},
#  {'id': 'HenrySr.', 'name': 'Mr. Barham'},
#  {'id': 'Mr_Seguier', 'name': 'Mr. Seguier'}]

# %% [markdown]
# #### How many mentions of people?

# %%
# Count all mentions of people
len([x for x in df.explode('people')['people'] if x])
# Out:
# 546

# %% [markdown]
# #### How many actual people?

# %%
# Count individual people
individual_people = set([x['id'] for x in df.explode('people')['people'] if x])
len(individual_people)
# Out:
# 296

# %% [markdown]
# #### How many people are not in the main list of people?

# %%
# Find all people that are not in the main list
people_list_ids = [x['id'] for x in people_list]
person_not_in_list = [x for x in individual_people if x not in people_list_ids]
person_not_in_list
# Out:
# ['George_Edwards, Mr._Edwards',
#  'King_James_2nd, King_James',
#  'Mrs_Edwards, Mrs._Edwards',
#  'Mrs_Dering, Mrs._Dering',
#  'Jean_Rodoplhe_Lavater, Dr._Lavater',
#  'John_Winthrop, Mr._Winthorpe',
#  'William_Hanbury, William_Hanbury',
#  'Charles_Lennox_Duke_of_Richmond, James_Stuart_Duke_of_Richmond',
#  'Mr_Maidstone, Mr._Maidstone']

# %% [markdown]
# #### And if we check more thoroughly?

# %%
# Find all people that are not in the main list, excluding special cases
len([x for x in person_not_in_list if [y for y in x.split(',') if y.strip() not in people_list_ids]])
# Out:
# 0

# %% [markdown]
# #### Now let's look at places

# %%
# Find all mentions of places
[x for x in df.explode('places')['places'] if x]
# Out:
# [{'id': 'East_Indies', 'name': 'East Indies'},
#  {'id': 'Norway', 'name': 'Norway'},
#  {'id': 'Lisbon', 'name': 'Lisbon'},
#  {'id': 'Lisbon', 'name': 'Lisbone'},
#  {'id': 'Malacca', 'name': 'Malacca'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Lisbon', 'name': 'Lisbon'},
#  {'id': 'Brasil', 'name': 'Brasile'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Guinea', 'name': 'Guinea'},
#  {'id': 'Malabar', 'name': 'Malabar'},
#  {'id': 'England', 'name': 'England'},
#  {'id': 'London', 'name': 'London'},
#  {'id': 'Coromandel', 'name': 'Coromandel'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Persia', 'name': 'Persian'},
#  {'id': 'Tonkin', 'name': 'Tunquin'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Suratte', 'name': 'Suratte'},
#  {'id': 'New_England', 'name': 'New England'},
#  {'id': 'Berbice', 'name': 'Berbices'},
#  {'id': 'Surinam', 'name': 'Surinam'},
#  {'id': 'West_Indies', 'name': 'West Indies'},
#  {'id': 'Surinam', 'name': 'Surinam'},
#  {'id': 'Guinea', 'name': 'Guinea'},
#  {'id': 'Bristol', 'name': 'hope near Bristol'},
#  {'id': 'Bristol', 'name': 'Bristol'},
#  {'id': 'Guinea', 'name': 'Guinea'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Isles_Scotland', 'name': 'Isles of Scotland'},
#  {'id': 'Turkey', 'name': 'Turkey'},
#  {'id': 'Brasil', 'name': 'Brasile'},
#  {'id': 'Brasil', 'name': 'Brasile'},
#  {'id': 'Brasil', 'name': 'Brasile'},
#  {'id': 'Borneo', 'name': 'Borneo'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Hudson_Bay', 'name': 'Hudsons Bay'},
#  {'id': 'Hudson_Bay', 'name': 'Hudsons bay'},
#  {'id': 'Hudson_Bay', 'name': 'Hudsons bay'},
#  {'id': 'Carolina', 'name': 'Carolina'},
#  {'id': 'Canada', 'name': 'Canada'},
#  {'id': 'Ireland', 'name': 'Ireland'},
#  {'id': 'Turkey', 'name': 'Turky'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Mexico', 'name': 'Mexico'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'West_Indies', 'name': 'W. Indies'},
#  {'id': 'Hudson_Bay', 'name': 'Hudsons bay'},
#  {'id': 'East_Indies', 'name': 'E. India'},
#  {'id': 'Spain', 'name': 'Spaine'},
#  {'id': 'Nuremberg', 'name': 'Nurinberg'},
#  {'id': 'Guinea', 'name': 'Guinea'},
#  {'id': 'Jamaica', 'name': 'Jamaica'},
#  {'id': 'Virginia', 'name': 'Virginia'},
#  {'id': 'Turkey', 'name': 'Turkish'},
#  {'id': 'Hudson_Bay', 'name': 'Hudsons bay'},
#  {'id': 'Greenland', 'name': 'Greenland'},
#  {'id': 'Fountain_Court_Strand', 'name': 'fountain court in the strand'},
#  {'id': 'Croydon', 'name': 'Croydon'},
#  {'id': 'East_Indies', 'name': 'E Indies'},
#  {'id': 'Livonia', 'name': 'Livonia'},
#  {'id': 'Jamaica', 'name': 'Jamaica'},
#  {'id': 'Barbary', 'name': 'Barbary'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'New_England', 'name': 'N England'},
#  {'id': 'Scotland', 'name': 'Scotland'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Surinam', 'name': 'Surinam'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Jamaica', 'name': 'Jama'},
#  {'id': 'Malaga', 'name': 'Malaga'},
#  {'id': 'Jamaica', 'name': 'Jamaica'},
#  {'id': 'Thames', 'name': 'Thames'},
#  {'id': 'Scotland', 'name': 'Scotland'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Jamaica', 'name': 'Jamaica'},
#  {'id': 'Jerusalem', 'name': 'Jerusalem'},
#  {'id': 'North_England', 'name': 'N. England'},
#  {'id': 'Hudson_Strait', 'name': 'Hudsons streights'},
#  {'id': 'Turkey', 'name': 'Turkey'},
#  {'id': 'Barbary', 'name': 'Barbary'},
#  {'id': 'Guinea', 'name': 'Guiney'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'East_Indies', 'name': 'East India'},
#  {'id': 'East_Indies', 'name': 'East Indies'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Persia', 'name': 'Persian'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Guinea', 'name': 'Guinea'},
#  {'id': 'Surinam', 'name': 'Surinam'},
#  {'id': 'Hudson_Strait', 'name': "Hudson's Streights"},
#  {'id': 'Angola', 'name': 'Angola'},
#  {'id': 'Muscovy', 'name': 'Muscovy'},
#  {'id': 'China', 'name': 'china'},
#  {'id': 'Smyrna', 'name': 'Smyrna'},
#  {'id': 'Spain', 'name': 'Spain'},
#  {'id': 'India', 'name': 'India'},
#  {'id': 'West_Indies', 'name': 'west Indian'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Jamaica', 'name': 'Jamaica'},
#  {'id': 'Jerusalem', 'name': 'Jerusalem'},
#  {'id': 'Bethlehem', 'name': 'Bethlem'},
#  {'id': 'Portugal', 'name': 'Portugall'},
#  {'id': 'Devonshire', 'name': 'Devonshire'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'West_Indies', 'name': 'West India'},
#  {'id': 'Canada', 'name': 'Canada'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'East_Indies', 'name': 'East Indian'},
#  {'id': 'Holland', 'name': 'Holland'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Rome', 'name': 'Rome'},
#  {'id': 'Legorn', 'name': 'Legorn'},
#  {'id': 'North_America', 'name': 'North America'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Canada', 'name': 'Canada'},
#  {'id': 'Canada', 'name': 'Canada'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Nuremberg', 'name': 'Nurenberg'},
#  {'id': 'Holland', 'name': 'Holland'},
#  {'id': 'Guinea', 'name': 'Guinea'},
#  {'id': 'Ireland', 'name': 'Ireland'},
#  {'id': 'East_Indies', 'name': 'E. India'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Persia', 'name': 'Persia'},
#  {'id': 'Canada', 'name': 'Canada'},
#  {'id': 'Holland', 'name': 'Holland'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Carolina', 'name': 'Carolina'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Malabar', 'name': 'Malabar'},
#  {'id': 'Pennsylvania', 'name': 'Penslvany'},
#  {'id': 'Menorca', 'name': 'Minorca'},
#  {'id': 'Barbary', 'name': 'Barbary'},
#  {'id': 'Hudson_Bay', 'name': 'Hudsons Bay'},
#  {'id': 'Hudson_Bay', 'name': 'Hudsons Bay'},
#  {'id': 'Flintshire', 'name': 'Flintshire'},
#  {'id': 'Strait_Magellan', 'name': 'Streights of Magellan'},
#  {'id': 'Portugal', 'name': 'Portugall'},
#  {'id': 'Scotland', 'name': 'Scotland'},
#  {'id': 'Flanders', 'name': 'Flanders'},
#  {'id': 'Cornwall', 'name': 'Cornwall'},
#  {'id': 'Guinea', 'name': 'Guinea'},
#  {'id': 'Holland', 'name': 'Holland'},
#  {'id': 'Lancashire', 'name': 'Lancashire'},
#  {'id': 'Canada', 'name': 'Canada'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Germany', 'name': 'Garmany'},
#  {'id': 'Persia', 'name': 'Persia'},
#  {'id': 'East_Indies', 'name': 'East Indies'},
#  {'id': 'Santa_Cruz', 'name': 'Santacruz'},
#  {'id': 'Portsmouth', 'name': 'Portsmouth'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Hudson_Bay', 'name': 'Hudson bay'},
#  {'id': 'Canada', 'name': 'Canada'},
#  {'id': 'Susquehanna', 'name': 'Susquehama'},
#  {'id': 'Delaware', 'name': 'delaware'},
#  {'id': 'Hudson_River', 'name': 'Hudson river'},
#  {'id': 'Philadelphia', 'name': 'Philadelphia'},
#  {'id': 'Susquehanna', 'name': 'Susquehama'},
#  {'id': 'Rome', 'name': 'Roman'},
#  {'id': 'Turkey', 'name': 'Turkish'},
#  {'id': 'Spain', 'name': 'Spain'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Virginia', 'name': 'Virginia'},
#  {'id': 'Rome', 'name': 'Roman'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Quoi', 'name': 'Quoi'},
#  {'id': 'Quoi', 'name': 'Quoi'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Malabar', 'name': 'Malabar'},
#  {'id': 'Hudson_Bay', 'name': 'Hudgson bay'},
#  {'id': 'New_England', 'name': 'new England'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Naples', 'name': 'Naples'},
#  {'id': 'New_England', 'name': 'New England'},
#  {'id': 'Germany', 'name': 'Germany'},
#  {'id': 'St_Paul', 'name': 'Pauls church yard'},
#  {'id': 'Barbados', 'name': 'Barbados'},
#  {'id': 'Peru', 'name': 'Peru'},
#  {'id': 'Oxfordshire', 'name': 'Oxfordshire'},
#  {'id': 'Flanders', 'name': 'Flanders'},
#  {'id': 'Madagascar', 'name': 'Mada= =gascar'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Madagascar', 'name': 'Madagascar'},
#  {'id': 'Jamaica', 'name': 'Jamaica'},
#  {'id': 'India', 'name': 'India'},
#  {'id': 'Geneva', 'name': 'Geneva'},
#  {'id': 'East_Indies', 'name': 'East Indies'},
#  {'id': 'New_England', 'name': 'new England'},
#  {'id': 'Borneo', 'name': 'Borneo'},
#  {'id': 'Westminster', 'name': 'Westminster'},
#  {'id': 'France', 'name': 'France'},
#  {'id': 'Lyon', 'name': 'Lyons'},
#  {'id': 'Paris', 'name': 'paris'},
#  {'id': 'West_Indies', 'name': 'West India'},
#  {'id': 'Brasil', 'name': 'Brasile'},
#  {'id': 'Jamaica', 'name': 'Jamaica'},
#  {'id': 'East_Indies', 'name': 'E. Indian'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Turkey', 'name': 'Turkey'},
#  {'id': 'West_Indies', 'name': 'West Indies'},
#  {'id': 'Turkey', 'name': 'Turkish'},
#  {'id': 'Scotland', 'name': 'Scotland'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Virginia', 'name': 'Virginia'},
#  {'id': 'Virginia', 'name': 'Virginia'},
#  {'id': 'Derbyshire', 'name': 'Darby shire'},
#  {'id': 'Turkey', 'name': 'Turkey'},
#  {'id': 'Naples', 'name': 'Naples'},
#  {'id': 'Hampshire', 'name': 'Hampshire'},
#  {'id': 'Strait_Magellan', 'name': 'Magell= an Streights'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'West_Indies', 'name': 'West Indians'},
#  {'id': 'Westminster', 'name': 'Westminster'},
#  {'id': 'Portugal', 'name': 'Portugall'},
#  {'id': 'East_Indies', 'name': 'East India'},
#  {'id': 'Hampshire', 'name': 'Hampshire'},
#  {'id': 'India', 'name': 'India'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Brussels', 'name': 'Brussels'},
#  {'id': 'Bavaria', 'name': 'Bavaria'},
#  {'id': 'India', 'name': 'India'},
#  {'id': 'East_Indies', 'name': 'East Indies'},
#  {'id': 'Jamaica', 'name': 'Jamaica'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Strait_Magellan', 'name': 'Streights of Magellan'},
#  {'id': 'Spain', 'name': 'Spain'},
#  {'id': 'Java', 'name': 'Java'},
#  {'id': 'Persia', 'name': 'Persian'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Tourn', 'name': 'Tourn'},
#  {'id': 'Jaffa', 'name': 'Joppa'},
#  {'id': 'Melo_Island', 'name': 'Melo Island'},
#  {'id': 'East_Indies', 'name': 'East India'},
#  {'id': 'Campeche', 'name': 'Campeche'},
#  {'id': 'Jamaica', 'name': 'Jamaica'},
#  {'id': 'Guinea', 'name': 'Guinea'},
#  {'id': 'Jamaica', 'name': 'Jamaica'},
#  {'id': 'Mount_Mill_St_Bartholomew', 'name': 'Mounts mill'},
#  {'id': 'East_Indies', 'name': 'E. India'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'East_Indies', 'name': 'East Indies'},
#  {'id': 'Turkey', 'name': 'Turkish'},
#  {'id': 'Darien', 'name': 'Darien'},
#  {'id': 'Scotland', 'name': 'Scotland'},
#  {'id': 'East_Indies', 'name': 'East Indies'},
#  {'id': 'Java', 'name': 'Java'},
#  {'id': 'Makassar', 'name': 'Macassar'},
#  {'id': 'Guinea', 'name': 'Guinea'},
#  {'id': 'Guinea', 'name': 'Guinea'},
#  {'id': 'Guinea', 'name': 'Guinea'},
#  {'id': 'New_York', 'name': 'New York'},
#  {'id': 'Florence', 'name': 'Florence'},
#  {'id': 'Rome', 'name': 'Rome'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Turkey', 'name': 'Turkey'},
#  {'id': 'Turkey', 'name': 'Turkish'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Jerusalem', 'name': 'Jerusalem'},
#  {'id': 'Scotland', 'name': 'Scotland'},
#  {'id': 'Persia', 'name': 'Persian'},
#  {'id': 'Persia', 'name': 'Persian'},
#  {'id': 'Turkey', 'name': 'Turkish'},
#  {'id': 'Persia', 'name': 'Persian'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Flanders', 'name': 'Flanders'},
#  {'id': 'East_Indies', 'name': 'East Indies'},
#  {'id': 'Prussia', 'name': 'Prussia'},
#  {'id': 'Scotland', 'name': 'Scotland'},
#  {'id': 'Strait_Magellan', 'name': 'streights of Magellan'},
#  {'id': 'Scotland', 'name': 'Scotland'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'East_Indies', 'name': 'East Indies'},
#  {'id': 'Spain', 'name': 'Spaine'},
#  {'id': 'East_Indies', 'name': 'East Indies'},
#  {'id': 'East_Indies', 'name': 'East Indies'},
#  {'id': 'Strait_Magellan', 'name': 'Streights of Magellan'},
#  {'id': 'Terra_Fuego', 'name': 'terra del fuego'},
#  {'id': 'East_Indies', 'name': 'East Indies'},
#  {'id': 'Suratte', 'name': 'Suratte'},
#  {'id': 'Persia', 'name': 'Persia'},
#  {'id': 'Turkey', 'name': 'Turkey'},
#  {'id': 'Turkey', 'name': 'Turkish'},
#  {'id': 'West_Indies', 'name': 'West Indies'},
#  {'id': 'East_Indies', 'name': 'East Indies'},
#  {'id': 'Holland', 'name': 'Holland'},
#  {'id': 'Surinam', 'name': 'Surinam'},
#  {'id': 'Corduba', 'name': 'Corduba'},
#  {'id': 'Spain', 'name': 'Spain'},
#  {'id': 'West_Indies', 'name': 'West Indians'},
#  {'id': 'North_America', 'name': 'North America'},
#  {'id': 'Persia', 'name': 'Persian'},
#  {'id': 'West_Indies', 'name': 'West Indies'},
#  {'id': 'West_Indies', 'name': 'West Indian'},
#  {'id': 'Strait_Magellan', 'name': 'streights of Magellan'},
#  {'id': 'Strait_Magellan', 'name': 'streights of Magellan'},
#  {'id': 'Strait_Magellan', 'name': 'Magellanic'},
#  {'id': 'East_Indies', 'name': 'East Indies'},
#  {'id': 'East_Indies', 'name': 'East Indies'},
#  {'id': 'Virginia', 'name': 'Virginia'},
#  {'id': 'Portugal', 'name': 'Portugall'},
#  {'id': 'Virginia', 'name': 'Virginia'},
#  {'id': 'Russia', 'name': 'Russia'},
#  {'id': 'New_England', 'name': 'New England'},
#  {'id': 'New_England', 'name': 'New England'},
#  {'id': 'Bourdeaux', 'name': 'Bourdeaux'},
#  {'id': 'France', 'name': 'France'},
#  {'id': 'Egypt', 'name': 'Egyptian'},
#  {'id': 'Russia', 'name': 'Russia'},
#  {'id': 'London', 'name': 'London'},
#  {'id': 'St_Paul', 'name': 'Pauls'},
#  {'id': 'Turkey', 'name': 'Turkish'},
#  {'id': 'Turkey', 'name': 'Turkish'},
#  {'id': 'Malta', 'name': 'Malta'},
#  {'id': 'East_Indies', 'name': 'East India'},
#  {'id': 'East_Indies', 'name': 'East India'},
#  {'id': 'East_Indies', 'name': 'East India'},
#  {'id': 'Malta', 'name': 'Malta'},
#  {'id': 'Flanders', 'name': 'Flanders'},
#  {'id': 'Brasil', 'name': 'Brasile'},
#  {'id': 'Brasil', 'name': 'Brasile'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Suratte', 'name': 'Suratte'},
#  {'id': 'Celebes', 'name': 'Celebes'},
#  {'id': 'Persia', 'name': 'Persia'},
#  {'id': 'Pegu', 'name': 'Pegu'},
#  {'id': 'Virginia', 'name': 'Virginia'},
#  {'id': 'India', 'name': 'India'},
#  {'id': 'Sens', 'name': 'Sens'},
#  {'id': 'Dominica', 'name': 'Dominica'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'India', 'name': 'India'},
#  {'id': 'Amsterdam', 'name': 'Amster= dam'},
#  {'id': 'Persia', 'name': 'Persia'},
#  {'id': 'Virginia', 'name': 'Virginia'},
#  {'id': 'Nieves', 'name': 'Nieves'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Epping_forest', 'name': 'Epping forest'},
#  {'id': 'Spain', 'name': 'Spain'},
#  {'id': 'Whitehall', 'name': 'Whitehall'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Switzerland', 'name': 'Swisserland'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Turkey', 'name': 'Turkish'},
#  {'id': 'Quaqua_coast', 'name': 'Quaqua coast'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Caribbean_Islands', 'name': 'Caribe Islands'},
#  {'id': 'Canton', 'name': 'Canton'},
#  {'id': 'Ware_park', 'name': 'Ware park'},
#  {'id': 'Epsom', 'name': 'Epsom'},
#  {'id': 'Suters_Hill', 'name': 'Suters hill'},
#  {'id': 'Epsom', 'name': 'Epsom'},
#  {'id': 'Epsom', 'name': 'Epsom'},
#  {'id': 'Gibraltar', 'name': 'Gibraltar'},
#  {'id': 'Gibraltar', 'name': 'Gibraltar'},
#  {'id': 'Newcastle', 'name': 'Newcastle'},
#  {'id': 'Guinea', 'name': 'Guinea'},
#  {'id': 'Florence', 'name': 'Florence'},
#  {'id': 'Guinea', 'name': 'Guinea'},
#  {'id': 'Entau', 'name': 'Entau'},
#  {'id': 'Ashante', 'name': 'Ashanta'},
#  {'id': 'Agrafee', 'name': 'Agrafee'},
#  {'id': 'Creepu', 'name': 'Creepu'},
#  {'id': 'River_Voller', 'name': 'river Voller'},
#  {'id': 'Whydah', 'name': 'Whidgah'},
#  {'id': 'Lapland', 'name': 'Lapland'},
#  {'id': 'Jamaica', 'name': 'Jamaica'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Japan', 'name': 'Japonese'},
#  {'id': 'Japan', 'name': 'Japonese'},
#  {'id': 'Pegu', 'name': 'Pegu'},
#  {'id': 'Japan', 'name': 'Japonese'},
#  {'id': 'Japan', 'name': 'Japonese'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'West_Indies', 'name': 'W. India'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Mogols_country', 'name': 'the great Mogols country'},
#  {'id': 'Lapland', 'name': 'Lapland'},
#  {'id': 'Turkey', 'name': 'Turkish'},
#  {'id': 'Mexico', 'name': 'Mexico'},
#  {'id': 'America', 'name': 'America'},
#  {'id': 'Lapland', 'name': 'Lapland'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Mogols_country', 'name': 'Mogulls country'},
#  {'id': 'Calabria', 'name': 'Calabria'},
#  {'id': 'Cleve', 'name': 'Cleve'},
#  {'id': 'Siberia', 'name': 'Siberia'},
#  {'id': 'Russia', 'name': 'Russia'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Dresden', 'name': 'Dresden'},
#  {'id': 'Berlin', 'name': 'Berlin'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Oxford', 'name': 'Oxford'},
#  {'id': 'New_England', 'name': 'New England'},
#  {'id': 'South_Carolina', 'name': 'South Carolina'},
#  {'id': 'France', 'name': 'France'},
#  {'id': 'Paris', 'name': 'Paris'},
#  {'id': 'New_England', 'name': 'New England'},
#  {'id': 'New_England', 'name': 'New England'},
#  {'id': 'Windsor', 'name': 'Windsor'},
#  {'id': 'Carolina', 'name': 'Carolina'},
#  {'id': 'Carolina', 'name': 'Carolina'},
#  {'id': 'South_Carolina', 'name': 'South Carolina'},
#  {'id': 'Carolina', 'name': '>Carolina'},
#  {'id': 'East_Indies', 'name': 'East Indies'},
#  {'id': 'Scotland', 'name': 'Scotland'},
#  {'id': 'East_Indies', 'name': 'E. Indies'},
#  {'id': 'Carolina', 'name': 'Carolina'},
#  {'id': 'East_Indies', 'name': 'East Indies'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Fort_George', 'name': 'fort St. George'},
#  {'id': 'East_Indies', 'name': 'E. Indies'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Sussex', 'name': 'Sussex'},
#  {'id': 'Bristol', 'name': 'Bristoll'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'America', 'name': 'America'},
#  {'id': 'Hudson_Bay', 'name': 'Hudsons bay'},
#  {'id': 'Africa', 'name': 'Africa'},
#  {'id': 'Spain', 'name': 'Spain'},
#  {'id': 'Turkey', 'name': 'Turkish'},
#  {'id': 'Africa', 'name': 'Africa'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Denmark', 'name': 'Denmark'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Gomroon', 'name': 'Gomroon'},
#  {'id': 'Darien', 'name': 'Darien'},
#  {'id': 'Carolina', 'name': 'Carolina'},
#  {'id': 'East_Indies', 'name': 'East India'},
#  {'id': 'North_Scotland', 'name': 'North of Scotland'},
#  {'id': 'Holland', 'name': 'Holland'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Vampo', 'name': 'Vampo'},
#  {'id': 'Canton', 'name': 'Canton'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'East_Indies', 'name': 'east India'},
#  {'id': 'Cheshire', 'name': 'Cheshire'},
#  {'id': 'Davis_Strait', 'name': "Davies's Straits"},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'America', 'name': 'America'},
#  {'id': 'Darien', 'name': 'Darien'},
#  {'id': 'Cartagena', 'name': 'Carthayener in America'},
#  {'id': 'East_Indies', 'name': 'East Ind =ians'},
#  {'id': 'East_Indies', 'name': 'East Indies'},
#  {'id': 'Malacca', 'name': 'Malacca'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Reculver', 'name': 'Reculver'},
#  {'id': 'Virginia', 'name': 'Virginia'},
#  {'id': 'South_Carolina', 'name': 'S. Carolina'},
#  {'id': 'Virginia', 'name': 'Virginia'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Bermudas', 'name': 'Bermudas'},
#  {'id': 'Malacca', 'name': 'Malacca'},
#  {'id': 'Catalonia', 'name': 'Catalonia'},
#  {'id': 'Davis_Strait', 'name': "Davis's straits"},
#  {'id': 'Virginia', 'name': 'Virginia'},
#  {'id': 'Luneburg', 'name': 'Luneburg'},
#  {'id': 'Lawrance', 'name': 'Lawrance'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Turkey', 'name': 'Turkey'},
#  {'id': 'Senegal', 'name': 'Senegal'},
#  {'id': 'Aethiopia', 'name': 'Æthiopish'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Persia', 'name': 'Persian'},
#  {'id': 'Virginia', 'name': 'Virginia'},
#  {'id': 'Turkey', 'name': 'Turkish'},
#  {'id': 'Pyrenees', 'name': 'Pyrenees'},
#  {'id': 'Turkey', 'name': 'Turky'},
#  {'id': 'East_Indies', 'name': 'East India'},
#  {'id': 'Madagascar', 'name': 'Madagascar'},
#  {'id': 'Congo', 'name': 'Congo'},
#  {'id': 'Marorla_Congo', 'name': 'Marorla of Congo'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Ireland', 'name': 'Ireland'},
#  {'id': 'Carolina', 'name': 'Carolina'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Reculver', 'name': 'Reculver'},
#  {'id': 'South_Carolina', 'name': 'S. Carolina'},
#  {'id': 'Portugal', 'name': 'Portugall'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Carolina', 'name': 'Carolina'},
#  {'id': 'Fort_George', 'name': 'fort St. George'},
#  {'id': 'East_Indies', 'name': 'E. I'},
#  {'id': 'America', 'name': 'America'},
#  {'id': 'Yorkshire', 'name': 'Yorkshire'},
#  {'id': 'Germany', 'name': 'Germany'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Lyon', 'name': 'Lyons'},
#  {'id': 'Sumatra', 'name': 'Sumatra'},
#  {'id': 'Scotland', 'name': 'Scotland'},
#  {'id': 'Bengal', 'name': 'Bengall'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'America', 'name': 'America'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'North_America', 'name': 'North America'},
#  {'id': 'America', 'name': 'America'},
#  {'id': 'Ireland', 'name': 'Ireland'},
#  {'id': 'Turkey', 'name': 'Turkish'},
#  {'id': 'Constantinople', 'name': 'Constantinople'},
#  {'id': 'Smyrna', 'name': 'Smyrna'},
#  {'id': 'Turkey', 'name': 'Turkish'},
#  {'id': 'Smyrna', 'name': 'Smyrna'},
#  {'id': 'Turkey', 'name': 'Turkish'},
#  {'id': 'Constantinople', 'name': 'Constantinople'},
#  {'id': 'Smyrna', 'name': 'Smyrna'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'France', 'name': 'France'},
#  {'id': 'Bohemia', 'name': 'Bohemia'},
#  {'id': 'Poland', 'name': 'Polonia'},
#  {'id': 'Germany', 'name': 'Germany'},
#  {'id': 'Windsor', 'name': 'Windsor'},
#  {'id': 'Paris', 'name': 'Paris'},
#  {'id': 'Westminster', 'name': 'Westminster'},
#  {'id': 'Egypt', 'name': 'Egypt'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Nuremberg', 'name': 'Nuremberg'},
#  {'id': 'Dieppe', 'name': 'Dieppe'},
#  {'id': 'East_Indies', 'name': 'East Indies'},
#  {'id': 'Sweden', 'name': 'Sweden'},
#  {'id': 'Norway', 'name': 'Norway'},
#  {'id': 'America', 'name': 'America'},
#  {'id': 'Windsor', 'name': 'Windsor'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Sheffield', 'name': 'Sheffield'},
#  {'id': 'Sheffield', 'name': 'Sheffield'},
#  {'id': 'Holland', 'name': 'Holland'},
#  {'id': 'Turkey', 'name': 'Turkish'},
#  {'id': 'Berlin', 'name': 'Berlin'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Malton', 'name': 'Malton'},
#  {'id': 'Filah', 'name': 'Filah'},
#  {'id': 'Harrogate', 'name': 'Harrogate'},
#  {'id': 'Buckby', 'name': 'Buckby'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Davis_Strait', 'name': "Davis's straits"},
#  {'id': 'Greenland', 'name': 'Groenland'},
#  {'id': 'North_America', 'name': 'North America'},
#  {'id': 'Guinea', 'name': 'Guinea'},
#  {'id': 'Windsor', 'name': 'Windsor'},
#  {'id': 'Guinea', 'name': 'Guinea'},
#  {'id': 'London', 'name': 'London'},
#  {'id': 'Guinea', 'name': 'Guinea'},
#  {'id': 'Paris', 'name': 'Paris'},
#  {'id': 'Malta', 'name': 'Malta'},
#  {'id': 'East_Indies', 'name': 'East Indies'},
#  {'id': 'Hampshire', 'name': 'Hampshire'},
#  {'id': 'Oxford', 'name': 'Oxford'},
#  {'id': 'East_Indies', 'name': 'East Indies'},
#  {'id': 'Carolina', 'name': 'Carolina'},
#  {'id': 'Malaga', 'name': 'Malaga'},
#  {'id': 'Malabar', 'name': 'Malabar'},
#  {'id': 'Rochester', 'name': 'Rochester'},
#  {'id': 'Malacca', 'name': 'Malacca'},
#  {'id': 'Yorkshire', 'name': 'Yorkshire'},
#  {'id': 'Bath', 'name': 'Bath'},
#  {'id': 'West_Indies', 'name': 'W. Indies'},
#  {'id': 'Guanaboa', 'name': 'Guanaboa'},
#  {'id': 'Jamaica', 'name': 'Jamaica'},
#  {'id': 'Bishopsgate', 'name': 'Bishops - gate'},
#  {'id': 'Italy', 'name': 'Italy'},
#  {'id': 'Malacca', 'name': 'Molucco Islands'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Bloomsbury_Square', 'name': 'Bloomsbury Square'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Kings_Langley', 'name': 'Kings Langley in Hertfordsh'},
#  {'id': 'East_Indies', 'name': 'East Indies'},
#  {'id': 'Italy', 'name': 'Italy'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'Japan', 'name': 'Japan'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Fort_George', 'name': 'fort St. George'},
#  {'id': 'East_Indies', 'name': 'East Indies'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'New_England', 'name': 'New England'},
#  {'id': 'North_England', 'name': 'N. England'},
#  {'id': 'New_England', 'name': 'New England'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'North_England', 'name': 'N. England'},
#  {'id': 'Holland', 'name': 'Holland'},
#  {'id': 'New_England', 'name': 'New England'},
#  {'id': 'America', 'name': 'America'},
#  {'id': 'Turkey', 'name': 'Turkish'},
#  {'id': 'Turkey', 'name': 'Turky'},
#  {'id': 'Petersburg', 'name': 'Petersburg'},
#  {'id': 'Hudson_Bay', 'name': 'Hudsons bay'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Malabar', 'name': 'Malabar'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'River_Gambia', 'name': 'river Gambia'},
#  {'id': 'Kamchatka', 'name': 'Kamcatchki'},
#  {'id': 'Petersburg', 'name': 'Peterburg.'},
#  {'id': 'Kamchatka', 'name': 'Kamcatchki'},
#  {'id': 'Petersburg', 'name': 'Petersburg'},
#  {'id': 'Russia', 'name': 'Russia'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'China', 'name': 'China'},
#  {'id': 'Montserrat', 'name': 'Monsserrat'},
#  {'id': 'East_Indies', 'name': 'East India'},
#  {'id': 'Campeche', 'name': 'Campeche'},
#  {'id': 'Campeche', 'name': 'Campeche'},
#  {'id': 'North_America', 'name': 'North America'},
#  {'id': 'Wales', 'name': 'wales'},
#  {'id': 'France', 'name': 'France'},
#  {'id': 'Lapland', 'name': 'Lapland'},
#  {'id': 'Lapland', 'name': 'Lapland'},
#  {'id': 'East_Indies', 'name': 'East India'},
#  {'id': 'Emuy', 'name': 'Emuy'},
#  {'id': 'Jamaica', 'name': 'Jamaica'},
#  {'id': 'Spain', 'name': 'Spaine'},
#  {'id': 'France', 'name': 'France'}]

# %% [markdown]
# #### How many mentions of places?

# %%
# Count all mentions of places
len([x for x in df.explode('places')['places'] if x])
# Out:
# 668

# %% [markdown]
# #### How many actual places?

# %%
# Count individual places
individual_places = set([x['id'] for x in df.explode('places')['places'] if x])
len(individual_places)
# Out:
# 181

# %% [markdown]
# #### How many places are not in the main list of places?

# %%
# Count all places that are not in the main list
place_list_ids = [x['id'] for x in place_list]
place_not_in_list = [x for x in individual_places if x not in place_list_ids]
len(place_not_in_list)
# Out:
# 0

# %% [markdown]
# #### Find all VIAF IDs of people

# %%
people_list_viaf = sorted([int(x['viaf']) for x in people_list if 'viaf' in x])
people_list_viaf
# Out:
# [26221,
#  29153,
#  30977,
#  40093,
#  40220,
#  42182,
#  42225,
#  46244,
#  48609,
#  60021,
#  77959,
#  85044,
#  93909,
#  108057,
#  117486,
#  126731,
#  132112,
#  155498,
#  156009,
#  175833,
#  176192,
#  194577,
#  237497,
#  284244,
#  300140,
#  361641,
#  363997,
#  366106,
#  441684,
#  774683,
#  792439,
#  792879,
#  805714,
#  805877,
#  822823,
#  837905,
#  849367,
#  895409,
#  934497,
#  956203,
#  1263219,
#  1456147,
#  1499948,
#  1562998,
#  2319765,
#  2327009,
#  2331192,
#  2358196,
#  2378232,
#  2411429,
#  2474502,
#  2479682,
#  2495579,
#  2496935,
#  2508854,
#  2515242,
#  2519559,
#  2521078,
#  2546468,
#  2551924,
#  2556684,
#  2589083,
#  2604336,
#  2604452,
#  2735066,
#  2769606,
#  2788543,
#  2809212,
#  2818528,
#  2818730,
#  2821751,
#  2832039,
#  2832981,
#  2870639,
#  2900775,
#  3086266,
#  3265477,
#  3267042,
#  3393065,
#  3396615,
#  3544559,
#  3893245,
#  3908040,
#  4499544,
#  4791162,
#  4798582,
#  4805023,
#  4805598,
#  4822479,
#  4919216,
#  4919216,
#  4940012,
#  4940467,
#  4940582,
#  4945401,
#  4951927,
#  4956694,
#  4973470,
#  5017560,
#  5041312,
#  5046077,
#  5061772,
#  5065380,
#  5113867,
#  5168708,
#  5190555,
#  5266955,
#  5273899,
#  5274099,
#  5274580,
#  5275263,
#  5298954,
#  5325507,
#  5362067,
#  5362235,
#  5735749,
#  5842045,
#  5861609,
#  5863902,
#  5874981,
#  6014298,
#  6167427,
#  6215669,
#  6273611,
#  6276752,
#  6352134,
#  6352962,
#  6353924,
#  6363145,
#  6374073,
#  6387970,
#  6410027,
#  6469121,
#  6800965,
#  6948619,
#  6953888,
#  7241919,
#  7244833,
#  7246209,
#  7248600,
#  7261692,
#  7263930,
#  7266580,
#  7326235,
#  7341469,
#  7380094,
#  7381185,
#  7400805,
#  7405452,
#  7415128,
#  7423980,
#  7425031,
#  7425989,
#  7425989,
#  7426596,
#  7428836,
#  7440183,
#  7453054,
#  7476431,
#  7502835,
#  7546811,
#  7725325,
#  7731668,
#  7732279,
#  7732694,
#  7736875,
#  7737032,
#  7791271,
#  7820717,
#  8145335,
#  8157223,
#  8167410,
#  8181420,
#  8183900,
#  8184591,
#  8192151,
#  8199472,
#  8282870,
#  8446526,
#  8461797,
#  8493468,
#  8583674,
#  8599154,
#  8790598,
#  8814941,
#  8928748,
#  9324349,
#  9720045,
#  9722692,
#  9787916,
#  9798235,
#  9827268,
#  9837888,
#  9849392,
#  9856920,
#  9857012,
#  9865630,
#  9877713,
#  9887952,
#  9894043,
#  9926861,
#  9928566,
#  9965263,
#  9970490,
#  9979313,
#  10034259,
#  10078948,
#  10151542,
#  10185310,
#  10188460,
#  10188879,
#  10198482,
#  10199025,
#  10211770,
#  10237226,
#  10584218,
#  10625832,
#  10625832,
#  10627197,
#  10629468,
#  10640462,
#  10658053,
#  10760478,
#  10763721,
#  10782288,
#  10908780,
#  10990268,
#  11058091,
#  11132722,
#  11260511,
#  11266459,
#  11267514,
#  11311615,
#  11377079,
#  11399968,
#  11462035,
#  12179247,
#  12179846,
#  12249427,
#  12298108,
#  12306898,
#  12323361,
#  12343831,
#  12346702,
#  12355548,
#  12377413,
#  12396611,
#  12405220,
#  12411440,
#  12416181,
#  12427288,
#  12463453,
#  12476776,
#  12545856,
#  12577068,
#  12619430,
#  12646823,
#  12647423,
#  12650271,
#  12651892,
#  12652091,
#  12652275,
#  12676360,
#  12677948,
#  12735772,
#  13047713,
#  13086266,
#  13087412,
#  13087514,
#  13091055,
#  13091713,
#  13101068,
#  13116531,
#  13116680,
#  13120553,
#  13226576,
#  13244783,
#  13251888,
#  13471767,
#  13520055,
#  13697267,
#  13738984,
#  13752267,
#  13790434,
#  14600129,
#  14609907,
#  14611974,
#  14625511,
#  14626888,
#  14631514,
#  14637261,
#  14644323,
#  14671283,
#  14691576,
#  14772060,
#  14773105,
#  14779364,
#  14789424,
#  14793378,
#  14793931,
#  14798553,
#  14799615,
#  14804235,
#  14814119,
#  14869558,
#  14876201,
#  14901383,
#  14937238,
#  15040910,
#  15117589,
#  15141474,
#  15141636,
#  15552397,
#  15610538,
#  15665190,
#  15716435,
#  15859805,
#  15863258,
#  16196881,
#  16197107,
#  16203838,
#  16249061,
#  16304279,
#  16783793,
#  17081533,
#  17094576,
#  17118124,
#  17213123,
#  17231738,
#  17231985,
#  17232714,
#  17237181,
#  17251152,
#  17258330,
#  17261560,
#  17264481,
#  17266522,
#  17277670,
#  17320058,
#  17355999,
#  17366406,
#  17414384,
#  17427540,
#  17440889,
#  17446949,
#  17459259,
#  17525359,
#  17561749,
#  17571331,
#  17571781,
#  17616048,
#  17997690,
#  18002661,
#  18003738,
#  18033780,
#  18100406,
#  18155373,
#  18337021,
#  18431861,
#  18581471,
#  18636408,
#  18647172,
#  18647753,
#  18650208,
#  18664895,
#  18897214,
#  19552454,
#  19552973,
#  19553659,
#  19556565,
#  19557125,
#  19635062,
#  19668788,
#  19687783,
#  19709327,
#  19710661,
#  19712599,
#  19715963,
#  19724806,
#  19725880,
#  19754288,
#  19790673,
#  19810665,
#  19827688,
#  19827688,
#  19885929,
#  20018411,
#  20020684,
#  20025298,
#  20026471,
#  20029793,
#  20033542,
#  20078711,
#  20080051,
#  20112530,
#  20407456,
#  20438019,
#  20461029,
#  20463354,
#  20857375,
#  21021187,
#  21021806,
#  21105841,
#  21105841,
#  21114185,
#  21274382,
#  21592774,
#  21706085,
#  21982758,
#  21985874,
#  22000018,
#  22010611,
#  22018516,
#  22063536,
#  22084759,
#  22145254,
#  22146457,
#  22150497,
#  22151653,
#  22167754,
#  22182610,
#  22200045,
#  22201759,
#  22209566,
#  22217492,
#  22237799,
#  22269855,
#  22369050,
#  22468266,
#  22469858,
#  22478268,
#  22479704,
#  22480316,
#  22482519,
#  22485966,
#  22510525,
#  22923750,
#  22953147,
#  23083871,
#  23196916,
#  23200544,
#  23282729,
#  23353145,
#  23471562,
#  23568272,
#  23581458,
#  23649689,
#  23673467,
#  23691214,
#  24160934,
#  24456891,
#  24544886,
#  24574846,
#  24576798,
#  24590559,
#  24592620,
#  24601933,
#  24611480,
#  24621346,
#  24624390,
#  24632783,
#  24634619,
#  24639786,
#  24644284,
#  24663685,
#  24685216,
#  24689876,
#  24697168,
#  24698734,
#  24704440,
#  24751220,
#  24839761,
#  24871345,
#  24945015,
#  24945528,
#  24947180,
#  24947445,
#  24972450,
#  24995924,
#  25368242,
#  25385506,
#  25397613,
#  25404031,
#  25406773,
#  25409673,
#  25477557,
#  25495585,
#  25551179,
#  25706944,
#  25708606,
#  25708606,
#  25743892,
#  25769488,
#  25774839,
#  25936371,
#  26024228,
#  26024696,
#  26032571,
#  26102718,
#  26104774,
#  26329288,
#  26916247,
#  26920765,
#  26939165,
#  26941960,
#  26959343,
#  27067718,
#  27069096,
#  27070583,
#  27071255,
#  27073010,
#  27075563,
#  27081216,
#  27088157,
#  27177605,
#  27199905,
#  27206124,
#  27215170,
#  27218731,
#  27271796,
#  27284327,
#  27412072,
#  27459106,
#  27466680,
#  27497293,
#  27500854,
#  27850041,
#  27850975,
#  27854068,
#  27862472,
#  27862866,
#  27917220,
#  27953920,
#  27959295,
#  28439325,
#  28498001,
#  28501721,
#  28538306,
#  28546230,
#  28571923,
#  28600475,
#  28611323,
#  28625627,
#  29366429,
#  29391602,
#  29408637,
#  29436338,
#  29463840,
#  29467576,
#  29524057,
#  29541174,
#  29543710,
#  29556453,
#  29557778,
#  29564062,
#  29567630,
#  29571577,
#  29575102,
#  29581678,
#  29584945,
#  29588767,
#  29602261,
#  29630623,
#  29688630,
#  29861558,
#  29878974,
#  29880157,
#  29881324,
#  29882803,
#  29889230,
#  29897872,
#  29912212,
#  29921691,
#  29928757,
#  29937454,
#  30288706,
#  30316052,
#  30328710,
#  30465849,
#  30474615,
#  30760894,
#  30955592,
#  30958060,
#  30964985,
#  30989953,
#  31358660,
#  31867735,
#  31872278,
#  31891705,
#  31918479,
#  31987109,
#  31992524,
#  31994819,
#  31998409,
#  32062949,
#  32063971,
#  32074997,
#  32094803,
#  32094842,
#  32149754,
#  32209934,
#  32334540,
#  32339606,
#  32394705,
#  32430927,
#  32730654,
#  32795252,
#  32808369,
#  32866457,
#  32901076,
#  32909717,
#  33082607,
#  33200802,
#  33432761,
#  33534300,
#  33543491,
#  34020534,
#  34196032,
#  34314416,
#  34324257,
#  34358601,
#  34447226,
#  34459614,
#  34466316,
#  34478273,
#  34487398,
#  34492536,
#  34497153,
#  34498004,
#  34498275,
#  34523593,
#  34553612,
#  34592037,
#  34594730,
#  34606296,
#  34661678,
#  34684157,
#  34724361,
#  34745882,
#  34758978,
#  34799386,
#  34801124,
#  34847427,
#  34852109,
#  34883804,
#  34883804,
#  35251748,
#  35252598,
#  35260631,
#  35393071,
#  35396839,
#  35516825,
#  35615600,
#  35658353,
#  35858164,
#  35919756,
#  36007034,
#  36030044,
#  36451287,
#  36478052,
#  36750583,
#  36772863,
#  36793577,
#  36794995,
#  36850442,
#  36908965,
#  36914355,
#  36915547,
#  36924377,
#  36925746,
#  36927363,
#  36936358,
#  36938051,
#  36938235,
#  36947382,
#  36947382,
#  36956972,
#  36972348,
#  36981134,
#  36987534,
#  37052502,
#  37090620,
#  37090620,
#  37105940,
#  37120846,
#  37217127,
#  37254774,
#  37255105,
#  37258937,
#  37260075,
#  37261652,
#  37262673,
#  37263479,
#  37264221,
#  37286784,
#  37695659,
#  37699007,
#  37711731,
#  37728104,
#  37729288,
#  37818720,
#  37848733,
#  37977693,
#  37981686,
#  38370228,
#  38372101,
#  38409870,
#  38446370,
#  39214638,
#  39226665,
#  39231370,
#  39234119,
#  39248876,
#  39386049,
#  39399338,
#  39399735,
#  39403638,
#  39415171,
#  39428787,
#  39446070,
#  39448641,
#  39450522,
#  39466716,
#  39475242,
#  39494028,
#  39603961,
#  39651058,
#  39671650,
#  39675309,
#  39717532,
#  39724695,
#  39728327,
#  39731051,
#  40159225,
#  40161749,
#  40176451,
#  40274712,
#  40577414,
#  40795740,
#  41706359,
#  41722742,
#  41800554,
#  41828866,
#  41838293,
#  41838958,
#  41843933,
#  41846508,
#  41858327,
#  41858358,
#  41868983,
#  41893590,
#  41918047,
#  41925299,
#  41935257,
#  41937557,
#  41961937,
#  41961971,
#  41998972,
#  42090768,
#  42112130,
#  42181048,
#  42182403,
#  42183257,
#  42183901,
#  42187109,
#  42187630,
#  42594905,
#  42617767,
#  42633949,
#  42649535,
#  42680007,
#  42692762,
#  42692762,
#  42777269,
#  42784511,
#  42972779,
#  43011325,
#  43242841,
#  43267973,
#  43334764,
#  43858028,
#  43919918,
#  44158892,
#  44159026,
#  44247227,
#  44289907,
#  44291859,
#  44317198,
#  44318307,
#  44335185,
#  44357385,
#  44358141,
#  44377383,
#  44383224,
#  44383224,
#  44383269,
#  44447841,
#  44546029,
#  44570672,
#  44572787,
#  44648006,
#  44648925,
#  44652408,
#  44674118,
#  44694963,
#  44735249,
#  44737963,
#  45071137,
#  45083556,
#  45083594,
#  45083732,
#  45086729,
#  45107306,
#  45236081,
#  45368351,
#  45706352,
#  45717380,
#  45763258,
#  45908274,
#  46310522,
#  46322679,
#  46572341,
#  46595267,
#  46627653,
#  46664586,
#  46756283,
#  46767474,
#  46770231,
#  46770352,
#  46783945,
#  46795488,
#  46796537,
#  46848150,
#  46848150,
#  46849116,
#  46849163,
#  46856107,
#  46887859,
#  46902352,
#  46920668,
#  46924807,
#  47001072,
#  47016953,
#  47033545,
#  47036535,
#  47038188,
#  47109526,
#  47109686,
#  47111010,
#  47113434,
#  47114781,
#  47153631,
#  47160055,
#  47163247,
#  47544099,
#  47563076,
#  47563478,
#  47563552,
#  47595361,
#  47612282,
#  47629722,
#  47643770,
#  47651257,
#  47666697,
#  47674362,
#  47812330,
#  48177074,
#  48180896,
#  48206747,
#  48207292,
#  48221764,
#  48246577,
#  48580582,
#  48790214,
#  48911341,
#  49087716,
#  49120647,
#  49145008,
#  49231791,
#  49234805,
#  49234879,
#  49256594,
#  49257108,
#  49261635,
#  49262010,
#  49303208,
#  49308476,
#  49309588,
#  49357645,
#  49516437,
#  49518541,
#  49563269,
#  49563810,
#  49564329,
#  49570720,
#  49572077,
#  49573088,
#  49578259,
#  49621697,
#  50006688,
#  50023446,
#  50024557,
#  50027622,
#  50037252,
#  50071123,
#  50151830,
#  50153775,
#  50170505,
#  50171862,
#  50338444,
#  50339760,
#  50449886,
#  50645901,
#  50726614,
#  50756810,
#  51253882,
#  51529264,
#  51542802,
#  51680456,
#  51684915,
#  51696979,
#  51698379,
#  51703551,
#  51717094,
#  51722094,
#  51739997,
#  51741908,
#  51744988,
#  51754496,
#  51758315,
#  51767169,
#  51774140,
#  51802677,
#  51806836,
#  51873515,
#  51905610,
#  52000852,
#  52030666,
#  52030666,
#  52038644,
#  52040052,
#  52051761,
#  52087210,
#  52125510,
#  52473338,
#  52473514,
#  52480802,
#  52488399,
#  52494176,
#  52498259,
#  52500576,
#  52523340,
#  52539912,
#  52568365,
#  52591252,
#  52626362,
#  52890109,
#  53062809,
#  53109445,
#  53130377,
#  53130543,
#  53152838,
#  53334571,
#  53476956,
#  53719286,
#  53999086,
#  54003324,
#  54014309,
#  54024146,
#  54136724,
#  54137049,
#  54146999,
#  54147648,
#  54156589,
#  54157151,
#  54179526,
#  54186411,
#  54190263,
#  54194455,
#  54197108,
#  54202214,
#  54245430,
#  54270300,
#  54274644,
#  54418791,
#  54450638,
#  54491765,
#  54491997,
#  54501262,
#  54553396,
#  54569203,
#  54579620,
#  54911327,
#  54916062,
#  54929912,
#  55062436,
#  55210218,
#  55261332,
#  55282183,
#  55374361,
#  ...]

# %% [markdown]
# #### Open all VIAF IDs of people to check if they exist

# %%
for viaf_id in people_list_viaf:
    url = 'https://viaf.org/viaf/{}/justlinks.json'.format(viaf_id)
    print(url)
    try:
        urllib.request.urlopen(url)
    except:
        print('DOES NOT EXIST')
# Out:
# https://viaf.org/viaf/26221/justlinks.json
# https://viaf.org/viaf/29153/justlinks.json
# https://viaf.org/viaf/30977/justlinks.json
# https://viaf.org/viaf/40093/justlinks.json
# https://viaf.org/viaf/40220/justlinks.json
# https://viaf.org/viaf/42182/justlinks.json
# https://viaf.org/viaf/42225/justlinks.json
# https://viaf.org/viaf/46244/justlinks.json
# https://viaf.org/viaf/48609/justlinks.json
# https://viaf.org/viaf/60021/justlinks.json
# https://viaf.org/viaf/77959/justlinks.json
# https://viaf.org/viaf/85044/justlinks.json
# https://viaf.org/viaf/93909/justlinks.json
# https://viaf.org/viaf/108057/justlinks.json
# https://viaf.org/viaf/117486/justlinks.json
# https://viaf.org/viaf/126731/justlinks.json
# https://viaf.org/viaf/132112/justlinks.json
# https://viaf.org/viaf/155498/justlinks.json
# https://viaf.org/viaf/156009/justlinks.json
# https://viaf.org/viaf/175833/justlinks.json
# https://viaf.org/viaf/176192/justlinks.json
# https://viaf.org/viaf/194577/justlinks.json
# https://viaf.org/viaf/237497/justlinks.json
# https://viaf.org/viaf/284244/justlinks.json
# https://viaf.org/viaf/300140/justlinks.json
# https://viaf.org/viaf/361641/justlinks.json
# https://viaf.org/viaf/363997/justlinks.json
# https://viaf.org/viaf/366106/justlinks.json
# https://viaf.org/viaf/441684/justlinks.json
# https://viaf.org/viaf/774683/justlinks.json
# https://viaf.org/viaf/792439/justlinks.json
# https://viaf.org/viaf/792879/justlinks.json
# https://viaf.org/viaf/805714/justlinks.json
# https://viaf.org/viaf/805877/justlinks.json
# https://viaf.org/viaf/822823/justlinks.json
# https://viaf.org/viaf/837905/justlinks.json
# https://viaf.org/viaf/849367/justlinks.json
# https://viaf.org/viaf/895409/justlinks.json
# https://viaf.org/viaf/934497/justlinks.json
# https://viaf.org/viaf/956203/justlinks.json
# https://viaf.org/viaf/1263219/justlinks.json
# https://viaf.org/viaf/1456147/justlinks.json
# https://viaf.org/viaf/1499948/justlinks.json
# https://viaf.org/viaf/1562998/justlinks.json
# https://viaf.org/viaf/2319765/justlinks.json
# https://viaf.org/viaf/2327009/justlinks.json
# https://viaf.org/viaf/2331192/justlinks.json
# https://viaf.org/viaf/2358196/justlinks.json
# https://viaf.org/viaf/2378232/justlinks.json
# https://viaf.org/viaf/2411429/justlinks.json
# https://viaf.org/viaf/2474502/justlinks.json
# https://viaf.org/viaf/2479682/justlinks.json
# https://viaf.org/viaf/2495579/justlinks.json
# https://viaf.org/viaf/2496935/justlinks.json
# https://viaf.org/viaf/2508854/justlinks.json
# https://viaf.org/viaf/2515242/justlinks.json
# https://viaf.org/viaf/2519559/justlinks.json
# https://viaf.org/viaf/2521078/justlinks.json
# https://viaf.org/viaf/2546468/justlinks.json
# https://viaf.org/viaf/2551924/justlinks.json
# https://viaf.org/viaf/2556684/justlinks.json
# https://viaf.org/viaf/2589083/justlinks.json
# https://viaf.org/viaf/2604336/justlinks.json
# https://viaf.org/viaf/2604452/justlinks.json
# https://viaf.org/viaf/2735066/justlinks.json
# https://viaf.org/viaf/2769606/justlinks.json
# https://viaf.org/viaf/2788543/justlinks.json
# https://viaf.org/viaf/2809212/justlinks.json
# https://viaf.org/viaf/2818528/justlinks.json
# https://viaf.org/viaf/2818730/justlinks.json
# https://viaf.org/viaf/2821751/justlinks.json
# https://viaf.org/viaf/2832039/justlinks.json
# https://viaf.org/viaf/2832981/justlinks.json
# https://viaf.org/viaf/2870639/justlinks.json
# https://viaf.org/viaf/2900775/justlinks.json
# https://viaf.org/viaf/3086266/justlinks.json
# https://viaf.org/viaf/3265477/justlinks.json
# https://viaf.org/viaf/3267042/justlinks.json
# https://viaf.org/viaf/3393065/justlinks.json
# https://viaf.org/viaf/3396615/justlinks.json
# https://viaf.org/viaf/3544559/justlinks.json
# https://viaf.org/viaf/3893245/justlinks.json
# https://viaf.org/viaf/3908040/justlinks.json
# https://viaf.org/viaf/4499544/justlinks.json
# https://viaf.org/viaf/4791162/justlinks.json
# https://viaf.org/viaf/4798582/justlinks.json
# https://viaf.org/viaf/4805023/justlinks.json
# https://viaf.org/viaf/4805598/justlinks.json
# https://viaf.org/viaf/4822479/justlinks.json
# https://viaf.org/viaf/4919216/justlinks.json
# https://viaf.org/viaf/4919216/justlinks.json
# https://viaf.org/viaf/4940012/justlinks.json
# https://viaf.org/viaf/4940467/justlinks.json
# https://viaf.org/viaf/4940582/justlinks.json
# https://viaf.org/viaf/4945401/justlinks.json
# https://viaf.org/viaf/4951927/justlinks.json
# https://viaf.org/viaf/4956694/justlinks.json
# https://viaf.org/viaf/4973470/justlinks.json
# https://viaf.org/viaf/5017560/justlinks.json
# https://viaf.org/viaf/5041312/justlinks.json
# https://viaf.org/viaf/5046077/justlinks.json
# https://viaf.org/viaf/5061772/justlinks.json
# https://viaf.org/viaf/5065380/justlinks.json
# https://viaf.org/viaf/5113867/justlinks.json
# https://viaf.org/viaf/5168708/justlinks.json
# https://viaf.org/viaf/5190555/justlinks.json
# https://viaf.org/viaf/5266955/justlinks.json
# https://viaf.org/viaf/5273899/justlinks.json
# https://viaf.org/viaf/5274099/justlinks.json
# https://viaf.org/viaf/5274580/justlinks.json
# https://viaf.org/viaf/5275263/justlinks.json
# https://viaf.org/viaf/5298954/justlinks.json
# https://viaf.org/viaf/5325507/justlinks.json
# https://viaf.org/viaf/5362067/justlinks.json
# https://viaf.org/viaf/5362235/justlinks.json
# https://viaf.org/viaf/5735749/justlinks.json
# https://viaf.org/viaf/5842045/justlinks.json
# https://viaf.org/viaf/5861609/justlinks.json
# https://viaf.org/viaf/5863902/justlinks.json
# https://viaf.org/viaf/5874981/justlinks.json
# https://viaf.org/viaf/6014298/justlinks.json
# https://viaf.org/viaf/6167427/justlinks.json
# https://viaf.org/viaf/6215669/justlinks.json
# https://viaf.org/viaf/6273611/justlinks.json
# https://viaf.org/viaf/6276752/justlinks.json
# https://viaf.org/viaf/6352134/justlinks.json
# https://viaf.org/viaf/6352962/justlinks.json
# https://viaf.org/viaf/6353924/justlinks.json
# https://viaf.org/viaf/6363145/justlinks.json
# https://viaf.org/viaf/6374073/justlinks.json
# https://viaf.org/viaf/6387970/justlinks.json
# https://viaf.org/viaf/6410027/justlinks.json
# https://viaf.org/viaf/6469121/justlinks.json
# https://viaf.org/viaf/6800965/justlinks.json
# https://viaf.org/viaf/6948619/justlinks.json
# https://viaf.org/viaf/6953888/justlinks.json
# https://viaf.org/viaf/7241919/justlinks.json
# https://viaf.org/viaf/7244833/justlinks.json
# https://viaf.org/viaf/7246209/justlinks.json
# https://viaf.org/viaf/7248600/justlinks.json
# https://viaf.org/viaf/7261692/justlinks.json
# https://viaf.org/viaf/7263930/justlinks.json
# https://viaf.org/viaf/7266580/justlinks.json
# https://viaf.org/viaf/7326235/justlinks.json
# https://viaf.org/viaf/7341469/justlinks.json
# https://viaf.org/viaf/7380094/justlinks.json
# https://viaf.org/viaf/7381185/justlinks.json
# https://viaf.org/viaf/7400805/justlinks.json
# https://viaf.org/viaf/7405452/justlinks.json
# https://viaf.org/viaf/7415128/justlinks.json
# https://viaf.org/viaf/7423980/justlinks.json
# https://viaf.org/viaf/7425031/justlinks.json
# https://viaf.org/viaf/7425989/justlinks.json
# https://viaf.org/viaf/7425989/justlinks.json
# https://viaf.org/viaf/7426596/justlinks.json
# https://viaf.org/viaf/7428836/justlinks.json
# https://viaf.org/viaf/7440183/justlinks.json
# https://viaf.org/viaf/7453054/justlinks.json
# https://viaf.org/viaf/7476431/justlinks.json
# https://viaf.org/viaf/7502835/justlinks.json
# https://viaf.org/viaf/7546811/justlinks.json
# https://viaf.org/viaf/7725325/justlinks.json
# https://viaf.org/viaf/7731668/justlinks.json
# https://viaf.org/viaf/7732279/justlinks.json
# https://viaf.org/viaf/7732694/justlinks.json
# https://viaf.org/viaf/7736875/justlinks.json
# https://viaf.org/viaf/7737032/justlinks.json
# https://viaf.org/viaf/7791271/justlinks.json
# https://viaf.org/viaf/7820717/justlinks.json
# https://viaf.org/viaf/8145335/justlinks.json
# https://viaf.org/viaf/8157223/justlinks.json
# https://viaf.org/viaf/8167410/justlinks.json
# https://viaf.org/viaf/8181420/justlinks.json
# https://viaf.org/viaf/8183900/justlinks.json
# https://viaf.org/viaf/8184591/justlinks.json
# https://viaf.org/viaf/8192151/justlinks.json
# https://viaf.org/viaf/8199472/justlinks.json
# https://viaf.org/viaf/8282870/justlinks.json
# https://viaf.org/viaf/8446526/justlinks.json
# https://viaf.org/viaf/8461797/justlinks.json
# https://viaf.org/viaf/8493468/justlinks.json
# https://viaf.org/viaf/8583674/justlinks.json
# https://viaf.org/viaf/8599154/justlinks.json
# https://viaf.org/viaf/8790598/justlinks.json
# https://viaf.org/viaf/8814941/justlinks.json
# https://viaf.org/viaf/8928748/justlinks.json
# https://viaf.org/viaf/9324349/justlinks.json
# https://viaf.org/viaf/9720045/justlinks.json
# https://viaf.org/viaf/9722692/justlinks.json
# https://viaf.org/viaf/9787916/justlinks.json
# https://viaf.org/viaf/9798235/justlinks.json
# https://viaf.org/viaf/9827268/justlinks.json
# https://viaf.org/viaf/9837888/justlinks.json
# https://viaf.org/viaf/9849392/justlinks.json
# https://viaf.org/viaf/9856920/justlinks.json
# https://viaf.org/viaf/9857012/justlinks.json
# https://viaf.org/viaf/9865630/justlinks.json
# https://viaf.org/viaf/9877713/justlinks.json
# https://viaf.org/viaf/9887952/justlinks.json
# https://viaf.org/viaf/9894043/justlinks.json
# https://viaf.org/viaf/9926861/justlinks.json
# https://viaf.org/viaf/9928566/justlinks.json
# https://viaf.org/viaf/9965263/justlinks.json
# https://viaf.org/viaf/9970490/justlinks.json
# https://viaf.org/viaf/9979313/justlinks.json
# https://viaf.org/viaf/10034259/justlinks.json
# https://viaf.org/viaf/10078948/justlinks.json
# https://viaf.org/viaf/10151542/justlinks.json
# https://viaf.org/viaf/10185310/justlinks.json
# https://viaf.org/viaf/10188460/justlinks.json
# https://viaf.org/viaf/10188879/justlinks.json
# https://viaf.org/viaf/10198482/justlinks.json
# https://viaf.org/viaf/10199025/justlinks.json
# https://viaf.org/viaf/10211770/justlinks.json
# https://viaf.org/viaf/10237226/justlinks.json
# https://viaf.org/viaf/10584218/justlinks.json
# https://viaf.org/viaf/10625832/justlinks.json
# https://viaf.org/viaf/10625832/justlinks.json
# https://viaf.org/viaf/10627197/justlinks.json
# https://viaf.org/viaf/10629468/justlinks.json
# https://viaf.org/viaf/10640462/justlinks.json
# https://viaf.org/viaf/10658053/justlinks.json
# https://viaf.org/viaf/10760478/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/10763721/justlinks.json
# https://viaf.org/viaf/10782288/justlinks.json
# https://viaf.org/viaf/10908780/justlinks.json
# https://viaf.org/viaf/10990268/justlinks.json
# https://viaf.org/viaf/11058091/justlinks.json
# https://viaf.org/viaf/11132722/justlinks.json
# https://viaf.org/viaf/11260511/justlinks.json
# https://viaf.org/viaf/11266459/justlinks.json
# https://viaf.org/viaf/11267514/justlinks.json
# https://viaf.org/viaf/11311615/justlinks.json
# https://viaf.org/viaf/11377079/justlinks.json
# https://viaf.org/viaf/11399968/justlinks.json
# https://viaf.org/viaf/11462035/justlinks.json
# https://viaf.org/viaf/12179247/justlinks.json
# https://viaf.org/viaf/12179846/justlinks.json
# https://viaf.org/viaf/12249427/justlinks.json
# https://viaf.org/viaf/12298108/justlinks.json
# https://viaf.org/viaf/12306898/justlinks.json
# https://viaf.org/viaf/12323361/justlinks.json
# https://viaf.org/viaf/12343831/justlinks.json
# https://viaf.org/viaf/12346702/justlinks.json
# https://viaf.org/viaf/12355548/justlinks.json
# https://viaf.org/viaf/12377413/justlinks.json
# https://viaf.org/viaf/12396611/justlinks.json
# https://viaf.org/viaf/12405220/justlinks.json
# https://viaf.org/viaf/12411440/justlinks.json
# https://viaf.org/viaf/12416181/justlinks.json
# https://viaf.org/viaf/12427288/justlinks.json
# https://viaf.org/viaf/12463453/justlinks.json
# https://viaf.org/viaf/12476776/justlinks.json
# https://viaf.org/viaf/12545856/justlinks.json
# https://viaf.org/viaf/12577068/justlinks.json
# https://viaf.org/viaf/12619430/justlinks.json
# https://viaf.org/viaf/12646823/justlinks.json
# https://viaf.org/viaf/12647423/justlinks.json
# https://viaf.org/viaf/12650271/justlinks.json
# https://viaf.org/viaf/12651892/justlinks.json
# https://viaf.org/viaf/12652091/justlinks.json
# https://viaf.org/viaf/12652275/justlinks.json
# https://viaf.org/viaf/12676360/justlinks.json
# https://viaf.org/viaf/12677948/justlinks.json
# https://viaf.org/viaf/12735772/justlinks.json
# https://viaf.org/viaf/13047713/justlinks.json
# https://viaf.org/viaf/13086266/justlinks.json
# https://viaf.org/viaf/13087412/justlinks.json
# https://viaf.org/viaf/13087514/justlinks.json
# https://viaf.org/viaf/13091055/justlinks.json
# https://viaf.org/viaf/13091713/justlinks.json
# https://viaf.org/viaf/13101068/justlinks.json
# https://viaf.org/viaf/13116531/justlinks.json
# https://viaf.org/viaf/13116680/justlinks.json
# https://viaf.org/viaf/13120553/justlinks.json
# https://viaf.org/viaf/13226576/justlinks.json
# https://viaf.org/viaf/13244783/justlinks.json
# https://viaf.org/viaf/13251888/justlinks.json
# https://viaf.org/viaf/13471767/justlinks.json
# https://viaf.org/viaf/13520055/justlinks.json
# https://viaf.org/viaf/13697267/justlinks.json
# https://viaf.org/viaf/13738984/justlinks.json
# https://viaf.org/viaf/13752267/justlinks.json
# https://viaf.org/viaf/13790434/justlinks.json
# https://viaf.org/viaf/14600129/justlinks.json
# https://viaf.org/viaf/14609907/justlinks.json
# https://viaf.org/viaf/14611974/justlinks.json
# https://viaf.org/viaf/14625511/justlinks.json
# https://viaf.org/viaf/14626888/justlinks.json
# https://viaf.org/viaf/14631514/justlinks.json
# https://viaf.org/viaf/14637261/justlinks.json
# https://viaf.org/viaf/14644323/justlinks.json
# https://viaf.org/viaf/14671283/justlinks.json
# https://viaf.org/viaf/14691576/justlinks.json
# https://viaf.org/viaf/14772060/justlinks.json
# https://viaf.org/viaf/14773105/justlinks.json
# https://viaf.org/viaf/14779364/justlinks.json
# https://viaf.org/viaf/14789424/justlinks.json
# https://viaf.org/viaf/14793378/justlinks.json
# https://viaf.org/viaf/14793931/justlinks.json
# https://viaf.org/viaf/14798553/justlinks.json
# https://viaf.org/viaf/14799615/justlinks.json
# https://viaf.org/viaf/14804235/justlinks.json
# https://viaf.org/viaf/14814119/justlinks.json
# https://viaf.org/viaf/14869558/justlinks.json
# https://viaf.org/viaf/14876201/justlinks.json
# https://viaf.org/viaf/14901383/justlinks.json
# https://viaf.org/viaf/14937238/justlinks.json
# https://viaf.org/viaf/15040910/justlinks.json
# https://viaf.org/viaf/15117589/justlinks.json
# https://viaf.org/viaf/15141474/justlinks.json
# https://viaf.org/viaf/15141636/justlinks.json
# https://viaf.org/viaf/15552397/justlinks.json
# https://viaf.org/viaf/15610538/justlinks.json
# https://viaf.org/viaf/15665190/justlinks.json
# https://viaf.org/viaf/15716435/justlinks.json
# https://viaf.org/viaf/15859805/justlinks.json
# https://viaf.org/viaf/15863258/justlinks.json
# https://viaf.org/viaf/16196881/justlinks.json
# https://viaf.org/viaf/16197107/justlinks.json
# https://viaf.org/viaf/16203838/justlinks.json
# https://viaf.org/viaf/16249061/justlinks.json
# https://viaf.org/viaf/16304279/justlinks.json
# https://viaf.org/viaf/16783793/justlinks.json
# https://viaf.org/viaf/17081533/justlinks.json
# https://viaf.org/viaf/17094576/justlinks.json
# https://viaf.org/viaf/17118124/justlinks.json
# https://viaf.org/viaf/17213123/justlinks.json
# https://viaf.org/viaf/17231738/justlinks.json
# https://viaf.org/viaf/17231985/justlinks.json
# https://viaf.org/viaf/17232714/justlinks.json
# https://viaf.org/viaf/17237181/justlinks.json
# https://viaf.org/viaf/17251152/justlinks.json
# https://viaf.org/viaf/17258330/justlinks.json
# https://viaf.org/viaf/17261560/justlinks.json
# https://viaf.org/viaf/17264481/justlinks.json
# https://viaf.org/viaf/17266522/justlinks.json
# https://viaf.org/viaf/17277670/justlinks.json
# https://viaf.org/viaf/17320058/justlinks.json
# https://viaf.org/viaf/17355999/justlinks.json
# https://viaf.org/viaf/17366406/justlinks.json
# https://viaf.org/viaf/17414384/justlinks.json
# https://viaf.org/viaf/17427540/justlinks.json
# https://viaf.org/viaf/17440889/justlinks.json
# https://viaf.org/viaf/17446949/justlinks.json
# https://viaf.org/viaf/17459259/justlinks.json
# https://viaf.org/viaf/17525359/justlinks.json
# https://viaf.org/viaf/17561749/justlinks.json
# https://viaf.org/viaf/17571331/justlinks.json
# https://viaf.org/viaf/17571781/justlinks.json
# https://viaf.org/viaf/17616048/justlinks.json
# https://viaf.org/viaf/17997690/justlinks.json
# https://viaf.org/viaf/18002661/justlinks.json
# https://viaf.org/viaf/18003738/justlinks.json
# https://viaf.org/viaf/18033780/justlinks.json
# https://viaf.org/viaf/18100406/justlinks.json
# https://viaf.org/viaf/18155373/justlinks.json
# https://viaf.org/viaf/18337021/justlinks.json
# https://viaf.org/viaf/18431861/justlinks.json
# https://viaf.org/viaf/18581471/justlinks.json
# https://viaf.org/viaf/18636408/justlinks.json
# https://viaf.org/viaf/18647172/justlinks.json
# https://viaf.org/viaf/18647753/justlinks.json
# https://viaf.org/viaf/18650208/justlinks.json
# https://viaf.org/viaf/18664895/justlinks.json
# https://viaf.org/viaf/18897214/justlinks.json
# https://viaf.org/viaf/19552454/justlinks.json
# https://viaf.org/viaf/19552973/justlinks.json
# https://viaf.org/viaf/19553659/justlinks.json
# https://viaf.org/viaf/19556565/justlinks.json
# https://viaf.org/viaf/19557125/justlinks.json
# https://viaf.org/viaf/19635062/justlinks.json
# https://viaf.org/viaf/19668788/justlinks.json
# https://viaf.org/viaf/19687783/justlinks.json
# https://viaf.org/viaf/19709327/justlinks.json
# https://viaf.org/viaf/19710661/justlinks.json
# https://viaf.org/viaf/19712599/justlinks.json
# https://viaf.org/viaf/19715963/justlinks.json
# https://viaf.org/viaf/19724806/justlinks.json
# https://viaf.org/viaf/19725880/justlinks.json
# https://viaf.org/viaf/19754288/justlinks.json
# https://viaf.org/viaf/19790673/justlinks.json
# https://viaf.org/viaf/19810665/justlinks.json
# https://viaf.org/viaf/19827688/justlinks.json
# https://viaf.org/viaf/19827688/justlinks.json
# https://viaf.org/viaf/19885929/justlinks.json
# https://viaf.org/viaf/20018411/justlinks.json
# https://viaf.org/viaf/20020684/justlinks.json
# https://viaf.org/viaf/20025298/justlinks.json
# https://viaf.org/viaf/20026471/justlinks.json
# https://viaf.org/viaf/20029793/justlinks.json
# https://viaf.org/viaf/20033542/justlinks.json
# https://viaf.org/viaf/20078711/justlinks.json
# https://viaf.org/viaf/20080051/justlinks.json
# https://viaf.org/viaf/20112530/justlinks.json
# https://viaf.org/viaf/20407456/justlinks.json
# https://viaf.org/viaf/20438019/justlinks.json
# https://viaf.org/viaf/20461029/justlinks.json
# https://viaf.org/viaf/20463354/justlinks.json
# https://viaf.org/viaf/20857375/justlinks.json
# https://viaf.org/viaf/21021187/justlinks.json
# https://viaf.org/viaf/21021806/justlinks.json
# https://viaf.org/viaf/21105841/justlinks.json
# https://viaf.org/viaf/21105841/justlinks.json
# https://viaf.org/viaf/21114185/justlinks.json
# https://viaf.org/viaf/21274382/justlinks.json
# https://viaf.org/viaf/21592774/justlinks.json
# https://viaf.org/viaf/21706085/justlinks.json
# https://viaf.org/viaf/21982758/justlinks.json
# https://viaf.org/viaf/21985874/justlinks.json
# https://viaf.org/viaf/22000018/justlinks.json
# https://viaf.org/viaf/22010611/justlinks.json
# https://viaf.org/viaf/22018516/justlinks.json
# https://viaf.org/viaf/22063536/justlinks.json
# https://viaf.org/viaf/22084759/justlinks.json
# https://viaf.org/viaf/22145254/justlinks.json
# https://viaf.org/viaf/22146457/justlinks.json
# https://viaf.org/viaf/22150497/justlinks.json
# https://viaf.org/viaf/22151653/justlinks.json
# https://viaf.org/viaf/22167754/justlinks.json
# https://viaf.org/viaf/22182610/justlinks.json
# https://viaf.org/viaf/22200045/justlinks.json
# https://viaf.org/viaf/22201759/justlinks.json
# https://viaf.org/viaf/22209566/justlinks.json
# https://viaf.org/viaf/22217492/justlinks.json
# https://viaf.org/viaf/22237799/justlinks.json
# https://viaf.org/viaf/22269855/justlinks.json
# https://viaf.org/viaf/22369050/justlinks.json
# https://viaf.org/viaf/22468266/justlinks.json
# https://viaf.org/viaf/22469858/justlinks.json
# https://viaf.org/viaf/22478268/justlinks.json
# https://viaf.org/viaf/22479704/justlinks.json
# https://viaf.org/viaf/22480316/justlinks.json
# https://viaf.org/viaf/22482519/justlinks.json
# https://viaf.org/viaf/22485966/justlinks.json
# https://viaf.org/viaf/22510525/justlinks.json
# https://viaf.org/viaf/22923750/justlinks.json
# https://viaf.org/viaf/22953147/justlinks.json
# https://viaf.org/viaf/23083871/justlinks.json
# https://viaf.org/viaf/23196916/justlinks.json
# https://viaf.org/viaf/23200544/justlinks.json
# https://viaf.org/viaf/23282729/justlinks.json
# https://viaf.org/viaf/23353145/justlinks.json
# https://viaf.org/viaf/23471562/justlinks.json
# https://viaf.org/viaf/23568272/justlinks.json
# https://viaf.org/viaf/23581458/justlinks.json
# https://viaf.org/viaf/23649689/justlinks.json
# https://viaf.org/viaf/23673467/justlinks.json
# https://viaf.org/viaf/23691214/justlinks.json
# https://viaf.org/viaf/24160934/justlinks.json
# https://viaf.org/viaf/24456891/justlinks.json
# https://viaf.org/viaf/24544886/justlinks.json
# https://viaf.org/viaf/24574846/justlinks.json
# https://viaf.org/viaf/24576798/justlinks.json
# https://viaf.org/viaf/24590559/justlinks.json
# https://viaf.org/viaf/24592620/justlinks.json
# https://viaf.org/viaf/24601933/justlinks.json
# https://viaf.org/viaf/24611480/justlinks.json
# https://viaf.org/viaf/24621346/justlinks.json
# https://viaf.org/viaf/24624390/justlinks.json
# https://viaf.org/viaf/24632783/justlinks.json
# https://viaf.org/viaf/24634619/justlinks.json
# https://viaf.org/viaf/24639786/justlinks.json
# https://viaf.org/viaf/24644284/justlinks.json
# https://viaf.org/viaf/24663685/justlinks.json
# https://viaf.org/viaf/24685216/justlinks.json
# https://viaf.org/viaf/24689876/justlinks.json
# https://viaf.org/viaf/24697168/justlinks.json
# https://viaf.org/viaf/24698734/justlinks.json
# https://viaf.org/viaf/24704440/justlinks.json
# https://viaf.org/viaf/24751220/justlinks.json
# https://viaf.org/viaf/24839761/justlinks.json
# https://viaf.org/viaf/24871345/justlinks.json
# https://viaf.org/viaf/24945015/justlinks.json
# https://viaf.org/viaf/24945528/justlinks.json
# https://viaf.org/viaf/24947180/justlinks.json
# https://viaf.org/viaf/24947445/justlinks.json
# https://viaf.org/viaf/24972450/justlinks.json
# https://viaf.org/viaf/24995924/justlinks.json
# https://viaf.org/viaf/25368242/justlinks.json
# https://viaf.org/viaf/25385506/justlinks.json
# https://viaf.org/viaf/25397613/justlinks.json
# https://viaf.org/viaf/25404031/justlinks.json
# https://viaf.org/viaf/25406773/justlinks.json
# https://viaf.org/viaf/25409673/justlinks.json
# https://viaf.org/viaf/25477557/justlinks.json
# https://viaf.org/viaf/25495585/justlinks.json
# https://viaf.org/viaf/25551179/justlinks.json
# https://viaf.org/viaf/25706944/justlinks.json
# https://viaf.org/viaf/25708606/justlinks.json
# https://viaf.org/viaf/25708606/justlinks.json
# https://viaf.org/viaf/25743892/justlinks.json
# https://viaf.org/viaf/25769488/justlinks.json
# https://viaf.org/viaf/25774839/justlinks.json
# https://viaf.org/viaf/25936371/justlinks.json
# https://viaf.org/viaf/26024228/justlinks.json
# https://viaf.org/viaf/26024696/justlinks.json
# https://viaf.org/viaf/26032571/justlinks.json
# https://viaf.org/viaf/26102718/justlinks.json
# https://viaf.org/viaf/26104774/justlinks.json
# https://viaf.org/viaf/26329288/justlinks.json
# https://viaf.org/viaf/26916247/justlinks.json
# https://viaf.org/viaf/26920765/justlinks.json
# https://viaf.org/viaf/26939165/justlinks.json
# https://viaf.org/viaf/26941960/justlinks.json
# https://viaf.org/viaf/26959343/justlinks.json
# https://viaf.org/viaf/27067718/justlinks.json
# https://viaf.org/viaf/27069096/justlinks.json
# https://viaf.org/viaf/27070583/justlinks.json
# https://viaf.org/viaf/27071255/justlinks.json
# https://viaf.org/viaf/27073010/justlinks.json
# https://viaf.org/viaf/27075563/justlinks.json
# https://viaf.org/viaf/27081216/justlinks.json
# https://viaf.org/viaf/27088157/justlinks.json
# https://viaf.org/viaf/27177605/justlinks.json
# https://viaf.org/viaf/27199905/justlinks.json
# https://viaf.org/viaf/27206124/justlinks.json
# https://viaf.org/viaf/27215170/justlinks.json
# https://viaf.org/viaf/27218731/justlinks.json
# https://viaf.org/viaf/27271796/justlinks.json
# https://viaf.org/viaf/27284327/justlinks.json
# https://viaf.org/viaf/27412072/justlinks.json
# https://viaf.org/viaf/27459106/justlinks.json
# https://viaf.org/viaf/27466680/justlinks.json
# https://viaf.org/viaf/27497293/justlinks.json
# https://viaf.org/viaf/27500854/justlinks.json
# https://viaf.org/viaf/27850041/justlinks.json
# https://viaf.org/viaf/27850975/justlinks.json
# https://viaf.org/viaf/27854068/justlinks.json
# https://viaf.org/viaf/27862472/justlinks.json
# https://viaf.org/viaf/27862866/justlinks.json
# https://viaf.org/viaf/27917220/justlinks.json
# https://viaf.org/viaf/27953920/justlinks.json
# https://viaf.org/viaf/27959295/justlinks.json
# https://viaf.org/viaf/28439325/justlinks.json
# https://viaf.org/viaf/28498001/justlinks.json
# https://viaf.org/viaf/28501721/justlinks.json
# https://viaf.org/viaf/28538306/justlinks.json
# https://viaf.org/viaf/28546230/justlinks.json
# https://viaf.org/viaf/28571923/justlinks.json
# https://viaf.org/viaf/28600475/justlinks.json
# https://viaf.org/viaf/28611323/justlinks.json
# https://viaf.org/viaf/28625627/justlinks.json
# https://viaf.org/viaf/29366429/justlinks.json
# https://viaf.org/viaf/29391602/justlinks.json
# https://viaf.org/viaf/29408637/justlinks.json
# https://viaf.org/viaf/29436338/justlinks.json
# https://viaf.org/viaf/29463840/justlinks.json
# https://viaf.org/viaf/29467576/justlinks.json
# https://viaf.org/viaf/29524057/justlinks.json
# https://viaf.org/viaf/29541174/justlinks.json
# https://viaf.org/viaf/29543710/justlinks.json
# https://viaf.org/viaf/29556453/justlinks.json
# https://viaf.org/viaf/29557778/justlinks.json
# https://viaf.org/viaf/29564062/justlinks.json
# https://viaf.org/viaf/29567630/justlinks.json
# https://viaf.org/viaf/29571577/justlinks.json
# https://viaf.org/viaf/29575102/justlinks.json
# https://viaf.org/viaf/29581678/justlinks.json
# https://viaf.org/viaf/29584945/justlinks.json
# https://viaf.org/viaf/29588767/justlinks.json
# https://viaf.org/viaf/29602261/justlinks.json
# https://viaf.org/viaf/29630623/justlinks.json
# https://viaf.org/viaf/29688630/justlinks.json
# https://viaf.org/viaf/29861558/justlinks.json
# https://viaf.org/viaf/29878974/justlinks.json
# https://viaf.org/viaf/29880157/justlinks.json
# https://viaf.org/viaf/29881324/justlinks.json
# https://viaf.org/viaf/29882803/justlinks.json
# https://viaf.org/viaf/29889230/justlinks.json
# https://viaf.org/viaf/29897872/justlinks.json
# https://viaf.org/viaf/29912212/justlinks.json
# https://viaf.org/viaf/29921691/justlinks.json
# https://viaf.org/viaf/29928757/justlinks.json
# https://viaf.org/viaf/29937454/justlinks.json
# https://viaf.org/viaf/30288706/justlinks.json
# https://viaf.org/viaf/30316052/justlinks.json
# https://viaf.org/viaf/30328710/justlinks.json
# https://viaf.org/viaf/30465849/justlinks.json
# https://viaf.org/viaf/30474615/justlinks.json
# https://viaf.org/viaf/30760894/justlinks.json
# https://viaf.org/viaf/30955592/justlinks.json
# https://viaf.org/viaf/30958060/justlinks.json
# https://viaf.org/viaf/30964985/justlinks.json
# https://viaf.org/viaf/30989953/justlinks.json
# https://viaf.org/viaf/31358660/justlinks.json
# https://viaf.org/viaf/31867735/justlinks.json
# https://viaf.org/viaf/31872278/justlinks.json
# https://viaf.org/viaf/31891705/justlinks.json
# https://viaf.org/viaf/31918479/justlinks.json
# https://viaf.org/viaf/31987109/justlinks.json
# https://viaf.org/viaf/31992524/justlinks.json
# https://viaf.org/viaf/31994819/justlinks.json
# https://viaf.org/viaf/31998409/justlinks.json
# https://viaf.org/viaf/32062949/justlinks.json
# https://viaf.org/viaf/32063971/justlinks.json
# https://viaf.org/viaf/32074997/justlinks.json
# https://viaf.org/viaf/32094803/justlinks.json
# https://viaf.org/viaf/32094842/justlinks.json
# https://viaf.org/viaf/32149754/justlinks.json
# https://viaf.org/viaf/32209934/justlinks.json
# https://viaf.org/viaf/32334540/justlinks.json
# https://viaf.org/viaf/32339606/justlinks.json
# https://viaf.org/viaf/32394705/justlinks.json
# https://viaf.org/viaf/32430927/justlinks.json
# https://viaf.org/viaf/32730654/justlinks.json
# https://viaf.org/viaf/32795252/justlinks.json
# https://viaf.org/viaf/32808369/justlinks.json
# https://viaf.org/viaf/32866457/justlinks.json
# https://viaf.org/viaf/32901076/justlinks.json
# https://viaf.org/viaf/32909717/justlinks.json
# https://viaf.org/viaf/33082607/justlinks.json
# https://viaf.org/viaf/33200802/justlinks.json
# https://viaf.org/viaf/33432761/justlinks.json
# https://viaf.org/viaf/33534300/justlinks.json
# https://viaf.org/viaf/33543491/justlinks.json
# https://viaf.org/viaf/34020534/justlinks.json
# https://viaf.org/viaf/34196032/justlinks.json
# https://viaf.org/viaf/34314416/justlinks.json
# https://viaf.org/viaf/34324257/justlinks.json
# https://viaf.org/viaf/34358601/justlinks.json
# https://viaf.org/viaf/34447226/justlinks.json
# https://viaf.org/viaf/34459614/justlinks.json
# https://viaf.org/viaf/34466316/justlinks.json
# https://viaf.org/viaf/34478273/justlinks.json
# https://viaf.org/viaf/34487398/justlinks.json
# https://viaf.org/viaf/34492536/justlinks.json
# https://viaf.org/viaf/34497153/justlinks.json
# https://viaf.org/viaf/34498004/justlinks.json
# https://viaf.org/viaf/34498275/justlinks.json
# https://viaf.org/viaf/34523593/justlinks.json
# https://viaf.org/viaf/34553612/justlinks.json
# https://viaf.org/viaf/34592037/justlinks.json
# https://viaf.org/viaf/34594730/justlinks.json
# https://viaf.org/viaf/34606296/justlinks.json
# https://viaf.org/viaf/34661678/justlinks.json
# https://viaf.org/viaf/34684157/justlinks.json
# https://viaf.org/viaf/34724361/justlinks.json
# https://viaf.org/viaf/34745882/justlinks.json
# https://viaf.org/viaf/34758978/justlinks.json
# https://viaf.org/viaf/34799386/justlinks.json
# https://viaf.org/viaf/34801124/justlinks.json
# https://viaf.org/viaf/34847427/justlinks.json
# https://viaf.org/viaf/34852109/justlinks.json
# https://viaf.org/viaf/34883804/justlinks.json
# https://viaf.org/viaf/34883804/justlinks.json
# https://viaf.org/viaf/35251748/justlinks.json
# https://viaf.org/viaf/35252598/justlinks.json
# https://viaf.org/viaf/35260631/justlinks.json
# https://viaf.org/viaf/35393071/justlinks.json
# https://viaf.org/viaf/35396839/justlinks.json
# https://viaf.org/viaf/35516825/justlinks.json
# https://viaf.org/viaf/35615600/justlinks.json
# https://viaf.org/viaf/35658353/justlinks.json
# https://viaf.org/viaf/35858164/justlinks.json
# https://viaf.org/viaf/35919756/justlinks.json
# https://viaf.org/viaf/36007034/justlinks.json
# https://viaf.org/viaf/36030044/justlinks.json
# https://viaf.org/viaf/36451287/justlinks.json
# https://viaf.org/viaf/36478052/justlinks.json
# https://viaf.org/viaf/36750583/justlinks.json
# https://viaf.org/viaf/36772863/justlinks.json
# https://viaf.org/viaf/36793577/justlinks.json
# https://viaf.org/viaf/36794995/justlinks.json
# https://viaf.org/viaf/36850442/justlinks.json
# https://viaf.org/viaf/36908965/justlinks.json
# https://viaf.org/viaf/36914355/justlinks.json
# https://viaf.org/viaf/36915547/justlinks.json
# https://viaf.org/viaf/36924377/justlinks.json
# https://viaf.org/viaf/36925746/justlinks.json
# https://viaf.org/viaf/36927363/justlinks.json
# https://viaf.org/viaf/36936358/justlinks.json
# https://viaf.org/viaf/36938051/justlinks.json
# https://viaf.org/viaf/36938235/justlinks.json
# https://viaf.org/viaf/36947382/justlinks.json
# https://viaf.org/viaf/36947382/justlinks.json
# https://viaf.org/viaf/36956972/justlinks.json
# https://viaf.org/viaf/36972348/justlinks.json
# https://viaf.org/viaf/36981134/justlinks.json
# https://viaf.org/viaf/36987534/justlinks.json
# https://viaf.org/viaf/37052502/justlinks.json
# https://viaf.org/viaf/37090620/justlinks.json
# https://viaf.org/viaf/37090620/justlinks.json
# https://viaf.org/viaf/37105940/justlinks.json
# https://viaf.org/viaf/37120846/justlinks.json
# https://viaf.org/viaf/37217127/justlinks.json
# https://viaf.org/viaf/37254774/justlinks.json
# https://viaf.org/viaf/37255105/justlinks.json
# https://viaf.org/viaf/37258937/justlinks.json
# https://viaf.org/viaf/37260075/justlinks.json
# https://viaf.org/viaf/37261652/justlinks.json
# https://viaf.org/viaf/37262673/justlinks.json
# https://viaf.org/viaf/37263479/justlinks.json
# https://viaf.org/viaf/37264221/justlinks.json
# https://viaf.org/viaf/37286784/justlinks.json
# https://viaf.org/viaf/37695659/justlinks.json
# https://viaf.org/viaf/37699007/justlinks.json
# https://viaf.org/viaf/37711731/justlinks.json
# https://viaf.org/viaf/37728104/justlinks.json
# https://viaf.org/viaf/37729288/justlinks.json
# https://viaf.org/viaf/37818720/justlinks.json
# https://viaf.org/viaf/37848733/justlinks.json
# https://viaf.org/viaf/37977693/justlinks.json
# https://viaf.org/viaf/37981686/justlinks.json
# https://viaf.org/viaf/38370228/justlinks.json
# https://viaf.org/viaf/38372101/justlinks.json
# https://viaf.org/viaf/38409870/justlinks.json
# https://viaf.org/viaf/38446370/justlinks.json
# https://viaf.org/viaf/39214638/justlinks.json
# https://viaf.org/viaf/39226665/justlinks.json
# https://viaf.org/viaf/39231370/justlinks.json
# https://viaf.org/viaf/39234119/justlinks.json
# https://viaf.org/viaf/39248876/justlinks.json
# https://viaf.org/viaf/39386049/justlinks.json
# https://viaf.org/viaf/39399338/justlinks.json
# https://viaf.org/viaf/39399735/justlinks.json
# https://viaf.org/viaf/39403638/justlinks.json
# https://viaf.org/viaf/39415171/justlinks.json
# https://viaf.org/viaf/39428787/justlinks.json
# https://viaf.org/viaf/39446070/justlinks.json
# https://viaf.org/viaf/39448641/justlinks.json
# https://viaf.org/viaf/39450522/justlinks.json
# https://viaf.org/viaf/39466716/justlinks.json
# https://viaf.org/viaf/39475242/justlinks.json
# https://viaf.org/viaf/39494028/justlinks.json
# https://viaf.org/viaf/39603961/justlinks.json
# https://viaf.org/viaf/39651058/justlinks.json
# https://viaf.org/viaf/39671650/justlinks.json
# https://viaf.org/viaf/39675309/justlinks.json
# https://viaf.org/viaf/39717532/justlinks.json
# https://viaf.org/viaf/39724695/justlinks.json
# https://viaf.org/viaf/39728327/justlinks.json
# https://viaf.org/viaf/39731051/justlinks.json
# https://viaf.org/viaf/40159225/justlinks.json
# https://viaf.org/viaf/40161749/justlinks.json
# https://viaf.org/viaf/40176451/justlinks.json
# https://viaf.org/viaf/40274712/justlinks.json
# https://viaf.org/viaf/40577414/justlinks.json
# https://viaf.org/viaf/40795740/justlinks.json
# https://viaf.org/viaf/41706359/justlinks.json
# https://viaf.org/viaf/41722742/justlinks.json
# https://viaf.org/viaf/41800554/justlinks.json
# https://viaf.org/viaf/41828866/justlinks.json
# https://viaf.org/viaf/41838293/justlinks.json
# https://viaf.org/viaf/41838958/justlinks.json
# https://viaf.org/viaf/41843933/justlinks.json
# https://viaf.org/viaf/41846508/justlinks.json
# https://viaf.org/viaf/41858327/justlinks.json
# https://viaf.org/viaf/41858358/justlinks.json
# https://viaf.org/viaf/41868983/justlinks.json
# https://viaf.org/viaf/41893590/justlinks.json
# https://viaf.org/viaf/41918047/justlinks.json
# https://viaf.org/viaf/41925299/justlinks.json
# https://viaf.org/viaf/41935257/justlinks.json
# https://viaf.org/viaf/41937557/justlinks.json
# https://viaf.org/viaf/41961937/justlinks.json
# https://viaf.org/viaf/41961971/justlinks.json
# https://viaf.org/viaf/41998972/justlinks.json
# https://viaf.org/viaf/42090768/justlinks.json
# https://viaf.org/viaf/42112130/justlinks.json
# https://viaf.org/viaf/42181048/justlinks.json
# https://viaf.org/viaf/42182403/justlinks.json
# https://viaf.org/viaf/42183257/justlinks.json
# https://viaf.org/viaf/42183901/justlinks.json
# https://viaf.org/viaf/42187109/justlinks.json
# https://viaf.org/viaf/42187630/justlinks.json
# https://viaf.org/viaf/42594905/justlinks.json
# https://viaf.org/viaf/42617767/justlinks.json
# https://viaf.org/viaf/42633949/justlinks.json
# https://viaf.org/viaf/42649535/justlinks.json
# https://viaf.org/viaf/42680007/justlinks.json
# https://viaf.org/viaf/42692762/justlinks.json
# https://viaf.org/viaf/42692762/justlinks.json
# https://viaf.org/viaf/42777269/justlinks.json
# https://viaf.org/viaf/42784511/justlinks.json
# https://viaf.org/viaf/42972779/justlinks.json
# https://viaf.org/viaf/43011325/justlinks.json
# https://viaf.org/viaf/43242841/justlinks.json
# https://viaf.org/viaf/43267973/justlinks.json
# https://viaf.org/viaf/43334764/justlinks.json
# https://viaf.org/viaf/43858028/justlinks.json
# https://viaf.org/viaf/43919918/justlinks.json
# https://viaf.org/viaf/44158892/justlinks.json
# https://viaf.org/viaf/44159026/justlinks.json
# https://viaf.org/viaf/44247227/justlinks.json
# https://viaf.org/viaf/44289907/justlinks.json
# https://viaf.org/viaf/44291859/justlinks.json
# https://viaf.org/viaf/44317198/justlinks.json
# https://viaf.org/viaf/44318307/justlinks.json
# https://viaf.org/viaf/44335185/justlinks.json
# https://viaf.org/viaf/44357385/justlinks.json
# https://viaf.org/viaf/44358141/justlinks.json
# https://viaf.org/viaf/44377383/justlinks.json
# https://viaf.org/viaf/44383224/justlinks.json
# https://viaf.org/viaf/44383224/justlinks.json
# https://viaf.org/viaf/44383269/justlinks.json
# https://viaf.org/viaf/44447841/justlinks.json
# https://viaf.org/viaf/44546029/justlinks.json
# https://viaf.org/viaf/44570672/justlinks.json
# https://viaf.org/viaf/44572787/justlinks.json
# https://viaf.org/viaf/44648006/justlinks.json
# https://viaf.org/viaf/44648925/justlinks.json
# https://viaf.org/viaf/44652408/justlinks.json
# https://viaf.org/viaf/44674118/justlinks.json
# https://viaf.org/viaf/44694963/justlinks.json
# https://viaf.org/viaf/44735249/justlinks.json
# https://viaf.org/viaf/44737963/justlinks.json
# https://viaf.org/viaf/45071137/justlinks.json
# https://viaf.org/viaf/45083556/justlinks.json
# https://viaf.org/viaf/45083594/justlinks.json
# https://viaf.org/viaf/45083732/justlinks.json
# https://viaf.org/viaf/45086729/justlinks.json
# https://viaf.org/viaf/45107306/justlinks.json
# https://viaf.org/viaf/45236081/justlinks.json
# https://viaf.org/viaf/45368351/justlinks.json
# https://viaf.org/viaf/45706352/justlinks.json
# https://viaf.org/viaf/45717380/justlinks.json
# https://viaf.org/viaf/45763258/justlinks.json
# https://viaf.org/viaf/45908274/justlinks.json
# https://viaf.org/viaf/46310522/justlinks.json
# https://viaf.org/viaf/46322679/justlinks.json
# https://viaf.org/viaf/46572341/justlinks.json
# https://viaf.org/viaf/46595267/justlinks.json
# https://viaf.org/viaf/46627653/justlinks.json
# https://viaf.org/viaf/46664586/justlinks.json
# https://viaf.org/viaf/46756283/justlinks.json
# https://viaf.org/viaf/46767474/justlinks.json
# https://viaf.org/viaf/46770231/justlinks.json
# https://viaf.org/viaf/46770352/justlinks.json
# https://viaf.org/viaf/46783945/justlinks.json
# https://viaf.org/viaf/46795488/justlinks.json
# https://viaf.org/viaf/46796537/justlinks.json
# https://viaf.org/viaf/46848150/justlinks.json
# https://viaf.org/viaf/46848150/justlinks.json
# https://viaf.org/viaf/46849116/justlinks.json
# https://viaf.org/viaf/46849163/justlinks.json
# https://viaf.org/viaf/46856107/justlinks.json
# https://viaf.org/viaf/46887859/justlinks.json
# https://viaf.org/viaf/46902352/justlinks.json
# https://viaf.org/viaf/46920668/justlinks.json
# https://viaf.org/viaf/46924807/justlinks.json
# https://viaf.org/viaf/47001072/justlinks.json
# https://viaf.org/viaf/47016953/justlinks.json
# https://viaf.org/viaf/47033545/justlinks.json
# https://viaf.org/viaf/47036535/justlinks.json
# https://viaf.org/viaf/47038188/justlinks.json
# https://viaf.org/viaf/47109526/justlinks.json
# https://viaf.org/viaf/47109686/justlinks.json
# https://viaf.org/viaf/47111010/justlinks.json
# https://viaf.org/viaf/47113434/justlinks.json
# https://viaf.org/viaf/47114781/justlinks.json
# https://viaf.org/viaf/47153631/justlinks.json
# https://viaf.org/viaf/47160055/justlinks.json
# https://viaf.org/viaf/47163247/justlinks.json
# https://viaf.org/viaf/47544099/justlinks.json
# https://viaf.org/viaf/47563076/justlinks.json
# https://viaf.org/viaf/47563478/justlinks.json
# https://viaf.org/viaf/47563552/justlinks.json
# https://viaf.org/viaf/47595361/justlinks.json
# https://viaf.org/viaf/47612282/justlinks.json
# https://viaf.org/viaf/47629722/justlinks.json
# https://viaf.org/viaf/47643770/justlinks.json
# https://viaf.org/viaf/47651257/justlinks.json
# https://viaf.org/viaf/47666697/justlinks.json
# https://viaf.org/viaf/47674362/justlinks.json
# https://viaf.org/viaf/47812330/justlinks.json
# https://viaf.org/viaf/48177074/justlinks.json
# https://viaf.org/viaf/48180896/justlinks.json
# https://viaf.org/viaf/48206747/justlinks.json
# https://viaf.org/viaf/48207292/justlinks.json
# https://viaf.org/viaf/48221764/justlinks.json
# https://viaf.org/viaf/48246577/justlinks.json
# https://viaf.org/viaf/48580582/justlinks.json
# https://viaf.org/viaf/48790214/justlinks.json
# https://viaf.org/viaf/48911341/justlinks.json
# https://viaf.org/viaf/49087716/justlinks.json
# https://viaf.org/viaf/49120647/justlinks.json
# https://viaf.org/viaf/49145008/justlinks.json
# https://viaf.org/viaf/49231791/justlinks.json
# https://viaf.org/viaf/49234805/justlinks.json
# https://viaf.org/viaf/49234879/justlinks.json
# https://viaf.org/viaf/49256594/justlinks.json
# https://viaf.org/viaf/49257108/justlinks.json
# https://viaf.org/viaf/49261635/justlinks.json
# https://viaf.org/viaf/49262010/justlinks.json
# https://viaf.org/viaf/49303208/justlinks.json
# https://viaf.org/viaf/49308476/justlinks.json
# https://viaf.org/viaf/49309588/justlinks.json
# https://viaf.org/viaf/49357645/justlinks.json
# https://viaf.org/viaf/49516437/justlinks.json
# https://viaf.org/viaf/49518541/justlinks.json
# https://viaf.org/viaf/49563269/justlinks.json
# https://viaf.org/viaf/49563810/justlinks.json
# https://viaf.org/viaf/49564329/justlinks.json
# https://viaf.org/viaf/49570720/justlinks.json
# https://viaf.org/viaf/49572077/justlinks.json
# https://viaf.org/viaf/49573088/justlinks.json
# https://viaf.org/viaf/49578259/justlinks.json
# https://viaf.org/viaf/49621697/justlinks.json
# https://viaf.org/viaf/50006688/justlinks.json
# https://viaf.org/viaf/50023446/justlinks.json
# https://viaf.org/viaf/50024557/justlinks.json
# https://viaf.org/viaf/50027622/justlinks.json
# https://viaf.org/viaf/50037252/justlinks.json
# https://viaf.org/viaf/50071123/justlinks.json
# https://viaf.org/viaf/50151830/justlinks.json
# https://viaf.org/viaf/50153775/justlinks.json
# https://viaf.org/viaf/50170505/justlinks.json
# https://viaf.org/viaf/50171862/justlinks.json
# https://viaf.org/viaf/50338444/justlinks.json
# https://viaf.org/viaf/50339760/justlinks.json
# https://viaf.org/viaf/50449886/justlinks.json
# https://viaf.org/viaf/50645901/justlinks.json
# https://viaf.org/viaf/50726614/justlinks.json
# https://viaf.org/viaf/50756810/justlinks.json
# https://viaf.org/viaf/51253882/justlinks.json
# https://viaf.org/viaf/51529264/justlinks.json
# https://viaf.org/viaf/51542802/justlinks.json
# https://viaf.org/viaf/51680456/justlinks.json
# https://viaf.org/viaf/51684915/justlinks.json
# https://viaf.org/viaf/51696979/justlinks.json
# https://viaf.org/viaf/51698379/justlinks.json
# https://viaf.org/viaf/51703551/justlinks.json
# https://viaf.org/viaf/51717094/justlinks.json
# https://viaf.org/viaf/51722094/justlinks.json
# https://viaf.org/viaf/51739997/justlinks.json
# https://viaf.org/viaf/51741908/justlinks.json
# https://viaf.org/viaf/51744988/justlinks.json
# https://viaf.org/viaf/51754496/justlinks.json
# https://viaf.org/viaf/51758315/justlinks.json
# https://viaf.org/viaf/51767169/justlinks.json
# https://viaf.org/viaf/51774140/justlinks.json
# https://viaf.org/viaf/51802677/justlinks.json
# https://viaf.org/viaf/51806836/justlinks.json
# https://viaf.org/viaf/51873515/justlinks.json
# https://viaf.org/viaf/51905610/justlinks.json
# https://viaf.org/viaf/52000852/justlinks.json
# https://viaf.org/viaf/52030666/justlinks.json
# https://viaf.org/viaf/52030666/justlinks.json
# https://viaf.org/viaf/52038644/justlinks.json
# https://viaf.org/viaf/52040052/justlinks.json
# https://viaf.org/viaf/52051761/justlinks.json
# https://viaf.org/viaf/52087210/justlinks.json
# https://viaf.org/viaf/52125510/justlinks.json
# https://viaf.org/viaf/52473338/justlinks.json
# https://viaf.org/viaf/52473514/justlinks.json
# https://viaf.org/viaf/52480802/justlinks.json
# https://viaf.org/viaf/52488399/justlinks.json
# https://viaf.org/viaf/52494176/justlinks.json
# https://viaf.org/viaf/52498259/justlinks.json
# https://viaf.org/viaf/52500576/justlinks.json
# https://viaf.org/viaf/52523340/justlinks.json
# https://viaf.org/viaf/52539912/justlinks.json
# https://viaf.org/viaf/52568365/justlinks.json
# https://viaf.org/viaf/52591252/justlinks.json
# https://viaf.org/viaf/52626362/justlinks.json
# https://viaf.org/viaf/52890109/justlinks.json
# https://viaf.org/viaf/53062809/justlinks.json
# https://viaf.org/viaf/53109445/justlinks.json
# https://viaf.org/viaf/53130377/justlinks.json
# https://viaf.org/viaf/53130543/justlinks.json
# https://viaf.org/viaf/53152838/justlinks.json
# https://viaf.org/viaf/53334571/justlinks.json
# https://viaf.org/viaf/53476956/justlinks.json
# https://viaf.org/viaf/53719286/justlinks.json
# https://viaf.org/viaf/53999086/justlinks.json
# https://viaf.org/viaf/54003324/justlinks.json
# https://viaf.org/viaf/54014309/justlinks.json
# https://viaf.org/viaf/54024146/justlinks.json
# https://viaf.org/viaf/54136724/justlinks.json
# https://viaf.org/viaf/54137049/justlinks.json
# https://viaf.org/viaf/54146999/justlinks.json
# https://viaf.org/viaf/54147648/justlinks.json
# https://viaf.org/viaf/54156589/justlinks.json
# https://viaf.org/viaf/54157151/justlinks.json
# https://viaf.org/viaf/54179526/justlinks.json
# https://viaf.org/viaf/54186411/justlinks.json
# https://viaf.org/viaf/54190263/justlinks.json
# https://viaf.org/viaf/54194455/justlinks.json
# https://viaf.org/viaf/54197108/justlinks.json
# https://viaf.org/viaf/54202214/justlinks.json
# https://viaf.org/viaf/54245430/justlinks.json
# https://viaf.org/viaf/54270300/justlinks.json
# https://viaf.org/viaf/54274644/justlinks.json
# https://viaf.org/viaf/54418791/justlinks.json
# https://viaf.org/viaf/54450638/justlinks.json
# https://viaf.org/viaf/54491765/justlinks.json
# https://viaf.org/viaf/54491997/justlinks.json
# https://viaf.org/viaf/54501262/justlinks.json
# https://viaf.org/viaf/54553396/justlinks.json
# https://viaf.org/viaf/54569203/justlinks.json
# https://viaf.org/viaf/54579620/justlinks.json
# https://viaf.org/viaf/54911327/justlinks.json
# https://viaf.org/viaf/54916062/justlinks.json
# https://viaf.org/viaf/54929912/justlinks.json
# https://viaf.org/viaf/55062436/justlinks.json
# https://viaf.org/viaf/55210218/justlinks.json
# https://viaf.org/viaf/55261332/justlinks.json
# https://viaf.org/viaf/55282183/justlinks.json
# https://viaf.org/viaf/55374361/justlinks.json
# https://viaf.org/viaf/55566763/justlinks.json
# https://viaf.org/viaf/55570282/justlinks.json
# https://viaf.org/viaf/55604015/justlinks.json
# https://viaf.org/viaf/56035211/justlinks.json
# https://viaf.org/viaf/56142625/justlinks.json
# https://viaf.org/viaf/56355512/justlinks.json
# https://viaf.org/viaf/56444938/justlinks.json
# https://viaf.org/viaf/56475249/justlinks.json
# https://viaf.org/viaf/56483497/justlinks.json
# https://viaf.org/viaf/56486309/justlinks.json
# https://viaf.org/viaf/56502526/justlinks.json
# https://viaf.org/viaf/56599724/justlinks.json
# https://viaf.org/viaf/56600587/justlinks.json
# https://viaf.org/viaf/56609913/justlinks.json
# https://viaf.org/viaf/56643729/justlinks.json
# https://viaf.org/viaf/56646427/justlinks.json
# https://viaf.org/viaf/56646427/justlinks.json
# https://viaf.org/viaf/56647196/justlinks.json
# https://viaf.org/viaf/56656245/justlinks.json
# https://viaf.org/viaf/56660281/justlinks.json
# https://viaf.org/viaf/56662292/justlinks.json
# https://viaf.org/viaf/56662497/justlinks.json
# https://viaf.org/viaf/56673731/justlinks.json
# https://viaf.org/viaf/56682703/justlinks.json
# https://viaf.org/viaf/56687474/justlinks.json
# https://viaf.org/viaf/56707902/justlinks.json
# https://viaf.org/viaf/56765783/justlinks.json
# https://viaf.org/viaf/56771726/justlinks.json
# https://viaf.org/viaf/56951183/justlinks.json
# https://viaf.org/viaf/56953632/justlinks.json
# https://viaf.org/viaf/56954975/justlinks.json
# https://viaf.org/viaf/56962668/justlinks.json
# https://viaf.org/viaf/56963322/justlinks.json
# https://viaf.org/viaf/56963658/justlinks.json
# https://viaf.org/viaf/56968148/justlinks.json
# https://viaf.org/viaf/56972467/justlinks.json
# https://viaf.org/viaf/57017721/justlinks.json
# https://viaf.org/viaf/57385885/justlinks.json
# https://viaf.org/viaf/57389662/justlinks.json
# https://viaf.org/viaf/57395592/justlinks.json
# https://viaf.org/viaf/57409981/justlinks.json
# https://viaf.org/viaf/57417862/justlinks.json
# https://viaf.org/viaf/57457152/justlinks.json
# https://viaf.org/viaf/57457152/justlinks.json
# https://viaf.org/viaf/57510406/justlinks.json
# https://viaf.org/viaf/57760529/justlinks.json
# https://viaf.org/viaf/58035147/justlinks.json
# https://viaf.org/viaf/58051139/justlinks.json
# ...
# https://viaf.org/viaf/78993713/justlinks.json
# https://viaf.org/viaf/79012766/justlinks.json
# https://viaf.org/viaf/79087234/justlinks.json
# https://viaf.org/viaf/79124355/justlinks.json
# https://viaf.org/viaf/79159546/justlinks.json
# https://viaf.org/viaf/79174737/justlinks.json
# https://viaf.org/viaf/79202769/justlinks.json
# https://viaf.org/viaf/79205127/justlinks.json
# https://viaf.org/viaf/79251462/justlinks.json
# https://viaf.org/viaf/79251518/justlinks.json
# https://viaf.org/viaf/79260992/justlinks.json
# https://viaf.org/viaf/79392926/justlinks.json
# https://viaf.org/viaf/80419210/justlinks.json
# https://viaf.org/viaf/81885515/justlinks.json
# https://viaf.org/viaf/81906694/justlinks.json
# https://viaf.org/viaf/83693449/justlinks.json
# https://viaf.org/viaf/83693449/justlinks.json
# https://viaf.org/viaf/84378729/justlinks.json
# https://viaf.org/viaf/84814826/justlinks.json
# https://viaf.org/viaf/84817588/justlinks.json
# https://viaf.org/viaf/84818534/justlinks.json
# https://viaf.org/viaf/86374293/justlinks.json
# https://viaf.org/viaf/86374335/justlinks.json
# https://viaf.org/viaf/86387382/justlinks.json
# https://viaf.org/viaf/86927622/justlinks.json
# https://viaf.org/viaf/87582164/justlinks.json
# https://viaf.org/viaf/87639971/justlinks.json
# https://viaf.org/viaf/88038776/justlinks.json
# https://viaf.org/viaf/88056977/justlinks.json
# https://viaf.org/viaf/88068054/justlinks.json
# https://viaf.org/viaf/88128935/justlinks.json
# https://viaf.org/viaf/88462278/justlinks.json
# https://viaf.org/viaf/88495229/justlinks.json
# https://viaf.org/viaf/88684229/justlinks.json
# https://viaf.org/viaf/88700153/justlinks.json
# https://viaf.org/viaf/88813424/justlinks.json
# https://viaf.org/viaf/88839524/justlinks.json
# https://viaf.org/viaf/88857565/justlinks.json
# https://viaf.org/viaf/88888319/justlinks.json
# https://viaf.org/viaf/88892951/justlinks.json
# https://viaf.org/viaf/88905668/justlinks.json
# https://viaf.org/viaf/88984774/justlinks.json
# https://viaf.org/viaf/88984774/justlinks.json
# https://viaf.org/viaf/88987908/justlinks.json
# https://viaf.org/viaf/89009260/justlinks.json
# https://viaf.org/viaf/89010402/justlinks.json
# https://viaf.org/viaf/89105442/justlinks.json
# https://viaf.org/viaf/89318980/justlinks.json
# https://viaf.org/viaf/89352673/justlinks.json
# https://viaf.org/viaf/89354395/justlinks.json
# https://viaf.org/viaf/89765469/justlinks.json
# https://viaf.org/viaf/90497456/justlinks.json
# https://viaf.org/viaf/90497528/justlinks.json
# https://viaf.org/viaf/90770180/justlinks.json
# https://viaf.org/viaf/90941241/justlinks.json
# https://viaf.org/viaf/91115259/justlinks.json
# https://viaf.org/viaf/91664246/justlinks.json
# https://viaf.org/viaf/91750131/justlinks.json
# https://viaf.org/viaf/93125901/justlinks.json
# https://viaf.org/viaf/93363329/justlinks.json
# https://viaf.org/viaf/93583902/justlinks.json
# https://viaf.org/viaf/93584593/justlinks.json
# https://viaf.org/viaf/95152459/justlinks.json
# https://viaf.org/viaf/95152542/justlinks.json
# https://viaf.org/viaf/95156657/justlinks.json
# https://viaf.org/viaf/95294215/justlinks.json
# https://viaf.org/viaf/95325712/justlinks.json
# https://viaf.org/viaf/95698910/justlinks.json
# https://viaf.org/viaf/95732431/justlinks.json
# https://viaf.org/viaf/95738623/justlinks.json
# https://viaf.org/viaf/95769577/justlinks.json
# https://viaf.org/viaf/95802130/justlinks.json
# https://viaf.org/viaf/95817357/justlinks.json
# https://viaf.org/viaf/95831645/justlinks.json
# https://viaf.org/viaf/95835805/justlinks.json
# https://viaf.org/viaf/95845519/justlinks.json
# https://viaf.org/viaf/95883212/justlinks.json
# https://viaf.org/viaf/96012772/justlinks.json
# https://viaf.org/viaf/96138145/justlinks.json
# https://viaf.org/viaf/96227101/justlinks.json
# https://viaf.org/viaf/96491971/justlinks.json
# https://viaf.org/viaf/96540498/justlinks.json
# https://viaf.org/viaf/96593406/justlinks.json
# https://viaf.org/viaf/96798395/justlinks.json
# https://viaf.org/viaf/96815532/justlinks.json
# https://viaf.org/viaf/96896929/justlinks.json
# https://viaf.org/viaf/96913428/justlinks.json
# https://viaf.org/viaf/96913503/justlinks.json
# https://viaf.org/viaf/97164633/justlinks.json
# https://viaf.org/viaf/98100996/justlinks.json
# https://viaf.org/viaf/98223258/justlinks.json
# https://viaf.org/viaf/98289961/justlinks.json
# https://viaf.org/viaf/98732271/justlinks.json
# https://viaf.org/viaf/98809541/justlinks.json
# https://viaf.org/viaf/98841872/justlinks.json
# https://viaf.org/viaf/99336186/justlinks.json
# https://viaf.org/viaf/99367617/justlinks.json
# https://viaf.org/viaf/99544852/justlinks.json
# https://viaf.org/viaf/99744686/justlinks.json
# https://viaf.org/viaf/99885687/justlinks.json
# https://viaf.org/viaf/100103055/justlinks.json
# https://viaf.org/viaf/100167171/justlinks.json
# https://viaf.org/viaf/100174106/justlinks.json
# https://viaf.org/viaf/100174728/justlinks.json
# https://viaf.org/viaf/100177692/justlinks.json
# https://viaf.org/viaf/100179866/justlinks.json
# https://viaf.org/viaf/100183205/justlinks.json
# https://viaf.org/viaf/100188133/justlinks.json
# https://viaf.org/viaf/100188302/justlinks.json
# https://viaf.org/viaf/100190422/justlinks.json
# https://viaf.org/viaf/100190716/justlinks.json
# https://viaf.org/viaf/100199084/justlinks.json
# https://viaf.org/viaf/100199531/justlinks.json
# https://viaf.org/viaf/100212546/justlinks.json
# https://viaf.org/viaf/100222314/justlinks.json
# https://viaf.org/viaf/100226865/justlinks.json
# https://viaf.org/viaf/100290798/justlinks.json
# https://viaf.org/viaf/100307263/justlinks.json
# https://viaf.org/viaf/100307263/justlinks.json
# https://viaf.org/viaf/100329291/justlinks.json
# https://viaf.org/viaf/100368494/justlinks.json
# https://viaf.org/viaf/100369167/justlinks.json
# https://viaf.org/viaf/100369926/justlinks.json
# https://viaf.org/viaf/100370422/justlinks.json
# https://viaf.org/viaf/100373787/justlinks.json
# https://viaf.org/viaf/100544816/justlinks.json
# https://viaf.org/viaf/100570413/justlinks.json
# https://viaf.org/viaf/100624484/justlinks.json
# https://viaf.org/viaf/100838209/justlinks.json
# https://viaf.org/viaf/100963417/justlinks.json
# https://viaf.org/viaf/100963417/justlinks.json
# https://viaf.org/viaf/100973436/justlinks.json
# https://viaf.org/viaf/101001270/justlinks.json
# https://viaf.org/viaf/101461637/justlinks.json
# https://viaf.org/viaf/102308168/justlinks.json
# https://viaf.org/viaf/102313829/justlinks.json
# https://viaf.org/viaf/102377186/justlinks.json
# https://viaf.org/viaf/103105679/justlinks.json
# https://viaf.org/viaf/103194586/justlinks.json
# https://viaf.org/viaf/103209764/justlinks.json
# https://viaf.org/viaf/103251693/justlinks.json
# https://viaf.org/viaf/103532239/justlinks.json
# https://viaf.org/viaf/103723261/justlinks.json
# https://viaf.org/viaf/106967757/justlinks.json
# https://viaf.org/viaf/106969992/justlinks.json
# https://viaf.org/viaf/107707317/justlinks.json
# https://viaf.org/viaf/107759071/justlinks.json
# https://viaf.org/viaf/108111862/justlinks.json
# https://viaf.org/viaf/109281572/justlinks.json
# https://viaf.org/viaf/111198494/justlinks.json
# https://viaf.org/viaf/120202325/justlinks.json
# https://viaf.org/viaf/120605471/justlinks.json
# https://viaf.org/viaf/120700490/justlinks.json
# https://viaf.org/viaf/120701914/justlinks.json
# https://viaf.org/viaf/120725861/justlinks.json
# https://viaf.org/viaf/120777159/justlinks.json
# https://viaf.org/viaf/120784081/justlinks.json
# https://viaf.org/viaf/120784243/justlinks.json
# https://viaf.org/viaf/120836054/justlinks.json
# https://viaf.org/viaf/121709579/justlinks.json
# https://viaf.org/viaf/121807519/justlinks.json
# https://viaf.org/viaf/122066131/justlinks.json
# https://viaf.org/viaf/136787000/justlinks.json
# https://viaf.org/viaf/137960212/justlinks.json
# https://viaf.org/viaf/145331463/justlinks.json
# https://viaf.org/viaf/152001720/justlinks.json
# https://viaf.org/viaf/155519451/justlinks.json
# https://viaf.org/viaf/160170991/justlinks.json
# https://viaf.org/viaf/160344796/justlinks.json
# https://viaf.org/viaf/160476097/justlinks.json
# https://viaf.org/viaf/160490445/justlinks.json
# https://viaf.org/viaf/160524259/justlinks.json
# https://viaf.org/viaf/160845120/justlinks.json
# https://viaf.org/viaf/161542773/justlinks.json
# https://viaf.org/viaf/165749760/justlinks.json
# https://viaf.org/viaf/167846391/justlinks.json
# https://viaf.org/viaf/169094252/justlinks.json
# https://viaf.org/viaf/171003193/justlinks.json
# https://viaf.org/viaf/171490539/justlinks.json
# https://viaf.org/viaf/172419710/justlinks.json
# https://viaf.org/viaf/172537224/justlinks.json
# https://viaf.org/viaf/172856346/justlinks.json
# https://viaf.org/viaf/173082250/justlinks.json
# https://viaf.org/viaf/173507721/justlinks.json
# https://viaf.org/viaf/174515068/justlinks.json
# https://viaf.org/viaf/178430789/justlinks.json
# https://viaf.org/viaf/179387045/justlinks.json
# https://viaf.org/viaf/180956489/justlinks.json
# https://viaf.org/viaf/186621146/justlinks.json
# https://viaf.org/viaf/186769324/justlinks.json
# https://viaf.org/viaf/189721157/justlinks.json
# https://viaf.org/viaf/198572397/justlinks.json
# https://viaf.org/viaf/199053905/justlinks.json
# https://viaf.org/viaf/200075964/justlinks.json
# https://viaf.org/viaf/210233935/justlinks.json
# https://viaf.org/viaf/212492791/justlinks.json
# https://viaf.org/viaf/222931549/justlinks.json
# https://viaf.org/viaf/224109980/justlinks.json
# https://viaf.org/viaf/227730938/justlinks.json
# https://viaf.org/viaf/231767384/justlinks.json
# https://viaf.org/viaf/232395833/justlinks.json
# https://viaf.org/viaf/232491387/justlinks.json
# https://viaf.org/viaf/233165469/justlinks.json
# https://viaf.org/viaf/234705467/justlinks.json
# https://viaf.org/viaf/234707403/justlinks.json
# https://viaf.org/viaf/235461864/justlinks.json
# https://viaf.org/viaf/237880884/justlinks.json
# https://viaf.org/viaf/240015966/justlinks.json
# https://viaf.org/viaf/240465878/justlinks.json
# https://viaf.org/viaf/241568675/justlinks.json
# https://viaf.org/viaf/242837058/justlinks.json
# https://viaf.org/viaf/243564429/justlinks.json
# https://viaf.org/viaf/245730896/justlinks.json
# https://viaf.org/viaf/246210075/justlinks.json
# https://viaf.org/viaf/246212057/justlinks.json
# https://viaf.org/viaf/247246566/justlinks.json
# https://viaf.org/viaf/248203740/justlinks.json
# https://viaf.org/viaf/250796979/justlinks.json
# https://viaf.org/viaf/250919692/justlinks.json
# https://viaf.org/viaf/255675899/justlinks.json
# https://viaf.org/viaf/259809397/justlinks.json
# https://viaf.org/viaf/259857623/justlinks.json
# https://viaf.org/viaf/261707238/justlinks.json
# https://viaf.org/viaf/263401905/justlinks.json
# https://viaf.org/viaf/264888804/justlinks.json
# https://viaf.org/viaf/266081375/justlinks.json
# https://viaf.org/viaf/266081375/justlinks.json
# https://viaf.org/viaf/266222116/justlinks.json
# https://viaf.org/viaf/268706743/justlinks.json
# https://viaf.org/viaf/276018980/justlinks.json
# https://viaf.org/viaf/278479781/justlinks.json
# https://viaf.org/viaf/278824281/justlinks.json
# https://viaf.org/viaf/279541491/justlinks.json
# https://viaf.org/viaf/279985506/justlinks.json
# https://viaf.org/viaf/281220600/justlinks.json
# https://viaf.org/viaf/281438691/justlinks.json
# https://viaf.org/viaf/281758280/justlinks.json
# https://viaf.org/viaf/282003452/justlinks.json
# https://viaf.org/viaf/282051040/justlinks.json
# https://viaf.org/viaf/282879892/justlinks.json
# https://viaf.org/viaf/284420686/justlinks.json
# https://viaf.org/viaf/286211863/justlinks.json
# https://viaf.org/viaf/287291307/justlinks.json
# https://viaf.org/viaf/288184597/justlinks.json
# https://viaf.org/viaf/288372064/justlinks.json
# https://viaf.org/viaf/288680395/justlinks.json
# https://viaf.org/viaf/288737265/justlinks.json
# https://viaf.org/viaf/289291613/justlinks.json
# https://viaf.org/viaf/289438307/justlinks.json
# https://viaf.org/viaf/289438307/justlinks.json
# https://viaf.org/viaf/289879940/justlinks.json
# https://viaf.org/viaf/291586216/justlinks.json
# https://viaf.org/viaf/291810542/justlinks.json
# https://viaf.org/viaf/291961291/justlinks.json
# https://viaf.org/viaf/292367721/justlinks.json
# https://viaf.org/viaf/293333063/justlinks.json
# https://viaf.org/viaf/294445798/justlinks.json
# https://viaf.org/viaf/295725501/justlinks.json
# https://viaf.org/viaf/296028686/justlinks.json
# https://viaf.org/viaf/296351773/justlinks.json
# https://viaf.org/viaf/297743028/justlinks.json
# https://viaf.org/viaf/299934989/justlinks.json
# https://viaf.org/viaf/302804192/justlinks.json
# https://viaf.org/viaf/304010538/justlinks.json
# https://viaf.org/viaf/304917391/justlinks.json
# https://viaf.org/viaf/304947898/justlinks.json
# https://viaf.org/viaf/305118711/justlinks.json
# https://viaf.org/viaf/305302952/justlinks.json
# https://viaf.org/viaf/306071895/justlinks.json
# https://viaf.org/viaf/306107782/justlinks.json
# https://viaf.org/viaf/306130448/justlinks.json
# https://viaf.org/viaf/306130801/justlinks.json
# https://viaf.org/viaf/306420532/justlinks.json
# https://viaf.org/viaf/309593637/justlinks.json
# https://viaf.org/viaf/309613770/justlinks.json
# https://viaf.org/viaf/310526579/justlinks.json
# https://viaf.org/viaf/310627750/justlinks.json
# https://viaf.org/viaf/310665411/justlinks.json
# https://viaf.org/viaf/310665793/justlinks.json
# https://viaf.org/viaf/311067558/justlinks.json
# https://viaf.org/viaf/311193035/justlinks.json
# https://viaf.org/viaf/311193216/justlinks.json
# https://viaf.org/viaf/315534549/justlinks.json
# https://viaf.org/viaf/315654880/justlinks.json
# https://viaf.org/viaf/315660436/justlinks.json
# https://viaf.org/viaf/315660542/justlinks.json
# https://viaf.org/viaf/315662153/justlinks.json
# https://viaf.org/viaf/316400216/justlinks.json
# https://viaf.org/viaf/316448538/justlinks.json
# https://viaf.org/viaf/316736531/justlinks.json
# https://viaf.org/viaf/316801251/justlinks.json
# https://viaf.org/viaf/317285061/justlinks.json
# https://viaf.org/viaf/12145857787923021175/justlinks.json
# https://viaf.org/viaf/12145857787923021175/justlinks.json
# https://viaf.org/viaf/12146522335832390026/justlinks.json
# https://viaf.org/viaf/43148933738654302743/justlinks.json
# https://viaf.org/viaf/43150030724010962913/justlinks.json
# https://viaf.org/viaf/47145003641961340275/justlinks.json
# https://viaf.org/viaf/47148207839200342239/justlinks.json
# https://viaf.org/viaf/67147905333279092795/justlinks.json
# https://viaf.org/viaf/76149066375565600915/justlinks.json
# https://viaf.org/viaf/96145857790523020035/justlinks.json
# https://viaf.org/viaf/143145857836223020026/justlinks.json
# https://viaf.org/viaf/224145542839596642372/justlinks.json
# https://viaf.org/viaf/259152744508927850007/justlinks.json
# https://viaf.org/viaf/299149294141680521071/justlinks.json
# https://viaf.org/viaf/333145857954723021375/justlinks.json
# https://viaf.org/viaf/348144647694593005200/justlinks.json
# https://viaf.org/viaf/507153596616951900007/justlinks.json
# https://viaf.org/viaf/507153596616951900007/justlinks.json
# https://viaf.org/viaf/514153954863505680001/justlinks.json
# https://viaf.org/viaf/587152636061920051255/justlinks.json
# https://viaf.org/viaf/642152261515917180000/justlinks.json
# https://viaf.org/viaf/664153063186219320005/justlinks.json
# https://viaf.org/viaf/724145662620905030177/justlinks.json
# https://viaf.org/viaf/725145857098322922128/justlinks.json
# https://viaf.org/viaf/972152502793910800003/justlinks.json
# https://viaf.org/viaf/2254154137634715370002/justlinks.json
# https://viaf.org/viaf/2836153653240655900000/justlinks.json
# https://viaf.org/viaf/3162152744523527850004/justlinks.json
# https://viaf.org/viaf/3745148705707037080009/justlinks.json
# https://viaf.org/viaf/4107155286646787180003/justlinks.json
# https://viaf.org/viaf/4331149619451404010004/justlinks.json
# https://viaf.org/viaf/5037148209311300460001/justlinks.json
# https://viaf.org/viaf/5526159035171401380003/justlinks.json
# https://viaf.org/viaf/6359150943160426760003/justlinks.json
# https://viaf.org/viaf/6407151778229018130006/justlinks.json
# https://viaf.org/viaf/6755152988214612790004/justlinks.json
# https://viaf.org/viaf/7903150749025716420002/justlinks.json
# https://viaf.org/viaf/8066154983560967860008/justlinks.json
# https://viaf.org/viaf/8867154983564767860001/justlinks.json
# https://viaf.org/viaf/9434152744554327850002/justlinks.json

# %% [markdown]
# #### Only one ID doesn't match. What is the name of the person?

# %%
[x for x in people_list if 'viaf' in x and int(x['viaf']) == 10760478][0]
# Out:
# {'id': 'Charles_Montigny', 'viaf': '10760478'}

# %% [markdown]
# #### Find all VIAF IDs of places

# %%
place_list_viaf = []

for x in place_list:
    if 'viaf' in x:
        try:
            place_list_viaf.append(int(x['viaf']))
        except:
            print(x)
    
place_list_viaf.sort()
# Out:
# {'lat': 51.35, 'lon': 1.383333, 'id': 'Isle_Thanet', 'viaf': '8.74E+21'}
# {'id': 'Portobelo', 'viaf': ' '}
# {'lat': -35.666667, 'lon': -55.783333, 'id': 'Rio_Plata', 'viaf': '1.14603E+18'}
# {'id': 'Troy', 'viaf': '1.11454E+19'}

# %% [markdown]
# #### Open all VIAF IDs of places to check if they exist

# %%
for viaf_id in place_list_viaf:
    url = 'https://viaf.org/viaf/{}/justlinks.json'.format(viaf_id)
    print(url)
    try:
        urllib.request.urlopen(url)
    except:
        print('DOES NOT EXIST')
# Out:
# https://viaf.org/viaf/122530980/justlinks.json
# https://viaf.org/viaf/123091922/justlinks.json
# https://viaf.org/viaf/123119883/justlinks.json
# https://viaf.org/viaf/123121838/justlinks.json
# https://viaf.org/viaf/123125090/justlinks.json
# https://viaf.org/viaf/123218997/justlinks.json
# https://viaf.org/viaf/123218997/justlinks.json
# https://viaf.org/viaf/123310773/justlinks.json
# https://viaf.org/viaf/123433385/justlinks.json
# https://viaf.org/viaf/123608439/justlinks.json
# https://viaf.org/viaf/123896014/justlinks.json
# https://viaf.org/viaf/123902398/justlinks.json
# https://viaf.org/viaf/124213732/justlinks.json
# https://viaf.org/viaf/124272308/justlinks.json
# https://viaf.org/viaf/124281406/justlinks.json
# https://viaf.org/viaf/124281423/justlinks.json
# https://viaf.org/viaf/124312582/justlinks.json
# https://viaf.org/viaf/124321959/justlinks.json
# https://viaf.org/viaf/124322655/justlinks.json
# https://viaf.org/viaf/124330404/justlinks.json
# https://viaf.org/viaf/124357912/justlinks.json
# https://viaf.org/viaf/124371179/justlinks.json
# https://viaf.org/viaf/124921812/justlinks.json
# https://viaf.org/viaf/124967002/justlinks.json
# https://viaf.org/viaf/125069454/justlinks.json
# https://viaf.org/viaf/125420191/justlinks.json
# https://viaf.org/viaf/125420191/justlinks.json
# https://viaf.org/viaf/125426357/justlinks.json
# https://viaf.org/viaf/125477381/justlinks.json
# https://viaf.org/viaf/125501644/justlinks.json
# https://viaf.org/viaf/125504622/justlinks.json
# https://viaf.org/viaf/125608209/justlinks.json
# https://viaf.org/viaf/126093597/justlinks.json
# https://viaf.org/viaf/126106244/justlinks.json
# https://viaf.org/viaf/126125725/justlinks.json
# https://viaf.org/viaf/126134059/justlinks.json
# https://viaf.org/viaf/126206931/justlinks.json
# https://viaf.org/viaf/126584662/justlinks.json
# https://viaf.org/viaf/126599932/justlinks.json
# https://viaf.org/viaf/126622508/justlinks.json
# https://viaf.org/viaf/126637168/justlinks.json
# https://viaf.org/viaf/126732315/justlinks.json
# https://viaf.org/viaf/126734787/justlinks.json
# https://viaf.org/viaf/126740035/justlinks.json
# https://viaf.org/viaf/126752226/justlinks.json
# https://viaf.org/viaf/127127940/justlinks.json
# https://viaf.org/viaf/127824921/justlinks.json
# https://viaf.org/viaf/127830627/justlinks.json
# https://viaf.org/viaf/127830899/justlinks.json
# https://viaf.org/viaf/127844338/justlinks.json
# https://viaf.org/viaf/127852195/justlinks.json
# https://viaf.org/viaf/127902977/justlinks.json
# https://viaf.org/viaf/127943223/justlinks.json
# https://viaf.org/viaf/127946988/justlinks.json
# https://viaf.org/viaf/127955606/justlinks.json
# https://viaf.org/viaf/128044385/justlinks.json
# https://viaf.org/viaf/128321639/justlinks.json
# https://viaf.org/viaf/128544491/justlinks.json
# https://viaf.org/viaf/128902416/justlinks.json
# https://viaf.org/viaf/128920607/justlinks.json
# https://viaf.org/viaf/128935789/justlinks.json
# https://viaf.org/viaf/128935864/justlinks.json
# https://viaf.org/viaf/128955856/justlinks.json
# https://viaf.org/viaf/128978640/justlinks.json
# https://viaf.org/viaf/128990823/justlinks.json
# https://viaf.org/viaf/129002681/justlinks.json
# https://viaf.org/viaf/129015040/justlinks.json
# https://viaf.org/viaf/129022729/justlinks.json
# https://viaf.org/viaf/129025607/justlinks.json
# https://viaf.org/viaf/129063625/justlinks.json
# https://viaf.org/viaf/129063625/justlinks.json
# https://viaf.org/viaf/129154192/justlinks.json
# https://viaf.org/viaf/130118089/justlinks.json
# https://viaf.org/viaf/130118559/justlinks.json
# https://viaf.org/viaf/130122410/justlinks.json
# https://viaf.org/viaf/130140031/justlinks.json
# https://viaf.org/viaf/130168302/justlinks.json
# https://viaf.org/viaf/130174478/justlinks.json
# https://viaf.org/viaf/130178328/justlinks.json
# https://viaf.org/viaf/130192898/justlinks.json
# https://viaf.org/viaf/130261285/justlinks.json
# https://viaf.org/viaf/130329623/justlinks.json
# https://viaf.org/viaf/130329623/justlinks.json
# https://viaf.org/viaf/130436007/justlinks.json
# https://viaf.org/viaf/130627690/justlinks.json
# https://viaf.org/viaf/130890862/justlinks.json
# https://viaf.org/viaf/130893302/justlinks.json
# https://viaf.org/viaf/131057853/justlinks.json
# https://viaf.org/viaf/131280462/justlinks.json
# https://viaf.org/viaf/131280745/justlinks.json
# https://viaf.org/viaf/131308391/justlinks.json
# https://viaf.org/viaf/131308391/justlinks.json
# https://viaf.org/viaf/131316875/justlinks.json
# https://viaf.org/viaf/131337264/justlinks.json
# https://viaf.org/viaf/131378566/justlinks.json
# https://viaf.org/viaf/131462011/justlinks.json
# https://viaf.org/viaf/131865526/justlinks.json
# https://viaf.org/viaf/131874314/justlinks.json
# https://viaf.org/viaf/131874314/justlinks.json
# https://viaf.org/viaf/132128474/justlinks.json
# https://viaf.org/viaf/132211363/justlinks.json
# https://viaf.org/viaf/132441531/justlinks.json
# https://viaf.org/viaf/132516299/justlinks.json
# https://viaf.org/viaf/132529210/justlinks.json
# https://viaf.org/viaf/132535661/justlinks.json
# https://viaf.org/viaf/132540216/justlinks.json
# https://viaf.org/viaf/132578315/justlinks.json
# https://viaf.org/viaf/132955773/justlinks.json
# https://viaf.org/viaf/133476995/justlinks.json
# https://viaf.org/viaf/133607895/justlinks.json
# https://viaf.org/viaf/133609710/justlinks.json
# https://viaf.org/viaf/133616250/justlinks.json
# https://viaf.org/viaf/133675177/justlinks.json
# https://viaf.org/viaf/133691467/justlinks.json
# https://viaf.org/viaf/133729873/justlinks.json
# https://viaf.org/viaf/133759298/justlinks.json
# https://viaf.org/viaf/133795859/justlinks.json
# https://viaf.org/viaf/133840547/justlinks.json
# https://viaf.org/viaf/134273104/justlinks.json
# https://viaf.org/viaf/134351237/justlinks.json
# https://viaf.org/viaf/134766632/justlinks.json
# https://viaf.org/viaf/134799371/justlinks.json
# https://viaf.org/viaf/134799371/justlinks.json
# https://viaf.org/viaf/134858717/justlinks.json
# https://viaf.org/viaf/134864542/justlinks.json
# https://viaf.org/viaf/134877579/justlinks.json
# https://viaf.org/viaf/134877580/justlinks.json
# https://viaf.org/viaf/134916509/justlinks.json
# https://viaf.org/viaf/134932498/justlinks.json
# https://viaf.org/viaf/134934050/justlinks.json
# https://viaf.org/viaf/135336679/justlinks.json
# https://viaf.org/viaf/135375457/justlinks.json
# https://viaf.org/viaf/135446758/justlinks.json
# https://viaf.org/viaf/135974050/justlinks.json
# https://viaf.org/viaf/135974051/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/135978082/justlinks.json
# https://viaf.org/viaf/135978478/justlinks.json
# https://viaf.org/viaf/136029148/justlinks.json
# https://viaf.org/viaf/136049044/justlinks.json
# https://viaf.org/viaf/136049224/justlinks.json
# https://viaf.org/viaf/136049224/justlinks.json
# https://viaf.org/viaf/136262178/justlinks.json
# https://viaf.org/viaf/136600716/justlinks.json
# https://viaf.org/viaf/136651400/justlinks.json
# https://viaf.org/viaf/136686783/justlinks.json
# https://viaf.org/viaf/137138322/justlinks.json
# https://viaf.org/viaf/137143608/justlinks.json
# https://viaf.org/viaf/137153818/justlinks.json
# https://viaf.org/viaf/137209992/justlinks.json
# https://viaf.org/viaf/137211783/justlinks.json
# https://viaf.org/viaf/137421431/justlinks.json
# https://viaf.org/viaf/137490784/justlinks.json
# https://viaf.org/viaf/137707668/justlinks.json
# https://viaf.org/viaf/137842517/justlinks.json
# https://viaf.org/viaf/138378805/justlinks.json
# https://viaf.org/viaf/138543438/justlinks.json
# https://viaf.org/viaf/138642187/justlinks.json
# https://viaf.org/viaf/138926424/justlinks.json
# https://viaf.org/viaf/139037820/justlinks.json
# https://viaf.org/viaf/139487232/justlinks.json
# https://viaf.org/viaf/139492016/justlinks.json
# https://viaf.org/viaf/139545573/justlinks.json
# https://viaf.org/viaf/139546160/justlinks.json
# https://viaf.org/viaf/139561846/justlinks.json
# https://viaf.org/viaf/139728511/justlinks.json
# https://viaf.org/viaf/139955738/justlinks.json
# https://viaf.org/viaf/140101415/justlinks.json
# https://viaf.org/viaf/140192382/justlinks.json
# https://viaf.org/viaf/140276705/justlinks.json
# https://viaf.org/viaf/140653532/justlinks.json
# https://viaf.org/viaf/140664856/justlinks.json
# https://viaf.org/viaf/140666509/justlinks.json
# https://viaf.org/viaf/140714405/justlinks.json
# https://viaf.org/viaf/140715260/justlinks.json
# https://viaf.org/viaf/141595502/justlinks.json
# https://viaf.org/viaf/141898513/justlinks.json
# https://viaf.org/viaf/141926311/justlinks.json
# https://viaf.org/viaf/141936652/justlinks.json
# https://viaf.org/viaf/141937103/justlinks.json
# https://viaf.org/viaf/141952272/justlinks.json
# https://viaf.org/viaf/141968767/justlinks.json
# https://viaf.org/viaf/142524829/justlinks.json
# https://viaf.org/viaf/142803650/justlinks.json
# https://viaf.org/viaf/142985214/justlinks.json
# https://viaf.org/viaf/143072237/justlinks.json
# https://viaf.org/viaf/143074613/justlinks.json
# https://viaf.org/viaf/143083976/justlinks.json
# https://viaf.org/viaf/143316992/justlinks.json
# https://viaf.org/viaf/143323430/justlinks.json
# https://viaf.org/viaf/143649512/justlinks.json
# https://viaf.org/viaf/144203711/justlinks.json
# https://viaf.org/viaf/144253584/justlinks.json
# https://viaf.org/viaf/144267190/justlinks.json
# https://viaf.org/viaf/144294767/justlinks.json
# https://viaf.org/viaf/144323980/justlinks.json
# https://viaf.org/viaf/144547294/justlinks.json
# https://viaf.org/viaf/144610141/justlinks.json
# https://viaf.org/viaf/144610141/justlinks.json
# https://viaf.org/viaf/144973547/justlinks.json
# https://viaf.org/viaf/145353708/justlinks.json
# https://viaf.org/viaf/145404323/justlinks.json
# https://viaf.org/viaf/145415800/justlinks.json
# https://viaf.org/viaf/145427148/justlinks.json
# https://viaf.org/viaf/145957840/justlinks.json
# https://viaf.org/viaf/146267734/justlinks.json
# https://viaf.org/viaf/146285843/justlinks.json
# https://viaf.org/viaf/146498747/justlinks.json
# https://viaf.org/viaf/146548876/justlinks.json
# https://viaf.org/viaf/146548876/justlinks.json
# https://viaf.org/viaf/146556747/justlinks.json
# https://viaf.org/viaf/146567981/justlinks.json
# https://viaf.org/viaf/146579883/justlinks.json
# https://viaf.org/viaf/146590466/justlinks.json
# https://viaf.org/viaf/146598398/justlinks.json
# https://viaf.org/viaf/146692549/justlinks.json
# https://viaf.org/viaf/146737597/justlinks.json
# https://viaf.org/viaf/146757738/justlinks.json
# https://viaf.org/viaf/147109072/justlinks.json
# https://viaf.org/viaf/147211710/justlinks.json
# https://viaf.org/viaf/147665514/justlinks.json
# https://viaf.org/viaf/147680224/justlinks.json
# https://viaf.org/viaf/147684646/justlinks.json
# https://viaf.org/viaf/147713487/justlinks.json
# https://viaf.org/viaf/147714862/justlinks.json
# https://viaf.org/viaf/147738740/justlinks.json
# https://viaf.org/viaf/147755335/justlinks.json
# https://viaf.org/viaf/147765588/justlinks.json
# https://viaf.org/viaf/148351965/justlinks.json
# https://viaf.org/viaf/148386330/justlinks.json
# https://viaf.org/viaf/148709451/justlinks.json
# https://viaf.org/viaf/148861381/justlinks.json
# https://viaf.org/viaf/148861381/justlinks.json
# https://viaf.org/viaf/148913826/justlinks.json
# https://viaf.org/viaf/148916436/justlinks.json
# https://viaf.org/viaf/148947373/justlinks.json
# https://viaf.org/viaf/148962304/justlinks.json
# https://viaf.org/viaf/149471694/justlinks.json
# https://viaf.org/viaf/149665036/justlinks.json
# https://viaf.org/viaf/149669363/justlinks.json
# https://viaf.org/viaf/150023893/justlinks.json
# https://viaf.org/viaf/150028558/justlinks.json
# https://viaf.org/viaf/150029386/justlinks.json
# https://viaf.org/viaf/150049686/justlinks.json
# https://viaf.org/viaf/150076018/justlinks.json
# https://viaf.org/viaf/150081023/justlinks.json
# https://viaf.org/viaf/150098567/justlinks.json
# https://viaf.org/viaf/150236186/justlinks.json
# https://viaf.org/viaf/150675140/justlinks.json
# https://viaf.org/viaf/150707604/justlinks.json
# https://viaf.org/viaf/151207259/justlinks.json
# https://viaf.org/viaf/151229994/justlinks.json
# https://viaf.org/viaf/151255387/justlinks.json
# https://viaf.org/viaf/151276369/justlinks.json
# https://viaf.org/viaf/151287843/justlinks.json
# https://viaf.org/viaf/151297017/justlinks.json
# https://viaf.org/viaf/151318698/justlinks.json
# https://viaf.org/viaf/151485978/justlinks.json
# https://viaf.org/viaf/151527740/justlinks.json
# https://viaf.org/viaf/151528321/justlinks.json
# https://viaf.org/viaf/151741417/justlinks.json
# https://viaf.org/viaf/151794179/justlinks.json
# https://viaf.org/viaf/152361066/justlinks.json
# https://viaf.org/viaf/152380653/justlinks.json
# https://viaf.org/viaf/152381862/justlinks.json
# https://viaf.org/viaf/152395020/justlinks.json
# https://viaf.org/viaf/152450284/justlinks.json
# https://viaf.org/viaf/152454816/justlinks.json
# https://viaf.org/viaf/152455339/justlinks.json
# https://viaf.org/viaf/152616518/justlinks.json
# https://viaf.org/viaf/152616518/justlinks.json
# https://viaf.org/viaf/152619802/justlinks.json
# https://viaf.org/viaf/152797039/justlinks.json
# https://viaf.org/viaf/153009195/justlinks.json
# https://viaf.org/viaf/153063450/justlinks.json
# https://viaf.org/viaf/153270746/justlinks.json
# https://viaf.org/viaf/153543201/justlinks.json
# https://viaf.org/viaf/153546881/justlinks.json
# https://viaf.org/viaf/153568702/justlinks.json
# https://viaf.org/viaf/153626210/justlinks.json
# https://viaf.org/viaf/153631400/justlinks.json
# https://viaf.org/viaf/153648760/justlinks.json
# https://viaf.org/viaf/153769983/justlinks.json
# https://viaf.org/viaf/154055230/justlinks.json
# https://viaf.org/viaf/154153261/justlinks.json
# https://viaf.org/viaf/154177642/justlinks.json
# https://viaf.org/viaf/154313685/justlinks.json
# https://viaf.org/viaf/154323889/justlinks.json
# https://viaf.org/viaf/154706100/justlinks.json
# https://viaf.org/viaf/154716289/justlinks.json
# https://viaf.org/viaf/154755082/justlinks.json
# https://viaf.org/viaf/154760885/justlinks.json
# https://viaf.org/viaf/154773300/justlinks.json
# https://viaf.org/viaf/154775570/justlinks.json
# https://viaf.org/viaf/154781010/justlinks.json
# https://viaf.org/viaf/154804451/justlinks.json
# https://viaf.org/viaf/154830608/justlinks.json
# https://viaf.org/viaf/154841577/justlinks.json
# https://viaf.org/viaf/154866065/justlinks.json
# https://viaf.org/viaf/154883795/justlinks.json
# https://viaf.org/viaf/155482669/justlinks.json
# https://viaf.org/viaf/155566727/justlinks.json
# https://viaf.org/viaf/155855229/justlinks.json
# https://viaf.org/viaf/155870508/justlinks.json
# https://viaf.org/viaf/155870729/justlinks.json
# https://viaf.org/viaf/155926635/justlinks.json
# https://viaf.org/viaf/155929994/justlinks.json
# https://viaf.org/viaf/155960902/justlinks.json
# https://viaf.org/viaf/156294421/justlinks.json
# https://viaf.org/viaf/156652814/justlinks.json
# https://viaf.org/viaf/157037914/justlinks.json
# https://viaf.org/viaf/157316462/justlinks.json
# https://viaf.org/viaf/158189703/justlinks.json
# https://viaf.org/viaf/158208597/justlinks.json
# https://viaf.org/viaf/158222363/justlinks.json
# https://viaf.org/viaf/158228124/justlinks.json
# https://viaf.org/viaf/158275772/justlinks.json
# https://viaf.org/viaf/158281946/justlinks.json
# https://viaf.org/viaf/158296428/justlinks.json
# https://viaf.org/viaf/158387156/justlinks.json
# https://viaf.org/viaf/158822968/justlinks.json
# https://viaf.org/viaf/159364209/justlinks.json
# https://viaf.org/viaf/159367111/justlinks.json
# https://viaf.org/viaf/159380011/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/159464558/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/159489370/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/159502092/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/159512356/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/159514763/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/159710485/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/160986471/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/162884679/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/166046036/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/167021112/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/168512951/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/168830626/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/168925906/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/173199953/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/173603120/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/180363010/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/180982702/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/182620392/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/232928875/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/233665742/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/233806393/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/234152339/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/234601772/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/234768684/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/235007026/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/235069100/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/235242513/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/235904198/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/235924579/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/235934307/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/235959579/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/236365773/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/236789368/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/236849128/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/237259345/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/237263761/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/237292804/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/237298336/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/238517527/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/239001081/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/239137019/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/239202507/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/239492321/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/239710836/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/240316829/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/240805445/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/241241514/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/241422889/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/241428861/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/242059897/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/242111207/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/243891216/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/244264840/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/244550567/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/245608584/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/246126882/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/246236571/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/246236571/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/246280004/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/246535206/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/247162069/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/247225556/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/247818212/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/248054003/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/248258990/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/248543380/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/251380480/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/251794742/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/252680782/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/253275800/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/255146259/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/255285986/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/256095765/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/258171512/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/261467287/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/261960983/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/262438290/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/262770197/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/264091107/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/265487382/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/266415900/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/266665986/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/267149707/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/268276259/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/268375304/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/268417032/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/294005587/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/304910304/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/305126934/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/308211225/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/308719648/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/308719648/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/308737817/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/309644416/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/311114459/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/312657476/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/312793147/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/315124935/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/315125202/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/315126463/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/315126548/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/315126791/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/315128562/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/315129048/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/315132541/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/315145763/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/315146199/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/315146656/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/315146708/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/315146921/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/315148152/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/315149415/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/315149415/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/315149503/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/315160354/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/315160374/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/315160770/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/315162232/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/315169422/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/315170406/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/315526186/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/315526329/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/315527391/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/316601174/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/316734166/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/316746075/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/316874805/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/14144647637882257010/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/22148120436794790133/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/51145003714561340859/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/53152501151310681322/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/83146937728413830171/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/94147905237079091870/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/98145858144823022755/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/146145541772496601443/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/183144928972854441419/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/234145857065822921806/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/717152502996710800000/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/2808160486110505180005/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/4345147907508479210008/justlinks.json
# DOES NOT EXIST
# https://viaf.org/viaf/5652148574317524430001/justlinks.json
# DOES NOT EXIST

# %% [markdown]
# #### Only one ID doesn't match. What is the name of the place?

# %%
[x for x in place_list if 'viaf' in x and x['viaf'] == '135974051'][0]
# Out:
# {'id': 'Yorkshire_Outhorn',
#  'lat': 53.93264,
#  'lon': -1.28712,
#  'viaf': '135974051'}

# %% [markdown]
# #### What is the distribution of all places in the main list?

# %%
from mapboxgl.utils import *
from mapboxgl.viz import *

places_with_coords = pd.DataFrame(place_list).dropna(subset=['lat', 'lon'])

geo = df_to_geojson(places_with_coords, lat='lat', lon='lon', precision=3)

token = 'pk.eyJ1IjoibWV0aWxsaSIsImEiOiJjbDB2c2IydzUxN3B5M2lxZHBpbDYxZmw2In0.buJ8OEPbHtUBg8mqHNNp7A'

color_breaks = [0,10,100,1000,10000]
color_stops = create_color_stops(color_breaks, colors='RdPu')

viz = CircleViz(geo, access_token=token, 
                radius = 3, center = (places_with_coords.lon.mean(), places_with_coords.lat.mean()), 
                zoom = 2,
                color_stops=color_stops,
                label_color = '#69F0AE',
                color_default='#DD00DD',
                stroke_color='#ffffff')
viz.show()
# Out:
# /home/dani/.local/lib/python3.5/site-packages/IPython/core/display.py:701: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe id="map", srcdoc="<!DOCTYPE html>
# <html>
# <head>
# <title>mapboxgl-jupyter viz</title>
# <meta charset='UTF-8' />
# <meta name='viewport'
#       content='initial-scale=1,maximum-scale=1,user-scalable=no' />
# <script type='text/javascript'
#         src='https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js'></script>
# <link type='text/css'
#       href='https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css'
#       rel='stylesheet' />
#
# <style type='text/css'>
#     body { margin:0; padding:0; }
#     .map { position: absolute; top:0; bottom:0; width:100%; }
#     .legend {
#         background-color: white;
#         color: #6e6e6e;
#         border-radius: 3px;
#         bottom: 10px;
#         box-shadow: 0 1px 2px rgba(0, 0, 0, 0.10);
#         font: 12px/20px 'Helvetica Neue', Arial, Helvetica, sans-serif;
#         padding: 0;
#         position: absolute;
#         right: 10px;
#         z-index: 1;
#         min-width: 100px;
#     }
#    .legend.horizontal {bottom: 10px; text-align: left;}
#
#     /* legend header */
#     .legend .legend-header { border-radius: 3px 3px 0 0; background: white; }
#     .legend .legend-title {
#         padding: 6px 12px 6px 12px;
#         text-shadow: 0 0 2px white;
#         text-transform: capitalize;
#         text-align: center;
#         font-weight: bold !important;
#         font-size: 14px;
#         font: 12px/20px 'Helvetica Neue', Arial, Helvetica, sans-serif;
#         max-width: 160px;
#     }
#     .legend-title {padding: 6px 12px 6px 12px; text-shadow: 0 0 2px #FFF; text-transform: capitalize; text-align: center; max-width: 160px; font-size: 0.9em; font-weight: bold;}
#     .legend.horizontal .legend-title {text-align: left;}
#
#     /* legend items */
#     .legend-content {margin: 6px 12px 6px 12px; overflow: hidden; padding: 0; float: left; list-style: none; font-size: 0.8em;}
#     .legend.vertical .legend-item {white-space: nowrap;}
#     .legend-value {display: inline-block; line-height: 18px; vertical-align: top;}
#     .legend.horizontal ul.legend-content li.legend-item .legend-value,
#     .legend.horizontal ul.legend-content li.legend-item {display: inline-block; float: left; width: 30px; margin-bottom: 0; text-align: center; min-height: 30px;}
#
#     /* legend key styles */
#     .legend-key {display: inline-block; height: 10px;}
#     .legend-key.default, .legend-key.square {border-radius: 0;}
#     .legend-key.circle {border-radius: 50%;}
#     .legend-key.rounded-square {border-radius: 20%;}
#     .legend.vertical .legend-key {width: 10px; margin-right: 5px; margin-left: 1px;}
#     .legend.horizontal .legend-key {width: 30px; margin-right: 0; margin-top: 1px; float: left;}
#     .legend.horizontal .legend-key.square, .legend.horizontal .legend-key.rounded-square, .legend.horizontal .legend-key.circle {margin-left: 10px; width: 10px;}
#     .legend.horizontal .legend-key.line {margin-left: 5px;}
#     .legend.horizontal .legend-key.line, .legend.vertical .legend-key.line {border-radius: 10%; width: 20px; height: 3px; margin-bottom: 2px;}
#
#     /* gradient bar alignment */
#     .gradient-bar {margin: 6px 12px 6px 12px;}
#     .legend.horizontal .gradient-bar {width: 88%; height: 10px;}
#     .legend.vertical .gradient-bar {width: 10px; min-height: 50px; position: absolute; bottom: 4px;}
#
#     /* contiguous vertical bars (discrete) */
#     .legend.vertical.contig .legend-key {height: 15px; width: 10px;}
#     .legend.vertical.contig li.legend-item {height: 15px;}
#     .legend.vertical.contig {padding-bottom: 6px;}
#
#     /* vertical radius legend */
#     .legend.horizontal.legend-variable-radius ul.legend-content li.legend-item .legend-value,
#     .legend.horizontal.legend-variable-radius ul.legend-content li.legend-item {width: 30px; min-height: 20px;}
#
#     /* scale annotation */
#     .mapboxgl-ctrl.mapboxgl-ctrl-scale { border-color: #6e6e6e;
#                                          background-color: white;
#                                          color: #131516; }
# </style>
#
#
# <style>
#     .gradient-bar.bordered, .legend-key.bordered { border: solid #ffffff 0.1px; }
# </style>
#
#
# </head>
# <body>
#
# <div id='map' class='map'></div>
#
# <script type='text/javascript'>
#
# var legendHeader;
#
# function calcColorLegend(myColorStops, title) {
#     // create legend
#     var legend = document.createElement('div'),
#         legendContainer = document.getElementsByClassName('mapboxgl-ctrl-bottom-right')[0];
#
#     if ('circle' === 'contiguous-bar') {
#         legend.className = 'legend vertical contig';
#     }
#     else {
#         legend.className = 'legend vertical';
#     }
#     legend.id = 'legend-0';
#     document.body.appendChild(legend);
#     // add legend header and content elements
#     var mytitle = document.createElement('div'),
#         legendContent = document.createElement('ul');
#     legendHeader = document.createElement('div');
#     mytitle.textContent = title;
#     mytitle.className = 'legend-title'
#     legendHeader.className = 'legend-header'
#     legendContent.className = 'legend-content'
#     legendHeader.appendChild(mytitle);
#     legend.appendChild(legendHeader);
#     legend.appendChild(legendContent);
#     if (false === true) {
#         var gradientText = 'linear-gradient(to right, ',
#             gradient = document.createElement('div');
#         gradient.className = 'gradient-bar';
#         legend.appendChild(gradient);
#     }
#     // calculate a legend entries on a Mapbox GL Style Spec property function stops array
#     for (p = 0; p < myColorStops.length; p++) {
#         if (!!document.getElementById('legend-color-points-value-' + p)) {
#             // update the legend if it already exists
#             document.getElementById('legend-color-points-value-' + p).textContent = myColorStops[p][0];
#             document.getElementById('legend-color-points-id-' + p).style.backgroundColor = myColorStops[p][1];
#         }
#         else {
#             // create the legend if it doesn't yet exist
#             var item = document.createElement('li');
#             item.className = 'legend-item';
#             var key = document.createElement('span');
#             key.className = 'legend-key circle';
#             key.id = 'legend-color-points-id-' + p;
#             key.style.backgroundColor = myColorStops[p][1];
#             var value = document.createElement('span');
#             value.className = 'legend-value';
#             value.id = 'legend-color-points-value-' + p;
#             item.appendChild(key);
#             item.appendChild(value);
#             legendContent.appendChild(item);
#
#             data = document.getElementById('legend-color-points-value-' + p)
#             // round number values in legend if precision defined
#             if ((typeof(myColorStops[p][0]) == 'number') && (typeof(null) == 'number')) {
#                 data.textContent = myColorStops[p][0].toFixed(null);
#             }
#             else {
#                 data.textContent = myColorStops[p][0];
#             }
#             // add color stop to gradient list
#             if (false === true) {
#                 if (p < myColorStops.length - 1) {
#                     gradientText = gradientText + myColorStops[p][1] + ', ';
#                 }
#                 else {
#                     gradientText = gradientText + myColorStops[p][1] + ')';
#                 }
#                 if ('vertical' === 'vertical') {
#                     gradientText = gradientText.replace('to right', 'to bottom');
#                 }
#             }
#         }
#     }
#     if (false === true) {
#         // convert to gradient scale appearance
#         gradient.style.background = gradientText;
#         // hide legend keys generated above
#         var keys = document.getElementsByClassName('legend-key');
#         for (var i=0; i < keys.length; i++) {
#             keys[i].style.visibility = 'hidden';
#         }
#         if ('vertical' === 'vertical') {
#             gradient.style.height = (legendContent.offsetHeight - 6) + 'px';
#         }
#     }
#     // add class for styling bordered legend keys
#     if (true) {
#         var keys = document.getElementsByClassName('legend-key');
#         for (var i=0; i < keys.le

# %% [markdown]
# #### What is the distribution of places in the Miscellanies?

# %%
places_with_coords = places_with_coords[places_with_coords['id'].isin(individual_places)] 

geo = df_to_geojson(places_with_coords, lat='lat', lon='lon', precision=3)

viz = CircleViz(geo, access_token=token, 
                radius = 3, center = (58, 33), 
                zoom = 2,
                color_stops=color_stops,
                label_color = '#69F0AE',
                color_default='#DD00DD',
                stroke_color='#ffffff')
viz.show()
# Out:
# <iframe id="map", srcdoc="<!DOCTYPE html>
# <html>
# <head>
# <title>mapboxgl-jupyter viz</title>
# <meta charset='UTF-8' />
# <meta name='viewport'
#       content='initial-scale=1,maximum-scale=1,user-scalable=no' />
# <script type='text/javascript'
#         src='https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js'></script>
# <link type='text/css'
#       href='https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css'
#       rel='stylesheet' />
#
# <style type='text/css'>
#     body { margin:0; padding:0; }
#     .map { position: absolute; top:0; bottom:0; width:100%; }
#     .legend {
#         background-color: white;
#         color: #6e6e6e;
#         border-radius: 3px;
#         bottom: 10px;
#         box-shadow: 0 1px 2px rgba(0, 0, 0, 0.10);
#         font: 12px/20px 'Helvetica Neue', Arial, Helvetica, sans-serif;
#         padding: 0;
#         position: absolute;
#         right: 10px;
#         z-index: 1;
#         min-width: 100px;
#     }
#    .legend.horizontal {bottom: 10px; text-align: left;}
#
#     /* legend header */
#     .legend .legend-header { border-radius: 3px 3px 0 0; background: white; }
#     .legend .legend-title {
#         padding: 6px 12px 6px 12px;
#         text-shadow: 0 0 2px white;
#         text-transform: capitalize;
#         text-align: center;
#         font-weight: bold !important;
#         font-size: 14px;
#         font: 12px/20px 'Helvetica Neue', Arial, Helvetica, sans-serif;
#         max-width: 160px;
#     }
#     .legend-title {padding: 6px 12px 6px 12px; text-shadow: 0 0 2px #FFF; text-transform: capitalize; text-align: center; max-width: 160px; font-size: 0.9em; font-weight: bold;}
#     .legend.horizontal .legend-title {text-align: left;}
#
#     /* legend items */
#     .legend-content {margin: 6px 12px 6px 12px; overflow: hidden; padding: 0; float: left; list-style: none; font-size: 0.8em;}
#     .legend.vertical .legend-item {white-space: nowrap;}
#     .legend-value {display: inline-block; line-height: 18px; vertical-align: top;}
#     .legend.horizontal ul.legend-content li.legend-item .legend-value,
#     .legend.horizontal ul.legend-content li.legend-item {display: inline-block; float: left; width: 30px; margin-bottom: 0; text-align: center; min-height: 30px;}
#
#     /* legend key styles */
#     .legend-key {display: inline-block; height: 10px;}
#     .legend-key.default, .legend-key.square {border-radius: 0;}
#     .legend-key.circle {border-radius: 50%;}
#     .legend-key.rounded-square {border-radius: 20%;}
#     .legend.vertical .legend-key {width: 10px; margin-right: 5px; margin-left: 1px;}
#     .legend.horizontal .legend-key {width: 30px; margin-right: 0; margin-top: 1px; float: left;}
#     .legend.horizontal .legend-key.square, .legend.horizontal .legend-key.rounded-square, .legend.horizontal .legend-key.circle {margin-left: 10px; width: 10px;}
#     .legend.horizontal .legend-key.line {margin-left: 5px;}
#     .legend.horizontal .legend-key.line, .legend.vertical .legend-key.line {border-radius: 10%; width: 20px; height: 3px; margin-bottom: 2px;}
#
#     /* gradient bar alignment */
#     .gradient-bar {margin: 6px 12px 6px 12px;}
#     .legend.horizontal .gradient-bar {width: 88%; height: 10px;}
#     .legend.vertical .gradient-bar {width: 10px; min-height: 50px; position: absolute; bottom: 4px;}
#
#     /* contiguous vertical bars (discrete) */
#     .legend.vertical.contig .legend-key {height: 15px; width: 10px;}
#     .legend.vertical.contig li.legend-item {height: 15px;}
#     .legend.vertical.contig {padding-bottom: 6px;}
#
#     /* vertical radius legend */
#     .legend.horizontal.legend-variable-radius ul.legend-content li.legend-item .legend-value,
#     .legend.horizontal.legend-variable-radius ul.legend-content li.legend-item {width: 30px; min-height: 20px;}
#
#     /* scale annotation */
#     .mapboxgl-ctrl.mapboxgl-ctrl-scale { border-color: #6e6e6e;
#                                          background-color: white;
#                                          color: #131516; }
# </style>
#
#
# <style>
#     .gradient-bar.bordered, .legend-key.bordered { border: solid #ffffff 0.1px; }
# </style>
#
#
# </head>
# <body>
#
# <div id='map' class='map'></div>
#
# <script type='text/javascript'>
#
# var legendHeader;
#
# function calcColorLegend(myColorStops, title) {
#     // create legend
#     var legend = document.createElement('div'),
#         legendContainer = document.getElementsByClassName('mapboxgl-ctrl-bottom-right')[0];
#
#     if ('circle' === 'contiguous-bar') {
#         legend.className = 'legend vertical contig';
#     }
#     else {
#         legend.className = 'legend vertical';
#     }
#     legend.id = 'legend-0';
#     document.body.appendChild(legend);
#     // add legend header and content elements
#     var mytitle = document.createElement('div'),
#         legendContent = document.createElement('ul');
#     legendHeader = document.createElement('div');
#     mytitle.textContent = title;
#     mytitle.className = 'legend-title'
#     legendHeader.className = 'legend-header'
#     legendContent.className = 'legend-content'
#     legendHeader.appendChild(mytitle);
#     legend.appendChild(legendHeader);
#     legend.appendChild(legendContent);
#     if (false === true) {
#         var gradientText = 'linear-gradient(to right, ',
#             gradient = document.createElement('div');
#         gradient.className = 'gradient-bar';
#         legend.appendChild(gradient);
#     }
#     // calculate a legend entries on a Mapbox GL Style Spec property function stops array
#     for (p = 0; p < myColorStops.length; p++) {
#         if (!!document.getElementById('legend-color-points-value-' + p)) {
#             // update the legend if it already exists
#             document.getElementById('legend-color-points-value-' + p).textContent = myColorStops[p][0];
#             document.getElementById('legend-color-points-id-' + p).style.backgroundColor = myColorStops[p][1];
#         }
#         else {
#             // create the legend if it doesn't yet exist
#             var item = document.createElement('li');
#             item.className = 'legend-item';
#             var key = document.createElement('span');
#             key.className = 'legend-key circle';
#             key.id = 'legend-color-points-id-' + p;
#             key.style.backgroundColor = myColorStops[p][1];
#             var value = document.createElement('span');
#             value.className = 'legend-value';
#             value.id = 'legend-color-points-value-' + p;
#             item.appendChild(key);
#             item.appendChild(value);
#             legendContent.appendChild(item);
#
#             data = document.getElementById('legend-color-points-value-' + p)
#             // round number values in legend if precision defined
#             if ((typeof(myColorStops[p][0]) == 'number') && (typeof(null) == 'number')) {
#                 data.textContent = myColorStops[p][0].toFixed(null);
#             }
#             else {
#                 data.textContent = myColorStops[p][0];
#             }
#             // add color stop to gradient list
#             if (false === true) {
#                 if (p < myColorStops.length - 1) {
#                     gradientText = gradientText + myColorStops[p][1] + ', ';
#                 }
#                 else {
#                     gradientText = gradientText + myColorStops[p][1] + ')';
#                 }
#                 if ('vertical' === 'vertical') {
#                     gradientText = gradientText.replace('to right', 'to bottom');
#                 }
#             }
#         }
#     }
#     if (false === true) {
#         // convert to gradient scale appearance
#         gradient.style.background = gradientText;
#         // hide legend keys generated above
#         var keys = document.getElementsByClassName('legend-key');
#         for (var i=0; i < keys.length; i++) {
#             keys[i].style.visibility = 'hidden';
#         }
#         if ('vertical' === 'vertical') {
#             gradient.style.height = (legendContent.offsetHeight - 6) + 'px';
#         }
#     }
#     // add class for styling bordered legend keys
#     if (true) {
#         var keys = document.getElementsByClassName('legend-key');
#         for (var i=0; i < keys.le

# %% [markdown]
# #### What places are mentioned the most?

# %%
plc = pd.DataFrame([x for x in df.explode('places')['places'].dropna()])
plc = plc.groupby(['id'])['id'].count().sort_values(ascending=False).to_frame()
plc = plc.rename(columns = {'id':'count'})
plc
# Out:
#                            count
# id
# China                         98
# Japan                         52
# East_Indies                   44
# Turkey                        28
# Guinea                        17
# Jamaica                       14
# Persia                        13
# New_England                   13
# West_Indies                   13
# Virginia                      12
# Hudson_Bay                    11
# Carolina                      10
# Scotland                      10
# Spain                          9
# America                        8
# Strait_Magellan                8
# Holland                        8
# Brasil                         7
# Canada                         7
# India                          6
# France                         6
# Lapland                        5
# Malabar                        5
# Portugal                       5
# Surinam                        5
# North_America                  5
# Malacca                        5
# Paris                          4
# Windsor                        4
# Rome                           4
# Flanders                       4
# Russia                         4
# Ireland                        4
# Smyrna                         4
# South_Carolina                 4
# Germany                        4
# Darien                         3
# Hampshire                      3
# Westminster                    3
# Malta                          3
# Fort_George                    3
# North_England                  3
# Nuremberg                      3
# Madagascar                     3
# Barbary                        3
# London                         3
# Petersburg                     3
# Epsom                          3
# Campeche                       3
# Suratte                        3
# Jerusalem                      3
# Davis_Strait                   3
# Bristol                        3
# Lisbon                         3
# Gibraltar                      2
# Lyon                           2
# Hudson_Strait                  2
# Mogols_country                 2
# Egypt                          2
# Kamchatka                      2
# Greenland                      2
# Malaga                         2
# Java                           2
# Constantinople                 2
# Florence                       2
# Mexico                         2
# Italy                          2
# Yorkshire                      2
# Quoi                           2
# Naples                         2
# St_Paul                        2
# Africa                         2
# Berlin                         2
# Canton                         2
# Susquehanna                    2
# Borneo                         2
# Sheffield                      2
# Norway                         2
# Reculver                       2
# Oxford                         2
# Pegu                           2
# Congo                          1
# Dominica                       1
# Dresden                        1
# Bermudas                       1
# Dieppe                         1
# Berbice                        1
# Bath                           1
# Bengal                         1
# Bavaria                        1
# Barbados                       1
# Ashante                        1
# Angola                         1
# Emuy                           1
# Amsterdam                      1
# Agrafee                        1
# England                        1
# Entau                          1
# Bethlehem                      1
# Bloomsbury_Square              1
# Devonshire                     1
# Bishopsgate                    1
# Cheshire                       1
# Corduba                        1
# Cornwall                       1
# Coromandel                     1
# Celebes                        1
# Epping_forest                  1
# Cartagena                      1
# Creepu                         1
# Croydon                        1
# Caribbean_Islands              1
# Calabria                       1
# Buckby                         1
# Delaware                       1
# Brussels                       1
# Denmark                        1
# Bourdeaux                      1
# Bohemia                        1
# Cleve                          1
# Derbyshire                     1
# Catalonia                      1
# Kings_Langley                  1
# Filah                          1
# Sumatra                        1
# Poland                         1
# Portsmouth                     1
# Prussia                        1
# Pyrenees                       1
# Quaqua_coast                   1
# River_Gambia                   1
# River_Voller                   1
# Rochester                      1
# Santa_Cruz                     1
# Senegal                        1
# Sens                           1
# Siberia                        1
# Sussex                         1
# Flintshire                     1
# Suters_Hill                    1
# Sweden                         1
# Switzerland                    1
# Terra_Fuego                    1
# Thames                         1
# Tonkin                         1
# Tourn                          1
# Vampo                          1
# Wales                          1
# Ware_park                      1
# Whitehall                      1
# Whydah                         1
# Philadelphia                   1
# Peru                           1
# Pennsylvania                   1
# Oxfordshire                    1
# Fountain_Court_Strand          1
# Geneva                         1
# Gomroon                        1
# Guanaboa                       1
# Harrogate                      1
# Hudson_River                   1
# Isles_Scotland                 1
# Jaffa                          1
# Lancashire                     1
# Lawrance                       1
# Legorn                         1
# Livonia                        1
# Luneburg                       1
# Makassar                       1
# Malton                         1
# Marorla_Congo                  1
# Melo_Island                    1
# Menorca                        1
# Montserrat                     1
# Mount_Mill_St_Bartholomew      1
# Muscovy                        1
# New_York                       1
# Newcastle                      1
# Nieves                         1
# North_Scotland                 1
# Aethiopia                      1

# %% [markdown]
# #### Let's plot the places on a bar chart

# %%
plt.figure(figsize=(14,6))
plt.xticks(range(30), rotation='vertical')
plc_filtered = plc[plc['count'] > 5]
plt.bar(plc_filtered.index,plc_filtered['count'])
plt.show()

# %% [markdown]
# #### Let's make a better map

# %%
places_with_coords_count = places_with_coords.join(plc, on='id', how='left')
places_with_coords_count.sort_values(by='count', ascending=False)

geo = df_to_geojson(places_with_coords_count, lat='lat', lon='lon', precision=3)

viz = GraduatedCircleViz(geo, access_token=token, 
                center = (58, 33),
                zoom = 2,
                radius_property='count',
                radius_stops=create_radius_stops([0, 5, 10, 20, 40, 60, 80, 100], 0.5, 30),
                color_stops=color_stops,
                label_color = '#69F0AE',
                color_default='#DD00DD',
                stroke_color='#ffffff')
viz.show()
# Out:
# <iframe id="map", srcdoc="<!DOCTYPE html>
# <html>
# <head>
# <title>mapboxgl-jupyter viz</title>
# <meta charset='UTF-8' />
# <meta name='viewport'
#       content='initial-scale=1,maximum-scale=1,user-scalable=no' />
# <script type='text/javascript'
#         src='https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js'></script>
# <link type='text/css'
#       href='https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css'
#       rel='stylesheet' />
#
# <style type='text/css'>
#     body { margin:0; padding:0; }
#     .map { position: absolute; top:0; bottom:0; width:100%; }
#     .legend {
#         background-color: white;
#         color: #6e6e6e;
#         border-radius: 3px;
#         bottom: 10px;
#         box-shadow: 0 1px 2px rgba(0, 0, 0, 0.10);
#         font: 12px/20px 'Helvetica Neue', Arial, Helvetica, sans-serif;
#         padding: 0;
#         position: absolute;
#         right: 10px;
#         z-index: 1;
#         min-width: 100px;
#     }
#    .legend.horizontal {bottom: 10px; text-align: left;}
#
#     /* legend header */
#     .legend .legend-header { border-radius: 3px 3px 0 0; background: white; }
#     .legend .legend-title {
#         padding: 6px 12px 6px 12px;
#         text-shadow: 0 0 2px white;
#         text-transform: capitalize;
#         text-align: center;
#         font-weight: bold !important;
#         font-size: 14px;
#         font: 12px/20px 'Helvetica Neue', Arial, Helvetica, sans-serif;
#         max-width: 160px;
#     }
#     .legend-title {padding: 6px 12px 6px 12px; text-shadow: 0 0 2px #FFF; text-transform: capitalize; text-align: center; max-width: 160px; font-size: 0.9em; font-weight: bold;}
#     .legend.horizontal .legend-title {text-align: left;}
#
#     /* legend items */
#     .legend-content {margin: 6px 12px 6px 12px; overflow: hidden; padding: 0; float: left; list-style: none; font-size: 0.8em;}
#     .legend.vertical .legend-item {white-space: nowrap;}
#     .legend-value {display: inline-block; line-height: 18px; vertical-align: top;}
#     .legend.horizontal ul.legend-content li.legend-item .legend-value,
#     .legend.horizontal ul.legend-content li.legend-item {display: inline-block; float: left; width: 30px; margin-bottom: 0; text-align: center; min-height: 30px;}
#
#     /* legend key styles */
#     .legend-key {display: inline-block; height: 10px;}
#     .legend-key.default, .legend-key.square {border-radius: 0;}
#     .legend-key.circle {border-radius: 50%;}
#     .legend-key.rounded-square {border-radius: 20%;}
#     .legend.vertical .legend-key {width: 10px; margin-right: 5px; margin-left: 1px;}
#     .legend.horizontal .legend-key {width: 30px; margin-right: 0; margin-top: 1px; float: left;}
#     .legend.horizontal .legend-key.square, .legend.horizontal .legend-key.rounded-square, .legend.horizontal .legend-key.circle {margin-left: 10px; width: 10px;}
#     .legend.horizontal .legend-key.line {margin-left: 5px;}
#     .legend.horizontal .legend-key.line, .legend.vertical .legend-key.line {border-radius: 10%; width: 20px; height: 3px; margin-bottom: 2px;}
#
#     /* gradient bar alignment */
#     .gradient-bar {margin: 6px 12px 6px 12px;}
#     .legend.horizontal .gradient-bar {width: 88%; height: 10px;}
#     .legend.vertical .gradient-bar {width: 10px; min-height: 50px; position: absolute; bottom: 4px;}
#
#     /* contiguous vertical bars (discrete) */
#     .legend.vertical.contig .legend-key {height: 15px; width: 10px;}
#     .legend.vertical.contig li.legend-item {height: 15px;}
#     .legend.vertical.contig {padding-bottom: 6px;}
#
#     /* vertical radius legend */
#     .legend.horizontal.legend-variable-radius ul.legend-content li.legend-item .legend-value,
#     .legend.horizontal.legend-variable-radius ul.legend-content li.legend-item {width: 30px; min-height: 20px;}
#
#     /* scale annotation */
#     .mapboxgl-ctrl.mapboxgl-ctrl-scale { border-color: #6e6e6e;
#                                          background-color: white;
#                                          color: #131516; }
# </style>
#
#
# <style>
#     .gradient-bar.bordered, .legend-key.bordered { border: solid #ffffff 0.1px; }
# </style>
#
#
# </head>
# <body>
#
# <div id='map' class='map'></div>
#
# <script type='text/javascript'>
#
# var legendHeader;
#
# function calcColorLegend(myColorStops, title) {
#     // create legend
#     var legend = document.createElement('div'),
#         legendContainer = document.getElementsByClassName('mapboxgl-ctrl-bottom-right')[0];
#
#     if ('circle' === 'contiguous-bar') {
#         legend.className = 'legend vertical contig';
#     }
#     else {
#         legend.className = 'legend vertical';
#     }
#     legend.id = 'legend-0';
#     document.body.appendChild(legend);
#     // add legend header and content elements
#     var mytitle = document.createElement('div'),
#         legendContent = document.createElement('ul');
#     legendHeader = document.createElement('div');
#     mytitle.textContent = title;
#     mytitle.className = 'legend-title'
#     legendHeader.className = 'legend-header'
#     legendContent.className = 'legend-content'
#     legendHeader.appendChild(mytitle);
#     legend.appendChild(legendHeader);
#     legend.appendChild(legendContent);
#     if (false === true) {
#         var gradientText = 'linear-gradient(to right, ',
#             gradient = document.createElement('div');
#         gradient.className = 'gradient-bar';
#         legend.appendChild(gradient);
#     }
#     // calculate a legend entries on a Mapbox GL Style Spec property function stops array
#     for (p = 0; p < myColorStops.length; p++) {
#         if (!!document.getElementById('legend-color-points-value-' + p)) {
#             // update the legend if it already exists
#             document.getElementById('legend-color-points-value-' + p).textContent = myColorStops[p][0];
#             document.getElementById('legend-color-points-id-' + p).style.backgroundColor = myColorStops[p][1];
#         }
#         else {
#             // create the legend if it doesn't yet exist
#             var item = document.createElement('li');
#             item.className = 'legend-item';
#             var key = document.createElement('span');
#             key.className = 'legend-key circle';
#             key.id = 'legend-color-points-id-' + p;
#             key.style.backgroundColor = myColorStops[p][1];
#             var value = document.createElement('span');
#             value.className = 'legend-value';
#             value.id = 'legend-color-points-value-' + p;
#             item.appendChild(key);
#             item.appendChild(value);
#             legendContent.appendChild(item);
#
#             data = document.getElementById('legend-color-points-value-' + p)
#             // round number values in legend if precision defined
#             if ((typeof(myColorStops[p][0]) == 'number') && (typeof(null) == 'number')) {
#                 data.textContent = myColorStops[p][0].toFixed(null);
#             }
#             else {
#                 data.textContent = myColorStops[p][0];
#             }
#             // add color stop to gradient list
#             if (false === true) {
#                 if (p < myColorStops.length - 1) {
#                     gradientText = gradientText + myColorStops[p][1] + ', ';
#                 }
#                 else {
#                     gradientText = gradientText + myColorStops[p][1] + ')';
#                 }
#                 if ('vertical' === 'vertical') {
#                     gradientText = gradientText.replace('to right', 'to bottom');
#                 }
#             }
#         }
#     }
#     if (false === true) {
#         // convert to gradient scale appearance
#         gradient.style.background = gradientText;
#         // hide legend keys generated above
#         var keys = document.getElementsByClassName('legend-key');
#         for (var i=0; i < keys.length; i++) {
#             keys[i].style.visibility = 'hidden';
#         }
#         if ('vertical' === 'vertical') {
#             gradient.style.height = (legendContent.offsetHeight - 6) + 'px';
#         }
#     }
#     // add class for styling bordered legend keys
#     if (true) {
#         var keys = document.getElementsByClassName('legend-key');
#         for (var i=0; i < keys.le

# %%
prs = pd.DataFrame([x for x in df.explode('people')['people'].dropna()])
prs = prs.groupby(['id'])['id'].count().sort_values(ascending=False).to_frame()
prs = prs.rename(columns = {'id':'count'})
prs
# Out:
#                                                     count
# id
# Dr._Brown                                              39
# James_Petiver                                          30
# Alexander_Brown                                        12
# Daniel_Waldo                                           11
# Mr._Bell                                                9
# Dr._Kempfer                                             9
# Richard_Middleton_Massey                                8
# Robert_Hooke                                            6
# Patrick_Adair                                           6
# Mr_Maidstone, Mr._Maidstone                             6
# John_Covel                                              5
# James_Wilson                                            5
# James_Cunningham                                        5
# Mr_Dupuys                                               5
# Jean_De_Fontaney                                        5
# John_Ranby                                              5
# John_Winthrop                                           5
# William_Courten                                         5
# Thomas_Short                                            4
# Gilbert_Heathcote                                       4
# Isaac_Newton                                            4
# Ambrose_Godfrey-Hanckwitz                               4
# Johann_Georg_Steigertahl                                4
# James_Theobalds_Esqr                                    4
# Mr._Clerk                                               4
# Martin_Lister                                           4
# Queen_Elizabeth_I                                       3
# Cromwell_Mortimer                                       3
# Elihu_Yale                                              3
# Mr_Roberts                                              3
# Charles_II                                              3
# Duke_of_Newcastle                                       3
# Capt_Christopher_Middleton                              3
# Caspar_Antonio                                          3
# Johann_Amman                                            3
# Alexander_Stuart                                        3
# John_Bartram                                            3
# Francis_Nicholson                                       2
# John_Conyers                                            2
# Mr_Maidstone                                            2
# Mr._Hodson                                              2
# John_Pinfold                                            2
# Dr_Hubbert                                              2
# Joy                                                     2
# Frederick_Slare                                         2
# King3                                                   2
# Edmund_Chishull                                         2
# Mr_Seguier                                              2
# Mr_Padmore                                              2
# Mr_Killegrew                                            2
# Mr_Lapthorn                                             2
# MrMC                                                    2
# George_Edwards, Mr._Edwards                             2
# John_Conduitt                                           2
# Gio_Bapt_Verle                                          2
# Hans_Sloane                                             2
# HenrySr.                                                2
# Mr._Laurie                                              2
# Mr_Elking                                               2
# Mr._Mason                                               2
# JohnFul                                                 2
# Joannes_Henricus_Hampe                                  2
# Abbe_Bernardo_Sterbini                                  2
# Matthew_Maty                                            2
# Benjamin_Franklin                                       2
# Thomas_Tennison                                         2
# Robert_Houston                                          2
# Mrs_Edwards, Mrs._Edwards                               2
# Capt_Jenkens                                            2
# Dr_Bokelman                                             2
# Capt_Walker                                             2
# Thomas_Stack                                            2
# Robert_Southwell                                        2
# Nicolas_Waites                                          2
# Charles_I                                               2
# Roger_Gale                                              2
# Peter_Collinson                                         2
# Rene_Reaumur                                            2
# Nehemiah_Grew                                           2
# Philip_Miller                                           2
# D_Woodward                                              2
# Dr_Douce                                                2
# Claude_Geoffroy1                                        2
# John_Bagford                                            1
# Dr_Groenfield                                           1
# Johannes_van_Musschenbroek                              1
# Capt_Hebden_                                            1
# Charles_Cadogan                                         1
# Jean_Rodoplhe_Lavater, Dr._Lavater                      1
# Jean_Rodolphe_Perronet                                  1
# Jean_Huber                                              1
# Charles_Leigh                                           1
# Charles_Lennox_Duke_of_Richmond, James_Stuart_D...      1
# Capt_Walduck                                            1
# Batty_Langley                                           1
# Beauvilliers                                            1
# Lady_Darlington                                         1
# Matthew_Gosset                                          1
# Abraham_Cyprianus                                       1
# Martha_Cooper                                           1
# Mark_Catesby                                            1
# Lord_Sondes                                             1
# Abraham_Waldron                                         1
# Lord_Colerane                                           1
# Lady_Sondes                                             1
# Lady_Kent                                               1
# Albertus_Seba                                           1
# James_Hodgson                                           1
# King_James_2nd, King_James                              1
# Arthur_Charlett                                         1
# Baron_Botmar                                            1
# John_Winthrop, Mr._Winthorpe                            1
# John_Thomas_Woolhouse                                   1
# John_Rawdon                                             1
# Baron_Rostgard                                          1
# John_Melling                                            1
# John_Jackson                                            1
# Charles_Lockyer                                         1
# Charles_Montagu                                         1
# Charles_Maitland                                        1
# Francois_Duquesnoy                                      1
# Francis_Hauksbee                                        1
# Francis_Aston                                           1
# FrancisBuccleuch                                        1
# Dr._Mausafia                                            1
# Father_Visdelon                                         1
# Miss_Stanley                                            1
# Dr_Battely                                              1
# Edward_Hawkins                                          1
# Dr_Browne                                               1
# Dr_Burnett                                              1
# Duke_of_Monmouth                                        1
# Duke_of_Grafton                                         1
# Duke_of_Cumberland                                      1
# Duke_of_Chandos                                         1
# Duke_of_Bourbon                                         1
# Duke_of_Argyle                                          1
# Duke_Marlborough                                        1
# Dr_Varin                                                1
# Dr_Labe                                                 1
# Dr._Hobbs                                               1
# Dr._Clifton                                             1
# J_Empson                                                1
# David_Krieg                                             1
# Isaaci_Barrow                                           1
# Dr_Hoffman                                              1
# Isaac_Waldron_Esqr                                      1
# Hoffsted_van_Essen                                      1
# Henry_Plumptre                                          1
# Henry_Newman                                            1
# Charles_Morton                                          1
# Christian_Zincke                                        1
# Hans_Holbein                                            1
# Governr_Jennings                                        1
# Governor_Bennet                                         1
# Giuseppe_Campani                                        1
# Colonel_Laws                                            1
# George_I                                                1
# George_Harris                                           1
# George_Edwards                                          1
# George_Cheyne                                           1
# George_Bell                                             1
# Dampier                                                 1
# Erik_Benzelius                                          1
# _Mr_Brown                                               1
# Monsr_Villette                                          1
# Mrs_Stephens                                            1
# Mrs_Smith                                               1
# Mrs_Shepherd                                            1
# Mrs_Sadler                                              1
# Mrs_Marshall                                            1
# Mrs_Hepheshebah_Parker                                  1
# Mrs_Heathcote                                           1
# Mrs_Hayes                                               1
# Mrs_Dering, Mrs._Dering                                 1
# Mrs_Byde                                                1
# Mrs_Bernard                                             1
# Mrs_Astall                                              1
# Mrs._Waters                                             1
# Mrs._Trenchfield                                        1
# Mrrown                                                  1
# Mr_Wright                                               1
# Mr_Wildy                                                1
# Mr_Walduck                                              1
# Mr_Villarmont                                           1
# Mr_Van_Mildert                                          1
# Mr_Talbot                                               1
# Mr_Styleman                                             1
# Mr_Standish                                             1
# Mr_Stallwood                                            1
# Mr_Skinner                                              1
# Mr_Seregold                                             1
# Mr_Scott                                                1
# Mr_Sainthill                                            1
# Mr_Robert_Walker                                        1
# Mr_Purnell                                              1
# Mrs_Steigertahl                                         1
# Navarette                                               1
# Mr_Orchard                                              1
# Oliver_Cromwell                                         1
# William_Watson                                          1
# William_Sherard                                         1
# William_Houstoun                                        1
# William_Hanbury, William_Hanbury                        1
# William_Dunker                                          1
# William_Cowper2                                         1
# William_Bentinck                                        1
# Vale_Vicor                                              1
# Thomas_Simon                                            1
# Thomas_Pitt                                             1
# Thomas_Knowlton                                         1
# Stephen_Gray                                            1
# Sr_Streynsham_Masters                                   1
# Sir_Charles_Wager                                       1
# Robert_Moray                                            1
# Robert_Harley                                           1
# Robert_Boyle                                            1
# Riley                                                   1
# Richard_Mead                                            1
# Revd_Mr_Scott                                           1
# Queen_Anne                                              1
# Prince_of_Hesse                                         1
# Pope_Clement_XII                                        1
# Pope_Alexander_VIII                                     1
# Pierre_Silvestre                                        1
# Philip_2nd_of_Spain                                     1
# Peirce_Dod                                              1
# Paul_Lucas                                              1
# Papenau                                                 1
# Mr_Paine                                                1
# Mr_Nichols                                              1
# Moses                                                   1
# Mr._Wild                                                1
# Mr._Serocold                                            1
# Mr._Robinson                                            1
# Mr._Pycolas                                             1
# Mr._Ott                                                 1
# Mr._Moults                                              1
# Mr._Marshall                                            1
# Mr._Launce                                              1
# Mr._Kenly                                               1
# Mr._Jones                                               1
# Mr._Homberg                                             1
# Mr._Hill                                                1
# Mr._Hennepin                                            1
# Mr._Harris                                              1
# Mr._Graham                                              1
# Mr._Gordon                                              1
# Mr._Godfroy                                             1
# Mr._Dering                                              1
# William_von_Schroder                                    1
# Mr._Cox                                                 1
# Mr._Cowper                                              1
# Mr._Cotts                                               1
# Mr._Clark                                               1
# Mr._Campbell                                            1
# Mr._Bradley                                             1
# Mr._Bewley                                              1
# Mr._Beddevoles                                          1
# Mr._Barrets                                             1
# Mr._Amyand                                              1
# Mr._Adams                                               1
# Mr._Staphorst                                           1
# Mr_Alexr_Light                                          1
# Mr_Nash                                                 1
# Mr_Alsop                                                1
# Mr_Muhleman                                             1
# Mr_Middleton                                            1
# Mr_Lyell                                                1
# Mr_Lenoy                                                1
# Mr_Lascelles                                            1
# Mr_Johnson                                              1
# Mr_John_Heathcote                                       1
# Mr_James                                                1
# Mr_Hoofnail                                             1
# Mr_Hodges                                               1
# Mr_Haynes                                               1
# Mr_Hawkeens                                             1
# Mr_Harvey                                               1
# Mr_Handisyde                                            1
# Mr_Handisyd                                             1
# Mr_Grubb                                                1
# Mr_Green                                                1
# Mr_Gore                                                 1
# Mr_Gilberts                                             1
# Mr_Gilbert                                              1
# Mr_Fairweather                                          1
# Mr_Fabre                                                1
# Mr_Doyly                                                1
# Mr_Desmarets                                            1
# Mr_Cotteret                                             1
# Mr_Collier                                              1
# Mr_Carmichael                                           1
# Mr_Burnett                                              1
# Mr_Bernard                                              1
# Mr._Dandridge                                           1

# %%
from matplotlib import *
# %matplotlib inline

plt.figure(figsize=(14,6))
plt.xticks(range(30), rotation='vertical')
prs_filtered = prs[prs['count'] > 3]
plt.bar(prs_filtered.index,prs_filtered['count'])
plt.show()

# %% [markdown]
# #### Second catalogue: Antiquities

# %%
# Check second catalogue
cats[1]
# Out:
# {'entries': [{'num_int': 700,
#    'num_str': '-700.',
#    'people': [{'id': 'Cardinal_Gualtieri', 'name': 'Cardinall Gualtieris'}],
#    'places': None,
#    'text': '-700. The figure of an old bearded man in terra cotta Ægyptian from Cardinall Gualtieris collection. Vid. 287. 216. m'},
#   {'num_int': 701,
#    'num_str': '-701.',
#    'people': None,
#    'places': None,
#    'text': '-701. A varietie of the same. Id. 216. m'},
#   {'num_int': 702,
#    'num_str': '-702.',
#    'people': None,
#    'places': None,
#    'text': '-702. _____ in white earthen ware. Id. 216. m'},
#   {'num_int': 703,
#    'num_str': '-703.',
#    'people': None,
#    'places': None,
#    'text': '-703. _____ blew earthen ware. Id. 216. m'},
#   {'num_int': 704,
#    'num_str': '-704.',
#    'people': None,
#    'places': None,
#    'text': '-704. The figure of a young man in blew earthen ware. Id.'},
#   {'num_int': 705,
#    'num_str': '-705.',
#    'people': None,
#    'places': None,
#    'text': '-705. _____ terra cotta. Id.'},
#   {'num_int': 706,
#    'num_str': '-706.',
#    'people': None,
#    'places': None,
#    'text': '-706. The _____ woman broken. Id. 216 m'},
#   {'num_int': 707,
#    'num_str': '-707.',
#    'people': None,
#    'places': None,
#    'text': '-707. A figure kneeling on one knee the arms lifted up in blew earthenware. from Ægypt Id. 216 m EH'},
#   {'num_int': 708,
#    'num_str': '-708.',
#    'people': None,
#    'places': None,
#    'text': '-708. A very small Ægyptian figure in blew enamel or earthen glased ware. Id. 216. m 216. m.'},
#   {'num_int': 709,
#    'num_str': '-709.',
#    'people': None,
#    'places': None,
#    'text': '-709. The same with a dogs face & 2 ears standing up Id. E H 216 m'},
#   {'num_int': 710,
#    'num_str': '-710.',
#    'people': None,
#    'places': None,
#    'text': '-710. The same wt. a lions or broad dogs face. Id. Vid. Montfaucon tom 2 supp. planch. CXXXV. E H 216 m'},
#   {'num_int': 711,
#    'num_str': '-711.',
#    'people': None,
#    'places': None,
#    'text': '-711. Another varietie of the same. Id. E H 216 m'},
#   {'num_int': 712,
#    'num_str': '-712.',
#    'people': None,
#    'places': None,
#    'text': '-712. An Harpocrates in a blewish white earthen ware. Id. 216. h.'},
#   {'num_int': 713,
#    'num_str': '-713.',
#    'people': None,
#    'places': None,
#    'text': '-713. A boys figure in whitish earthen ware. Id. 216 m'},
#   {'num_int': 714,
#    'num_str': '-714.',
#    'people': None,
#    'places': None,
#    'text': '-714. A womans head. Id. 216 m'},
#   {'num_int': 715,
#    'num_str': '-715.',
#    'people': None,
#    'places': None,
#    'text': '-715. Serapiss head. Or Jupiters head wt. a modius upon it. very ill done. Id. or Priapus 216 m'},
#   {'num_int': 716,
#    'num_str': '-716.',
#    'people': None,
#    'places': None,
#    'text': '-716. Another. Id. 216 m'},
#   {'num_int': 717,
#    'num_str': '-717.',
#    'people': None,
#    'places': None,
#    'text': '-717. Another. Id. 216 m'},
#   {'num_int': 718,
#    'num_str': '-718.',
#    'people': None,
#    'places': None,
#    'text': '-718. Another. 216 m'},
#   {'num_int': 719,
#    'num_str': '-719.',
#    'people': None,
#    'places': None,
#    'text': "-719. A flatt gray pebble wt. sev.ll Hieroglyphic's upon both sides of it. Id."},
#   {'num_int': 720,
#    'num_str': '-720.',
#    'people': None,
#    'places': None,
#    'text': '-720. A flatt gray pebble wt. a busto in small relievo upon it Id.'},
#   {'num_int': 721,
#    'num_str': '-721.',
#    'people': None,
#    'places': None,
#    'text': '-721. Duo capita adversa legend concordia Augustorum wt. three termini A. on the backside of a pebble. Id. 216 m'},
#   {'num_int': 722,
#    'num_str': '-722.',
#    'people': None,
#    'places': None,
#    'text': '-722. A gray pebble wt. a more standing in relievo upon it Id.'},
#   {'num_int': 723,
#    'num_str': '-723.',
#    'people': None,
#    'places': None,
#    'text': '-723. A flint with vivit post funera virtus upon it. Id.'},
#   {'num_int': 724,
#    'num_str': '-724',
#    'people': None,
#    'places': None,
#    'text': '-724 An ancient pendant of a piece of shell or pearl. Id. ✓ 215 27. a'},
#   {'num_int': 725,
#    'num_str': '-725.',
#    'people': None,
#    'places': None,
#    'text': '-725. An ancient gold necklace wt. emeralds strung on a gold chaine. Id. ✓'},
#   {'num_int': 726,
#    'num_str': '-726.',
#    'people': [{'id': 'Robert_Houston', 'name': 'Dr. Houston'}],
#    'places': [{'id': 'Peru', 'name': 'Peru'}],
#    'text': '-726. An earthen bottle of gray earth colourd black in the form of a porpoise wt. a handle from Peru by Dr. Houston said to be one of their gods. ( idol.) A.W.F. 1882 242'},
#   {'num_int': 727,
#    'num_str': '-727.',
#    'people': None,
#    'places': None,
#    'text': '-727. Another of two coloured red earths in the form of the busto of a man. Id. A.W.F 1882'},
#   {'num_int': 728,
#    'num_str': '-728.',
#    'people': None,
#    'places': None,
#    'text': '-728. Another of 4. bottles of gray earth wt. the fig. statue of a man drinking. Id. A.W.F. 1882'},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': '154'},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': 'Antiquities.'},
#   {'num_int': 1,
#    'num_str': '-1',
#    'people': None,
#    'places': None,
#    'text': '-1 A Roman stone weight wt. 4 points on its top, for the marks of its weight. Vid. Montfaucon XCIII Pl. a la 168.page tom: 3. 216. m 245 C'},
#   {'num_int': 2,
#    'num_str': '-2',
#    'people': None,
#    'places': None,
#    'text': '-2 A Roman urn of red earth. 245.'},
#   {'num_int': 3,
#    'num_str': '-3.',
#    'people': None,
#    'places': None,
#    'text': '-3. The cover of an urn of gray earth. 245.'},
#   {'num_int': 4,
#    'num_str': '-4.',
#    'people': [{'id': 'John_Conyers', 'name': 'Mr. Conyers'}],
#    'places': [{'id': 'Goodman_fields', 'name': 'Goodmans fields'}],
#    'text': '-4. A Gray earthen bottle taken up by Mr. Conyers in Goodmans fields amongst urns anno 1680 when . they were digging for new- foundations. H. 6 3/4in Præfericulum such as is figured in Montfaucon tom. 2 supp. pl. XVI. page 16. E. H 245. A.W.F. 1852.'},
#   {'num_int': 5,
#    'num_str': '5.',
#    'people': None,
#    'places': None,
#    'text': '5. Another bottle of the same ------- 0. 2. 6. one handled jug. H. 7 1/4in A.W.F. 1853. 245.'},
#   {'num_int': 6,
#    'num_str': '6.',
#    'people': None,
#    'places': None,
#    'text': '6. A large urn of gray earth. 245.'},
#   {'num_int': 7,
#    'num_str': '7.',
#    'people': None,
#    'places': None,
#    'text': '7. A small urn with 2 greyhounds follow: =ing a hare of gray earth. 245.'},
#   {'num_int': 8,
#    'num_str': '8.',
#    'people': None,
#    'places': None,
#    'text': '8. A small gray earthen urn wrought about the edges .s10.s -----} 1. 5. 0. 245.'},
#   {'num_int': 9,
#    'num_str': '9',
#    'people': None,
#    'places': None,
#    'text': '9 A very small urn of gray earth 6sh.-----} 0. 10. 0.'},
#   {'num_int': 10,
#    'num_str': '10.',
#    'people': None,
#    'places': None,
#    'text': '10. A large patera of gray earth. . . 245. EH'},
#   {'num_int': 11,
#    'num_str': '11.',
#    'people': None,
#    'places': None,
#    'text': '11. A small patera of red earth with the word Roma ? at bottom of the inside 1 5 s ----} 0. 10. 0. 216 l 23.'},
#   {'num_int': 12,
#    'num_str': '12.',
#    'people': None,
#    'places': None,
#    'text': '12. One piece of another with DOMVNG 216. a'},
#   {'num_int': 729,
#    'num_str': '-729.',
#    'people': None,
#    'places': [{'id': 'Isle_of_Sheppey', 'name': 'Island Sheppey'},
#     {'id': 'Canterbury', 'name': 'Canterbury.'}],
#    'text': '-729. A large Roman patera of red earth on the under part covered wt. small vermiculi or tubuli marine & some rock oysters, on the concave side wt. rock oysters Taken up from the sea by a rock between the end of the Island Sheppey & the main continent. from Canterbury. Mr. - 199.'},
#   {'num_int': 730,
#    'num_str': '-730.',
#    'people': None,
#    'places': None,
#    'text': '-730. A piece of another covered wt. vermiculi & an oyster perforated by them. Id. 199.'},
#   {'num_int': 731,
#    'num_str': '-731.',
#    'people': None,
#    'places': None,
#    'text': '-731. Another piece by the same on wch. are the beginings or Sprouts of abies marina, silkwreck &c. Id. 199.'},
#   {'num_int': 732,
#    'num_str': '-732.',
#    'people': None,
#    'places': None,
#    'text': '-732. A piece of a lesser earthen patera Id. 199.'},
#   {'num_int': 733,
#    'num_str': '-733.',
#    'people': None,
#    'places': None,
#    'text': '-733. A smaller patera wt. 2 large oyster shells, some barnacles, or balani & a muscle wt. tubuli. Id. 207 199.'},
#   {'num_int': 734,
#    'num_str': '-734.',
#    'people': None,
#    'places': None,
#    'text': '-734. A vessell wt. 2 ears in the form of a crucible of red earth on wch. grows vesicaria marina & a small balanus. Id. 245 199.'},
#   {'num_int': 735,
#    'num_str': '-735.',
#    'people': None,
#    'places': None,
#    'text': '-735. An ancient Roman sepulchral small lamp. 216. h'},
#   {'num_int': 736,
#    'num_str': '-736.',
#    'people': None,
#    'places': None,
#    'text': '-736. A chinese piece of leather used by them putt on their Glans in congressa Venereo. ( Ring for ye Penis ) 245 216. n'},
#   {'num_int': 737,
#    'num_str': '-737.',
#    'people': None,
#    'places': None,
#    'text': '-737. Some Ægyptian figures in a basalles. 245 216. m'},
#   {'num_int': 738,
#    'num_str': '738.',
#    'people': [{'id': 'Johann_Jakob_Scheuchzer', 'name': 'Mr. Jo. Scheuchzer'}],
#    'places': [{'id': 'Zurich', 'name': 'Zurich'},
#     {'id': 'Baden', 'name': 'Baden'},
#     {'id': 'Zurich', 'name': 'Zurich'}],
#    'text': '738. 4 Tesseræ Badenses found in the fields near Zurich & Baden of severall magnitudes sent to me by Mr. Jo. Scheuchzer from Zurich wt. his dissertation abt them. 245. 216. n'},
#   {'num_int': 739,
#    'num_str': '-739.',
#    'people': None,
#    'places': [{'id': 'Richborough', 'name': 'Richborow'},
#     {'id': 'Canterbury', 'name': 'Canterbury'},
#     {'id': 'Kent', 'name': 'Kent'}],
#    'text': '-739. A large Roman patera of fine red earth wt. the letters Crispus. on the bottom from Richborow near Canterbury in Kent. 245.'},
#   {'num_int': 740,
#    'num_str': '-740.',
#    'people': None,
#    'places': None,
#    'text': '-740. Another wt. Oysters no. 3. growing in it. Id. 245.'},
#   {'num_int': 741,
#    'num_str': '-741.',
#    'people': None,
#    'places': None,
#    'text': '-741. A small deep red large Roman patera. Id. 245.'},
#   {'num_int': 742,
#    'num_str': '-742.',
#    'people': None,
#    'places': None,
#    'text': '-742. One larger. Id. 245.'},
#   {'num_int': 743,
#    'num_str': '-743.',
#    'people': [{'id': 'Mr_Cooke', 'name': 'Mr. Cooke'}],
#    'places': [{'id': 'Isle_Wight', 'name': 'Isle of Wight'}],
#    'text': '-743. A large brasse instrument called a Celta by some or wedge by others found in the Isle of Wight by Mr. Cooke who gave it me vid his letters. L. 8.in E H 216 f 2 + A.W.F. 1852 X'},
#   {'num_int': 744,
#    'num_str': '-744.',
#    'people': None,
#    'places': None,
#    'text': '-744. Montfaucon tom 3. p. 2 pl. CLXXXVIII. L. 4 4/8. E H 218. f 2 + A.W.F. 1852 X'},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': '155'},
#   {'num_int': 13,
#    'num_str': '13.',
#    'people': None,
#    'places': None,
#    'text': '13. A piece of a patera. with Sulpici at bottom. 216. l.'},
#   {'num_int': 14,
#    'num_str': '14.',
#    'people': None,
#    'places': None,
#    'text': '14. A piece without any writing upon it. 216: l.'},
#   {'num_int': 15,
#    'num_str': '15.',
#    'people': None,
#    'places': None,
#    'text': '15. A plain piece of the sides of one. 216: l.'},
#   {'num_int': 16,
#    'num_str': '16.',
#    'people': None,
#    'places': None,
#    'text': "16. A piece of a red earthen patera flourish'd abt. the edges with - leaves &c. 216. l."},
#   {'num_int': 17,
#    'num_str': '17.',
#    'people': None,
#    'places': None,
#    'text': '17. A small piece of one with a fox? on it 216. l.'},
#   {'num_int': 18,
#    'num_str': '18.',
#    'people': None,
#    'places': None,
#    'text': '18. A plain Roman Lamp of a whitish earth. A.W.F. 1852. E H X'},
#   {'num_int': 19,
#    'num_str': '19.',
#    'people': None,
#    'places': [{'id': 'Rome', 'name': 'Roman'}],
#    'text': '19. A Roman Lamp in the form of a shoe. X'},
#   {'num_int': 20,
#    'num_str': '20.',
#    'people': None,
#    'places': None,
#    'text': '20. A Roman lamp of red earth with a bulls head upon it and a crescent. Vid Montfaucon tom. 5. part. 2. pl. CXLV in ca 206 pag. E H A.W.F. 1852.'},
#   {'num_int': 21,
#    'num_str': '21.',
#    'people': [{'id': 'Dr_Huntington', 'name': 'Dr. Huntington'}],
#    'places': None,
#    'text': '21. An Ægyptian idol of blew earth taken out of a mummie by Dr. Huntington. 183. 183.'},
#   {'num_int': 22,
#    'num_str': '22.',
#    'people': None,
#    'places': [{'id': 'Mount_Vesuvius', 'name': 'Mount Vesuvius'}],
#    'text': '22. Figura Velata stans dextra pateram tenens. The pedestall is a cinder from Mount Vesuvius. 220.'},
#   {'num_int': 23,
#    'num_str': '23.',
#    'people': [{'id': 'John_Conyers', 'name': 'Mr. Conyers'}],
#    'places': [{'id': 'Fleet_Ditch', 'name': 'fleet ditch'}],
#    'text': '23. A Roman Lachrymatorie found at the making of fleet ditch near a wooden coffin, by Mr. Conyers. EH 216 e'},
#   {'num_int': 745,
#    'num_str': '-745.',
#    'people': None,
#    'places': None,
#    'text': '-745. A very large brasse spear point found at the same place wt a hole at base. l Dagger blade. 216 f 2 A.W.F. 1854. X'},
#   {'num_int': 746,
#    'num_str': '-746.',
#    'people': None,
#    'places': None,
#    'text': '-746. The same a little different. 216 f 2. A.W.F. 1854. X'},
#   {'num_int': 747,
#    'num_str': '747.',
#    'people': None,
#    'places': None,
#    'text': '747. The same smaller. 216 f 2 A.W.F. 1853. X'},
#   {'num_int': 748,
#    'num_str': '-748.',
#    'people': None,
#    'places': None,
#    'text': '-748. Another yet smaller. They were all found together. 216 f 2 A.W.F. 1853. X'},
#   {'num_int': 749,
#    'num_str': '-749.',
#    'people': [{'id': 'Mr._Compton', 'name': 'Mr. Compton'}],
#    'places': [{'id': 'Rome', 'name': 'Rome'}],
#    'text': '-749. An Iron sacrificing chopping knife from Rome by Mr. Compton. Vid. Monfaucon Antiq. t. 2. p. 248. pl. LXV 216. O 21. L.'},
#   {'num_int': 750,
#    'num_str': '-750.',
#    'people': None,
#    'places': None,
#    'text': '-750. The figure of a lion in brasse from the same. Ægypt 216. O'},
#   {'num_int': 751,
#    'num_str': '-751.',
#    'people': None,
#    'places': None,
#    'text': '-751. monkey. Id. 216. O'},
#   {'num_int': 752,
#    'num_str': '-752.',
#    'people': None,
#    'places': None,
#    'text': '-752. Jupiter. Id. 216. O'},
#   {'num_int': 753,
#    'num_str': '-753.',
#    'people': None,
#    'places': None,
#    'text': '-753. priapus wt. a chain. Id. 216. n'},
#   {'num_int': 754,
#    'num_str': '-754.',
#    'people': None,
#    'places': [{'id': 'Constantinople', 'name': 'Constantinople'},
#     {'id': 'Etruscan', 'name': 'Etruscan'}],
#    'text': '-754. A small red earthen urn taken up near Constantinople a little painted as the Etruscan. wt. 3 anse. 246 EH 10'},
#   {'num_int': 755,
#    'num_str': '-755.',
#    'people': [{'id': 'Mr_Charles_de_la_Fontaine',
#      'name': 'Mr Charles de la fontaine'}],
#    'places': [{'id': 'Cotterstock', 'name': 'Cotterstock'},
#     {'id': 'Oundle', 'name': 'Oundle'},
#     {'id': 'Northamptonshire', 'name': 'Northamptonshire'}],
#    'text': '-755. Some tessella taken from a Roman pavement 20 foot Sqr. of sevll. colours found in Cotterstock field near Oundle in Northamptonshire given me by Mr Charles de la fontaine. See a Gazetteer. 216. O'},
#   {'num_int': 756,
#    'num_str': '-756.',
#    'people': None,
#    'places': [{'id': 'Richborough', 'name': 'Richborough'},
#     {'id': 'Kent', 'name': 'Kent'}],
#    'text': '-756. A very large red Roman Earthen deep patera broken on one side wt. 2 concentric circles of lines in the inside round the center the workmans name defaced from Richborough in Kent. 245. 245'},
#   {'num_int': 757,
#    'num_str': '-757.',
#    'people': None,
#    'places': None,
#    'text': '-757. A smaller workmans name EN - - - 245.'},
#   {'num_int': 758,
#    'num_str': '-758.',
#    'people': None,
#    'places': None,
#    'text': '-758. One covered on the inside & outside wt. recremts of the sea oysters, abies marina &c. from the same 245.'},
#   {'num_int': 759,
#    'num_str': '-759.',
#    'people': None,
#    'places': None,
#    'text': '-759. Another the with 2 concentric circles of lines as above the makers name INSALNIO. Id. 245.'},
#   {'num_int': 760,
#    'num_str': '-760.',
#    'people': None,
#    'places': None,
#    'text': '-760. Another wt.the makers name ANSI--- 245.'},
#   {'num_int': 761,
#    'num_str': '-761.',
#    'people': None,
#    'places': None,
#    'text': '-761. Another wt. ______ ALBULINI very entire. 245.'},
#   {'num_int': 762,
#    'num_str': '-762.',
#    'people': None,
#    'places': None,
#    'text': '-762. Another with the lips doubld over on wch. are made flat fishes? 245.'},
#   {'num_int': 763,
#    'num_str': '-763.',
#    'people': None,
#    'places': None,
#    'text': '-763. The same covered wt. quisquilie or recrets of the sea &c. 245.'},
#   {'num_int': 764,
#    'num_str': '-764.',
#    'people': None,
#    'places': None,
#    'text': '-764. The same wt. an oyster on the inside. 245'},
#   {'num_int': 765,
#    'num_str': '-765.',
#    'people': None,
#    'places': None,
#    'text': '-765. The same wt. shallow brim, like a salver wt. the letters M P _____ 245'},
#   {'num_int': 766,
#    'num_str': '-766.',
#    'people': None,
#    'places': None,
#    'text': '-766. A Small deep patera for sacrificing wt. the words MATERNI. 245'},
#   {'num_int': 767,
#    'num_str': '-767.',
#    'people': None,
#    'places': None,
#    'text': '-767. Another smaller the words effaced. 245'},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': '156'},
#   {'num_int': 24,
#    'num_str': '24.',
#    'people': None,
#    'places': None,
#    'text': '24. A lachrymatory some what large Montfaucon tom 5. pl. c. 216. e EH'},
#   {'num_int': 25,
#    'num_str': '25.',
#    'people': None,
#    'places': None,
#    'text': '25. A glasse vessell for holding the ointments wch. Were putt near the dead by the Romans. Id. 216. e EH A. W. F. 1852.'},
#   {'num_int': 26,
#    'num_str': '26.',
#    'people': None,
#    'places': None,
#    'text': '26. A piece of one of these vessells very thick 216. b 20. J.'},
#   {'num_int': 27,
#    'num_str': '27.',
#    'people': None,
#    'places': None,
#    'text': '27. The bottom of one of them or of an urn of glasse. 216. h. 20. J.'},
#   {'num_int': 28,
#    'num_str': '28.',
#    'people': None,
#    'places': None,
#    'text': '28. The ear of a glasse urn. 216. h. 20. J. 2 free'},
#   {'num_int': 29,
#    'num_str': '29.',
#    'people': [{'id': 'Mr_Conyers', 'name': 'Mr Conyers'}],
#    'places': None,
#    'text': '29. A piece of ancient glasse covered over wt. a sulphurous or pyriticall substance substance called by Mr Conyers Electrum Britannicum }----- 0. 0. 6 216 h 20. J.'},
#   {'num_int': 30,
#    'num_str': '30.',
#    'people': None,
#    'places': [{'id': 'Essex_Brentwood', 'name': 'Essex near Brentwood'}],
#    'text': '30. An ancient brasse hatchet head found in Essex near Brentwood in a gravell pitt. L 5 3/4 E H 216. fn A.W.F. 1852. X'},
#   {'num_int': 31,
#    'num_str': '31.',
#    'people': [{'id': 'Oldsworth', 'name': 'Mr. Oldesworth'}],
#    'places': [{'id': 'Camden', 'name': 'Camdeno'}],
#    'text': '31. Electrum Britanicum Antiquorum sen pars vasis aurei pallidi super vitrum sic appellatum in Camdeno. In fundamento N. Sti. Pauli. / more from Mr. Oldesworth. 216. h 20 J.'},
#   {'num_int': 32,
#    'num_str': '32.',
#    'people': None,
#    'places': None,
#    'text': '32. An old brasse key. Vid. Montfaucon LIV Pl. a la 106 page L. 111. 216 o'},
#   {'num_int': 33,
#    'num_str': '33.',
#    'people': [{'id': 'Dr_John_Harwood, Dr_Harwood', 'name': 'Dr. Harwood'}],
#    'places': [{'id': None, 'name': 'Uriconium'},
#     {'id': 'Wroxeter_Shropshire', 'name': 'Wroxeter in Shropshire'}],
#    'text': '33. The brasse foot of a Roman idol or votum taken up at Uriconium or Wroxeter in Shropshire given me by Dr. Harwood. Vid. Montfaucon 2d. p. l. pag 2 Pl. c. fig. 5. L. 2 1/2in 220 VII. 9 O A. W. F. 1853.'},
#   {'num_int': 768,
#    'num_str': '-768.',
#    'people': None,
#    'places': [{'id': 'Richborough', 'name': 'Richborow'},
#     {'id': 'Kent', 'name': 'Kent'}],
#    'text': '-768. A small red earthen patera wt out any lips very intire wt. the workmans name EXTIMUS taken up at Richborow in Kent 245. CC'},
#   {'num_int': 769,
#    'num_str': '-769.',
#    'people': None,
#    'places': None,
#    'text': '-769. The same wt. balani oysters & vermiculi upon it Id. 245. CCI'},
#   {'num_int': 770,
#    'num_str': '-770.',
#    'people': None,
#    'places': None,
#    'text': '-770. The same wt. a round brim or margin turned downwards. Id wt. a rose in the center of its inside & vermiculi wt. earth without 245. CCII'},
#   {'num_int': 771,
#    'num_str': '-771.',
#    'people': None,
#    'places': None,
#    'text': '-771. The Same oysters & balani marks on it. Id 245. CCIII'},
#   {'num_int': 772,
#    'num_str': '-772.',
#    'people': None,
#    'places': None,
#    'text': '-772. A small deep patera wt. oysters in it. Id. 245. CCIV'},
#   {'num_int': 773,
#    'num_str': '-773.',
#    'people': None,
#    'places': None,
#    'text': '-773. A small deep red earthen patera widening towards the top, ex plain brim or margin the makers name within QINTVSM. Id. 245. CCV'},
#   {'num_int': 774,
#    'num_str': '-774.',
#    'people': None,
#    'places': None,
#    'text': '-774. One larger wt. The workmans name QVINT - M. smaller balani &c. on it. Id. 245. CCVI.'},
#   {'num_int': 775,
#    'num_str': '775.',
#    'people': None,
#    'places': None,
#    'text': '775. One larger wt. ...--NTI.....---- on it wt. oysters & balani on it. Id. 245. CCVVII'},
#   {'num_int': 776,
#    'num_str': '-776.',
#    'people': None,
#    'places': None,
#    'text': '-776. One of the same bignesse wt. ---- obliterated on it. Id. wt. a large balanus. 245. CCVVII'},
#   {'num_int': 777,
#    'num_str': '-777.',
#    'people': None,
#    'places': None,
#    'text': '-777. A large deep patera wt. an inscription IN--- NT_ NS--- Id. wt. a double circle inwards. 245. CCIX'},
#   {'num_int': 778,
#    'num_str': '-778.',
#    'people': None,
#    'places': None,
#    'text': '-778. The same wt. oysters vermicul &o covered wt. them oysters Id 245. CCX'},
#   {'num_int': 779,
#    'num_str': '-779.',
#    'people': None,
#    'places': None,
#    'text': '-779. The same = wt. INTE... ATIVS-- Id. 245. CCXI.'},
#   {'num_int': 780,
#    'num_str': '-780 789',
#    'people': None,
#    'places': None,
#    'text': '-780 789 The same very large broken & cemented wt. a rose in the center. Id. 245. CCXII'},
#   {'num_int': 781,
#    'num_str': '-781.',
#    'people': [{'id': 'Mr._Gordon', 'name': 'Mr. Gordon'}],
#    'places': [{'id': 'Cartagena', 'name': 'Cartagena'},
#     {'id': 'America', 'name': 'America'}],
#    'text': '-781. A very large calabash from Cartagena in America wherein are carved by the Indians animals &c. by Mr. Gordon. Vid. 1850. Miscell. ad Miscellan. CCXIII.'},
#   {'num_int': 782,
#    'num_str': '-782.',
#    'people': None,
#    'places': None,
#    'text': '-782. An Ægyptian figure of a woman in a very heavy metal having on her left arm a basket in her hand laid on her breast a.----- on her right hand stretching out her arm a something wanting wt. many , ornaments & some hieroglyphicall characters Ægypt 220 CCXXIII E H'},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': '157'},
#   {'num_int': 34,
#    'num_str': '34.',
#    'people': None,
#    'places': None,
#    'text': '34. An Ancient British ? arrowhead of yellow flint. 216. h 20. J'},
#   {'num_int': 35,
#    'num_str': '35.',
#    'people': None,
#    'places': None,
#    'text': '35. 216. n 21. O. An are armilla ? of Jett or kennell coal.'},
#   {'num_int': 36,
#    'num_str': '36.',
#    'people': None,
#    'places': None,
#    'text': '36. A goose in brasse. 216 n'},
#   {'num_int': 37,
#    'num_str': '37.',
#    'people': None,
#    'places': None,
#    'text': '37. A mouse in the same.'},
#   {'num_int': 38,
#    'num_str': '38.',
#    'people': None,
#    'places': None,
#    'text': '38. A piece of an Armilla. Vid. Montfaucon. tom. 3. XXXI pl a la. 50 page. 216 n 216. O'},
#   {'num_int': 39,
#    'num_str': '39.',
#    'people': None,
#    'places': None,
#    'text': '39. Severall pieces of severall sorts of armilla or fibula Vid. Montfaucon tom. 3. pag. 48 pl. XXVII'},
#   {'num_int': 40,
#    'num_str': '40.',
#    'people': None,
#    'places': None,
#    'text': '40. A Stile ? 216. m'},
#   {'num_int': 41,
#    'num_str': '41.',
#    'people': None,
#    'places': None,
#    'text': '41. Large & small pins of bone & brasse. 216. m'},
#   {'num_int': 42,
#    'num_str': '42.',
#    'people': None,
#    'places': None,
#    'text': '42. of bone. for making netts. 216 a 20 m'},
#   {'num_int': 43,
#    'num_str': '43.',
#    'people': None,
#    'places': None,
#    'text': '43. of bone. 216. h 20 m'},
#   {'num_int': 44,
#    'num_str': '44.',
#    'people': None,
#    'places': None,
#    'text': '44. of bone. 216. h 20 J.'},
#   {'num_int': 45,
#    'num_str': '45.',
#    'people': None,
#    'places': None,
#    'text': '45. An ancient brasse thimble. 216. m'},
#   {'num_int': 46,
#    'num_str': '46.',
#    'people': None,
#    'places': None,
#    'text': "46. Small green glasse beads found with armilla's &c. 216. h 20. J."},
#   {'num_int': 47,
#    'num_str': '-47.',
#    'people': [{'id': 'Sr_Peter_Lely', 'name': 'Sr. Peter Lely'},
#     {'id': 'Charles_Montagu', 'name': 'Ld Ch Halifax'}],
#    'places': None,
#    'text': '-47. A head statue of the Emperor Verus ? in white marble belonged to Sr. Peter Lely bought of his son for }--- 6. 9. 0. & presented by me to Ld Ch Halifax.'},
#   {'num_int': 783,
#    'num_str': '-783.',
#    'people': None,
#    'places': [{'id': 'Richborough', 'name': 'Richborrough'}],
#    'text': '-783. The same with 756. intire wt. oysters, & in the midle or ar center a starr or rose. from Richborrough. 245. CCXXVIII'},
#   {'num_int': 784,
#    'num_str': '-784.',
#    'people': None,
#    'places': None,
#    'text': '-784. A small deep patera intire without a lip, the workmans name saturnen. wt. same oyster spat. Id. & 2 concentric prickd circles 245. CCXXIX.'},
#   {'num_int': 785,
#    'num_str': '-785.',
#    'people': None,
#    'places': None,
#    'text': '-785. The same broken wt. CRISPIN. The makers name. Id. 245.'},
#   {'num_int': 786,
#    'num_str': '-786.',
#    'people': None,
#    'places': None,
#    'text': '-786. Tea root wt. the stem or trunk rising out of it burnt on the under side for carving into figures after the Chinese manner 239 CCXXXII.'},
#   {'num_int': 787,
#    'num_str': '-787.',
#    'people': [{'id': 'Mr_Dupuys', 'name': 'Monsr. dupuys'}],
#    'places': None,
#    'text': '-787. The same carvd into a mans figure holding the head of a dragon in his left hand extended, & in his right hand an haffe moon wt. a ball in it standing on the figure of an ox lying down from Monsr. dupuys. 239. CCXXXIII'},
#   {'num_int': 787,
#    'num_str': '-787.',
#    'people': [{'id': 'Mr._Compton', 'name': 'Mr. Compton'}],
#    'places': [{'id': 'Rome', 'name': 'Rome'}],
#    'text': '-787. Severall pieces of old Roman antiquailles brought from Rome by Mr. Compton. 216. k.'},
#   {'num_int': 788,
#    'num_str': '788.',
#    'people': None,
#    'places': [{'id': 'Reculver', 'name': 'Reculver'}],
#    'text': '788. Pieces of armillæ, rings &c. from Reculver 216 k 20. m'},
#   {'num_int': 789,
#    'num_str': '789.',
#    'people': None,
#    'places': None,
#    'text': '789. A two eard small earthen black bottle. 216 k'},
#   {'num_int': 790,
#    'num_str': '790.',
#    'people': None,
#    'places': None,
#    'text': "790. A one eard bottle of a gray colour'd earthen ware. 216 k"},
#   {'num_int': 791,
#    'num_str': '791.',
#    'people': None,
#    'places': None,
#    'text': '791. The halfe of the same redish. 216 k'},
#   {'num_int': 792,
#    'num_str': '792.',
#    'people': None,
#    'places': None,
#    'text': '792. The mouth of one blackish. 216 k.'},
#   {'num_int': 793,
#    'num_str': '793.',
#    'people': None,
#    'places': None,
#    'text': "793. Part of a very wide mouth'd earthen vase. 216 k"},
#   {'num_int': 794,
#    'num_str': '794.',
#    'people': None,
#    'places': None,
#    'text': '794. An earthen ware priapus? 216 l'},
#   {'num_int': 795,
#    'num_str': '795.',
#    'people': None,
#    'places': None,
#    'text': '795. Another smaller? 216 l'},
#   {'num_int': 796,
#    'num_str': '796.',
#    'people': None,
#    'places': None,
#    'text': '796. An earthen ware matrix ? 216 l'},
#   {'num_int': 797,
#    'num_str': '797.',
#    'people': None,
#    'places': None,
#    'text': '797. Another smaller. 216 l'},
#   {'num_int': 798,
#    'num_str': '798.',
#    'people': None,
#    'places': None,
#    'text': '798. Severall pieces of urns. 216 l'},
#   {'num_int': 799,
#    'num_str': '-799.',
#    'people': None,
#    'places': [{'id': 'Reculver', 'name': 'Reculver'}],
#    'text': '-799. A large red earthen ware Roman patera wt. out lips at. tubals vermium, balani &c. on it from Reculver. 245.'},
#   {'num_int': 800,
#    'num_str': '800.',
#    'people': None,
#    'places': None,
#    'text': '800. A small one wt. L LVSM on it. 245'},
#   {'num_int': 801,
#    'num_str': '-801.',
#    'people': None,
#    'places': None,
#    'text': '-801. A Ægyptian Scarab wt. the elytron sulcated length ways &c. 199'},
#   {'num_int': 802,
#    'num_str': '-802.',
#    'people': None,
#    'places': None,
#    'text': '-802. lesser not sulcated wt. Hieraglyphics.'},
#   {'num_int': 803,
#    'num_str': '-803.',
#    'people': None,
#    'places': None,
#    'text': '-803. A gray earthen Lamp wt. 2 corona Laurea upon it.'},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': '158 Antiquites.'},
#   {'num_int': 48,
#    'num_str': '48.',
#    'people': None,
#    'places': [{'id': 'Fleet_Ditch', 'name': 'fleet- ditch'}],
#    'text': "48. A piece of a coffin of oak turn'd blackish taken up out of the earth when fleet- ditch was dugg at feet depth where were likewise lachrymat= =ories. 216 k. 21. L."},
#   {'num_int': 49,
#    'num_str': '49.',
#    'people': [{'id': 'King_James', 'name': 'King James'}],
#    'places': None,
#    'text': "49. A piece of the covering of King James's Coffin. 216. k. 21. L."},
#   {'num_int': 50,
#    'num_str': '50.',
#    'people': None,
#    'places': [{'id': 'Baden', 'name': 'Baden'},
#     {'id': 'Schaffhausen', 'name': 'Scaffhausen'},
#     {'id': 'Switzerland', 'name': 'Swisserland'}],
#    'text': '50. Dice found at Baden seven leagues from Scaffhausen in Swisserland in a close near the town wall & said to be Naturall. 216. m'},
#   {'num_int': 51,
#    'num_str': '51.',
#    'people': None,
#    'places': [{'id': 'Bethlehem', 'name': 'Bethlehem'}],
#    'text': '51. Pieces of the mosaic work of the temple or great church at Bethlehem w ch. is admirable & was built by St. Helena. 99'},
#   {'num_int': 52,
#    'num_str': '52.',
#    'people': None,
#    'places': None,
#    'text': '52. A piece of an ancient glasse urn or other vessell wt. armatura or electrum on it? 216 k 216 h. 20 J.'},
#   {'num_int': 53,
#    'num_str': '53.',
#    'people': None,
#    'places': None,
#    'text': "53. A piece of a patera of red earth wt. L SΛTR - - grav'd on its outside. 216 i"},
#   {'num_int': 54,
#    'num_str': '54.',
#    'people': None,
#    'places': None,
#    'text': '54. A piece of a patera on the outside of wch. are a lyon , fleurs &c. of red earth. 216. h'},
#   {'num_int': 55,
#    'num_str': '55.',
#    'people': None,
#    'places': None,
#    'text': '55. A piece of a large red earthen patera wt. letters on it.'},
#   {'num_int': 56,
#    'num_str': '56.',
#    'people': None,
#    'places': None,
#    'text': '56. A piece of the ring of the same.'},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': '216 l'},
#   {'num_int': 804,
#    'num_str': '804.',
#    'people': None,
#    'places': None,
#    'text': '804. Two heads one of a man wt. whiskers another a deaths head wrote on A la faint Nabot point de demint a la mort carvd in ivory. A W.F. A.W.F. 1853. ivory.'},
#   {'num_int': 805,
#    'num_str': '-805.',
#    'people': None,
#    'places': [{'id': 'Canterbury', 'name': 'Canterbury'}],
#    'text': '-805. A large earthen patera red & of the best earth from the neighbourhood of Canterbury. 245.'},
#   {'num_int': 806,
#    'num_str': '806.',
#    'people': [{'id': 'Abbe_Bernardo_Sterbini', 'name': 'Abbe Sterbini'}],
#    'places': [{'id': 'Italy', 'name': 'Italy'}],
#    'text': '806. A hollow dish or patera in shape like a salver wt. a pedestall made of pale red earth covered wt. a black varnish from the Etrusci in Italy by the Abbe Sterbini. 246'},
#   {'num_int': 807,
#    'num_str': '-807.',
#    'people': None,
#    'places': None,
#    'text': '-807. Another wt. the varnish covered wt. the earth in which it lay. Id. 246'},
#   {'num_int': 808,
#    'num_str': '-808.',
#    'people': None,
#    'places': None,
#    'text': '-808. Another lesser. Id. E H 246'},
#   {'num_int': 809,
#    'num_str': '-809. 899.',
#    'people': None,
#    'places': None,
#    'text': '-809. 899. Another yet lesser. Id. EH 246'},
#   {'num_int': 810,
#    'num_str': '-810. 800.',
#    'people': None,
#    'places': None,
#    'text': '-810. 800. Another lesser. Id. EH 246'},
#   {'num_int': 811,
#    'num_str': '-811.',
#    'people': None,
#    'places': None,
#    'text': '-811. The smallest. Id. ? 246.'},
#   {'num_int': 812,
#    'num_str': '-812.',
#    'people': None,
#    'places': None,
#    'text': '-812. The same wt. no. 806. only the bottom of the pedestall not varnished. Id. 246.'},
#   {'num_int': 813,
#    'num_str': '-813.',
#    'people': None,
#    'places': None,
#    'text': '-813. A very large basire of stone or bakd earth of a black colour. Id. EH 246.'},
#   {'num_int': 814,
#    'num_str': '-814.',
#    'people': None,
#    'places': None,
#    'text': '-814. Another gray with a wreathed loop or handle and a three lined pointed waved line round the upper edge wch. is bowed inwards EH 246.'},
#   {'num_int': 815,
#    'num_str': '-815.',
#    'people': None,
#    'places': None,
#    'text': '-815. A small dish or patera wt. 3 pointed circles in the center of red earth lacquered or varnished black on a short pedestall. Id. 246'},
#   {'num_int': 816,
#    'num_str': '-816.',
#    'people': None,
#    'places': None,
#    'text': '-816. A small cup like a coffee cup. of the same materials wt. some concentrick ornamen t all circles. Id. EH 246'},
#   {'num_int': 817,
#    'num_str': '817.',
#    'people': None,
#    'places': None,
#    'text': '817. The same broader & shallower wt. the edges notched or engraved. Id. 246.'},
#   {'num_int': 818,
#    'num_str': '-818.',
#    'people': None,
#    'places': None,
#    'text': '-818. The same wt. an hollow knob rising in the midle wt. out any pedestall Id. 246'},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': '159'},
#   {'num_int': 57,
#    'num_str': '-57.',
#    'people': None,
#    'places': None,
#    'text': '-57. A piece of a red earthen pat = = era. wt. figures on its outside. 245. E H 216 l.'},
#   {'num_int': 58,
#    'num_str': '-58.',
#    'people': None,
#    'places': None,
#    'text': '-58. A piece of a glasse urn. 216. h. 20 J'},
#   {'num_int': 59,
#    'num_str': '-59.',
#    'people': None,
#    'places': None,
#    'text': '-59. Another piece wt. the mark of the iron on it & some armatura or electrum. 216. h. 20. J.'},
#   {'num_int': 60,
#    'num_str': '-60.',
#    'people': None,
#    'places': None,
#    'text': '-60. A blew glasse for mosaic work. 216 k.'},
#   {'num_int': 61,
#    'num_str': '-61.',
#    'people': None,
#    'places': None,
#    'text': '-61. Red Glass. guilded. 216. h 20. J.'},
#   {'num_int': 62,
#    'num_str': '-62.',
#    'people': None,
#    'places': None,
#    'text': '-62. A piece of a fibula. 216. m'},
#   {'num_int': 63,
#    'num_str': '-63.',
#    'people': None,
#    'places': None,
#    'text': '-63. A piece of a Roman Brick'},
#   {'num_int': 64,
#    'num_str': '64.',
#    'people': None,
#    'places': None,
#    'text': '64. An ancient, British? arrow head of a flint. 163 28 b'},
#   {'num_int': 65,
#    'num_str': '65.',
#    'people': None,
#    'places': [{'id': 'Virginia', 'name': 'Virginia'}],
#    'text': '65. One of sparr. from Virginia. 163. 28 b'},
#   {'num_int': 66,
#    'num_str': '66.',
#    'people': None,
#    'places': [{'id': 'Strait_Magellan', 'name': 'Streights of Magellan'}],
#    'text': '66. One of a green flint from the Streights of Magellan.'},
#   {'num_int': 67,
#    'num_str': '67.',
#    'people': None,
#    'places': None,
#    'text': '67. A ring for containing a medall of wood 245 19 f'},
#   {'num_int': 68,
#    'num_str': '68.',
#    'people': None,
#    'places': None,
#    'text': '68. Another of horn. 245 19 f'},
#   {'num_int': 69,
#    'num_str': '69.',
#    'people': None,
#    'places': None,
#    'text': '69. Another. 245 19 f'},
#   {'num_int': 819,
#    'num_str': '-819.',
#    'people': [{'id': 'Abbe_Bernardo_Sterbini', 'name': 'Abbe Sterbini'}],
#    'places': [{'id': 'Etruscan', 'name': 'Etruscan'},
#     {'id': 'Rome', 'name': 'Rome'}],
#    'text': '-819. A Shallow porrenger of red earth glazed wt. a shiny thin black . varnish or crust wt. Etruscan characters on the bottom of it in of it & 2 square handles standing horizontally upon it from Rome by the Abbe Sterbini. 246'},
#   {'num_int': 820,
#    'num_str': '-820.',
#    'people': None,
#    'places': None,
#    'text': '-820. The same without characters. Id. 246.'},
#   {'num_int': 821,
#    'num_str': '-821.',
#    'people': None,
#    'places': None,
#    'text': '-821. The same Id. 246.'},
#   {'num_int': 822,
#    'num_str': '-822.',
#    'people': None,
#    'places': None,
#    'text': '-822. The same Id 246.'},
#   {'num_int': 823,
#    'num_str': '-823.',
#    'people': None,
#    'places': None,
#    'text': '-823. The same deeper wt. the handles raised. Id. 246'},
#   {'num_int': 824,
#    'num_str': '-824.',
#    'people': None,
#    'places': None,
#    'text': '-824. The same lesser. Id. E H 246'},
#   {'num_int': 825,
#    'num_str': '-825.',
#    'people': None,
#    'places': None,
#    'text': '-825. The same lesser Id. 246'},
#   {'num_int': 826,
#    'num_str': '-826.',
#    'people': None,
#    'places': None,
#    'text': '-826. The same deeper & adornd wt. lines on the outside. Id. EH 246'},
#   {'num_int': 827,
#    'num_str': '-827.',
#    'people': None,
#    'places': None,
#    'text': '-827. The same plain. Id. EH 246'},
#   {'num_int': 828,
#    'num_str': '-828.',
#    'people': None,
#    'places': None,
#    'text': '-828. The same lesser. Id. EH 246'},
#   {'num_int': 829,
#    'num_str': '-829.',
#    'people': None,
#    'places': None,
#    'text': '-829. The same larger ? 246'},
#   {'num_int': 830,
#    'num_str': '-830.',
#    'people': None,
#    'places': None,
#    'text': '-830. The same large wt. concentric black circles. Id. 246'},
#   {'num_int': 831,
#    'num_str': '-831.',
#    'people': None,
#    'places': None,
#    'text': '-831. The same wt. a corona laurea. Id. 246'},
#   {'num_int': 832,
#    'num_str': '-832.',
#    'people': None,
#    'places': None,
#    'text': '-832. The same wt. a pedestall. Id. E H 246.'},
#   {'num_int': 833,
#    'num_str': '-833.',
#    'people': None,
#    'places': None,
#    'text': '-833. The same lesser. Id. 246.'},
#   {'num_int': 834,
#    'num_str': '-834.',
#    'people': None,
#    'places': None,
#    'text': '-834. The same larger & plain. Id. 246'},
#   {'num_int': 835,
#    'num_str': '-835.',
#    'people': None,
#    'places': None,
#    'text': '-835. The same wt. straight lines for ornament. Id. 246'},
#   {'num_int': 836,
#    'num_str': '-836.',
#    'people': None,
#    'places': None,
#    'text': '-836. The same lesser wt. many ornaments. Id. EH 246'},
#   {'num_int': 837,
#    'num_str': '-837.',
#    'people': None,
#    'places': None,
#    'text': '-837. A two eard deep. pott wt. black varnish. Id. EH 246'},
#   {'num_int': 838,
#    'num_str': '-838.',
#    'people': None,
#    'places': None,
#    'text': '-838. The same lesser. Id. 246'},
#   {'num_int': 839,
#    'num_str': '-839.',
#    'people': None,
#    'places': None,
#    'text': '-839. The same Id. 246'},
#   {'num_int': 840,
#    'num_str': '-840.',
#    'people': None,
#    'places': None,
#    'text': '-840. The same adornd wt. white flowers. Id. EH 246'},
#   {'num_int': 841,
#    'num_str': '-841.',
#    'people': None,
#    'places': None,
#    'text': '-841. The same wt. raised ansee or ears Id. 246'},
#   {'num_int': 842,
#    'num_str': '-842.',
#    'people': None,
#    'places': None,
#    'text': '-842. The same. Id. 246'},
#   {'num_int': 843,
#    'num_str': '-843.',
#    'people': None,
#    'places': None,
#    'text': '-843. The same broken. Id. 246'},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': '160'},
#   {'num_int': 70,
#    'num_str': '-70',
#    'people': None,
#    'places': None,
#    'text': '-70 A ring for holding a medall of ivory. 245. 19. f'},
#   {'num_int': 71,
#    'num_str': '71.',
#    'people': None,
#    'places': None,
#    'text': '71. Another. 245. 19. f'},
#   {'num_int': 72,
#    'num_str': '72.',
#    'people': None,
#    'places': None,
#    'text': '72. A kind of asphaltum sealed wt. Arabic characters ? 245. 19 K.'},
#   {'num_int': 73,
#    'num_str': '73.',
#    'people': None,
#    'places': None,
#    'text': '73. The same. 245 19 K.'},
#   {'num_int': 74,
#    'num_str': '74.',
#    'people': None,
#    'places': None,
#    'text': '74. The same.'},
#   {'num_int': 75,
#    'num_str': '75.',
#    'people': None,
#    'places': None,
#    'text': '75. Plaister of paris in the form of a heart ? 245. 244 a 19. O'},
#   {'num_int': 76,
#    'num_str': '76.',
#    'people': [{'id': 'Robert_Hooke', 'name': 'Dr. Hook'}],
#    'places': None,
#    'text': "76. A pillar carv'd in the form of a palm tree trunk. Dr. Hook. 245. 244 a 20 m"},
#   {'num_int': 77,
#    'num_str': '-77.',
#    'people': [{'id': 'Robert_Hooke', 'name': 'Mr. Robert Hook'}],
#    'places': None,
#    'text': '-77. Black marble wt. characters on it? Mr. Robert Hook Anno Dom. 1686. a. 245. 244'},
#   {'num_int': 78,
#    'num_str': '-78.',
#    'people': None,
#    'places': None,
#    'text': '-78. A Block for grinding colours?'},
#   {'num_int': 79,
#    'num_str': '-79. 80',
#    'people': None,
#    'places': None,
#    'text': '-79. 80 An Ancient Spear head. 216. n'},
#   {'num_int': 80,
#    'num_str': '-80.',
#    'people': None,
#    'places': None,
#    'text': '-80. The cover of an urne of gray earth. 216'},
#   {'num_int': 81,
#    'num_str': '-81.',
#    'people': None,
#    'places': None,
#    'text': '-81. A piece of a metallic ancient speculum. L. 3in 216 h 20 J. A.W.F. 1853'},
#   {'num_int': 844,
#    'num_str': '-844.',
#    'people': [{'id': 'Abbe_Bernardo_Sterbini', 'name': 'Abbe Sterbini'}],
#    'places': None,
#    'text': '-844. A vessell for containing of ointments &c of red earth wt. a corona Laurea on its out ward side & 2 ears close to its mouth. from the Etrusci by the Abbe Sterbini. EH 248 C'},
#   {'num_int': 845,
#    'num_str': '-845.',
#    'people': None,
#    'places': None,
#    'text': '-845. The same all black wt. a varnish the top not so open. Id. 248 c'},
#   {'num_int': 846,
#    'num_str': '-846',
#    'people': None,
#    'places': None,
#    'text': '-846 Another wt. the ears of ansee standing up EH 248 c'},
#   {'num_int': 847,
#    'num_str': '-847.',
#    'people': None,
#    'places': None,
#    'text': '-847. Another in the form of a flower pott open at top. & adorned very much wt. white lines. Id. EH 248 c'},
#   {'num_int': 848,
#    'num_str': '-848.',
#    'people': None,
#    'places': None,
#    'text': '-848. A small cup. wt. 2 horizontalle ears. Id. EH 248 c.'},
#   {'num_int': 849,
#    'num_str': '-849.',
#    'people': None,
#    'places': None,
#    'text': '-849. One all black much deeper EH 248. c'},
#   {'num_int': 850,
#    'num_str': '-850.',
#    'people': None,
#    'places': None,
#    'text': '-850. A cup wt. one ear & wrought by sevll. figures Id. 248. c'},
#   {'num_int': 851,
#    'num_str': '-851.',
#    'people': None,
#    'places': None,
#    'text': '-851. A large cup wt. out any ear wt. a pedestall. Id. EH 248 c'},
#   {'num_int': 852,
#    'num_str': '-852.',
#    'people': None,
#    'places': None,
#    'text': '-852. A deep small vessell wt. one ear for ointments. Id. EH 248 c.'},
#   {'num_int': 853,
#    'num_str': '-853.',
#    'people': None,
#    'places': None,
#    'text': '-853. The same. Id. EH 248 c.'},
#   {'num_int': 854,
#    'num_str': '-854.',
#    'people': None,
#    'places': None,
#    'text': '-854. A litle bottle wt. one ear varnished over wt. black & the figure of a wheel on the foreside. Id. EH 248 c.'},
#   {'num_int': 855,
#    'num_str': '-855.',
#    'people': None,
#    'places': None,
#    'text': '-855. A lamp. of the same pale earthen ware wt. a greyhound & hare on its upper side. Id. 248. c'},
#   {'num_int': 856,
#    'num_str': '-856.',
#    'people': None,
#    'places': None,
#    'text': '-856. The same wt. a belly to contain much oil & a place perforated like a sand box & a nozzle for the wick? Id 248 c'},
#   {'num_int': 857,
#    'num_str': '-857.',
#    'people': None,
#    'places': None,
#    'text': '-857. A small flat lamp. wt. a concentric circle on its upper side. Id. EH 248. c'},
#   {'num_int': 858,
#    'num_str': '-858.',
#    'people': None,
#    'places': None,
#    'text': '-858. The same wt. 854. only some ornamts. on the upper part. Id. 246'},
#   {'num_int': 859,
#    'num_str': '-859.',
#    'people': None,
#    'places': None,
#    'text': '-859. The same wt. deep Sulci on it Id. E H 246'},
#   {'num_int': 860,
#    'num_str': '-860',
#    'people': None,
#    'places': None,
#    'text': '-860 The same adornd wt. other figures. Id.'},
#   {'num_int': 861,
#    'num_str': '-861.',
#    'people': None,
#    'places': None,
#    'text': '-861. The same wt. 852. Id.'},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': '161'},
#   {'num_int': 82,
#    'num_str': '-82.',
#    'people': None,
#    'places': None,
#    'text': '-82. pieces of red patera. 216. i.'},
#   {'num_int': 83,
#    'num_str': '-83.',
#    'people': None,
#    'places': None,
#    'text': '-83. pieces of antient glasse metall &c. EH 216. h. 20. J.'},
#   {'num_int': 84,
#    'num_str': '-84.',
#    'people': None,
#    'places': None,
#    'text': '-84. An Ægyptian wooden idoll taken from the pyramids. vid Figures. E H 183.'},
#   {'num_int': 85,
#    'num_str': '85.',
#    'people': None,
#    'places': [{'id': 'St_Paul', 'name': 'Pauls'}],
#    'text': '85. Pietre comesse or Mosaic work found under Pauls. 216. g A.W.F. 1853.'},
#   {'num_int': 86,
#    'num_str': '-86.',
#    'people': [{'id': 'Robert_Hooke', 'name': 'Dr. Hook'}],
#    'places': None,
#    'text': "-86. Electrum Britannicum , colour'd glasse I suppose from lime. from Dr. Hook. 216. h. 20 M"},
#   {'num_int': 87,
#    'num_str': '-87.',
#    'people': None,
#    'places': None,
#    'text': "-87. Colour'd glasse blew & green from the same."},
#   {'num_int': 88,
#    'num_str': '-88.',
#    'people': None,
#    'places': [{'id': 'Cicero_house',
#      'name': "Cicero's house at Mola between Gayette & Cuma at Formio"}],
#    'text': "-88. Glasse of sevll. colours taken up out of Cicero's house at Mola between Gayette & Cuma at Formio. 216. m"},
#   {'num_int': 89,
#    'num_str': '-89.',
#    'people': None,
#    'places': None,
#    'text': '-89. A piece of an ancient brasse sword ? Vid. Monfaucon. Antiq. tom. 2d p. 148 pl. LXVI. tom. 4 Part 2. 216. n. A.W.F. 1853. X'},
#   {'num_int': 90,
#    'num_str': '-90.',
#    'people': None,
#    'places': None,
#    'text': '-90. A runick Almanac , small? 245. a 244'},
#   {'num_int': 91,
#    'num_str': '-91.',
#    'people': None,
#    'places': None,
#    'text': "-91. Earthen ware copper'd or gilded over? 216. i"},
#   {'num_int': 862,
#    'num_str': '-862.',
#    'people': [{'id': 'Abbe_Bernardo_Sterbini', 'name': 'Abbe Sterbini'}],
#    'places': [{'id': 'Rome', 'name': 'Rome'}],
#    'text': '-862. An open cup wt out any ears like a common coffee cup of red earth varnishd black from Rome by the Abbe Sterbini. 246'},
#   {'num_int': 863,
#    'num_str': '-863.',
#    'people': None,
#    'places': None,
#    'text': '-863. The same wt. one ear. Id. 246'},
#   {'num_int': 864,
#    'num_str': '-864.',
#    'people': None,
#    'places': None,
#    'text': '-864. The same wt. a hollow furrow round its top as if for the receiving a cover. Id. 246'},
#   {'num_int': 865,
#    'num_str': '-865.',
#    'people': None,
#    'places': None,
#    'text': '-865. A small pott or vessell for ointments wt. one ear all blacked wt. varnish or . Id. 246'},
#   {'num_int': 866,
#    'num_str': '-866.',
#    'people': None,
# ...
#   {'num_int': 333,
#    'num_str': '-333.',
#    'people': None,
#    'places': None,
#    'text': '-333. A cows grinder from the same? 216. o'},
#   {'num_int': 334,
#    'num_str': '-334.',
#    'people': None,
#    'places': None,
#    'text': "-334. A lacker'd peel ? or voider ?"},
#   {'num_int': 335,
#    'num_str': '-335.',
#    'people': None,
#    'places': None,
#    'text': '-335. A bagg made of an African grasse? k. 244.'},
#   {'num_int': 336,
#    'num_str': '-336.',
#    'people': None,
#    'places': [{'id': 'Reculver', 'name': 'Reculver'}],
#    'text': '-336. A large gray urn from Reculver cliffe wt. small balani growing on it.'},
#   {'num_int': 337,
#    'num_str': '-337.',
#    'people': None,
#    'places': None,
#    'text': "-337. A large red earth'd patera from the same. 245."},
#   {'num_int': 338,
#    'num_str': '-338.',
#    'people': None,
#    'places': None,
#    'text': '-338. One smaller wt. an inscription at bottom from the same. 245.'},
#   {'num_int': 339,
#    'num_str': '-339.',
#    'people': None,
#    'places': None,
#    'text': '-339. Another smaller. 245.'},
#   {'num_int': 340,
#    'num_str': '-340.',
#    'people': None,
#    'places': None,
#    'text': '-340. One smaller wt. a flower at bottom. from the same. 245.'},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': '186'},
#   {'num_int': 341,
#    'num_str': '-341.',
#    'people': None,
#    'places': [{'id': 'Reculver', 'name': 'Reculver'},
#     {'id': 'Canterbury', 'name': 'Canterbury'}],
#    'text': '-341. A fibula from Reculver cliffe or Canterbury. 216. o 20 m. A. W. F. 1852'},
#   {'num_int': 342,
#    'num_str': '-342.',
#    'people': None,
#    'places': None,
#    'text': '-342. A brasse thimble from the same. 216. o 20 m.'},
#   {'num_int': 343,
#    'num_str': '-343.',
#    'people': None,
#    'places': None,
#    'text': '-343. A Silver bodkin from the same. 216. o.'},
#   {'num_int': 344,
#    'num_str': '-344.',
#    'people': None,
#    'places': None,
#    'text': '-344. A black & white glasse large bead from the same. 216. o 20 J.'},
#   {'num_int': 345,
#    'num_str': '-345.',
#    'people': None,
#    'places': None,
#    'text': '-345. A redish flint made into a button from the same. 216. o 20. J.'},
#   {'num_int': 346,
#    'num_str': '-346.',
#    'people': None,
#    'places': [{'id': 'Reculver', 'name': 'Reculver'}],
#    'text': '-346. A tile wt. raised edges taken out of Reculver ruines now covered wt. the sea on wch. appear oysters.'},
#   {'num_int': 347,
#    'num_str': '-347.',
#    'people': None,
#    'places': None,
#    'text': '-347. A piece of a celta taken up there. 216. f 2 X'},
#   {'num_int': 348,
#    'num_str': '-348.',
#    'people': None,
#    'places': None,
#    'text': '-348. An iron key from the same. 216 o 21. L.'},
#   {'num_int': 349,
#    'num_str': '-349.',
#    'people': None,
#    'places': None,
#    'text': '-349. The handle of a brasse spoon from the same. 216. o'},
#   {'num_int': 350,
#    'num_str': '-350.',
#    'people': None,
#    'places': None,
#    'text': '-350. A small red earthen patera from the same wt. a name on the bottom. 245.'},
#   {'num_int': 351,
#    'num_str': '-351.',
#    'people': None,
#    'places': None,
#    'text': '-351. A smaller with oyster shells & small balani upon it. Id. 245.'},
#   {'num_int': 352,
#    'num_str': '-352.',
#    'people': None,
#    'places': None,
#    'text': '-352. The head of Julia mammæa ? Id. 216 n'},
#   {'num_int': 353,
#    'num_str': '-353.',
#    'people': None,
#    'places': None,
#    'text': '-353. An entire brasse key from the same. Vid Montfaucon LIV a la 106. page tom 111. A.W.F. 1852.'},
#   {'num_int': 354,
#    'num_str': '-354.',
#    'people': None,
#    'places': None,
#    'text': '-354. An entire fibula & pieces of fibulæ Id. 216 k'},
#   {'num_int': 355,
#    'num_str': '-355.',
#    'people': None,
#    'places': None,
#    'text': '-355. A brasse stylus ? naile & large pin? Id. 216. o'},
#   {'num_int': 356,
#    'num_str': '-356.',
#    'people': None,
#    'places': None,
#    'text': '-356. Isis & Orus. described &. figured in Montfaucon Vol. 2 supp. p. 281. pl. CXIII E H 220'},
#   {'num_int': 357,
#    'num_str': '-357.',
#    'people': None,
#    'places': [{'id': 'Reculver', 'name': 'Reculver'},
#     {'id': 'Kent', 'name': 'Kent'}],
#    'text': '-357. A large red earthen patera found at Reculver in Kent'},
#   {'num_int': 358,
#    'num_str': '-358.',
#    'people': None,
#    'places': None,
#    'text': '-358. A lesser. 245'},
#   {'num_int': 359,
#    'num_str': '-359.',
#    'people': None,
#    'places': None,
#    'text': '-359. a brasse key. ib. Vid Montfaucon LIV Pl. a la 106. p. t. 3. 216. n'},
#   {'num_int': 360,
#    'num_str': '-360.',
#    'people': None,
#    'places': None,
#    'text': '-360. A salt cellar. ib. 216 n 21. L'},
#   {'num_int': 361,
#    'num_str': '-361.',
#    'people': None,
#    'places': None,
#    'text': '-361. A talk from the coals burnt ib? 216. n.'},
#   {'num_int': 362,
#    'num_str': '-362.',
#    'people': None,
#    'places': None,
#    'text': '-362. A pair of iron tongues. ib? 21 L'},
#   {'num_int': 363,
#    'num_str': '-363.',
#    'people': [{'id': 'D_Woodward', 'name': 'Woodward'}],
#    'places': None,
#    'text': '-363. Tabula in summa parte arcuata, at opinor ex basalte Lapide Æthiopice durissimo in duas partes divisa &c vid. Woodward antiq. p. 262. No. 6 fig.'},
#   {'num_int': 364,
#    'num_str': '-364.',
#    'people': None,
#    'places': [{'id': 'Windsor', 'name': 'Windsor'}],
#    'text': '-364. A large two handed sword from Windsor 252.'},
#   {'num_int': 365,
#    'num_str': '-365.',
#    'people': None,
#    'places': None,
#    'text': '-365. An iron mace from the same loose ring on handle. L. 21 3/4. 252 A.W.F. 1854'},
#   {'num_int': 366,
#    'num_str': '-366.',
#    'people': None,
#    'places': None,
#    'text': '-366. A dagger or poignard from the same. 245.'},
#   {'num_int': 367,
#    'num_str': '-367.',
#    'people': None,
#    'places': None,
#    'text': '-367. A lamp for wt. 4 weeks. star fashion.. Id. given to the Society. Antiq. being their arms.'},
#   {'num_int': 368,
#    'num_str': '-368.',
#    'people': None,
#    'places': None,
#    'text': '-368. A round one for one Id. f. 245. 244 19 J.'},
#   {'num_int': 369,
#    'num_str': '-369.',
#    'people': None,
#    'places': None,
#    'text': '-369. A tuba or trumpet Id. 245.'},
#   {'num_int': None,
#    'num_str': None,
#    'people': [{'id': 'Thomas_Hollis', 'name': 'Thomas Hollis'}],
#    'places': None,
#    'text': 'Thomas Hollis of Lincolns Inn. desires the honour of presenting the several antiquitys descri= bed in the following catalogue to the British Museum Bronzes.'},
#   {'num_int': 1,
#    'num_str': '1',
#    'people': None,
#    'places': None,
#    'text': '1 Three figures of Osiris of different sizes 13 K'},
#   {'num_int': 2,
#    'num_str': '2',
#    'people': None,
#    'places': None,
#    'text': '2 Isis sitting'},
#   {'num_int': 3,
#    'num_str': '3',
#    'people': None,
#    'places': None,
#    'text': '3 Typhon'},
#   {'num_int': 4,
#    'num_str': '4',
#    'people': None,
#    'places': None,
#    'text': '4 Anubis or Cynocephalus'},
#   {'num_int': 5,
#    'num_str': '5',
#    'people': None,
#    'places': None,
#    'text': '5 Three small figures of Harpocrates, with different attributes.'},
#   {'num_int': 6,
#    'num_str': '6',
#    'people': None,
#    'places': None,
#    'text': '6 A human figure found in a mummie'},
#   {'num_int': 7,
#    'num_str': '7',
#    'people': None,
#    'places': None,
#    'text': '7 A head perhaps a Triton'},
#   {'num_int': 8,
#    'num_str': '8',
#    'people': None,
#    'places': None,
#    'text': '8 A small bust of Jupiter Ammon.'},
#   {'num_int': 9,
#    'num_str': '9',
#    'people': None,
#    'places': None,
#    'text': '9 Two small figures of Jupiter. 13 H'},
#   {'num_int': 10,
#    'num_str': '10',
#    'people': None,
#    'places': None,
#    'text': '10 Minerva.'},
#   {'num_int': 11,
#    'num_str': '11',
#    'people': None,
#    'places': None,
#    'text': '11 Three lesser figures of Minerva'},
#   {'num_int': 12,
#    'num_str': '12',
#    'people': None,
#    'places': None,
#    'text': '12 Four figures of Mercury of different sizes. G 2 f a'},
#   {'num_int': 13,
#    'num_str': '13',
#    'people': None,
#    'places': None,
#    'text': '13 Two small figures of Venus. G G'},
#   {'num_int': 14,
#    'num_str': '14.',
#    'people': None,
#    'places': None,
#    'text': '14. Four figures of Cupid, with various attributes. 1 f a G'},
#   {'num_int': 15,
#    'num_str': '15',
#    'people': None,
#    'places': None,
#    'text': '15 A figure of a Boy, perhaps Anteros. 14 i'},
#   {'num_int': 16,
#    'num_str': '16.',
#    'people': [{'id': 'Richard_Mead', 'name': 'Dr. Mead'}],
#    'places': None,
#    'text': '16. Two figures of young priapus, from Dr. Meads collection. see Musei Meadiani Par. 11. P 231. peiapuo sub puereli forma globo insideppi a pene enormi super quem so H 2in. Id. pedem penem q alone tens jum writers at frnotra atti m ur H 2in. Hug of both 2in 14 i k'},
#   {'num_int': 17,
#    'num_str': '17',
#    'people': None,
#    'places': None,
#    'text': '17 A Bust of silenus. 13 H'},
#   {'num_int': 18,
#    'num_str': '18',
#    'people': None,
#    'places': None,
#    'text': '18 Eight figures of Hercules. 13 I III'},
#   {'num_int': 19,
#    'num_str': '19',
#    'people': None,
#    'places': None,
#    'text': '19 Three figures of Commodus, or the Roman Hercules II'},
#   {'num_int': None,
#    'num_str': None,
#    'people': None,
#    'places': None,
#    'text': '187'},
#   {'num_int': 370,
#    'num_str': '-370.',
#    'people': None,
#    'places': [{'id': 'Reculver', 'name': 'Reculver'},
#     {'id': 'Kent', 'name': 'Kent'}],
#    'text': '-370. A red patera from Reculver in Kent wt. the word Quintum ? on the bottom. 245.'},
#   {'num_int': 371,
#    'num_str': '-371.',
#    'people': None,
#    'places': [{'id': 'Windsor', 'name': 'Windsor'}],
#    'text': '-371. A very large iron spurr from Windsor where it was- found inclosed in a chimney. 245.'},
#   {'num_int': 372,
#    'num_str': '-372.',
#    'people': None,
#    'places': [{'id': 'Windsor', 'name': 'near Windsor'}],
#    'text': '-372. A celtis , or wedge wt. a hollow on each side for a handle found near Windsor in the forrest in an- antient fortification. L. 6 1/4 EH 216. f.2. A.W.F 1852. X'},
#   {'num_int': 373,
#    'num_str': '-373.',
#    'people': None,
#    'places': None,
#    'text': '-373. Another with a loop to it. Id. 216. f2 X'},
#   {'num_int': 374,
#    'num_str': '-374.',
#    'people': None,
#    'places': [{'id': 'Reculver', 'name': 'Reculver'}],
#    'text': '-374. A large brasse Roman key from Reculver. 216. n A.W.F. 1852.'},
#   {'num_int': 375,
#    'num_str': '-375.',
#    'people': None,
#    'places': None,
#    'text': '-375. Another ? Id. 216. n A.W.F. 1852'},
#   {'num_int': 376,
#    'num_str': '-376.',
#    'people': None,
#    'places': None,
#    'text': '-376. A smaller. Id. 216. n A.W.F. 1852'},
#   {'num_int': 377,
#    'num_str': '-377.',
#    'people': None,
#    'places': None,
#    'text': '-377. Another. Id. 216. n A.W.F. 1852'},
#   {'num_int': 378,
#    'num_str': '-378.',
#    'people': None,
#    'places': None,
#    'text': '-378. A nail. Id. 216. n'},
#   {'num_int': 379,
#    'num_str': '-379.',
#    'people': None,
#    'places': [{'id': 'Windsor', 'name': 'Windsor'}],
#    'text': "-379. An enamell'd box from Windsor. 216. l 30"},
#   {'num_int': 380,
#    'num_str': '-380.',
#    'people': None,
#    'places': [{'id': 'Reculver', 'name': 'Reculver'}],
#    'text': '-380. The figure of a boy sitting holding up his hands. From Reculver. H 1in. 216. m A.W.F. 1853'},
#   {'num_int': 381,
#    'num_str': '-381.',
#    'people': None,
#    'places': None,
#    'text': '-381. A piece of a Mosaic Pavement , red & white , ye tessecræ, or dice, of wch it is composed are about 1/2 inch square. 216. h.'},
#   {'num_int': 382,
#    'num_str': '-382.',
#    'people': [{'id': 'Mr_Purnell', 'name': 'Mr. Purnell'}],
#    'places': [{'id': 'Smyrna', 'name': 'Smyrna'}],
#    'text': '-382. A brasse sepulchrall Lamp in the figure of a dolphin wt a boy sitting on it. Taken from a tomb in Smyrna by Mr. Purnell. 245. A.W.F. 1852.'},
#   {'num_int': 383,
#    'num_str': '-383.',
#    'people': None,
#    'places': None,
#    'text': '-383. A brasse sepulchrall Lamp , taken from the same, in the form of a crab. L H. 5 3/4. 245. A.W.F. 1853.'},
#   {'num_int': 384,
#    'num_str': '-384.',
#    'people': [{'id': 'Robert_Wood', 'name': 'Dr. Wood'}],
#    'places': [{'id': 'North_Elmham', 'name': 'North Elmham in Nor. folk'}],
#    'text': '-384. An earthen large urn found at North Elmham in Nor. folk 1711. Dr. Wood. It had burnt bones unit & had lines upon it wt. some impressions. 245.'},
#   {'num_int': 385,
#    'num_str': '-385.',
#    'people': None,
#    'places': None,
#    'text': '-385. Another wt. protuberances on it Id. both these we gray . Saxon. H. 245. A.W.F. 1855.'},
#   {'num_int': 386,
#    'num_str': '-386.',
#    'people': None,
#    'places': [{'id': 'St_Paul', 'name': 'Pauls'}],
#    'text': '-386. One larger & taller from Pauls church yd. Id.'},
#   {'num_int': 387,
#    'num_str': '-387.',
#    'people': None,
#    'places': [{'id': 'Reculver', 'name': 'Reculver'}],
#    'text': '-387. The cover of a large Roman urne of a pale red colour from Reculver in 245.'},
#   {'num_int': 388,
#    'num_str': '-388.',
#    'people': None,
#    'places': None,
#    'text': '-388. A large red R patera , penscas in the inside impressd. Id. 245.'},
#   {'num_int': 389,
#    'num_str': '-389.',
#    'people': None,
#    'places': None,
#    'text': '-389. One shallower ( Roim ) impressd on the inside. Id.'},
#   {'num_int': 390,
#    'num_str': '-390',
#    'people': None,
#    'places': None,
#    'text': '-390 A small red patera. Id. 245.'},
#   {'num_int': 391,
#    'num_str': '-391.',
#    'people': None,
#    'places': None,
#    'text': '-391. A pale red narrow mouthd urne. Id.'},
#   {'num_int': 20,
#    'num_str': '20.',
#    'people': None,
#    'places': None,
#    'text': '20. A juvenile naked figure adorned with a Chaplet, and the arms broken off See Monumenta Kempiana P. 91. Num: 49. fd H. 4in.'},
#   {'num_int': 21,
#    'num_str': '21.',
#    'people': None,
#    'places': None,
#    'text': '21. a male figure standing, wt its his right arm extended and a Garment wraped about his lefft, which falls over his Knee on that side.'},
#   {'num_int': 22,
#    'num_str': '22.',
#    'people': None,
#    'places': None,
#    'text': '22. A male figure, wt a Compass in his right hand'},
#   {'num_int': 23,
#    'num_str': '23',
#    'people': None,
#    'places': None,
#    'text': '23 A General in his Military dress. fd'},
#   {'num_int': 24,
#    'num_str': '24',
#    'people': None,
#    'places': None,
#    'text': '24 Two Roman Soldiers fd'},
#   {'num_int': 25,
#    'num_str': '25',
#    'people': None,
#    'places': None,
#    'text': '25 Two camillis, of different sizes. 11'},
#   {'num_int': 26,
#    'num_str': '26.',
#    'people': None,
#    'places': None,
#    'text': '26. A grotesque figure & bust. 1'},
#   {'num_int': 27,
#    'num_str': '27.',
#    'people': None,
#    'places': None,
#    'text': '27. An arm, hand, and a foot.'},
#   {'num_int': 28,
#    'num_str': '28.',
#    'people': None,
#    'places': None,
#    'text': '28. A Small Tyger, Cow, rabbit, & (dolphin) fd fd lost in Bringing 1'},
#   {'num_int': 29,
#    'num_str': '29.',
#    'people': None,
#    'places': None,
#    'text': '29. A Bull standing H. 3 3/4. L. 3 3/4. 1 13 K to d A.W.F. 1853.'},
#   {'num_int': 30,
#    'num_str': '30.',
#    'people': None,
#    'places': None,
#    'text': '30. A Cow lying down L 4in. 1 A.W.F. 1853'},
#   {'num_int': 31,
#    'num_str': '31',
#    'people': None,
#    'places': None,
#    'text': '31 A Horse Galloping.'},
#   {'num_int': 32,
#    'num_str': '32.',
#    'people': None,
#    'places': None,
#    'text': '32. Three small vases. A.W.F.'},
#   {'num_int': 33,
#    'num_str': '33.',
#    'people': None,
#    'places': None,
#    'text': '33. Ten matrices for marking earthen ware vessels, and other purposes J. 6'},
#   {'num_int': 34,
#    'num_str': '34',
#    'people': None,
#    'places': None,
#    'text': '34 Six rings of different sizes, for Various pur= poses.'},
#   {'num_int': 35,
#    'num_str': '35',
#    'people': None,
#    'places': None,
#    'text': '35 Eight Keys, of different forms and sizes. J 5'},
#   ...],
#  'length': 1376,
#  'title': 'Antiquities.'}

# %% [markdown]
# #### What is the title?

# %%
# Print title of first catalogue
cats[1]['title']
# Out:
# 'Antiquities.'

# %% [markdown]
# #### What is the length?

# %%
# Print title of first catalogue
len(cats[1]['entries'])
# Out:
# 1376

# %% [markdown]
# #### What is the first entry?

# %%
# Print first entry
cats[1]['entries'][1]
# Out:
# {'num_int': 701,
#  'num_str': '-701.',
#  'people': None,
#  'places': None,
#  'text': '-701. A varietie of the same. Id. 216. m'}

# %% [markdown]
# #### Put the second catalogue in a data frame

# %%
# Create dataframe from first catalogue
df2 = pd.DataFrame(cats[1]['entries'])

# Set visualisation options
pd.set_option('precision', 0)

# Print the dataframe
df2

# Drop nulls
df2 = df.dropna(subset=['num_int'])

# Sort by entry number
df2 = df.sort_values(by=['num_int'])

# Print the dataframe
df2
# Out:
#       num_int      num_str                                             people  \
# 704         1            1                                               None
# 891         1            1                                               None
# 1036        1            1                                               None
# 1067        1            1                                               None
# 1071        1            1       [{'id': 'Richard_Mead', 'name': 'Dr. Mead'}]
# 884         1            1                                               None
# 743         1            1                                               None
# 942         1            1                                               None
# 831         1            1  [{'id': 'William_Lethieullier', 'name': 'Colon...
# 31          1           -1                                               None
# 717         1           1.                                               None
# 943         2            2                                               None
# 832         2            2                                               None
# 718         2           2.  [{'id': 'Mr_Alexander_Gordon', 'name': 'Mr Ale...
# 1037        2            2                                               None
# 885         2            2                                               None
# 705         2            2                                               None
# 1068        2            2                                               None
# 32          2           -2                                               None
# 789         2            2                                               None
# 1072        2            2                                               None
# 33          3          -3.                                               None
# 1038        3            3                                               None
# 944         3            3                                               None
# 886         3            3                                               None
# 719         3           3.                                               None
# 1073        3            3                                               None
# 1069        3            3                                               None
# 833         3            3                                               None
# 790         3            3                                               None
# 1074        4            4                                               None
# 1039        4            4                                               None
# 887         4            4                                               None
# 737         4           4.                                               None
# 834         4            4                                               None
# 945         4            4                                               None
# 805         4            4                                               None
# 34          4          -4.    [{'id': 'John_Conyers', 'name': 'Mr. Conyers'}]
# 806         5            5                                               None
# 888         5            5                                               None
# 946         5            5                                               None
# 35          5           5.                                               None
# 738         5            5                                               None
# 1040        5            5                                               None
# 835         5            5                                               None
# 1075        5            5                                               None
# 1041        6           6.                                               None
# 36          6           6.                                               None
# 855         6            6                                               None
# 739         6            6                                               None
# 1076        6            6                                               None
# 947         6            6                                               None
# 37          7           7.                                               None
# 1042        7            7                                               None
# 740         7            7                                               None
# 856         7            7                                               None
# 948         7            7                                               None
# 1086        7            7                                               None
# 857         8            8  [{'id': 'William_Lethieullier', 'name': 'Colon...
# 38          8           8.                                               None
# 741         8           8.                                               None
# 1087        8           8.                                               None
# 949         8            8                                               None
# 1043        8            8       [{'id': 'Richard_Mead', 'name': 'Dr. Mead'}]
# 1088        9            9                                               None
# 39          9            9                                               None
# 858         9            9                                               None
# 950         9            9                                               None
# 1044        9            9                                               None
# 951        10           10                                               None
# 859        10           10                                               None
# 40         10          10.                                               None
# 1089       10          10.                                               None
# 1063       10          10.                                               None
# 1064       11          11.       [{'id': 'Richard_Mead', 'name': 'Dr. Mead'}]
# 860        11          11.                                               None
# 952        11           11                                               None
# 1090       11          11.                                               None
# 41         11          11.                                               None
# 861        12          12.                                               None
# 1065       12          12.                                               None
# 953        12           12                                               None
# 42         12          12.                                               None
# 954        13           13                                               None
# 881        13           13                                               None
# 60         13          13.                                               None
# 61         14          14.                                               None
# 882        14           14                                               None
# 955        14          14.                                               None
# 956        15           15                                               None
# 62         15          15.                                               None
# 957        16          16.       [{'id': 'Richard_Mead', 'name': 'Dr. Mead'}]
# 63         16          16.                                               None
# 958        17           17                                               None
# 64         17          17.                                               None
# 959        18           18                                               None
# 65         18          18.                                               None
# 960        19           19                                               None
# 66         19          19.                                               None
# 67         20          20.                                               None
# 984        20          20.                                               None
# 985        21          21.                                               None
# 68         21          21.  [{'id': 'Dr_Huntington', 'name': 'Dr. Huntingt...
# 986        22          22.                                               None
# 69         22          22.                                               None
# 70         23          23.    [{'id': 'John_Conyers', 'name': 'Mr. Conyers'}]
# 987        23           23                                               None
# 95         24          24.                                               None
# 988        24           24                                               None
# 96         25          25.                                               None
# 989        25           25                                               None
# 990        26          26.                                               None
# 97         26          26.                                               None
# 991        27          27.                                               None
# 98         27          27.                                               None
# 992        28          28.                                               None
# 99         28          28.                                               None
# 993        29          29.                                               None
# 100        29          29.       [{'id': 'Mr_Conyers', 'name': 'Mr Conyers'}]
# 994        30          30.                                               None
# 101        30          30.                                               None
# 102        31          31.    [{'id': 'Oldsworth', 'name': 'Mr. Oldesworth'}]
# 995        31           31                                               None
# 103        32          32.                                               None
# 996        32          32.                                               None
# 104        33          33.  [{'id': 'Dr_John_Harwood, Dr_Harwood', 'name':...
# 997        33          33.                                               None
# 121        34          34.                                               None
# 998        34           34                                               None
# 122        35          35.                                               None
# 999        35           35                                               None
# 1000       36           36                                               None
# 123        36          36.                                               None
# 1001       37           37                                               None
# 124        37          37.                                               None
# 1002       38           38                                               None
# 125        38          38.                                               None
# 1003       39           39                                               None
# 126        39          39.                                               None
# 127        40          40.                                               None
# 1026       40          40.                                               None
# 128        41          41.                                               None
# 1027       41           41                                               None
# 1028       42          42.                                               None
# 129        42          42.                                               None
# 1029       43          43.                                               None
# 130        43          43.                                               None
# 1030       44          44.                                               None
# 131        44          44.                                               None
# 132        45          45.                                               None
# 1031       45          45.                                               None
# 1032       46          46.                                               None
# 133        46          46.                                               None
# 134        47         -47.  [{'id': 'Sr_Peter_Lely', 'name': 'Sr. Peter Le...
# 1033       47           47                                               None
# 158        48          48.                                               None
# 1034       48          48.                                               None
# 159        49          49.       [{'id': 'King_James', 'name': 'King James'}]
# 160        50          50.                                               None
# 161        51          51.                                               None
# 162        52          52.                                               None
# 163        53          53.                                               None
# 164        54          54.                                               None
# 165        55          55.                                               None
# 166        56          56.                                               None
# 184        57         -57.                                               None
# 185        58         -58.                                               None
# 186        59         -59.                                               None
# 187        60         -60.                                               None
# 188        61         -61.                                               None
# 189        62         -62.                                               None
# 190        63         -63.                                               None
# 191        64          64.                                               None
# 192        65          65.                                               None
# 193        66          66.                                               None
# 194        67          67.                                               None
# 195        68          68.                                               None
# 196        69          69.                                               None
# 223        70          -70                                               None
# 224        71          71.                                               None
# 225        72          72.                                               None
# 226        73          73.                                               None
# 227        74          74.                                               None
# 228        75          75.                                               None
# 229        76          76.       [{'id': 'Robert_Hooke', 'name': 'Dr. Hook'}]
# 230        77         -77.  [{'id': 'Robert_Hooke', 'name': 'Mr. Robert Ho...
# 231        78         -78.                                               None
# 232        79      -79. 80                                               None
# 233        80         -80.                                               None
# 234        81         -81.                                               None
# 254        82         -82.                                               None
# 255        83         -83.                                               None
# 256        84         -84.                                               None
# 257        85          85.                                               None
# 258        86         -86.       [{'id': 'Robert_Hooke', 'name': 'Dr. Hook'}]
# 259        87         -87.                                               None
# 260        88         -88.                                               None
# 261        89         -89.                                               None
# 262        90         -90.                                               None
# 263        91         -91.                                               None
# 283        92         -92.                                               None
# 284        93         -93.        [{'id': 'John_Conyers', 'name': 'Conyers'}]
# 285        94         -94.                                               None
# 286        95         -95.                                               None
# 287        96         -96.                                               None
# 288        97         -97.                                               None
# 289        98          98.    [{'id': 'John_Conyers', 'name': 'Mr. Conyers'}]
# 290        99          99.                                               None
# 291       100        -100.  [{'id': 'Jean_Rodoplhe_Lavater, Dr._Lavater', ...
# 317       100       -100*.  [{'id': 'Richard_Richardson', 'name': 'Dr. Ric...
# 318       101        -101.                                               None
# 319       102        -102.                                               None
# 320       103        -103.                                               None
# 321       104        -104.                                               None
# 322       105        -105.                                               None
# 323       106        -106.       [{'id': 'Mr._Martin', 'name': 'Mr. Martin'}]
# 324       107        -107.  [{'id': 'Owen_Brigstocke', 'name': 'Mr. Brigst...
# 350       108        -108.      [{'id': 'John_Morton', 'name': 'Mr. Morton'}]
# 351       109        -109.  [{'id': 'Thomas_Browne', 'name': 'Sr. Tho. Bro...
# 352       110        -110.                                               None
# 353       111        -111.                                               None
# 354       112        -112.                                               None
# 355       113        -113.       [{'id': 'Oldisworth', 'name': 'Oldisworth'}]
# 374       114        -114.                                               None
# 375       115        -115.                                               None
# 376       116        -116.                                               None
# 377       117        -117.                                               None
# 378       118        -118.                                               None
# 379       119        -119.                                               None
# 380       120        -120.                                               None
# 399       121        -121.                                               None
# 400       122        -122.                                               None
# 401       123        -123.         [{'id': 'Dr._Brown', 'name': 'Dr. Brown'}]
# 402       124        -124.                                               None
# 403       125        -125.                                               None
# 404       126        -126.                                               None
# 405       127        -127.                                               None
# 406       128        -128.                                               None
# 426       129        -129.                                               None
# 427       130        -130.                                               None
# 428       131        -131.                                               None
# 429       132        -132.           [{'id': 'Dr._Brown', 'name': 'Dr. Br.'}]
# 430       133        -133.                                               None
# 431       134        -134.       [{'id': 'Oldisworth', 'name': 'Oldisworth'}]
# 432       135        -135.           [{'id': 'Mr._Sandys', 'name': 'Sandys'}]
# 433       136        -136.                                               None
# 434       137        -137.                                               None
# 457       138        -138.           [{'id': 'Dr._Brown', 'name': 'Dr. Br.'}]
# 458       139        -139.            [{'id': 'Dr._Brown', 'name': 'Dr. Br'}]
# 459       140        -140.           [{'id': 'Dr._Brown', 'name': 'Dr. Br.'}]
# 460       141        -141.                                               None
# 461       142        -142.                                               None
# 462       143        -143.                                               None
# 463       144        -144.         [{'id': 'Edward_Browne', 'name': 'E. B.'}]
# 487       145        -145.            [{'id': 'Dr._Brown', 'name': 'Dr. Br'}]
# 488       146        -146.            [{'id': 'Dr._Brown', 'name': 'Dr. Br'}]
# 489       147        -147.                                               None
# 490       148        -148.            [{'id': 'Dr._Brown', 'name': 'Dr. Br'}]
# 491       149        -149.          [{'id': 'Mr_Lloyd', 'name': 'Mr. Lloyd'}]
# 492       150        -150.                                               None
# 493       151        -151.      [{'id': 'John_Morton', 'name': 'Mr. Morton'}]
# 512       152        -152.                                               None
# 513       153        -153.                                               None
# 514       154        -154.        [{'id': 'Mr_Hodges', 'name': 'Mr. Hodges'}]
# 515       155        -155.                                               None
# 516       156        -156.                                               None
# 517       157        -157.        [{'id': 'Mr_Cairns', 'name': 'Mr. Cairns'}]
# 518       158        -158.                                               None
# 538       159        -159.  [{'id': 'Bp_of_Norwich', 'name': 'Bp of Norwic...
# 539       160        -160.                                               None
# 540       161        -161.                                               None
# 541       162        -162.                                               None
# 542       163        -163.                                               None
# 543       164        -164.                                               None
# 544       165        -165.                                               None
# 545       166         166.                                               None
# 572       167        -167.  [{'id': 'Charles_Townshend', 'name': 'Ld Peter...
# 573       168        -168.            [{'id': 'John_Morton', 'name': 'Mort'}]
# 574       169        -169.                                               None
# 575       170        -170.           [{'id': 'John_Morton', 'name': 'Mort.'}]
# 576       171        -171.            [{'id': 'John_Morton', 'name': 'Mort'}]
# 577       172        -172.                                               None
# 578       173        -173.  [{'id': 'Mr._Wainwright', 'name': 'Mr. Wainwri...
# 595       174        -174.                                               None
# 596       175        -175.                                               None
# 597       176        -176.                                               None
# 598       177        -177.                                               None
# 599       178        -178.                                               None
# 600       179        -179.                                               None
# 601       180        -180.      [{'id': 'Daniel_Waldo', 'name': 'Dr. Waldo'}]
# 602       181        -181.  [{'id': 'Jean_Rodoplhe_Lavater, Dr._Lavater', ...
# 603       182        -182.                                               None
# 618       183        -183.  [{'id': 'Jius', 'name': 'Jo. Bapt. Ottius'}, {...
# 619       184        -184.  [{'id': 'Richard_Middleton_Massey', 'name': 'D...
# 620       185        -185.  [{'id': 'Adrian_Beverland', 'name': 'Mr. Bever...
# 621       186        -186.                                               None
# 622       187        -187.                                               None
# 623       188        -188.        [{'id': 'Dr_Brooks', 'name': 'Dr. Brooks'}]
# 624       189        -189.    [{'id': 'Martin_Lister', 'name': 'Dr. Lister'}]
# 625       190        -190.           [{'id': 'James_Petiver', 'name': 'Pet'}]
# 626       191        -191.           [{'id': 'James_Petiver', 'name': 'Pet'}]
# 627       192        -192.                                               None
# 639       193        -193.           [{'id': 'James_Petiver', 'name': 'Pet'}]
# 640       194        -194.                                               None
# 641       195        -195.                                               None
# 642       196        -196.             [{'id': 'John_Kempe', 'name': 'Kemp'}]
# 643       197        -197.                                               None
# 644       198        -198.                                               None
# 645       199        -199.                                               None
# 646       200        -200.                                               None
# 647       201        -201.             [{'id': 'John_Kempe', 'name': 'Kemp'}]
# 648       202        -202.             [{'id': 'John_Kempe', 'name': 'Kemp'}]
# 649       203        -203.             [{'id': 'John_Kempe', 'name': 'Kemp'}]
# 650       204        -204.                                               None
# 651       205        -205.                                               None
# 652       206        -206.                                               None
# 653       207        -207.                                               None
# 654       208        -208.                                               None
# 655       209        -209.                                               None
# 656       210        -210.                                               None
# 660       211        -211.             [{'id': 'John_Kempe', 'name': 'Kemp'}]
# 661       212        -212.                                               None
# 662       213        -213.                                               None
# 663       214        -214.                                               None
# 664       215        -215.                                               None
# 665       216        -216.                                               None
# 666       217        -217.                                               None
# 667       218        -218.                                               None
# 668       219        -219.                                               None
# 669       220        -220.                                               None
# 670       221        -221.  [{'id': 'Pierre_Silvestre', 'name': 'Dr. Sylve...
# 671       222        -222.                                               None
# 672       223        -223.                                               None
# 673       224        -224.                                               None
# 674       225        -225.                                               None
# 675       226        -226.                                               None
# 676       227        -227.                                               None
# 677       228        -228.                                               None
# 678       229        -229.             [{'id': 'John_Kempe', 'name': 'Kemp'}]
# 685       230        -230.             [{'id': 'John_Kempe', 'name': 'Kemp'}]
# 686       231        -231.             [{'id': 'John_Kempe', 'name': 'Kemp'}]
# 687       232        -232.             [{'id': 'John_Kempe', 'name': 'Kemp'}]
# 688       233        -233.                                               None
# 689       234        -234.                                               None
# 690       235        -235.                                               None
# 691       236        -236.             [{'id': 'John_Kempe', 'name': 'Kemp'}]
# 692       237        -237.                                               None
# 693       238        -238.  [{'id': 'William_Ellis', 'name': 'Wm. Ellis Es...
# 694       239        -239.                                               None
# 695       240        -240.                                               None
# 696       241        -241.                                               None
# 697       242        -242.                                               None
# 698       243        -243.                                               None
# 707       244        -244.                                               None
# 745       244       -244*.  [{'id': 'Charles_Cadogan', 'name': 'Lord Cadog...
# 708       245        -245.                                               None
# 746       245       -245*.                                               None
# 747       246       -246*.                                               None
# 709       246        -246.        [{'id': 'John_Conyers', 'name': 'Conyers'}]
# 748       247       -247*.                                               None
# 710       247        -247.                                               None
# 749       248       -248*.                                               None
# 711       248        -248.        [{'id': 'John_Conyers', 'name': 'Conyers'}]
# 750       249       -249*.  [{'id': 'Lord_Burlington', 'name': 'Lord Burli...
# 712       249        -249.           [{'id': 'James_Petiver', 'name': 'Pet'}]
# 751       250       -250*.       [{'id': 'Andr_Hay', 'name': 'Mr. And. Hay'}]
# 713       250        -250.                                               None
# 752       251       -251*.                                               None
# 714       251        -251.                                               None
# 756       252          252                                               None
# 753       252       -252*.                                               None
# 715       252        -252.                                               None
# 757       253          253                                               None
# 721       253        -253.                                               None
# 722       254        -254.      [{'id': 'Mr_Kennedy', 'name': 'Mr. Kennedy'}]
# 758       254          254                                               None
# 792       255       -255*.                                               None
# 759       255          255                                               None
# 723       255        -255.         [{'id': 'Mr._Smith', 'name': 'Mr. Smith'}]
# 724       256        -256.  [{'id': 'John_Kempe', 'name': 'Mr. Kemp'}, {'i...
# 760       256          256                                               None
# 793       256       -256.*        [{'id': 'Mr_Dupuys', 'name': 'Mr. Dupuys'}]
# 725       257        -257.  [{'id': 'John_Conyers', 'name': 'Mr. Conyers'}...
# 761       257          257                                               None
# 794       257       -257*.                                               None
# 795       258       -258*.                                               None
# 762       258          258                                               None
# 726       258        -258.    [{'id': 'John_Conyers', 'name': 'Mr. Conyers'}]
# 727       259        -259.    [{'id': 'D_Woodward', 'name': 'Dr. Woodwards'}]
# 763       259          259                                               None
# 796       259       -259*.                                               None
# 728       260        -260.                                               None
# 797       260       -260*.                                               None
# 764       260          260                                               None
# 729       261        -261.                                               None
# 765       261          261                                               None
# 798       261       -261.*                                               None
# 799       262       -262*.                                               None
# 766       262          262                                               None
# 730       262        -262.         [{'id': 'D_Woodward', 'name': 'Woodward'}]
# 800       263       -263*.                                               None
# 767       263          263                                               None
# 731       263        -263.                                               None
# 801       264       -264*.                                               None
# 732       264        -264.                                               None
# 802       265       -265*.                                               None
# 733       265        -265.                                               None
# 734       266        -266.                                               None
# 803       266       -266*.                                               None
# 804       267       -267*.                                               None
# 735       267         267.                                               None
# 808       268       -268*.                                               None
# 736       268         268.                                               None
# 809       269        -269.                                               None
# 810       270        -270.                                               None
# 811       271        -271.                                               None
# 812       272        -272.                                               None
# 813       273         -273                                               None
# 814       274        -274.                                               None
# 815       275        -275.                                               None
# 816       276        -276.                                               None
# 817       277        -277.                                               None
# 818       278        -278.                                               None
# 819       279        -279.                                               None
# 820       280        -280.                                               None
# 821       281        -281.                                               None
# 822       282        -282.                                               None
# 823       283         283.                                               None
# 824       284        -284.                                               None
# 825       285        -285.                                               None
# 826       286        -286.                                               None
# 837       287        -287.                                               None
# 838       288        -288.                                               None
# 839       288        -288.                                               None
# 840       290        -290.                                               None
# 841       291         291.                                               None
# 842       292        -292.                                               None
# 843       293        -293.                                               None
# 844       294        -294.                                               None
# 845       295        -295.                                               None
# 846       296        -296.                                               None
# 847       297        -297.                                               None
# 848       298        -298.                                               None
# 849       299        -299.                                               None
# 850       300        -300.                                               None
# 851       301        -301.  [{'id': 'William_Stukely', 'name': 'Dr. Stukel...
# 852       302        -302.     [{'id': 'Mr._Stanley', 'name': 'Mr. Stanley'}]
# 853       303        -303.                                               None
# 854       304        -304.  [{'id': 'Sr._John_Colbatch', 'name': 'Sr. John...
# 863       305        -305.                                               None
# 864       306        -306.                                               None
# 865       307        -307.                                               None
# 866       308        -308.                                               None
# 867       309        -309.                                               None
# 868       310        -310.                                               None
# 869       311        -311.                                               None
# 870       312        -312.                                               None
# 871       313        -313.                                               None
# 872       314        -314.                                               None
# 873       315        -315.  [{'id': 'Sir_Griffith_Williams', 'name': 'Sr. ...
# 874       316        -316.                                               None
# 875       317        -317.                                               None
# 876       318        -318.                                               None
# 877       319        -319.                                               None
# 878       320        -320.                                               None
# 879       321        -321.                                               None
# 880       322        -322.                                               None
# 893       323        -323.                                               None
# 894       324        -324.                                               None
# 895       325        -325.                                               None
# 896       326        -326.                                               None
# 897       327        -327.                                               None
# 898       328        -328.                                               None
# 899       329        -329.  [{'id': 'Mr_Hildesley', 'name': 'Mr. Hildesley'}]
# 900       330        -330.                                               None
# 901       331        -331.                                               None
# 902       332        -332.                                               None
# 903       333        -333.                                               None
# 904       334        -334.                                               None
# 905       335        -335.                                               None
# 906       336        -336.                                               None
# 907       337        -337.                                               None
# 908       338        -338.                                               None
# 909       339        -339.                                               None
# 910       340        -340.                                               None
# 912       341        -341.                                               None
# 913       342        -342.                                               None
# 914       343        -343.                                               None
# 915       344        -344.                                               None
# 916       345        -345.                                               None
# 917       346        -346.                                               None
# 918       347        -347.                                               None
# 919       348        -348.                                               None
# 920       349        -349.                                               None
# 921       350        -350.                                               None
# 922       351        -351.                                               None
# 923       352        -352.                                               None
# 924       353        -353.                                               None
# 925       354        -354.                                               None
# 926       355        -355.                                               None
# 927       356        -356.                                               None
# 928       357        -357.                                               None
# 929       358        -358.                                               None
# 930       359        -359.                                               None
# 931       360        -360.                                               None
# 932       361        -361.                                               None
# 933       362        -362.                                               None
# 934       363        -363.         [{'id': 'D_Woodward', 'name': 'Woodward'}]
# 935       364        -364.                                               None
# 936       365        -365.                                               None
# 937       366        -366.                                               None
# 938       367        -367.                                               None
# 939       368        -368.                                               None
# 940       369        -369.                                               None
# 962       370        -370.                                               None
# 963       371        -371.                                               None
# 964       372        -372.                                               None
# 965       373        -373.                                               None
# 966       374        -374.                                               None
# 967       375        -375.                                               None
# 968       376        -376.                                               None
# 969       377        -377.                                               None
# 970       378        -378.                                               None
# 971       379        -379.                                               None
# 972       380        -380.                                               None
# 973       381        -381.                                               None
# 974       382        -382.      [{'id': 'Mr_Purnell', 'name': 'Mr. Purnell'}]
# 975       383        -383.                                               None
# 976       384        -384.        [{'id': 'Robert_Wood', 'name': 'Dr. Wood'}]
# 977       385        -385.                                               None
# 978       386        -386.                                               None
# 979       387        -387.                                               None
# 980       388        -388.                                               None
# 981       389        -389.                                               None
# 982       390         -390                                               None
# 983       391        -391.                                               None
# 1005      392        -392.                                               None
# 1006      393        -393.                                               None
# 1007      394        -394.                                               None
# 1008      395        -395.                                               None
# 1009      396        -396.                                               None
# 1010      397        -397.                                               None
# 1011      398        -398.                                               None
# 1012      399        -399.                                               None
# 1013      400        -400.  [{'id': 'Mrs_Dering, Mrs._Dering', 'name': 'Mr...
# 1014      401        -401.                                               None
# 1015      402        -402.                                               None
# 1016      403        -403.                                               None
# 1017      404        -404.  [{'id': 'Mrs_Standish', 'name': 'M rs. Standis...
# 1018      405        -405.    [{'id': 'D_Woodward', 'name': 'Dr. Woodwards'}]
# 1019      406        -406.      [{'id': 'D_Woodward', 'name': 'D. Woodward'}]
# 1020      407        -407.  [{'id': 'Mrs_Dering, Mrs._Dering', 'name': 'Mr...
# 1021      408        -408.                                               None
# 1022      409        -409.   [{'id': 'Lord_Pembroke', 'name': 'Lo Pembroke'}]
# 1023      410        -410.                                               None
# 1024      411        -411.                                               None
# 1025      412         412.                                               None
# 1046      412        -412.        [{'id': 'Mr_George', 'name': 'Mr. George'}]
# 1047      413         -413  [{'id': 'Mr_Maidstone, Mr._Maidstone', 'name':...
# 1048      414        -414.                                               None
# 1049      415        -415.                                               None
# 1050      416        -416.  [{'id': 'Soranzo', 'name': 'Soranzos'}, {'id':...
# 1051      417        -417.                                               None
# 1052      418        -418.                                               None
# 1053      419         -419                                               None
# 1054      420        -420.                                               None
# 1055      421        -421.                                               None
# 1056      422        -422.                                               None
# 1057      423        -423.                                               None
# 1058      424        -424.                                               None
# 1059      425        -425.                                               None
# 1060      426        -426.                                               None
# 1061      427        -427.                                               None
# 1062      428        -428.                                               None
# 1078      429        -429.  [{'id': 'Soranzo', 'name': 'Soranzo'}, {'id': ...
# 1079      430        -430.                                               None
# 1080      431        -431.                                               None
# 1081      432        -432.                                               None
# 1082      433        -433.                                               None
# 1083      434        -434.                                               None
# 1084      435        -435.  [{'id': 'Cromwell_Mortimer', 'name': 'Cr: Mort...
# 1085      436        -436.                                               None
# 1092      437        -437.  [{'id': 'Cromwell_Mortimer', 'name': 'C. Morti...
# 1093      438        -438.  [{'id': 'Sr_George_Rook', 'name': 'Sr. George ...
# 1094      439        -439.                                               None
# 1095      440        -440.                                               None
# 1103      441        -441.                                               None
# 1099      441         441.  [{'id': 'Cromwell_Mortimer', 'name': 'Cr. Mort...
# 1104      442        -442.                                               None
# 1105      443         -443  [{'id': 'William_Stukely', 'name': 'Wm. Stukel...
# 1106      444        -444.        [{'id': 'Mr_Leneve', 'name': 'Mr. Leneve'}]
# ...
# 247   -856. The same wt. a belly to contain much oil...
# 248   -857. A small flat lamp. wt. a concentric circ...
# 249   -858. The same wt. 854. only some ornamts. on ...
# 250     -859. The same wt. deep Sulci on it Id. E H 246
# 251         -860 The same adornd wt. other figures. Id.
# 252                         -861. The same wt. 852. Id.
# 264   -862. An open cup wt out any ears like a commo...
# 265                 -863. The same wt. one ear. Id. 246
# 266   -864. The same wt. a hollow furrow round its t...
# 267   -865. A small pott or vessell for ointments wt...
# 268   -866. Another red wt. leaves in black for Laur...
# 269   -867. Another wt. lines, balls, & lines black ...
# 270   -868. The same wt. 2 ears putt close to the mo...
# 271   -869. The same wt. 2 ears broken of its top. w...
# 272   -870. A small flatt bottle wt. one ear all bla...
# 273                        -871. Another. Id. EH 248. e
# 274      -872. Another wt. the ear different. Id. 248 e
# 275   -873. A larger bottle of the same kind adorned...
# 276   -874. The same wt. the mouth three cornered & ...
# 277   -875. The same call'd Guttus wt. Faustinas hea...
# 278   -876. The same wt. 806 p. 144. with the foot o...
# 279                    -877. 865. as befor. Id EH 248 e
# 280                           -878. The same lesser. EH
# 281   -879. A small entir urn or cup of the same wt....
# 292   -880 The head of an old man in red earth from ...
# 293                            -881 Serapis. Id. 248. e
# 294   -882. A very large bellied lachrimatory from t...
# 295                   -883. Another smaller. Id. 248. e
# 296                     -884 Another smaller Id. 248. e
# 297                            -885 Another. Id. 248. e
# 298                   -886. Another smaller. Id. 248. e
# 299                -887. Another very small. Id. 248. e
# 300              -888. Another very long. Id. 248. e EH
# 301          -889 Another of blewish marble. Id. 248. e
# 302            -890. Another of white alabaster. 248. e
# 303   -891. A smaller one of paler red earth wt. a b...
# 304   -892. The same wt. the belly furrowed & having...
# 305      893. The same wt. one ear painted . Id. 248. e
# 306   -894. A large bowl or salver on a pedestall wt...
# 307   -895. One lesser all black . Id. 248. a 248 e E H
# 308   -896. Another all black except & circles of re...
# 309         -897. The same lesser all black . Id. 248 a
# 310                 -898. Another lesser. Id. 248 a E H
# 311                     -899. One lesser. Id. 248 a E H
# 312   -900. The same sort of bowl adorned on the ins...
# 313           -901. The same wt. different ornamts. Id.
# 314           -902. The same wt. different figures. Id.
# 315                                     -903. The same.
# 325   -904. A black bowl of red earth lackerd or var...
# 326                        -905. Another. Id. 248 a E H
# 327                -906. Another larger. Id. 248. a E H
# 328   -907. A very large cup of the same wt. a pedes...
# 329               -908. The same lesser. Id. 248. a E H
# 330              -909. Another of gray earth. Id. 248 a
# 331                            -910 Another. Id. 248. a
# 332                    -911. Another lesser. Id. 248. a
# 333        -912. Another of the lesser. Id. E H 248 a a
# 334   -913. A jugg wt. a three cornered mouth & orna...
# 335   -914. The same wt. the belly ribbd. Id. E H 248 a
# 336          -915. The same a differen form. Id. 248. a
# 337   -916. The same lesser wt. a round mouth. Id & ...
# 338   -917. A plain small one eard bottle of the sam...
# 339   -918. The same. Id. Prœfericulum vid Monfaucon...
# 340   -919. The same wt. a very large belly. Id. 248. a
# 341        -920. The same wt. lines on its belly 248. a
# 342   -921. A lamp wt. one ear on its top. Id. E H 2...
# 343   -922. A one eard wide mouthd vessell for ointm...
# 344   -923. A porringer wt. two 4 cornered horizonta...
# 345         -924. Twelve marble weights. Id. 199 e 19 m
# 346   -925. A busto of wt. the head dresse very inti...
# 347   -926. Another wt. a different head dresse. Id....
# 348                       -927. Another different Id. ✓
# 356   -928. The head of a man in red earth wt. his h...
# 357   -929. A small brick perforated & quadrangular ...
# 358              -930. Another. Id. 248. d A.W.F. 1852.
# 359   -931. A head of a woman wt a head dresse diffe...
# 360   -932. Another different in whitish earth. Id. ...
# 361             -933. A veiled priests head. Id. 248. d
# 362   -934. A head of a woman in red terra cotta wt ...
# 363   -935. A veiled busto in whitish terra cotta. I...
# 364   -936. A figure of Ceres? Standing her left han...
# 365   -937. _____ of ------- having in her left hand...
# 366   -938. _____ of ----- having in her left hand I...
# 367                           -939. _____ of Id. 248. d
# 368   -940. _____ of victory holding on its head Ser...
# 369   -941. _____ of holding a palm branch on its le...
# 370             -942. _____ of a woman ----- Id. 248. d
# 371                       -943. _____veiled. Id. 248. d
# 372   -944. ----- of a man holding wt. both hands up...
# 381   -945. A figure in red terra cotta in his left ...
# 382                -946. A Ægyptian figure of Id. 248 d
# 383                         -947. Another of Id. 248. d
# 384                          -948. _____ of . Id. 248 d
# 385                          -949 _____ of in Id. 248 d
# 386   -950. _____ of wt with a modium upo his head. ...
# 387   -951. A veiled figure of a woman sitting. Id. ...
# 388                            -952. Another. Id. 248 d
# 389   -953. Another wt. a wheel in the right hand Id...
# 390        -954. The same wt. some variations. Id 248 d
# 391   -955. Two of the same figures sitting wt wheel...
# 392   -956. Two of the same wt. a child between thei...
# 393   -957. _____ on one of their laps Id vid Montfa...
# 394   -958. Two bustos on the same pedestall wt. a b...
# 395   -959. Three figures sitting on the same pedest...
# 396   -960. _____ The midle one as if the mother of ...
# 397            -961. A decumbent figure on a couch. Id.
# 407   -962. One figure wt. the head of another faste...
# 408   -963. A head wt. 2 faces & a crescent at top r...
# 409                             -964. A cow. Id. 248. d
# 410   -965. A bird Id. Vid. Montfaucon Supp. tom. 2 ...
# 411   -966. A small round bottle in a round figure &...
# 412   -967. A lachrimatory small at the ends & swell...
# 413   -968. A lachrymatory of serpentine stone Id. 2...
# 414   -969. _____ of red terra cotta wt. the bulb. a...
# 415     -970. A Gorgons head in gray clay bakd. Id. 250
# 416                                -971. A mash Id. 250
# 417              -972. Halfe a face in relievo. Id. 250
# 418            -973. _____ in basso r p elievo. Id. 250
# 419   -974. An old lamp of gray clay wt. four leaves...
# 420         -975. _____ wt. a victory on it. Id. 250. X
# 421              -976. _____ two figures of men. Id 250
# 422   -977. _____ of red earth at top a man on haft ...
# 423   -978. _____ A bachus at top at bottom C. Jul. ...
# 424   -979. _____ two dolphins at top. at bottom. Cl...
# 435   -980. A Roman Lamp of red earth wt. a leopard ...
# 436   -981. _____ wt. a stag at top. Id. A.W.F. 1852...
# 437         -982. _____ The same. Id. 250 A.W.F. 1852 X
# 438   -983. _____ wt. a lion. Id &c. wt Letters defa...
# 439               -984. wt. a dog on its top. Id. 250 X
# 440         -985. _____ wt 2 people fighting. Id. 250 X
# 441                     -986. _____ wt. a mask. Id. 250
# 442                  -987. _____ wt. Europa &c. Id. 250
# 443   -988. _____ wt. 2 victories standing Id. on th...
# 444   -989. _____ wt. an augurs & a vessell Id. at b...
# 445       -990. _____ four leaves at top. Id. E H 250 X
# 446   -991. _____ wt. a corona laureal top. Id. E H ...
# 447   -992. _____ quercea at top. Id. OP E H 250 A.W...
# 448   -993. _____ a hare eating a bunch of grapes. I...
# 449   -994. _____ a Galley & a boy in it. Id. 250 A....
# 450   -995. _____ Victory holding a crown in his rig...
# 451          -996. _____ The same. Id. 250 A.W.F. 1852.
# 452   -997. _____ wt. a figure standing holding on h...
# 453   -998. _____ cupid & his bow on the top &c. & u...
# 454     -999. _____ wt. a figure holding a globe. Id. X
# 455   -1000. _____ wt. Cupid & minerva. at top & ___...
# 464   -1001. An ancient Roman lamp. of pale red eart...
# 465   -1002. _____ wt. an ol a broken figure on the ...
# 466   -1003 1004. _____ wt. figures not distinct at ...
# 467   -1004. 250. _____ wt. points disposed regularl...
# 468   -1005. The figure of a woman gradient wt. a ma...
# 469   -1006. A womans left a Volun hand in gray clay...
# 470         -1007. Another. A mans left hand Id. id 250
# 471   -1008. A mask wt. a moduis upon the head. Id. 250
# 472                             -1009. Another. Id. 250
# 473                   -1010. A third different. Id. 250
# 474   -1011. A lamp in the form of a bird. Id. 250 A...
# 475                     -1012. _____ a mans shoe Id 250
# 476   -1013. _____ a womans shoe. Id. wt. a vine wt....
# 477   -1014. _____ of a mouse inlaid wt. turchoises ...
# 478      -1015. An old mans head in clay stone. Id. 250
# 479             -1016. A boys head in the same. Id. 250
# 480           -1017 8. A mans head in white marble. 250
# 481   -1018. A diademated head in parian marble or a...
# 482   -1019. A boys head knockd of of another. Id hu...
# 483               -1020. A Girles head in the same. Id.
# 484                  -1021. A boys head in the same Id.
# 485         -1022. Jupiter Hammon? in the same. Id. 250
# 494   -1023. 1024 A bak'd earth Roman lamp wt a mask...
# 495   -1024. A Gorgons head wt. points around it on ...
# 496   -1025. A bulls head on the upper part & ----- ...
# 497   -1026. A busto of Mercury wt. his wings at top...
# 498   -1027. A very small plain lamp without any ins...
# 499   -1028. The same in white earth wt. lines on. i...
# 500   -1029. A very plain Roman lamp, small & having...
# 501   -1030. _____ wt. 2 wide holes & 2 handles. Id....
# 502   -1031. _____ a busto on the upper part & under...
# 503   -1032. _ A large lamp of red earth wt. Jupiter...
# 504    -1033. __Two wrestlers on the upper side Id. 250
# 505   -1034. _____ a figure having upon his back a _...
# 506   -1035. _____ having on the upper side a vase 2...
# 507   -1036. _____ a head upon a _____ hasta &c Id. ...
# 508   -1037. 1038 _____ a prickly fish. Id. A.W.F. 1...
# 509   -1038. _____ a hare feeding under side IMARMI....
# 510   -1039. _____ sheep feeding a tree before them ...
# 519   -1040. A Roman lamp of red bak'd earth on the ...
# 520   -1041. _____ wt. a figure walking having on hi...
# 521   -1042. _____cupid sitting playing upon a __ Id...
# 522   -1043. _____ a figure &c ----- within a -- Cor...
# 523   -1044. The same wt. 1035. underside has LEABAR...
# 524   -1045. A large red clay Roman lamp wt. a Coron...
# 525   -1046. _____ bust of a mask on the upper side ...
# 526   -1047. _____ An eagle wt. a caduceus &c. Id. E...
# 528   -1048. _____ the figure of the sun in a radiat...
# 527   -1048. _____ A figure sitting on -.-- on the u...
# 529   -1049. _____ a Dog following an hare. Id. E H ...
# 530             -1050. _ A dog following a hare. Id 250
# 531   -1051. _____ An eagle, on the under side CLO.H...
# 532   -1052. _____ 1026. in his left a mask - letter...
# 533   -1053. _____ a gladiator. underside TITVE- E H...
# 534   -1054. _____ very small a small figure in a co...
# 535   -1055. _____ a Cupid on a couch, underside ΛEL...
# 536   -1056. _____ Hercules sitting his club in his ...
# 546   -1057. A Roman lamp of red terracotta on the u...
# 547   -1058. _____ a busto on the DVNMANIATS. Id. 250 X
# 548   -1059. __ A figure riding upon a dolphin under...
# 549   -1060 _____ of 6 leaves on the upper side Id. ...
# 550   -1061. _____ of 2 palm leaves upon one deep & ...
# 551   -1062. _____ wt. one ear rising in the midle &...
# 552   -1063. _____ wt. a corona laurea &on. the uppe...
# 553   -1064. _____ a mask wt. a corona quercea Id. w...
# 554   -1065. _____ 1061. cover'd all over with palm ...
# 555       -1066. _____ The same wt. 1061. Id. E H 250 X
# 556   -1067. _____ The sun wt. on the underside ERAC...
# 557   -1068. _____ Castor & pollux underneath L ____...
# 558   -1069. _____ two palm leaves or branches. Id. ...
# 559   -1070. _____ disposd otherways. Id E H 250 A.W...
# 560         -1071. _____ wt. a corona laurea. Id. 250 X
# 561   -1072. _____ wt. double circles of leaves at t...
# 562   -1073. _____ wt. Herennia Porviva Sin &c. on t...
# 563   -1074. _____ a cupid sitting underside has Sen...
# 564   -1075. _____ Mens at work underneath. Florent....
# 565   -1076. _____ Three figures round wch. a corona...
# 566   -1077. _____ 1059. underneath. CLo. Hel. Id. E...
# 567   -1078. _____ Jupiter Sitting underneath _____ ...
# 568   -1079. _____ A bega wt. 2 lions? _____ Hel. Id...
# 569      -1080. _____ security sitting wt. in his Id. X
# 570   -1081. _____ A bird sitting on a branch of lau...
# 579   -1082. An Etruscan or Roman lamp on the concav...
# 580   -1083. _____ wt. in 2 borders one of straight ...
# 581   -1084. _____ with a scallop on its upper side....
# 582   -1085. _____ a Cupid on the upper part. C.oppi...
# 583   -1086. 1886 _____ A mask --- wt. on the upper ...
# 584   -1087. _____ A horse with a groom &c. --- Id. ...
# 585   -1088. _____ A figure wt. 2 hands stretched ou...
# 586   -1089. _____ Dolphin & anchor on the upper sid...
# 587     -1090. _____ Two gladiators fighting. Id. 250 X
# 588   -1091. _____ Three doggs killing a Stagg. Id. ...
# 589   -1092. _____a figure holding out in his right ...
# 590   -1093. _____ Anchises carrying Æneas, on the u...
# 591   -1094. _____ Castor & Pollux wt. 2 crosses for...
# 592   -1095. _____ A dogg upon a swine. Id. E H 250 ...
# 593   -1096. _____ A victory carrying trophies under...
# 604   -1097. A Roman red earth bak'd lamp wt. Bachus...
# 605   -1098. _____ wt. a horse running on the top & ...
# 606   -1099. _____ A figure carrying a torch - on th...
# 607   -1100. _____ a figure standing wt. in his arms...
# 608   -1101. _____ A radiated figure holding in his ...
# 609   -1102. _____ A large deep lamp wt. a corona la...
# 610   -1103. _____ >gradient figure under munt ---- ...
# 611   -1104. _____ wt. 2 nozzles underneath N in a c...
# 612          -1105. A boy riding on a dolphin E H 250 X
# 613   -1106. _____ A victory pouring Something into ...
# 614   -1107. _____ Two figures in a Corona & underne...
# 615   -1108. _____ A rabbet feeding on the other sid...
# 616   -1109. _____ Two wrestlers underneath ---- Id....
# 628   -1110. A lamp wt. upon its upper part figure s...
# 629   -1111. _____ a dolphin & Id. E H 250 A.W.F. 18...
# 630   -1112. _____ a figure standing under Flor ent ...
# 631   -1113 _____ within a radiated border & concent...
# 632   -1114. A small brasse statue of a man standing...
# 633              -1115. A dog? walking. Id. brasse. 220
# 634   -1116. A busto of Mercury? Brasse. Id. Vid. Mo...
# 635   -1117. A punch? Minus. Id. markd formerly 534 220
# 636   1118. A brass Handle of some old Vessel, to wh...
# 637   1119. An ibis preserved by the Ægyptians in an...
# 657   1120. 1. An black ebbany Cabinet where= in are...
# 658   1121. Pieces of gray earthen Roman Urns found ...
# 679   1122. One page of an Ancient Book such as is m...
# 680   1123. Model in Lead of 2 antique gold Rings fo...
# 681   1124 Urns Estruscan wt. covers &c vid Antea Mo...
# 682   1125. The Model of a Brasse Celta wt. a loop f...
# 683   1126. Gallia me genuit nomen mitis divitis und...
# 699   1127. A blew flower an Hyacinth Modern made at...
# 700   1128 Two cherries? Antique found at Adrians Vi...
# 701                       1129 A Bird from the same. id

# %% [markdown]
# #### Find duplicate entries

# %%
# Find duplicates
df2.duplicated(subset=['num_int']).value_counts()
# Out:
# False    1128
# True      151
# dtype: int64
