# %% [markdown]
# # Sloane Lab XML Parser

# %% [markdown]
# This notebook parses the TEI XML files from the Enlightenment Architectures project, extracts the data that we want to import into the Sloane Lab knowledge base, and checks if there are any errors or inconsistencies.

# %% [markdown]
# #### Import libraries

# %%
# -*- coding: future_fstrings -*-
import os
import re
import sys
import urllib
import titlecase
import pandas as pd

import rdflib
from rdflib import Namespace, URIRef, BNode, Literal
from rdflib.namespace import RDF, RDFS, OWL, XSD

from viapy import api
from bs4 import BeautifulSoup as Soup
from mapboxgl.utils import *
from mapboxgl.viz import *

from matplotlib import *
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### XML File path

# %%
# XML file path
XML_PATH = 'data/fossils_v.xml'

# %% [markdown]
# #### Function to handle catalogue numbers

# %%
# Function to transform the catalogue number to an integer
def cat_to_int(catnum):
    catnum = re.search('\d+', catnum)
    if catnum:
        return int(catnum.group(0))
    return None

# %% [markdown]
# #### Load all catalogues and their entries

# %%
# Open the XML file
with open(XML_PATH) as xml_file:

    # Read the file
    xml = xml_file.read()
    
    # Parse the file
    parsed_xml = Soup(xml, 'lxml')
    
    # Create empty list of people
    people_list = []
    
    # Create empty list of places
    place_list = []
    
    # For each person in the XML list...
    for person in parsed_xml.find('listperson').find_all('person'):

        # Create dictionary with person's internal ID
        person_dict = {'id': person['xml:id']}
        
        # Find the person's external IDs
        person_ids = person.find_all('idno')
        
        # For each external ID...
        for person_id in person_ids:

            # If the type of ID is VIAF...
            if person_id['type'] == 'viaf':
                
                # Add VIAF ID to person dictionary
                person_dict['viaf'] = person_id.text 
 
            # Otherwise, print person
            else:
                print(person)
 
        person_dict['names'] = [x.text for x in person.find_all('persname')]

        # Add the dictionary to the list
        people_list.append(person_dict)
    
    # For each place in the XML list...
    for place in parsed_xml.find('listplace').find_all('place'):
        
        # Create dictionary with place's internal ID
        place_dict = {'id': place['xml:id']}

        # Find the person's external IDs
        place_ids = place.find_all('idno')
        
        # For each external ID...
        for place_id in place_ids:
            
            # If the type of ID is VIAF...
            if place_id['type'] == 'viaf':
            
                # Add VIAF ID to place dictionary
                place_dict['viaf'] = place_id.text

            # If the type of ID is GEO...
            elif place_id['type'] == 'geo':
                
                try:
                    # Extract latitude and longitude
                    lat, lon = place_id.text.split(',')
                
                    # Add latitude to place dictionary
                    place_dict['lat'] = float(lat.strip())
                
                    # Add longitude to place dictionary
                    place_dict['lon'] = float(lon.strip())
                except:
                    print(place)
                
            # Otherwise, print place
            else:
                print(place)
        
        place_dict['names'] = [x.text for x in place.find_all('placename')]
            
        # Add the dictionary to the list
        place_list.append(place_dict)

# Open the JSON file
#with open("out/people.json", "w") as people_file:
#    json.dump(people_list, people_file)

# Open the JSON file
#with open("out/places.json", "w") as places_file:
#    json.dump(place_list, places_file)
# Out:
# <place xml:id="Eichstadt">
# <placename>Eichstadt</placename>
# <idno type="viaf">124967002</idno>
# <idno type="geo"> 124967002</idno>
# </place>
# <place xml:id="Hispaniola">
# <placename>Hispaniola</placename>
# <placename>wreck on the coast of Espanola</placename>
# <idno type="viaf">242111207</idno>
# <idno type="geo"> failed</idno>
# </place>
# <place xml:id="Katzenelnbogen">
# <placename>Country of Catzellenbogen &amp; belonging to the Landgrave of Hesse cassell,
#        northward of Mayence</placename>
# <idno type="viaf">129154192 </idno>
# <idno type="geo"> 50.26745,†7.97322</idno>
# </place>
# <place xml:id="Manila">
# <placename>Maniglia in the East Indies </placename>
# <idno type="viaf">128902416</idno>
# <idno type="geo"> 14.6042,†120.9822</idno>
# </place>
# <place xml:id="Melo_Island">
# <placename>Melo Island</placename>
# <idno type="geo"> 11.03333,†-15.21667</idno>
# </place>
# <place xml:id="New_England">
# <placename>New England</placename>
# <idno type="geo"> 44,†-71</idno>
# </place>
# <place xml:id="Oundle">
# <placename>Oundle</placename>
# <idno type="viaf">308719648 </idno>
# <idno type="geo"> 308719648 </idno>
# </place>
# <place xml:id="River_Craven">
# <placename>river above Ingleton in Craven</placename>
# <idno type="viaf">138642187</idno>
# <idno type="geo"> 54.15392,†-2.46849</idno>
# </place>
# <place xml:id="Santa_Maria_Campeche">
# <placename>Sta Maria near Campeche</placename>
# <idno type="viaf">136049224</idno>
# <idno type="geo"> 18.83333,†-90.25</idno>
# </place>
# <place xml:id="Surentum">
# <placename>Surentum</placename>
# <idno type="viaf">154773300</idno>
# <idno type="geo"> 47.51,†6.8</idno>
# </place>
# <place xml:id="Wolfenbuettel">
# <placename>Asse in Wolfembatle</placename>
# <placename>Wolfem =butle</placename>
# <idno type="viaf">140714405</idno>
# <idno type="geo"> 52.16442,†10.54095</idno>
# </place>

# %%
# List of catalogues
cats = []

# Open the XML file
with open(XML_PATH) as xml_file:

    # Find all catalogues in the manuscript
    catalogues = parsed_xml.find_all('div2')
    
    print(len(catalogues))
    
    prevDict = {}
    
    pageNum = "NHM-UK_L_433034_001a"
    prevPageNum = None
    prevParent = None
    force = False
    
    # For each catalogue...
    for catalogue in catalogues:
        
        # Create catalogue dictionary
        cat_dict = {}
        
        # Create list of entries
        cat_dict['entries'] = []
        
        # Get catalogue title
        cat_dict['title'] = catalogue.find('label').text
        
        # Find all entries in the catalogue
        entries = catalogue.find_all('div3')
    
        # For each entry...
        for entry in entries:
            
            # Get number of entry
            catnum = entry.find('ea:catnum').get_text() if entry.find('ea:catnum') else None
            
            # Get people
            people = entry.find_all('persname')
            
            # Get places
            places = entry.find_all('placename')
            
            # Create entry dictionary
            entry_dict = {
                'num_str': ' '.join(catnum.split()) if catnum else None,
                'num_int': cat_to_int(catnum) if catnum else None,
                'text': ' '.join(entry.text.split()),
                'people': [{'id': x['ref'].strip('#') if 'ref' in x.attrs else None, 'name': ' '.join(x.text.split())} for x in people] if people else None,
                'places': [{'id': x['ref'].strip('#') if 'ref' in x.attrs else None, 'name': ' '.join(x.text.split())} for x in places] if places else None
            }
        
            # Append entry to entry list
            cat_dict['entries'].append(entry_dict)
        
        # Append catalogue to catalogue list
        cats.append(cat_dict)
# Out:
# 4

# %% [markdown]
# #### How many people in the list?

# %%
len(people_list)
# Out:
# 2706

# %% [markdown]
# #### How many places in the list?

# %%
len(place_list)
# Out:
# 553

# %% [markdown]
# #### How many catalogues?

# %%
# Print number of catalogues
len(cats)
# Out:
# 4

# %% [markdown]
# #### What are their titles?

# %%
# Print all catalogue titles
[x['title'].strip() for x in cats]
# Out:
# ['Fishes.', 'Birds.', 'Eggs.', 'Quadrupeds.']

# %% [markdown]
# #### What are their lengths?

# %%
# Compute catalogue lengths
for x in cats:
    x['length'] = len(x['entries'])

[x['length'] for x in cats]
# Out:
# [1606, 964, 257, 1956]

# %% [markdown]
# #### Transform the list of catalogues into a dataframe

# %%
cat_df = pd.DataFrame(cats)
cat_df
# Out:
#                                              entries        title  length
# 0  [{'num_str': '-1484.', 'num_int': 1484, 'text'...      Fishes.    1606
# 1  [{'num_str': None, 'num_int': None, 'text': '1...       Birds.     964
# 2  [{'num_str': None, 'num_int': None, 'text': '2...        Eggs.     257
# 3  [{'num_str': None, 'num_int': None, 'text': '2...  Quadrupeds.    1956

# %% [markdown]
# #### Display the lengths of the catalogues

# %%
plt.figure(figsize=(14,6))
plt.xticks(range(30), rotation='vertical')
plt.bar(cat_df['title'],cat_df['length'])
plt.show()

# %% [markdown]
# #### First catalogue: Coralls

# %%
# Check first catalogue
cats[0]
# Out:
# {'entries': [{'num_str': '-1484.',
#    'num_int': 1484,
#    'text': '-1484. A very large sharks jaw from the coast of Guinea. 241 f <',
#    'people': None,
#    'places': [{'id': 'Guinea', 'name': 'Guinea'}]},
#   {'num_str': '-1485.',
#    'num_int': 1485,
#    'text': '-1485. A wholes eye from Capt. Craycoot. m. 7',
#    'people': [{'id': None, 'name': 'Capt. Craycoot.'}],
#    'places': None},
#   {'num_str': '-1486.',
#    'num_int': 1486,
#    'text': '-1486. Bones from the heads of fishes small. P. 221. i.',
#    'people': None,
#    'places': None},
#   {'num_str': '-1487.',
#    'num_int': 1487,
#    'text': '-1487. 22 W larger. 221. i.',
#    'people': None,
#    'places': None},
#   {'num_str': '-1488.',
#    'num_int': 1488,
#    'text': '-1488. Dentes raiæ. 221. i.',
#    'people': None,
#    'places': None},
#   {'num_str': '-1489.',
#    'num_int': 1489,
#    'text': '-1489. Lapides e capite carpionum. L. 221. i.',
#    'people': None,
#    'places': None},
#   {'num_str': '-1490.',
#    'num_int': 1490,
#    'text': "-1490. Ova piscium petrefacta. mark'd 382. 221. i.",
#    'people': None,
#    'places': None},
#   {'num_str': '-1491.',
#    'num_int': 1491,
#    'text': '-1491. The sword of a sword fish, rough rounder & brown. 221. i',
#    'people': None,
#    'places': None},
#   {'num_str': '-1492.',
#    'num_int': 1492,
#    'text': '-1492. 22 w A small dog fish, from D r. Massy. in Sp. V. n. 7',
#    'people': [{'id': None, 'name': 'D r. Massy.'}],
#    'places': None},
#   {'num_str': '-1493.',
#    'num_int': 1493,
#    'text': '-1493. 1. polypus 2. A serpens marinus or tenia from M r. Edgcomb from near Plymmouth in Sp. V. n 7.',
#    'people': [{'id': None, 'name': 'M r. Edgcomb'}],
#    'places': [{'id': 'Plymouth', 'name': 'Plymmouth'}]},
#   {'num_str': '-1494.',
#    'num_int': 1494,
#    'text': '-1494. 1. A weaver. 2. Lumpus? w t. its eggs. 3. A monstrous Batata resembling a human body. in Sp V n. 7',
#    'people': None,
#    'places': None},
#   {'num_str': '-1495.',
#    'num_int': 1495,
#    'text': '-1495. cheple One of the round bones between the Vertebres of a whale 239',
#    'people': None,
#    'places': None},
#   {'num_str': '-1496.',
#    'num_int': 1496,
#    'text': '-1496. chaple Another wt. the cartilage going between both thrown uppon the Island of Bermudas by a Storm 239.',
#    'people': None,
#    'places': [{'id': 'Bermudas', 'name': 'Bermudas'}]},
#   {'num_str': '-1497.',
#    'num_int': 1497,
#    'text': '-1497. Ossa carpioaum. 221 i.',
#    'people': None,
#    'places': None},
#   {'num_str': '-1498.',
#    'num_int': 1498,
#    'text': '-1498. An egg w t. its appendices taken out of the belly of a dog fish. at Cows. Pet. 221. i.',
#    'people': None,
#    'places': None},
#   {'num_str': '-1499.',
#    'num_int': 1499,
#    'text': '-1499. A small palat of an orbis. P. 221. l',
#    'people': None,
#    'places': None},
#   {'num_str': '-1500.',
#    'num_int': 1500,
#    'text': '-1500. Testapiscis Catcher dicta Cun. P. 162. g. 221. i',
#    'people': None,
#    'places': None},
#   {'num_str': '-1501.',
#    'num_int': 1501,
#    'text': '-1501. The bone of a fish. 221. i',
#    'people': None,
#    'places': None},
#   {'num_str': '1502.',
#    'num_int': 1502,
#    'text': '1502. The Sceleta of fishes in a blackislate from er Garnet Pet N o. 5 - N o. 68 P. 17',
#    'people': None,
#    'places': None},
#   {'num_str': '1.',
#    'num_int': 1,
#    'text': '3 Fishes. 1. Canis Carchariæ alt. Spec. u. p. + n. c. 2. 6 d d. Worm. p. 271.',
#    'people': None,
#    'places': None},
#   {'num_str': '2.',
#    'num_int': 2,
#    'text': '2. Canis Carchariæ pinna. 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '3.',
#    'num_int': 3,
#    'text': '3. Canis Carchariæ cauda. 4 f < 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '4.',
#    'num_int': 4,
#    'text': '4. Canis Carchariæ mandibulæ. f < 241 &c',
#    'people': None,
#    'places': None},
#   {'num_str': '5.',
#    'num_int': 5,
#    'text': '5. A black slate with the impression of a fish upon it. The Scales appear & some armatura or pyrites. An Lapis fissilis Islebiams. 222. a',
#    'people': None,
#    'places': None},
#   {'num_str': '6.',
#    'num_int': 6,
#    'text': '6. A white slate with the impression of a small fish upon it. From mount Lebanon. 222. c',
#    'people': None,
#    'places': [{'id': None, 'name': 'mount Lebanon'}]},
#   {'num_str': '7.',
#    'num_int': 7,
#    'text': '7. Faber Salviani. Will. tab. S. i6. + f < 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '8.',
#    'num_int': 8,
#    'text': '8. Piscis triangularis cornutus Clusÿ: Will. tab. J. 14. + b 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '9.',
#    'num_int': 9,
#    'text': '9. Rana piscatrix Salviani. Will. tab. E. 1. + Charlton p. 73. Worm p. 27. Loppius Arled. 241',
#    'people': None,
#    'places': None},
#   {'num_str': '10.',
#    'num_int': 10,
#    'text': '10. Ranæ piscatricis caput. Ib. + 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '11.',
#    'num_int': 11,
#    'text': '11. Idem. N o. 8. lesser. + f ÿ 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '12.',
#    'num_int': 12,
#    'text': '12. An Muræna Salviani. Tab. G. 1. Will? a 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '13.',
#    'num_int': 13,
#    'text': '13. An Serpentis Marini caput. Will. tab. G. 4? f < 241',
#    'people': None,
#    'places': None},
#   {'num_str': '14.',
#    'num_int': 14,
#    'text': '14. Testudo marina. Jonst. tab. 8. N o. 8. ad quadraped 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '15.',
#    'num_int': 15,
#    'text': '15. The Sun fish. Mola Salviani. tab. J. 26. Will. +',
#    'people': None,
#    'places': None},
#   {'num_str': '16.',
#    'num_int': 16,
#    'text': '16. The taile of a young Albacore. f < 241.&',
#    'people': None,
#    'places': None},
#   {'num_str': '17.',
#    'num_int': 17,
#    'text': '17. Zygæna Salviani. Will. tab. B. 1. The balance fish. + 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '-1503.',
#    'num_int': 1503,
#    'text': '3a -1503. A young remora A silver fish from china A young shark A scolopendra from China. from M r. Hodgson. m Sp. V. 7. m.',
#    'people': [{'id': None, 'name': 'M r. Hodgson.'}],
#    'places': [{'id': 'China', 'name': 'China'}]},
#   {'num_str': '1504.',
#    'num_int': 1504,
#    'text': '1504. 225. mm 22 W Dog fish teeth &c from the chalk pitts in Kent 221. w.',
#    'people': None,
#    'places': [{'id': 'Kent', 'name': 'Kent'}]},
#   {'num_str': '1505.',
#    'num_int': 1505,
#    'text': '1505. The vertebra of a shark black on the out side & wi thin chalk Id. 221. w',
#    'people': None,
#    'places': None},
#   {'num_str': '1506.',
#    'num_int': 1506,
#    'text': "1506. Two s tickle backs from Hampshire w t. round knobbs like pease of a pearl. colour w ch. kill'd them from Niece sloane in Sp. V. o-3",
#    'people': [{'id': None, 'name': 'Niece sloane'}],
#    'places': [{'id': 'Hampshire', 'name': 'Hampshire'}]},
#   {'num_str': '1507.',
#    'num_int': 1507,
#    'text': '1507. 37. 22 W. Ad Glossopotra sent me from Joh. Petrus Tschudius from the Canton of Glaris in Swisserland',
#    'people': None,
#    'places': [{'id': 'Switzerland', 'name': 'Swisserland'}]},
#   {'num_str': '1508.',
#    'num_int': 1508,
#    'text': '1508. 37. Piscis diluviani sceleton fossili in Lapide Glaronens. Idem',
#    'people': None,
#    'places': None},
#   {'num_str': '1509',
#    'num_int': 1509,
#    'text': '1509 37. Ichtyites 6 in Lapide fossili nigro Glaronens. Idem.',
#    'people': None,
#    'places': None},
#   {'num_str': '1510 1500',
#    'num_int': 1510,
#    'text': '1510 1500 The bone of some Fish? Vid Antea 221 e',
#    'people': None,
#    'places': None},
#   {'num_str': '1511',
#    'num_int': 1511,
#    'text': '1511 Teeth or bones? vid. Antea vid. 433. 221 e',
#    'people': None,
#    'places': None},
#   {'num_str': '18.',
#    'num_int': 18,
#    'text': '4 18. Galeus Glaucus. Will. tab. 8. B. + 4 The blewshar',
#    'people': None,
#    'places': None},
#   {'num_str': '19.',
#    'num_int': 19,
#    'text': '19. Pristis sive serra Clusÿ. Will. tab. + B. 9. fig. 5. Worm. p. 288. a 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '20.',
#    'num_int': 20,
#    'text': '20. Rostrum delphini, Will. tab. A. 1. f < 241',
#    'people': None,
#    'places': None},
#   {'num_str': '21.',
#    'num_int': 21,
#    'text': '21. Squatino-raia. F. cl. Column. Will. + tab. D. 5. N o. 1. b 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '-22.',
#    'num_int': 22,
#    'text': '-22. EjuDem. Caput? from M r. Maidstone. from Virginia? Shagreen. Rays head. f < 241.',
#    'people': [{'id': None, 'name': 'M r. Maidstone.'}],
#    'places': [{'id': None, 'name': 'Virginia'}]},
#   {'num_str': '23.',
#    'num_int': 23,
#    'text': '23. Guacuima Brasil Will. tab. E. 2. + fig. 3. b 241. &c',
#    'people': None,
#    'places': None},
#   {'num_str': '24.',
#    'num_int': 24,
#    'text': '24. Lampetra major Salv. Will. tab. + G. 2. A Lamprey from the Severn. b 241.',
#    'people': None,
#    'places': [{'id': None, 'name': 'Severn'}]},
#   {'num_str': '25.',
#    'num_int': 25,
#    'text': '25. Iperuquiba Brasiliensibus. Will. tab. + G. 8? a. f < 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '26.',
#    'num_int': 26,
#    'text': '26. Lupus marinus Schonfeldÿ. Will. + tab. H. 3. N o. 1. Worm p. 275 Ex Piscis hujus dentiby molaribus fingere solent Gemmarÿ frandulent lapide Bufonio magno diverdere Pretio 241 f <',
#    'people': None,
#    'places': None},
#   {'num_str': '27.',
#    'num_int': 27,
#    'text': '27. Pristis sive Serræ Serra Will. tab. + B. 9. fig. 5. b 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '28',
#    'num_int': 28,
#    'text': '28 An Orbis Salvian. Primus. Rond. Will. + tab. J. 1? 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '29.',
#    'num_int': 29,
#    'text': '29. Orbis hirsutus densis & exiquis muric= =ibus donatus. Will. tab. J. 3. 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '30.',
#    'num_int': 30,
#    'text': '30. Histrix piscis Clusÿ Guamajacu Guara + Brasiliensibus an orbis muricatus primus & alter Clusÿ. Will. tab. J. 5. vid. seg. f ✓ CLXXVII',
#    'people': None,
#    'places': None},
#   {'num_str': '*1484. *1404',
#    'num_int': 1484,
#    'text': '4a *1484. *1404 22 X A long yellowish bufornites. 221 c',
#    'people': None,
#    'places': None},
#   {'num_str': '*1485.',
#    'num_int': 1485,
#    'text': '*1485. 22 X blackish 221. dd 221 c',
#    'people': None,
#    'places': None},
#   {'num_str': '*14',
#    'num_int': 14,
#    'text': '*14 The tongue of a nari nari blackish from Maryland one joint. fossil A fishes eye. 221 c',
#    'people': None,
#    'places': [{'id': 'Maryland', 'name': 'Maryland'}]},
#   {'num_str': '*1487.',
#    'num_int': 1487,
#    'text': '*1487. An operculum or umbilicas marinus. 221 i',
#    'people': None,
#    'places': None},
#   {'num_str': '*1488.',
#    'num_int': 1488,
#    'text': '*1488. A large sceleton of a fishes head 221. ff',
#    'people': None,
#    'places': None},
#   {'num_str': '*1489.',
#    'num_int': 1489,
#    'text': '*1489. Cataphractus Brasilianus? 221 ff',
#    'people': None,
#    'places': None},
#   {'num_str': '*1490.',
#    'num_int': 1490,
#    'text': '*1490. The severall bones of the two ch ap aps of a 221 ff',
#    'people': None,
#    'places': None},
#   {'num_str': '*1491.',
#    'num_int': 1491,
#    'text': '*1491. Sev ll. chaps of the lupus pisai. 221 ff',
#    'people': None,
#    'places': None},
#   {'num_str': '*1492.',
#    'num_int': 1492,
#    'text': '*1492. sev ll. glossopetræ from Virginia & malta. 221 ff',
#    'people': None,
#    'places': [{'id': None, 'name': 'Virginia'}]},
#   {'num_str': '*1493.',
#    'num_int': 1493,
#    'text': '*1493. A larger & smaller. of sapies. 221 ff',
#    'people': None,
#    'places': None},
#   {'num_str': '*1494.',
#    'num_int': 1494,
#    'text': '*1494. A strange vertilne of as fish each joint being a hollow cup. 221. ff',
#    'people': None,
#    'places': None},
#   {'num_str': '*1495.',
#    'num_int': 1495,
#    'text': '*1495. 70 a piece of a fish bone. 221. ff',
#    'people': None,
#    'places': None},
#   {'num_str': '*1496.',
#    'num_int': 1496,
#    'text': '*1496. A white meconits w t. part of a sharks tooth in it. 221. ff',
#    'people': None,
#    'places': None},
#   {'num_str': '*1497.',
#    'num_int': 1497,
#    'text': '*1497. Meconites cineres coloris e birsa fluvio agri - Basileensis. vid. scheuchrers lithograph. Helvet. p. 40. fig. 55. 221. ff',
#    'people': None,
#    'places': None},
#   {'num_str': '*1498.',
#    'num_int': 1498,
#    'text': '*1498. Prichles of a thorn back. 221. ff',
#    'people': None,
#    'places': None},
#   {'num_str': '*1499.',
#    'num_int': 1499,
#    'text': '*1499. 22 X Siliquastra from Witney. 221 ff',
#    'people': None,
#    'places': [{'id': 'Witney', 'name': 'Witney'}]},
#   {'num_str': '*1500.',
#    'num_int': 1500,
#    'text': '*1500. 22 X Bufonite roundish , orange coloured black & brown. 221 ff',
#    'people': None,
#    'places': None},
#   {'num_str': '*1501.',
#    'num_int': 1501,
#    'text': '*1501. 22 X yellow w t. a whiteish eye. 221 ff',
#    'people': None,
#    'places': None},
#   {'num_str': '*1502.',
#    'num_int': 1502,
#    'text': '*1502. 22 X Brown w t. a yellow eye 221 ff',
#    'people': [{'id': None, 'name': 'Brown'}],
#    'places': None},
#   {'num_str': '*1503.',
#    'num_int': 1503,
#    'text': '*1503. many small grown together & separate 22 X',
#    'people': None,
#    'places': None},
#   {'num_str': '*1504.',
#    'num_int': 1504,
#    'text': '*1504. taken out of the jaw not petrified 221 ff',
#    'people': None,
#    'places': None},
#   {'num_str': '*1505.',
#    'num_int': 1505,
#    'text': '*1505. 92? long black white & striated.',
#    'people': None,
#    'places': None},
#   {'num_str': '1506.',
#    'num_int': 1506,
#    'text': '1506. A very small sharks vertebre. 22 W',
#    'people': None,
#    'places': None},
#   {'num_str': '1507.',
#    'num_int': 1507,
#    'text': '1507. Very small sharks teeth.',
#    'people': None,
#    'places': None},
#   {'num_str': '-1508.',
#    'num_int': 1508,
#    'text': '-1508. Unicornn fossile Worm. M. 221 ff 7',
#    'people': None,
#    'places': None},
#   {'num_str': '-1509.',
#    'num_int': 1509,
#    'text': '-1509. The sceleton of a salmon trout 7 6 foot long taken near Colchester being left by the tide given me by M r. Panlet',
#    'people': [{'id': None, 'name': 'M r. Panlet'}],
#    'places': [{'id': 'Colchester', 'name': 'Colchester'}]},
#   {'num_str': '1510.',
#    'num_int': 1510,
#    'text': '1510. Ossis fragmen forte alicusus ceti ex fodinis Aren =ariorum fr om S r. Monti 221 ff',
#    'people': [{'id': None, 'name': 'S r. Monti'}],
#    'places': None},
#   {'num_str': '-30',
#    'num_int': 30,
#    'text': '5 -30 CLXXVIII Histrix piscis longissimis spinis donatus. Will. tab. I. b. from Jamaica. b 241.',
#    'people': None,
#    'places': [{'id': 'Jamaica', 'name': 'Jamaica'}]},
#   {'num_str': '32.',
#    'num_int': 32,
#    'text': '32. Orbis muricatus & reticulatus 0. 2. 6. e M. S. R. tab. I. N o. 7. Will. 0. 2. 6. + 241',
#    'people': None,
#    'places': None},
#   {'num_str': '33.',
#    'num_int': 33,
#    'text': '33. Idem. + 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '34.',
#    'num_int': 34,
#    'text': '34. Idem. + 241',
#    'people': None,
#    'places': None},
#   {'num_str': '35.',
#    'num_int': 35,
#    'text': '35. Idem with N o. 31. small. b 241',
#    'people': None,
#    'places': None},
#   {'num_str': '36.',
#    'num_int': 36,
#    'text': '36. Idem. Orbis muricatus. Will. tab. 5. App. b 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '37.',
#    'num_int': 37,
#    'text': '37. Idem. 241',
#    'people': None,
#    'places': None},
#   {'num_str': '38.',
#    'num_int': 38,
#    'text': "38. Xiphias piscis. Will. tab. I. 27. Worm. p. 270. + The sword fish. Nez d'Espadon, poisson de mer. B iron p. 276. f < 241.",
#    'people': None,
#    'places': None},
#   {'num_str': '39.',
#    'num_int': 39,
#    'text': '39. pisciculus cornutus. Bont. Will. tab. I. 13.',
#    'people': None,
#    'places': None},
#   {'num_str': '40.',
#    'num_int': 40,
#    'text': '40. Piscis triangularis cornibus carens. + Clus. p. 142? Will. tab. I. 13. capitis cornibus carens. &. ib. tab. I. 16? ex toto cornibus carens. &. tab. + J. 18? b 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '41.',
#    'num_int': 41,
#    'text': '41. Piscis triangularis ex toto maculosus. Will. tab. I. 17. 2. 6 b 241',
#    'people': None,
#    'places': None},
#   {'num_str': '42.',
#    'num_int': 42,
#    'text': '42. piscis quadrangularis rostratus. Will. + tab. I. 11. b 241',
#    'people': None,
#    'places': None},
#   {'num_str': '43.',
#    'num_int': 43,
#    'text': '43. Guaperva maxima caudata e M. S. R. Balisters &c Will. tab. I. 23. Arted Sipion p 8 f < 241',
#    'people': None,
#    'places': None},
#   {'num_str': '44.',
#    'num_int': 44,
#    'text': '44. Acus Aristotelis Species altera major. + Will. tab. I. 25. f < 241',
#    'people': None,
#    'places': None},
#   {'num_str': '-1511.',
#    'num_int': 1511,
#    'text': '5a -1511. Drum bones. Pet. 37.',
#    'people': None,
#    'places': None},
#   {'num_str': '-1512.',
#    'num_int': 1512,
#    'text': '-1512. Bones of some cetacesus fish. 37',
#    'people': None,
#    'places': None},
#   {'num_str': '-1513.',
#    'num_int': 1513,
#    'text': '-1513. 22 W Dog fish bones. teeth. 37',
#    'people': None,
#    'places': None},
#   {'num_str': '-1514.',
#    'num_int': 1514,
#    'text': '-1514. Sev ll. bones found in the Witney quarry near Oxford. 37',
#    'people': None,
#    'places': [{'id': 'Witney', 'name': 'Witney'},
#     {'id': 'Oxford', 'name': 'Oxford'}]},
#   {'num_str': '-1515.',
#    'num_int': 1515,
#    'text': '-1515. Impressions of the scales of fishes on stone? 37.',
#    'people': None,
#    'places': None},
#   {'num_str': '-1516.',
#    'num_int': 1516,
#    'text': '-1516. The single joint of a whales vertebræ wherin on one end side is the trencher like bone, the other it is wanting taken from a gravele pitt 8 foot deep 8 miles from the sea w t. shells used in manuring the ground. The whole sceleton was 40 foot long given me by M r. Nichols. 222. a',
#    'people': [{'id': None, 'name': 'M r. Nichols.'}],
#    'places': None},
#   {'num_str': '-1517.',
#    'num_int': 1517,
#    'text': '-1517. Pisum lapideum candidum? 222. c',
#    'people': None,
#    'places': None},
#   {'num_str': '-1518.',
#    'num_int': 1518,
#    'text': '-1518. Vesicaria marina ramosa? 222. c',
#    'people': None,
#    'places': None},
#   {'num_str': '-1519.',
#    'num_int': 1519,
#    'text': '-1519. A Scaly fish wt. a dentated horn on its back. f < 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '-1520.',
#    'num_int': 1520,
#    'text': '-1520. A morses jaw & head. f < 241',
#    'people': None,
#    'places': None},
#   {'num_str': '-1521.',
#    'num_int': 1521,
#    'text': '-1521. A morses mustacho. f < 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '1522.',
#    'num_int': 1522,
#    'text': '1522. Rosmari dens. 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '1523.',
#    'num_int': 1523,
#    'text': '1523. Raiæ clavate cauda. 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '1524.',
#    'num_int': 1524,
#    'text': '1524. A plaise both sides like the underside of an ordinary plaise a 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '1525.',
#    'num_int': 1525,
#    'text': '1525. The tail of a raia levis. f < 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '1526.',
#    'num_int': 1526,
#    'text': '1526. A large fish w t. one finn on the back. f < 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '1527.',
#    'num_int': 1527,
#    'text': '1527. Young carchariæ? n. 6 +',
#    'people': None,
#    'places': None},
#   {'num_str': '1528',
#    'num_int': 1528,
#    'text': '1528 The round head of a bone of a very large whale',
#    'people': None,
#    'places': None},
#   {'num_str': '1529.',
#    'num_int': 1529,
#    'text': '1529. The head of a trout whose upper chap was mostly wanting. 221. ff',
#    'people': None,
#    'places': None},
#   {'num_str': '1530.',
#    'num_int': 1530,
#    'text': '1530. a small black fish, with 2 fins under the gills like fore. feet. (It had N o. 3541. Insect?) n. 2.',
#    'people': None,
#    'places': None},
#   {'num_str': '1531.',
#    'num_int': 1531,
#    'text': '1531. A scaly fish from Jamaica.',
#    'people': None,
#    'places': [{'id': 'Jamaica', 'name': 'Jamaica'}]},
#   {'num_str': '45.',
#    'num_int': 45,
#    'text': '6 45. Lumpus Anglorum. Will. tab. N. + n. ÿ. f < 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '46.',
#    'num_int': 46,
#    'text': '46. Delphinus Belgis. Will. tab. O. 2. + 241 f <',
#    'people': None,
#    'places': None},
#   {'num_str': '47.',
#    'num_int': 47,
#    'text': '47. Monoceros piscis e M. S. R. Will. tab. O. 4. 2 prickles of each side the tasle. f < 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '48.',
#    'num_int': 48,
#    'text': '48. Hirundo Salv. Will. tab. P. 4. + the flying fish. a 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '49.',
#    'num_int': 49,
#    'text': '49. Idem. + b 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '50.',
#    'num_int': 50,
#    'text': '50. Idem. very large. + f < 241',
#    'people': None,
#    'places': None},
#   {'num_str': '51.',
#    'num_int': 51,
#    'text': '51. Acus maxima Squammosa. Will. + tab. P. 8. 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '52.',
#    'num_int': 52,
#    'text': '52. Scorpius Virginianus. Salviani Will. tab. X. 15 2. + App. p. 25. b 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '53.',
#    'num_int': 53,
#    'text': '53. An Scorpius ous Salviani major Rond. Gesn. p. 1017. Will. tab. X. + 13? Barbulæ? f <',
#    'people': None,
#    'places': None},
#   {'num_str': '54.',
#    'num_int': 54,
#    'text': '54. An Diaboli marini cutis. Will. tab. + 9. App. N o. 3?',
#    'people': None,
#    'places': None},
#   {'num_str': '55.',
#    'num_int': 55,
#    'text': '55. Piscis Monocerotis cornu. Will. tab. A. 2. S 241',
#    'people': None,
#    'places': None},
#   {'num_str': '56.',
#    'num_int': 56,
#    'text': '56. A piece of whale bone.',
#    'people': None,
#    'places': None},
#   {'num_str': '57.',
#    'num_int': 57,
#    'text': '57. Torpedo. Will. p. 81. Torpille on Tremble. de Reaumur + memoires de ad Roy. des Sciences Ameet 714 p. 344. 4 to. b 241.',
#    'people': [{'id': None, 'name': 'Reaumur'}],
#    'places': None},
#   {'num_str': '58.',
#    'num_int': 58,
#    'text': '58. Squatina. Salv. Will. tab. D3. p. 79. + The monk or angel fish. f < 239.',
#    'people': None,
#    'places': None},
#   {'num_str': '59.',
#    'num_int': 59,
#    'text': '59. Idem a young one. + 241',
#    'people': None,
#    'places': None},
#   {'num_str': '1532.',
#    'num_int': 1532,
#    'text': '6a 1532. The sail of the Carvell fish. Urtica &c A very large glossopetra from Virginia found 221. dd -1533. 10 foot under ground there by 221 ff',
#    'people': None,
#    'places': [{'id': None, 'name': 'Virginia'}]},
#   {'num_str': '1534.',
#    'num_int': 1534,
#    'text': '1534. Shark stone from the head of a shark M r. Clerk. 221 ff',
#    'people': [{'id': None, 'name': 'M r. Clerk.'}],
#    'places': None},
#   {'num_str': '1535.',
#    'num_int': 1535,
#    'text': '1535. Sharks eggs from M r. Ames. m. Sp. V. 221 ff 227',
#    'people': [{'id': None, 'name': 'M r. Ames.'}],
#    'places': None},
#   {'num_str': '-1536.',
#    'num_int': 1536,
#    'text': '-1536. Sharks teeth found in the chalk pitts in Kent 221 ff 227',
#    'people': None,
#    'places': [{'id': 'Kent', 'name': 'Kent'}]},
#   {'num_str': '1537.',
#    'num_int': 1537,
#    'text': '1537. Palat of the fish Nari nari from Brasile 221 ff',
#    'people': None,
#    'places': [{'id': 'Brasil', 'name': 'Brasile'}]},
#   {'num_str': '1538. 158',
#    'num_int': 1538,
#    'text': '1538. 158 A deep or o a range colourd bufonites from the same 221 ff',
#    'people': None,
#    'places': None},
#   {'num_str': '1539.',
#    'num_int': 1539,
#    'text': "1539. A acus vulgaris sive oppiani. Acusprima spec i es condel. gesn Bελo'rn pαφis Græcis Pa 109 Rau synops piscium &c. The Horn fish or Gar fish. 221 e",
#    'people': None,
#    'places': None},
#   {'num_str': '1540 1530',
#    'num_int': 1540,
#    'text': '1540 1530 A bufonites of a dark colour ✓ 172',
#    'people': None,
#    'places': None},
#   {'num_str': '1541.',
#    'num_int': 1541,
#    'text': "1541. The skin of a young one of. 68. senter'd before under a former N o. ✓ 221. b",
#    'people': None,
#    'places': None},
#   {'num_str': '1542',
#    'num_int': 1542,
#    'text': "1542 Orbis piscis muricatus without his two Mandibles & pr echaps enter'd before or N o Lost 241 a",
#    'people': None,
#    'places': None},
#   {'num_str': '1543.',
#    'num_int': 1543,
#    'text': '1543. Two pieces of blue slate small w t. the impressions of Scalops of fishes from Whitehaven from Dr. Browning vide his Description N o. 12 37',
#    'people': [{'id': None, 'name': 'Dr. Browning'}],
#    'places': [{'id': 'Whitehaven', 'name': 'Whitehaven'}]},
#   {'num_str': '1544. 1543',
#    'num_int': 1544,
#    'text': '1544. 1543 Another piece of the same sort N o. 13. Id.',
#    'people': None,
#    'places': None},
#   {'num_str': '60.',
#    'num_int': 60,
#    'text': '7 60. Catulus minor Salvian. Will. tab + B. 4.',
#    'people': None,
#    'places': None},
#   {'num_str': '61.',
#    'num_int': 61,
#    'text': '61. A whalebone with the hair on it, as 56. large. D 241',
#    'people': None,
#    'places': None},
#   {'num_str': '62.',
#    'num_int': 62,
#    'text': '62. The same . 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '63.',
#    'num_int': 63,
#    'text': '63. The mandible of a sort of Lupus - marinus with teeth in it like the lapis bufonis. 241 f <',
#    'people': None,
#    'places': None},
#   {'num_str': '64.',
#    'num_int': 64,
#    'text': '64. Os Sepiæ. 221. ff',
#    'people': None,
#    'places': None},
#   {'num_str': '65.',
#    'num_int': 65,
#    'text': '65. An the intestines of some fish or skin of an eel?',
#    'people': None,
#    'places': None},
#   {'num_str': '66.',
#    'num_int': 66,
#    'text': '66. An Guaperva histrix. Will. tab. I. + 21. a 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '67.',
#    'num_int': 67,
#    'text': '67. Acarauna minor quadrata e M. S. R. + Will. tab. O3. N o. 2. a 241',
#    'people': None,
#    'places': None},
#   {'num_str': '68.',
#    'num_int': 68,
#    'text': '68. Acus maxima squamosa idem N o ? 51 + f ✓ a 241',
#    'people': None,
#    'places': None},
#   {'num_str': '69.',
#    'num_int': 69,
#    'text': '69. Lupus Salviani. Will. tab. R. 1? + 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '70.',
#    'num_int': 70,
#    'text': '70. Idem? + a 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '71.',
#    'num_int': 71,
#    'text': '71. Idem? + f < 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '72.',
#    'num_int': 72,
#    'text': '72. Milvas Salv. Will. tab. S. 6. + f < 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '73.',
#    'num_int': 73,
#    'text': '73. A wing of the same . 221 c',
#    'people': None,
#    'places': None},
#   {'num_str': '74.',
#    'num_int': 74,
#    'text': '74. Scarus Cretensis Aldrovandi. Will. + tab. X. 10. 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '75.',
#    'num_int': 75,
#    'text': '75.',
#    'people': None,
#    'places': None},
#   {'num_str': '1545.',
#    'num_int': 1545,
#    'text': "7a 1545. A Third piece mark'd by him N o 14. Id. 37.",
#    'people': None,
#    'places': None},
#   {'num_str': '1546.',
#    'num_int': 1546,
#    'text': '1546. The fore finn of the Manati. made into a sceleton from M rs. Hall 218 288',
#    'people': [{'id': None, 'name': 'M rs. Hall'}],
#    'places': None},
#   {'num_str': '1547.',
#    'num_int': 1547,
#    'text': '1547. A stone with Ova piscium. Vid A tea 221: y',
#    'people': None,
#    'places': None},
#   {'num_str': '1548',
#    'num_int': 1548,
#    'text': '1548 A yound Dorado? vid. Antea N o. 801? 158 221 ff',
#    'people': None,
#    'places': None},
#   {'num_str': '1549.',
#    'num_int': 1549,
#    'text': "1549. The tooth of a Whale mark'd formerly 120. 222. c.",
#    'people': None,
#    'places': None},
#   {'num_str': '1550.',
#    'num_int': 1550,
#    'text': '1550. Ichthyolithi Eichstadensi. from Ferdinandus Jacobus Barerus at Norimberge 222. t.',
#    'people': None,
#    'places': [{'id': 'Nuremberg', 'name': 'Norimberge'}]},
#   {'num_str': '1551.',
#    'num_int': 1551,
#    'text': '1551. An cupriscus Will. p. 152. tab. 1. 19. from Barbadoes by the Rev d. M r. Clerk 221. aa',
#    'people': [{'id': None, 'name': 'M r. Clerk'}],
#    'places': [{'id': 'Barbados', 'name': 'Barbadoes'}]},
#   {'num_str': '1552.',
#    'num_int': 1552,
#    'text': '1552. An Acarauna Will. - Id. 221. r',
#    'people': None,
#    'places': None},
#   {'num_str': '1553.',
#    'num_int': 1553,
#    'text': '1553. An Scarus. Will. p. 306 Tab. v. s. Id. 221. r',
#    'people': None,
#    'places': None},
#   {'num_str': '1554.',
#    'num_int': 1554,
#    'text': '1554. The two jaws of the Nari Nari from Barbadoes by the Rev d. M r. Clerk; 221. c.',
#    'people': [{'id': None, 'name': 'M r. Clerk'}],
#    'places': [{'id': 'Barbados', 'name': 'Barbadoes'}]},
#   {'num_str': '1555.',
#    'num_int': 1555,
#    'text': '1555. 22 x Teeth of some Amphibious creature. Id. 221. c.',
#    'people': None,
#    'places': None},
#   {'num_str': '1556.',
#    'num_int': 1556,
#    'text': '1556. A Remora and a centiqacs sent to Dr. Mead from Bengal from Dr. Stack m. 7.',
#    'people': [{'id': None, 'name': 'Dr. Mead'},
#     {'id': None, 'name': 'Dr. Stack'}],
#    'places': [{'id': 'Bengal', 'name': 'Bengal'}]},
#   {'num_str': '1557.',
#    'num_int': 1557,
#    'text': "1557. The Mango Fish from the same vid Edwards's Ornitholog. Vol. 4. p. 208. m. 7.",
#    'people': [{'id': None, 'name': 'Edwards'}],
#    'places': None},
#   {'num_str': '1558.',
#    'num_int': 1558,
#    'text': '1558. A Remora belonging to the Duke of Richmond & bought by D r. Stack at the sale of his museum m. 7.',
#    'people': [{'id': None, 'name': 'Duke of Richmond'},
#     {'id': None, 'name': 'Stack'}],
#    'places': None},
#   {'num_str': '76.',
#    'num_int': 76,
#    'text': '8 76. Nari Nari Brasil. cauda Will. p. 66. tab. c. 1. N o. 5? The whip ray.',
#    'people': None,
#    'places': None},
#   {'num_str': '77.',
#    'num_int': 77,
#    'text': '77. Aquilæ Will. p. 64. tab. C. 2. cauda? f <',
#    'people': None,
#    'places': None},
#   {'num_str': '78.',
#    'num_int': 78,
#    'text': '78. An Aquilæ caput. Ej. Ib. vel Raiæ f < 241',
#    'people': None,
#    'places': None},
#   {'num_str': '79.',
#    'num_int': 79,
#    'text': '79. Idem. 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '80.',
#    'num_int': 80,
#    'text': '80. Pastinacæ Marine D. F. C. Cauda. Will. tab. D. 5?',
#    'people': [{'id': None, 'name': 'D. F.'}],
#    'places': None},
#   {'num_str': '81.',
#    'num_int': 81,
#    'text': '81. Idem. 0. 4. 0. G <',
#    'people': None,
#    'places': None},
#   {'num_str': '82.',
#    'num_int': 82,
#    'text': '82. The same . f <',
#    'people': None,
#    'places': None},
#   {'num_str': '83.',
#    'num_int': 83,
#    'text': '83. Pastinacæ marinæ vel Raiæ cauda.',
#    'people': None,
#    'places': None},
#   {'num_str': '84.',
#    'num_int': 84,
#    'text': '84. The same . Shagrin. smoother. an tail of a ray.',
#    'people': None,
#    'places': None},
#   {'num_str': '85.',
#    'num_int': 85,
#    'text': '85. The same .',
#    'people': None,
#    'places': None},
#   {'num_str': '86.',
#    'num_int': 86,
#    'text': '86. The basilish made up of the fins &c of a ray. 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '87.',
#    'num_int': 87,
#    'text': '87. An The finn bones of a ray. 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '88.',
#    'num_int': 88,
#    'text': '88. An the chops or mandibles of some fish. or amphibious animal.',
#    'people': None,
#    'places': None},
#   {'num_str': '89.',
#    'num_int': 89,
#    'text': '89. Mandibles of a ray. like 21. & 22. &c f < 221 ff',
#    'people': None,
#    'places': None},
#   {'num_str': '1559.',
#    'num_int': 1559,
#    'text': '8a 1559. The Head of a large Fish described by Catesby in his Nat. Hist. Flor. from D o. 241. a',
#    'people': [{'id': None, 'name': 'Catesby'}],
#    'places': None},
#   {'num_str': '1560.',
#    'num_int': 1560,
#    'text': '1560. Sp. Roon A pair of large Fins of some fish. D o.',
#    'people': None,
#    'places': None},
#   {'num_str': '1561.',
#    'num_int': 1561,
#    'text': "1561. Sp. Roon A young Shark stuff'd. D o.",
#    'people': None,
#    'places': None},
#   {'num_str': '1562',
#    'num_int': 1562,
#    'text': '1562 A small orbis. D o. 221. p.',
#    'people': None,
#    'places': None},
#   {'num_str': '1563.',
#    'num_int': 1563,
#    'text': '1563. The same w t. 1490. D o. 221. i',
#    'people': None,
#    'places': None},
#   {'num_str': None,
#    'num_int': None,
#    'text': 'End. Two Teeth of the Sperma Ceti Whale Given by Gustavus Brander Esq r. A Rana piscatrix in Sp. given by James Theobabds Esq r.',
#    'people': [{'id': None, 'name': 'Gustavus Brander'},
#     {'id': None, 'name': 'James'}],
#    'places': None},
#   {'num_str': '90.',
#    'num_int': 90,
#    'text': '9 90. Whales pizzle. Penis balence grandis.',
#    'people': None,
#    'places': None},
#   {'num_str': '91.',
#    'num_int': 91,
#    'text': "91. A roundish bone w ch. is plac'd between every 2 vertebres of the back bone of a whale. 239.",
#    'people': None,
#    'places': None},
#   {'num_str': '92.',
#    'num_int': 92,
#    'text': '92. The ear bone of a whale? f 4 241',
#    'people': None,
#    'places': None},
#   {'num_str': '93.',
#    'num_int': 93,
#    'text': '93. The tooth of a sperma ceti whale. b < 245 241',
#    'people': None,
#    'places': None},
#   {'num_str': '94.',
#    'num_int': 94,
#    'text': '94. The same with 92. ✓ 222',
#    'people': None,
#    'places': None},
#   {'num_str': '-95.',
#    'num_int': 95,
#    'text': '-95. The head & mandibles of a pike. ✓ 221. i',
#    'people': None,
#    'places': None},
#   {'num_str': '-96.',
#    'num_int': 96,
#    'text': '-96. The mandibles of aquila piseis or Ray the same with 78? f < 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '-97.',
#    'num_int': 97,
#    'text': '-97. Milvus Salviani. From Guinea given by an acquaintance of M r. Fortrey. + f <',
#    'people': [{'id': None, 'name': 'M r. Fortrey'}],
#    'places': [{'id': 'Guinea', 'name': 'Guinea'}]},
#   {'num_str': '-98.',
#    'num_int': 98,
#    'text': '-98. Another given by Coll. Wharton. + b 241.',
#    'people': [{'id': None, 'name': 'Coll. Wharton.'}],
#    'places': None},
#   {'num_str': '99.',
#    'num_int': 99,
#    'text': '99. ✓ The radius or sting of the pastinaca marina or Aquila. 221. l',
#    'people': None,
#    'places': None},
#   {'num_str': '100.',
#    'num_int': 100,
#    'text': '100. ✓ Pikes of the dog fish from Scotland. 4. 0. 0. 6. Galeus Acatithias Clus. exotieus. Will. p. 57. tab. vid. quadrup. 1751. B. 9. fig. 6. from the Orkneyes from Dr. Preston. 221. n',
#    'people': [{'id': None, 'name': 'Dr. Preston.'}],
#    'places': [{'id': 'Scotland', 'name': 'Scotland'},
#     {'id': 'Orkney_Islands', 'name': 'Orkneyes'}]},
#   {'num_str': '101.',
#    'num_int': 101,
#    'text': '101. ✓ Penis & testicles of an alligator or 0. 1. 0. crocodile from Surinam. vid. quadr. 1751. 0. 1. 0. 22',
#    'people': None,
#    'places': [{'id': 'Surinam', 'name': 'Surinam'}]},
#   {'num_str': '102.',
#    'num_int': 102,
#    'text': '102. ✓ Part of the mandible of the rana pisca = =trix ? Pike? 221. f.',
#    'people': None,
#    'places': None},
#   {'num_str': '103.',
#    'num_int': 103,
#    'text': '103. piscis monocerotis embryonis alicusus cornu. Willuglib. tab. A. 2. 221 l',
#    'people': None,
#    'places': None},
#   {'num_str': '-104.',
#    'num_int': 104,
#    'text': '-104. ✓ pars cort u piscis monocerotis. Ib. from the East Indies from Dr. Waldo at suratte. 221. l.',
#    'people': [{'id': None, 'name': 'Dr. Waldo'}],
#    'places': [{'id': 'East_Indies', 'name': 'East Indies'},
#     {'id': None, 'name': 'suratte'}]},
#   {'num_str': '105.',
#    'num_int': 105,
#    'text': '105. ✓ Galeus glaucus Rond. Will. tab. B. 8. 18. 221. n',
#    'people': None,
#    'places': None},
#   {'num_str': '106.',
#    'num_int': 106,
#    'text': '10 106. ✓ pristis sive serra. + 221 l',
#    'people': None,
#    'places': None},
#   {'num_str': '107.',
#    'num_int': 107,
#    'text': '107. ✓ The same D + 0. 1. 6. 221. w',
#    'people': None,
#    'places': None},
#   {'num_str': '108.',
#    'num_int': 108,
#    'text': '108. Gelly found in a sharks head w ch. turns to a white powder & is used to promote travell in women. 221. l 221. w',
#    'people': None,
#    'places': None},
#   {'num_str': '109.',
#    'num_int': 109,
#    'text': '109. ✓ Aquilæ piscis vel pastinaæ marinœ radius or stiu n g. f < 221. e',
#    'people': None,
#    'places': None},
#   {'num_str': '110.',
#    'num_int': 110,
#    'text': '110. Raiæ cujusdam mandibulæ an - 0. 2. 6. Rockfish Jaw. 0. 2. 6. 221 dd',
#    'people': None,
#    'places': None},
#   {'num_str': '111.',
#    'num_int': 111,
#    'text': '111. part of the same . 221. dd.',
#    'people': None,
#    'places': None},
#   {'num_str': '112.',
#    'num_int': 112,
#    'text': '112. An part of the Jaw of a ray or of its stomach? 221. dd',
#    'people': None,
#    'places': None},
#   {'num_str': '113.',
#    'num_int': 113,
#    'text': '113. The mandible upper? of a ray an of the Nari nari? 221. cc',
#    'people': None,
#    'places': None},
#   {'num_str': '114.',
#    'num_int': 114,
#    'text': '114. Teeth of a ray an of the aquila? 221 ff',
#    'people': None,
#    'places': None},
#   {'num_str': '115.',
#    'num_int': 115,
#    'text': '115. Round bone an one of those between the vertebres of the whale, porpesse, or dolphin? 221 c',
#    'people': None,
#    'places': None},
#   {'num_str': '116.',
#    'num_int': 116,
#    'text': '116. ✓ Galei cujusdam fætus chorion. matricula marina vulgo crapault de mer. Bell de aq. p. 68. 221 k',
#    'people': [{'id': None, 'name': 'Bell'}],
#    'places': None},
#   {'num_str': '117.',
#    'num_int': 117,
#    'text': '117. ✓ Another sort of the same from Carolina. 0. 0. 2.',
#    'people': None,
#    'places': [{'id': None, 'name': 'Carolina'}]},
#   {'num_str': '118.',
#    'num_int': 118,
#    'text': '118. Squatina Salv. Will. tab. D. 3. a + young one. 221. r',
#    'people': None,
#    'places': None},
#   {'num_str': '119.',
#    'num_int': 119,
#    'text': '119. The ovarium of a buccinum. vid. 5121. de Va e. 221. ff',
#    'people': None,
#    'places': None},
#   {'num_str': '120.',
#    'num_int': 120,
#    'text': '11 120. The ova of a shell ? fish.',
#    'people': None,
#    'places': None},
#   {'num_str': '121.',
#    'num_int': 121,
#    'text': '121. ✓ Guacucuia Brasiliensibus. Marcgr. Ray. p. 89. tab. E. 2. N o. 3. + 221. n.',
#    'people': None,
#    'places': None},
#   {'num_str': '122.',
#    'num_int': 122,
#    'text': '122. ✓ Acara mucu Brasiliensibus Marcgr. - Raÿ. p. 91. tab. E. 2. N o. 2. 221. n.',
#    'people': None,
#    'places': None},
#   {'num_str': '123.',
#    'num_int': 123,
#    'text': '123. Passer fluviatilis, a Flounder. Raÿ. Will. Tab. F. fig. 5? 221. ff',
#    'people': None,
#    'places': None},
#   {'num_str': '124.',
#    'num_int': 124,
#    'text': '124. ✓ Iperuquiba Brasiliensibus. Marcgr. + Ray. tab. G. 8. fig. 2. An Imper= =ati remora. App. tab. 9. fig. 2? ejusdem? 221. p.',
#    'people': None,
#    'places': None},
#   {'num_str': '-125.',
#    'num_int': 125,
#    'text': '-125. ✓ Orbis hirsutus densis & exiguis murici= =bus donatus. Will. tab. I. 3. From Virginia. 221. n.',
#    'people': None,
#    'places': [{'id': None, 'name': 'Virginia'}]},
#   {'num_str': '126.',
#    'num_int': 126,
#    'text': '126. ✓ Histrix piscis Clusÿ. Guamaia =cus Guara Brasiliensibus. an orbis muricatus primus & alter. Clusÿ. Will tab. I. 5? A young one. a 241. 221 ff. 221. i.',
#    'people': None,
#    'places': None},
#   {'num_str': '127.',
#    'num_int': 127,
#    'text': '127. Psciculus Cornutus. Bont. Will 0. 2. 6. tab. I. 13. fig. 1. D 0. 2. 6. 221. g',
#    'people': None,
#    'places': None},
#   {'num_str': '128.',
#    'num_int': 128,
#    'text': '128. ✓ Piscis triangularis cornibus carens Clus= ÿ. Will. tab. I. 13. fig. 2. & tab. J. 16. 221. n.',
#    'people': None,
#    'places': None},
#   {'num_str': '129.',
#    'num_int': 129,
#    'text': '129. ✓ Piscis triangularis cornutus. Clus. Will. tab. I. 14. 221. a',
#    'people': None,
#    'places': None},
#   {'num_str': '130.',
#    'num_int': 130,
#    'text': '12 130. ✓ Guaperva histrix Will. 0. 10. 0. tab. I. 21. 0. 10. 0. 221. n.',
#    'people': None,
#    'places': None},
#   {'num_str': '131.',
#    'num_int': 131,
#    'text': '131. ✓ Acus Aristotelis species altera major. Will. tab. I. 25. 221. n',
#    'people': None,
#    'places': None},
#   {'num_str': '132.',
#    'num_int': 132,
#    'text': '132. The same . + 221. ff',
#    'people': None,
#    'places': None},
#   {'num_str': '133.',
#    'num_int': 133,
#    'text': '133. The same . + 0. 1. 0. 221. e',
#    'people': None,
#    'places': None},
#   {'num_str': '134.',
#    'num_int': 134,
#    'text': '134. The same shorter & broader. + 221. e',
#    'people': None,
#    'places': None},
#   {'num_str': '135.',
#    'num_int': 135,
#    'text': '135. ✓ Hippocampus non aculeatus incisuris raris. Will. + tab. I. 25. fig. 4. 221. a',
#    'people': None,
#    'places': None},
#   {'num_str': '136.',
#    'num_int': 136,
#    'text': '136. Hippocampus non aculeatus incisuris crebris Indiæ Occidentalis. ib. fig. 5. + 221. a.',
#    'people': None,
#    'places': None},
#   {'num_str': '137.',
#    'num_int': 137,
#    'text': '137. ✓ Spina scolopacis. Will. p. 161. tab. + I. 25. fig. 6. 221. a',
#    'people': None,
#    'places': None},
#   {'num_str': '138.',
#    'num_int': 138,
#    'text': '138. ✓ Cataphractus Schonfeldÿ. Will. tab. N. 6. fig. 2 & 3. 221 a',
#    'people': None,
#    'places': None},
#   {'num_str': '139.',
#    'num_int': 139,
#    'text': '139. Cutaphractus from Virginia 0. 1. 0. 221 ff.',
#    'people': None,
#    'places': [{'id': None, 'name': 'Virginia'}]},
#   {'num_str': '140.',
#    'num_int': 140,
#    'text': '140. ✓ Lumpus Anglorum. Will. tab + N. 11. 221. a',
#    'people': None,
#    'places': None},
#   {'num_str': '141.',
#    'num_int': 141,
#    'text': '141. ✓ Guaperva Brasiliens. Will. + tab. O. 1? vel Aba tab. S. 185. 221. n',
#    'people': None,
#    'places': None},
#   {'num_str': '142.',
#    'num_int': 142,
#    'text': '13 142. ✓ Acus Oppiani Caput. Will. + tab. P. 2. 221. n.',
#    'people': None,
#    'places': None},
#   {'num_str': '143.',
#    'num_int': 143,
#    'text': '143. Accipenser Salv. sturgeon. + 221. ff',
#    'people': None,
#    'places': None},
#   {'num_str': '144.',
#    'num_int': 144,
#    'text': '144. ✓ Lyra Salviaris Will. tab. S. 3. brought by me from Montpelier. + 221. p.',
#    'people': None,
#    'places': [{'id': 'Montpellier', 'name': 'Montpelier'}]},
#   {'num_str': '145.',
#    'num_int': 145,
#    'text': '145. ✓ Faber Salviaris. Will. tab. + S. 16. From the same place. 221. a.',
#    'people': None,
#    'places': None},
#   {'num_str': '146.',
#    'num_int': 146,
#    'text': '146. ✓ Scorpius Salviaris Will. tab. + X. 12. 221. ff',
#    'people': None,
#    'places': None},
#   {'num_str': '147.',
#    'num_int': 147,
#    'text': '147. ✓ Idem redish. 6 d + 0. 1. 0. 221. a',
#    'people': None,
#    'places': None},
#   {'num_str': '148.',
#    'num_int': 148,
#    'text': '148. ✓ Orbis Muricatus. Will. App. 0. 1. 6. + tab. 5. fig. 2. + 0. 1. 6. 221. i.',
#    'people': None,
#    'places': None},
#   {'num_str': '149.',
#    'num_int': 149,
#    'text': '149. ✓ The same with 128. only smaller. + piscis triangularis parvulus. 221. l',
#    'people': None,
#    'places': None},
#   {'num_str': '150.',
#    'num_int': 150,
#    'text': '150. ✓ An Cataphractus? + 221. n',
#    'people': None,
#    'places': None},
#   {'num_str': '151.',
#    'num_int': 151,
#    'text': '151. ✓ An mustelæ fluviatilis species? + 221 l.',
#    'people': None,
#    'places': None},
#   {'num_str': '152.',
#    'num_int': 152,
#    'text': '152. ✓ An Turdus? + 221. n.',
#    'people': None,
#    'places': None},
#   {'num_str': '153.',
#    'num_int': 153,
#    'text': '14 153. ✓ An corax vel cuculi species? + 221. ff',
#    'people': None,
#    'places': None},
#   {'num_str': '154.',
#    'num_int': 154,
#    'text': '154. Ruffe percæ species? + 0. 2. 0. 221. a O. 2',
#    'people': None,
#    'places': None},
#   {'num_str': '155.',
#    'num_int': 155,
#    'text': '155. An rana piscatrix? 221. n',
#    'people': None,
#    'places': None},
#   {'num_str': '156.',
#    'num_int': 156,
#    'text': '156. 221. n',
#    'people': None,
#    'places': None},
#   {'num_str': '157.',
#    'num_int': 157,
#    'text': '157. 221 r',
#    'people': None,
#    'places': None},
#   {'num_str': '158.',
#    'num_int': 158,
#    'text': '158. 221. ff',
#    'people': None,
#    'places': None},
#   {'num_str': '159.',
#    'num_int': 159,
#    'text': '159. The mandibles of a fish an orbis vel raiæ species? 221 y',
#    'people': None,
#    'places': None},
#   {'num_str': '160.',
#    'num_int': 160,
#    'text': '160. The same of a lupus piscis from Virginia an of the sheep fish. 221. cc.',
#    'people': None,
#    'places': [{'id': None, 'name': 'Virginia'}]},
#   {'num_str': '161.',
#    'num_int': 161,
#    'text': '161. part of a mandible of the same . 221. cc',
#    'people': None,
#    'places': None},
#   {'num_str': '-162.',
#    'num_int': 162,
#    'text': '-162. The entire mandibles of another . / Toadstones or the grinding teeth of the fish lupus marinus vid. Johnston tab. 47. / Maxilla cum truplus serve dentium manati. P./A fragment of the mandible of the lupus piscis w t. the dentes moles in it. M. 221. cc',
#    'people': None,
#    'places': None},
#   {'num_str': '-163.',
#    'num_int': 163,
#    'text': '-163. Halfe of the mandible of the same . 221. cc',
#    'people': None,
#    'places': None},
#   {'num_str': '-164.',
#    'num_int': 164,
#    'text': '-164. The palat or mandible of another of these fishes. 221. ff c',
#    'people': None,
#    'places': None},
#   {'num_str': '165.',
#    'num_int': 165,
#    'text': '165. A very small fishes head. 221. e',
#    'people': None,
#    'places': None},
#   {'num_str': None,
#    'num_int': None,
#    'text': '14a X Langue de Serpent, Glossopetra. Biron. 265.',
#    'people': None,
#    'places': None},
#   {'num_str': '166.',
#    'num_int': 166,
#    'text': '15 166. An lumpus Anglorum? +',
#    'people': None,
#    'places': None},
#   {'num_str': '167.',
#    'num_int': 167,
#    'text': '167. Lumpus? + 221. ff',
#    'people': None,
#    'places': None},
#   {'num_str': '-168.',
#    'num_int': 168,
#    'text': '-168. Cataphractus. + 221. ff.',
#    'people': None,
#    'places': None},
#   {'num_str': '-169?',
#    'num_int': 169,
#    'text': '-169? ✓ The same w t. N o. 154: + 221. a',
#    'people': None,
#    'places': None},
#   {'num_str': '-170.',
#    'num_int': 170,
#    'text': '-170. ✓ The vertebres of a shark lodged in a clay from the tile pitts at Richmond y e. two vertebres are dislocated. 221. ff. &c',
#    'people': None,
#    'places': [{'id': 'Tile_pits_Richmond', 'name': 'tile pitts at Richmond'}]},
#   {'num_str': '-171.',
#    'num_int': 171,
#    'text': '-171. 22 w The vertebre of a shark filled with stony matter & fossil? 221. c 221. i.',
#    'people': None,
#    'places': None},
#   {'num_str': '172.',
#    'num_int': 172,
#    'text': '172. 22 W The large tooth of a shark imbedded in a whitish friable stone from. Malta. Gray & serrated. X 221. cc 221. dd 221. ff.',
#    'people': None,
#    'places': [{'id': 'Malta', 'name': 'Malta'}]},
#   {'num_str': '173.',
#    'num_int': 173,
#    'text': '173. One of the same teeth out of its bed. 0. 5. 0 221. y',
#    'people': None,
#    'places': None},
#   {'num_str': '174.',
#    'num_int': 174,
#    'text': '174. A lesser tooth of a shark imbedded in its stone or earth. From malta yellow & not serrated. 221. c.c.',
#    'people': None,
#    'places': [{'id': None, 'name': 'malta'}]},
#   {'num_str': '175.',
#    'num_int': 175,
#    'text': '175. One of the same out of its bed gray. 221. cc',
#    'people': None,
#    'places': None},
#   {'num_str': '176.',
#    'num_int': 176,
#    'text': '176. A sharks tooth short & gray w t. 2 lesser ones at its base. 221. cc',
#    'people': None,
#    'places': None},
#   {'num_str': '177.',
#    'num_int': 177,
#    'text': '177. One longer & narrower w t. 2 appendices 221. cc',
#    'people': None,
#    'places': None},
#   {'num_str': '178.',
#    'num_int': 178,
#    'text': '178. A very small one w t. appendices 221. ff.',
#    'people': None,
#    'places': None},
#   {'num_str': '179.',
#    'num_int': 179,
#    'text': '179. W A long one w t out appendices. 3 Boxes 221. ff',
#    'people': None,
#    'places': None},
# ...
#   {'num_str': '-787.',
#    'num_int': 787,
#    'text': '-787. A dog fishes or sharks tooth from Malta. From M r. Beverland. 221. ff. dd',
#    'people': [{'id': None, 'name': 'M r. Beverland.'}],
#    'places': [{'id': 'Malta', 'name': 'Malta'}]},
#   {'num_str': '-788.',
#    'num_int': 788,
#    'text': '-788. 22 x Bufonite s of severall sizes 303 roundish. From Dr. Lister. 221. cc',
#    'people': [{'id': None, 'name': 'Dr. Lister.'}],
#    'places': None},
#   {'num_str': '-789.',
#    'num_int': 789,
#    'text': '-789. 92 The same long & boat like From the same . 221. cc.',
#    'people': None,
#    'places': None},
#   {'num_str': '-790.',
#    'num_int': 790,
#    'text': '-790. Bones from the heads of a sort of codfish. From Virginia From the same . 221 g',
#    'people': None,
#    'places': [{'id': None, 'name': 'Virginia'}]},
#   {'num_str': '-791.',
#    'num_int': 791,
#    'text': '-791. A very small flying fish. From the East Indies by M r. Bradyll. o. 3',
#    'people': [{'id': None, 'name': 'M r. Bradyll.'}],
#    'places': [{'id': 'East_Indies', 'name': 'East Indies'}]},
#   {'num_str': '-792.',
#    'num_int': 792,
#    'text': '90 -792. A larger Harengus alatus or flying fish. From the East- Indies by M r. Bradyll. n. 6',
#    'people': [{'id': None, 'name': 'M r. Bradyll.'}],
#    'places': [{'id': None, 'name': 'East- Indies'}]},
#   {'num_str': '-793.',
#    'num_int': 793,
#    'text': '-793. The same somewhat larger. From the same . o. 1',
#    'people': None,
#    'places': None},
#   {'num_str': '-794.',
#    'num_int': 794,
#    'text': '-794. The same larger. From the same . p. 7',
#    'people': None,
#    'places': None},
#   {'num_str': '-795.',
#    'num_int': 795,
#    'text': '-795. The same of the largest size From the same .',
#    'people': None,
#    'places': None},
#   {'num_str': '-796.',
#    'num_int': 796,
#    'text': '-796. A small remora. From the same . n. 3 6',
#    'people': None,
#    'places': None},
#   {'num_str': '-797.',
#    'num_int': 797,
#    'text': '-797. An acus piscis. From the same . o. 4 6',
#    'people': None,
#    'places': None},
#   {'num_str': '-798.',
#    'num_int': 798,
#    'text': '-798. The mandible of a lupas piscis from the East Indies where in are four round dentes molares a litle oblong & situated having long necks. given me by Mong r.- Masson. 221. a',
#    'people': [{'id': None, 'name': 'Mong r.- Masson'}],
#    'places': [{'id': 'East_Indies', 'name': 'East Indies'}]},
#   {'num_str': '-799.',
#    'num_int': 799,
#    'text': '-799. An orbis Piscis brown on the back & while on the belly. From M r. Staphorst. from Guiner.',
#    'people': [{'id': None, 'name': 'M r. Staphorst.'}],
#    'places': None},
#   {'num_str': '-800.',
#    'num_int': 800,
#    'text': '-800. A varaino temo or Abacutaya? From the same . n. 3',
#    'people': None,
#    'places': None},
#   {'num_str': '-801.',
#    'num_int': 801,
#    'text': '-801. Dorados very small or young from the same . n. 2 221. ff',
#    'people': None,
#    'places': None},
#   {'num_str': '-802.',
#    'num_int': 802,
#    'text': '91 -802. Two Eggs of a thorn back taken out of their uterus by a fishmonger it had both Yolk & white. / with a grey Lizard O. 1 221. ff.',
#    'people': None,
#    'places': None},
#   {'num_str': '-803.',
#    'num_int': 803,
#    'text': '-803. Orbis piscis minor lævis, dorso Nigro lineis cinereis variegato, ventre candido. From M r. Burnet from Porto bell.',
#    'people': [{'id': None, 'name': 'M r. Burnet'}],
#    'places': None},
#   {'num_str': '-804.',
#    'num_int': 804,
#    'text': '-804. Raia minor clavis crebris radiatis donata. From Jamaica by M r. Barham.',
#    'people': [{'id': None, 'name': 'M r. Barham.'}],
#    'places': [{'id': 'Jamaica', 'name': 'Jamaica'}]},
#   {'num_str': '-805.',
#    'num_int': 805,
#    'text': '-805. The vertebre of a shark or whale petrified & draggd up with oysters near Sheernesse. From Dr. Thorpe. 221 c',
#    'people': [{'id': None, 'name': 'Dr. Thorpe.'}],
#    'places': [{'id': 'Sheerness', 'name': 'Sheernesse'}]},
#   {'num_str': '-806.',
#    'num_int': 806,
#    'text': '-806. The sword of a sword fish. Pet. 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '-807.',
#    'num_int': 807,
#    'text': '-807. The Jaw of a shark. Id. f <',
#    'people': None,
#    'places': None},
#   {'num_str': '-808.',
#    'num_int': 808,
#    'text': '-808. pisciculus capita quatuor spinis validis & acutis armato. Pet. f < p. 2',
#    'people': None,
#    'places': None},
#   {'num_str': '-809.',
#    'num_int': 809,
#    'text': '-809. Idem. p. 2',
#    'people': None,
#    'places': None},
#   {'num_str': '-810.',
#    'num_int': 810,
#    'text': '-810. Pisciculus unico cornu in capits parte pooter iori donatus. Id. n. 2',
#    'people': None,
#    'places': None},
#   {'num_str': '-811.',
#    'num_int': 811,
#    'text': '-811. Idem minor? Id. p. 4 6',
#    'people': None,
#    'places': None},
#   {'num_str': '-812.',
#    'num_int': 812,
#    'text': '92 -812. Pisciculus argeuleus? Pet. p. 2.',
#    'people': None,
#    'places': None},
#   {'num_str': '-813.',
#    'num_int': 813,
#    'text': '-813. Orbis minimus? Id. r. 8',
#    'people': None,
#    'places': None},
#   {'num_str': '-814.',
#    'num_int': 814,
#    'text': '-814. Sepiæ pars? Id. m. 3',
#    'people': None,
#    'places': None},
#   {'num_str': '-815.',
#    'num_int': 815,
#    'text': '-815. Patella articulata? Id. r. 8.',
#    'people': None,
#    'places': None},
#   {'num_str': '-816.',
#    'num_int': 816,
#    'text': '-816. Two small remoræ. Pet. o. 7',
#    'people': None,
#    'places': None},
#   {'num_str': '-817.',
#    'num_int': 817,
#    'text': '-817. Sepia. Id. m. 4',
#    'people': None,
#    'places': None},
#   {'num_str': '-818.',
#    'num_int': 818,
#    'text': '-818. Barbus major Cornubiensis cirris bifurcatis the great forked X beard. Ray. pise. syn. p. 163. fig. 7? Pet. p. 5',
#    'people': None,
#    'places': None},
#   {'num_str': '-819.',
#    'num_int': 819,
#    'text': '-819. pisciculus &c Id. p. 6 3',
#    'people': None,
#    'places': None},
#   {'num_str': '-820.',
#    'num_int': 820,
#    'text': '-820. Lyra cornuta. Id. n. 1',
#    'people': None,
#    'places': None},
#   {'num_str': '-821.',
#    'num_int': 821,
#    'text': '-821. Orbis albus nobulis fuscis notatus prægnaus. Id. w t. a young one n. 4 6.',
#    'people': None,
#    'places': None},
#   {'num_str': '-822.',
#    'num_int': 822,
#    'text': '-822. Harengus alatus vel piscis volaus miner. Id. n. 3',
#    'people': None,
#    'places': None},
#   {'num_str': '-823.',
#    'num_int': 823,
#    'text': '-823. Ijdem',
#    'people': None,
#    'places': None},
#   {'num_str': '-824.',
#    'num_int': 824,
#    'text': '-824. Acus? Encrasicholus? Shrimps? Id.',
#    'people': None,
#    'places': None},
#   {'num_str': '-825.',
#    'num_int': 825,
#    'text': '-825. A broad fish Scaled, of a brown colour. Id. p. 4 6',
#    'people': None,
#    'places': None},
#   {'num_str': '830.',
#    'num_int': 830,
#    'text': '92a 830. Ehenei, seu Remora, pesce, &c Imperati Napol. 1590. p. 779. Edit. 2 d. Venet. 1672. p. 684. Latin. Edit. p. 908.',
#    'people': None,
#    'places': None},
#   {'num_str': '826.',
#    'num_int': 826,
#    'text': '93 826. piscis Hanengiformis argenteus Squamis donatus. Lumbricus latus taken out of the same . Id et. o. 7',
#    'people': None,
#    'places': None},
#   {'num_str': '-827.',
#    'num_int': 827,
#    'text': '-827. Holothurius &c? n. 4',
#    'people': None,
#    'places': None},
#   {'num_str': '-828.',
#    'num_int': 828,
#    'text': '-828. Mola junior? Pet. o. 6. 3',
#    'people': None,
#    'places': None},
#   {'num_str': '-829.',
#    'num_int': 829,
#    'text': '-829. Serpens marinus e cinereo fuscus? Id. p. 3',
#    'people': None,
#    'places': None},
#   {'num_str': '-830.',
#    'num_int': 830,
#    'text': '-830. Remoræ. 3. Id. m. 4 6',
#    'people': None,
#    'places': None},
#   {'num_str': '-831.',
#    'num_int': 831,
#    'text': '-831. Idem. o. 3',
#    'people': None,
#    'places': None},
#   {'num_str': '-832.',
#    'num_int': 832,
#    'text': '-832. 1. Idem. 2. Acus? Id. p. 4 p. 3',
#    'people': None,
#    'places': None},
#   {'num_str': '-833.',
#    'num_int': 833,
#    'text': '-833. Piscis volans. Id. p. 4',
#    'people': None,
#    'places': None},
#   {'num_str': '-834.',
#    'num_int': 834,
#    'text': '-834. Idem. p. 4',
#    'people': None,
#    'places': None},
#   {'num_str': '-835.',
#    'num_int': 835,
#    'text': '-835. Hippocampus. Id. R. 3 221. ff',
#    'people': None,
#    'places': None},
#   {'num_str': '-836.',
#    'num_int': 836,
#    'text': '-836. Idem minor? Id. o. 2 221. ff',
#    'people': None,
#    'places': None},
#   {'num_str': '-837.',
#    'num_int': 837,
#    'text': '-837. Idem. m. 2. 6 o. 2 221. ff',
#    'people': None,
#    'places': None},
#   {'num_str': '-838.',
#    'num_int': 838,
#    'text': '-838. Acus? Id. o. 2 221. ff',
#    'people': None,
#    'places': None},
#   {'num_str': '-839.',
#    'num_int': 839,
#    'text': '-839. Serpens marinus minor? Id. p. 8 <',
#    'people': None,
#    'places': None},
#   {'num_str': '-840.',
#    'num_int': 840,
#    'text': '94 -840. Loligo. Pet. m. 2',
#    'people': None,
#    'places': None},
#   {'num_str': '-841.',
#    'num_int': 841,
#    'text': '-841. Abucataja Pis? Id. p. 3 6',
#    'people': None,
#    'places': None},
#   {'num_str': '-842.',
#    'num_int': 842,
#    'text': '-842. Spratts? m. 3 6',
#    'people': None,
#    'places': None},
#   {'num_str': '-843.',
#    'num_int': 843,
#    'text': '-843. Remoræ. p. 3 6',
#    'people': None,
#    'places': None},
#   {'num_str': '-844.',
#    'num_int': 844,
#    'text': '-844. A Cullistroy. Id. p. 3 6',
#    'people': None,
#    'places': None},
#   {'num_str': '-845.',
#    'num_int': 845,
#    'text': '-845. Urtica marina. Id. m. 3',
#    'people': None,
#    'places': None},
#   {'num_str': '-846.',
#    'num_int': 846,
#    'text': '-846. A sharks jaw from M r. Burnet. Id.',
#    'people': [{'id': None, 'name': 'M r. Burnet.'}],
#    'places': None},
#   {'num_str': '-847.',
#    'num_int': 847,
#    'text': '-847. Ova sepiæ? Id. m. 3. 221. ff.',
#    'people': None,
#    'places': None},
#   {'num_str': '-848.',
#    'num_int': 848,
#    'text': '-848. Uranoscopus junior? Id. Worm. p. 271. X m. 4 6',
#    'people': None,
#    'places': None},
#   {'num_str': '-849.',
#    'num_int': 849,
#    'text': '-849. Ovarium &c? Id. 221. ff',
#    'people': None,
#    'places': None},
#   {'num_str': '-850.',
#    'num_int': 850,
#    'text': '-850. Harengus Junior? Id. o. 2 6',
#    'people': None,
#    'places': None},
#   {'num_str': '-851.',
#    'num_int': 851,
#    'text': '-851. particula cutis piscis &c? Id. o. 2',
#    'people': None,
#    'places': None},
#   {'num_str': '-852.',
#    'num_int': 852,
#    'text': '-852. Large bone of a codfish from Virginia. Id. 221. e',
#    'people': None,
#    'places': [{'id': None, 'name': 'Virginia'}]},
#   {'num_str': '-853.',
#    'num_int': 853,
#    'text': '-853. Idem lesser. Id. 221. l.',
#    'people': None,
#    'places': None},
#   {'num_str': '-854.',
#    'num_int': 854,
#    'text': '-854. Sharkstone. Pulv. Id. 221. e',
#    'people': None,
#    'places': None},
#   {'num_str': '-855.',
#    'num_int': 855,
#    'text': '-855. A Small old wife. 2. A Silver fish like the ausata. Id.',
#    'people': None,
#    'places': None},
#   {'num_str': '-856.',
#    'num_int': 856,
#    'text': '95 -856. A large headed blackish fish. Pet. n. 2',
#    'people': None,
#    'places': None},
#   {'num_str': '-857.',
#    'num_int': 857,
#    'text': '-857. A large piscis triangularis. Id. f < 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '-858.',
#    'num_int': 858,
#    'text': '-858. A sharks vertebra. 221. c',
#    'people': None,
#    'places': None},
#   {'num_str': '-859.',
#    'num_int': 859,
#    'text': '-859. ✓ Piscis triangularis, apice acuto utrinqz, & areis radialis angulosis extantibus undiqz, obsitey. M rs. Alsop. 221. v',
#    'people': [{'id': None, 'name': 'M rs. Alsop.'}],
#    'places': None},
#   {'num_str': '-860.',
#    'num_int': 860,
#    'text': '-860. ✓ An old wife. Id. 221. p.',
#    'people': None,
#    'places': None},
#   {'num_str': '-861.',
#    'num_int': 861,
#    'text': '-861. ✓ Pisc is cornutus quad rangularis. Id. 221. a',
#    'people': None,
#    'places': None},
#   {'num_str': '-862.',
#    'num_int': 862,
#    'text': '-862. ✓ The fin of a seal black & white, Id. 221. v',
#    'people': None,
#    'places': None},
#   {'num_str': '-863.',
#    'num_int': 863,
#    'text': "-863. piscis parvus fuscas capite maxi mo. Pet. perish'd 221. c",
#    'people': None,
#    'places': None},
#   {'num_str': '-864.',
#    'num_int': 864,
#    'text': '-864. pisciculus dorso nigro frigro ventre argenteo. Id. Scarabeus cimex 221. c',
#    'people': None,
#    'places': None},
#   {'num_str': '-865.',
#    'num_int': 865,
#    'text': '-865. g 2 A broken piece of a large glosso= petra. Id. 221',
#    'people': None,
#    'places': None},
#   {'num_str': '-866.',
#    'num_int': 866,
#    'text': '-866. The vertebra of a shark. Id. 221. g',
#    'people': None,
#    'places': None},
#   {'num_str': '-867.',
#    'num_int': 867,
#    'text': '-867. Milvus Lyra? Id. 241. g',
#    'people': None,
#    'places': None},
#   {'num_str': '-868.',
#    'num_int': 868,
#    'text': '96 -868. Acus Chinensis maxima - corpore compresso. Pet. Gaz. tab 68. N o. 1. From China. b. 241.',
#    'people': None,
#    'places': [{'id': 'China', 'name': 'China'}]},
#   {'num_str': '-869.',
#    'num_int': 869,
#    'text': '-869. Hystrix piscis. From Jamaica Id.',
#    'people': None,
#    'places': [{'id': 'Jamaica', 'name': 'Jamaica'}]},
#   {'num_str': '-870.',
#    'num_int': 870,
#    'text': '-870. The Tail of an Albacore. Id. f <',
#    'people': None,
#    'places': None},
#   {'num_str': '-871',
#    'num_int': 871,
#    'text': '-871 22 W Glossopetra longa maxima cinerea non deutata. Id. 221. f',
#    'people': None,
#    'places': None},
#   {'num_str': '-872.',
#    'num_int': 872,
#    'text': '-872. ✓ Ovum Raiæob Long quadratum filamertis donatum pellucid an- e cinereo rubrum. Pet. 221. n',
#    'people': None,
#    'places': None},
#   {'num_str': '-873.',
#    'num_int': 873,
#    'text': '-873. Idem nigrum quadratum. # Id. 221. g',
#    'people': None,
#    'places': None},
#   {'num_str': '-874.',
#    'num_int': 874,
#    'text': '-874. Idem sine filamentis. Id. 221. g',
#    'people': None,
#    'places': None},
#   {'num_str': '-876. -875',
#    'num_int': 876,
#    'text': '-876. -875 Acus piscis. Id. 221. c',
#    'people': None,
#    'places': None},
#   {'num_str': '-877.',
#    'num_int': 877,
#    'text': '-877. Ovarium? Id. vid. Tessa N o. 768 303. c.',
#    'people': None,
#    'places': None},
#   {'num_str': '-878.',
#    'num_int': 878,
#    'text': '-878. Raia clavata? Id.',
#    'people': None,
#    'places': None},
#   {'num_str': '-879.',
#    'num_int': 879,
#    'text': '-879. Hystrix piseis? Id. < 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '-880.',
#    'num_int': 880,
#    'text': '-880. Orbis minor fuscus angulosus spinosus. Pet. Philippines? o. 3',
#    'people': None,
#    'places': [{'id': 'Philippines', 'name': 'Philippines'}]},
#   {'num_str': '-881.',
#    'num_int': 881,
#    'text': '-881. Piseiculus e luteo fuseus. Id. n. 2',
#    'people': None,
#    'places': None},
#   {'num_str': '-882.',
#    'num_int': 882,
#    'text': '-882. Piseiculus dorso fusco, ventre arg',
#    'people': None,
#    'places': None},
#   {'num_str': '-883.',
#    'num_int': 883,
#    'text': "97 -883. The sceleton of a dolphin or porpus's head. f < CLXXVI 299.",
#    'people': None,
#    'places': None},
#   {'num_str': '-884.',
#    'num_int': 884,
#    'text': '-884. A very large old wife. f 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '-885.',
#    'num_int': 885,
#    'text': '-885. Hystrix piscis. Pet. 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '-886.',
#    'num_int': 886,
#    'text': '-886. Lupus? Id. f < 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '-887.',
#    'num_int': 887,
#    'text': '-887. Chagrin skin. Id. 209 239.',
#    'people': None,
#    'places': None},
#   {'num_str': '-888.',
#    'num_int': 888,
#    'text': '-888. A young Sturgeon. Id. b 241.',
#    'people': None,
#    'places': None},
#   {'num_str': '-889.',
#    'num_int': 889,
#    'text': '-889. Milvus salviani? M rs Id. Alsop.',
#    'people': [{'id': None, 'name': 'M rs Id.'},
#     {'id': None, 'name': 'Alsop.'}],
#    'places': None},
#   ...],
#  'title': 'Fishes.',
#  'length': 1606}

# %% [markdown]
# #### What is the first catalogue?

# %%
# Print title of first catalogue
cats[0]['title']
# Out:
# 'Fishes.'

# %% [markdown]
# #### How many catalogue entries?

# %%
# Print number of entries in first catalogue
len(cats[0]['entries'])
# Out:
# 1606

# %% [markdown]
# #### What is the first entry?

# %%
# Print first entry
cats[0]['entries'][0]
# Out:
# {'num_str': '-1484.',
#  'num_int': 1484,
#  'text': '-1484. A very large sharks jaw from the coast of Guinea. 241 f <',
#  'people': None,
#  'places': [{'id': 'Guinea', 'name': 'Guinea'}]}

# %% [markdown]
# #### Put all the data in a dataframe

# %%
# List of dataframes
dataframes = []

# For each catalogue (excluding indexes)...
for cat in [x for i, x in enumerate(cats) if i not in (3, 6)]:

    # Create dataframe from each catalogue
    df = pd.DataFrame(cat['entries'])

    # Set visualisation options
    pd.options.display.precision = 0

    # Print the dataframe
    df

    # Drop nulls
    df = df.dropna(subset=['num_int'])

    # Sort by entry number
    df = df.sort_values(by=['num_int'])
    
    # Append dataframe to list
    dataframes.append(df)

# Print the first dataframe
dataframes[0]
# Out:
#     num_str  num_int                                               text  \
# 19       1.        1  3 Fishes. 1. Canis Carchariæ alt. Spec. u. p. ...
# 20       2.        2                     2. Canis Carchariæ pinna. 241.
# 21       3.        3               3. Canis Carchariæ cauda. 4 f < 241.
# 22       4.        4           4. Canis Carchariæ mandibulæ. f < 241 &c
# 23       5.        5  5. A black slate with the impression of a fish...
# ..      ...      ...                                                ...
# 191   1559.     1559  8a 1559. The Head of a large Fish described by...
# 192   1560.     1560  1560. Sp. Roon A pair of large Fins of some fi...
# 193   1561.     1561         1561. Sp. Roon A young Shark stuff'd. D o.
# 194    1562     1562                   1562 A small orbis. D o. 221. p.
# 195   1563.     1563              1563. The same w t. 1490. D o. 221. i
#
#                                 people places
# 19                                None   None
# 20                                None   None
# 21                                None   None
# 22                                None   None
# 23                                None   None
# ..                                 ...    ...
# 191  [{'id': None, 'name': 'Catesby'}]   None
# 192                               None   None
# 193                               None   None
# 194                               None   None
# 195                               None   None
#
# [1598 rows x 5 columns]

# %% [markdown]
# #### Declare prefixes and create graph

# %%
# Create namespaces
slb=Namespace("http://sloanelab.org/");
ecrm=Namespace("http://erlangen-crm.org/current/");
crmdig=Namespace("http://www.ics.forth.gr/isl/CRMdig/");

# Create graph
graph = rdflib.Graph()

# Bind prefixes
graph.bind("slb", slb)
graph.bind("ecrm", ecrm)
graph.bind("crmdig", crmdig)

# %% [markdown]
# #### Add catalogues

# %%
# Manuscript
msIRI = slb[f'E22/fossils_v'];
graph.add((msIRI, RDF.type, ecrm['E22_Human-Made_Object']))
graph.add((msIRI, ecrm.P2_has_type, slb['E22/manuscript']))
graph.add((msIRI, RDFS.label, Literal('Fossils V')))

# XML
xmlIRI = slb[f'D1/fossils_v'];
graph.add((xmlIRI, RDF.type, crmdig.D1_Digital_Object))
graph.add((xmlIRI, ecrm.P2_has_type, slb['E55/historical_dataset']))
graph.add((xmlIRI, RDFS.label, Literal('Fossils V')))

# Link XML to manuscript
graph.add((xmlIRI, slb['P130.10_contains_elements_of'], msIRI))

# Catalogues
cat1IRI = slb[f'E73/fishes'];
graph.add((cat1IRI, RDF.type, ecrm.E73_Information_Object))
graph.add((cat1IRI, ecrm.P2_has_type, slb['E55/historical_catalogue']))
graph.add((cat1IRI, RDFS.label, Literal('Fishes')))

cat2IRI = slb[f'E73/birds'];
graph.add((cat2IRI, RDF.type, ecrm.E73_Information_Object))
graph.add((cat2IRI, ecrm.P2_has_type, slb['E55/historical_catalogue']))
graph.add((cat2IRI, RDFS.label, Literal('Birds')))

cat3IRI = slb[f'E73/eggs'];
graph.add((cat3IRI, RDF.type, ecrm.E73_Information_Object))
graph.add((cat3IRI, ecrm.P2_has_type, slb['E55/historical_catalogue']))
graph.add((cat3IRI, RDFS.label, Literal('Eggs')))

cat4IRI = slb[f'E73/quadrupeds'];
graph.add((cat4IRI, RDF.type, ecrm.E73_Information_Object))
graph.add((cat4IRI, ecrm.P2_has_type, slb['E55/historical_catalogue']))
graph.add((cat4IRI, RDFS.label, Literal('Quadrupeds')))

graph.add((xmlIRI, ecrm.P148_has_component, cat1IRI))
graph.add((xmlIRI, ecrm.P148_has_component, cat2IRI))
graph.add((xmlIRI, ecrm.P148_has_component, cat3IRI))
graph.add((xmlIRI, ecrm.P148_has_component, cat4IRI))
# Out:
# <Graph identifier=N0461e413b2a34b459b59d33c533babe9 (<class 'rdflib.graph.Graph'>)>

# %%
catNames = ['fishes', 'birds', 'eggs', 'quadrupeds']

# For each dataframe...
for i, df in enumerate(dataframes):

  # For each row in the dataframe...
  for index, row in df.iterrows():
    
    # Get entry number
    entryNumStr = row["num_str"]
    entryNumInt = int(row["num_int"])
    
    # Get entry text
    entryText = row["text"]
    
    # Get people and places
    people = row["people"] or []
    places = row["places"] or []
    
    # Create entry IRI
    entryIRI = slb[f'E73/{catNames[i]}/{entryNumInt}'];
    
    # Create page IRI
    # pageIRI = slb[f'E19/miscellanies/{pageID}'];

    catTitle = titlecase.titlecase(catNames[i].replace('_',' '))
    
    # Add entry to graph
    graph.add((entryIRI, RDF.type, ecrm.E73_Information_Object))
    graph.add((entryIRI, RDFS.label, Literal(f'{catTitle} Entry {entryNumInt}')))
    graph.add((entryIRI, ecrm.P2_has_type, slb['E55/catalogue_entry']))
    
    # Add entry text to graph
    graph.add((entryIRI, ecrm.P190_has_symbolic_content, Literal(entryText)))
    
    # Add entry number to graph
    graph.add((entryIRI, ecrm.P1_is_identified_by, Literal(entryNumStr)))
    
    # Add page to graph
    # graph.add((pageIRI, RDF.type, ecrm.E19_Physical_Object))
   
    # Connect entry to page
    # graph.add((pageIRI, ecrm.P128_carries, entryIRI))
    
    # Connect entry to catalogue
    graph.add((slb[f'E73/{catNames[i]}'], ecrm.P148_has_component, entryIRI))
    
    # Create object IRI
    objIRI = slb[f'E19/{catNames[i]}/{entryNumInt}'];
    
    # Connect entry to object
    graph.add((objIRI, RDF.type, ecrm.E19_Physical_Object))
    graph.add((objIRI, RDFS.label, Literal(f'{catTitle} Object {entryNumInt}')))
    graph.add((entryIRI, ecrm.P129_is_about, objIRI))

    # For each person...
    for person in people:
        
        if not person["id"]:
            print(person)
        else:
            # Create person IRI
            personIRI = slb[f'E21/{person["id"].strip().replace(" ", "_")}'];
        
            # Connect person to entry
            graph.add((entryIRI, ecrm.P67_refers_to, personIRI))

    # For each place...
    for place in places:
        
        # Create place IRI
        try:
            placeIRI = slb[f'E53/{place["id"].strip().replace(" ", "_")}'];
        except AttributeError:
            print(place["id"])
        else:
            graph.add((entryIRI, ecrm.P67_refers_to, placeIRI))
# Out:
# None
# {'id': None, 'name': 'M r. Maidstone.'}
# None
# None
# {'id': None, 'name': 'Reaumur'}
# {'id': None, 'name': 'D. F.'}
# {'id': None, 'name': 'M r. Fortrey'}
# {'id': None, 'name': 'Coll. Wharton.'}
# {'id': None, 'name': 'Dr. Preston.'}
# {'id': None, 'name': 'Dr. Waldo'}
# None
# {'id': None, 'name': 'Bell'}
# None
# None
# None
# None
# None
# {'id': None, 'name': 'Dr. Leigh'}
# {'id': None, 'name': 'M r. Massy'}
# None
# {'id': None, 'name': 'Dr. Walraven'}
# {'id': None, 'name': 'M r. Beverland.'}
# {'id': None, 'name': 'M r. Bonivert.'}
# None
# None
# {'id': None, 'name': 'Clark'}
# {'id': None, 'name': 'Bell.'}
# {'id': None, 'name': 'Dampier'}
# None
# {'id': None, 'name': 'D. N'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'M r. Floyd'}
# {'id': None, 'name': 'Dr. Robinson.'}
# {'id': None, 'name': 'M r. Floid.'}
# {'id': None, 'name': 'M r. Floid.'}
# {'id': None, 'name': 'D. Floid.'}
# {'id': None, 'name': 'M r. Petiver.'}
# {'id': None, 'name': 'D r. Preston.'}
# {'id': None, 'name': 'Dr. Stuart.'}
# None
# None
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'M r. Edwin.'}
# None
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'D r. Lavater.'}
# {'id': None, 'name': 'Lluid.'}
# None
# {'id': None, 'name': 'Dr. sterard'}
# {'id': None, 'name': 'Courten.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'M r. Viller'}
# None
# {'id': None, 'name': 'M r. Vernon.'}
# {'id': None, 'name': 'Dr. Robinson.'}
# None
# None
# {'id': None, 'name': 'M r. Vernon'}
# {'id': None, 'name': 'M r. Vernon'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'M r. Vernon'}
# {'id': None, 'name': 'Vernon'}
# {'id': None, 'name': 'Dr. Krieg.'}
# {'id': None, 'name': 'M r. Vernons.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Vernon'}
# None
# {'id': None, 'name': 'M r. Vernon.'}
# {'id': None, 'name': 'M r. Vernon'}
# {'id': None, 'name': 'Dr. Plott.'}
# {'id': None, 'name': 'Dr. Lavater.'}
# {'id': None, 'name': 'Dr. Stuart.'}
# {'id': None, 'name': 'M r. Hill.'}
# None
# {'id': None, 'name': 'Dr. Stuart.'}
# None
# None
# None
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'M r. Lluid.'}
# {'id': None, 'name': 'Lluid.'}
# None
# {'id': None, 'name': 'M r. Clerk.'}
# {'id': None, 'name': 'Earl of Arundel'}
# {'id': None, 'name': 'Dr. Leigh'}
# None
# None
# {'id': None, 'name': 'M r. Vernon.'}
# {'id': None, 'name': 'M r. Gore.'}
# None
# {'id': None, 'name': 'M r. Hicks'}
# {'id': None, 'name': 'M r. Hodges.'}
# {'id': None, 'name': 'Dr. Adair.'}
# None
# {'id': None, 'name': 'Dr. Dolnas.'}
# {'id': None, 'name': 'Dr. Br.'}
# None
# {'id': None, 'name': 'Dr. Br.'}
# {'id': None, 'name': 'Dr. Br.'}
# {'id': None, 'name': 'D r'}
# {'id': None, 'name': 'S r. Tho. Brown.'}
# {'id': None, 'name': 'Dr. Br.'}
# {'id': None, 'name': 'S t. Thomas Brown.'}
# {'id': None, 'name': 'S r. Tho. Brown.'}
# {'id': None, 'name': 'Dr. Br.'}
# {'id': None, 'name': 'Dr. Br.'}
# {'id': None, 'name': 'Dr. Br.'}
# None
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Lluid.'}
# None
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'M r. Ayrie.'}
# {'id': None, 'name': 'M r. Ayrie.'}
# {'id': None, 'name': 'M r. Hodges.'}
# {'id': None, 'name': 'Dr. Colas of Prussia.'}
# {'id': None, 'name': 'Lady Coply'}
# {'id': None, 'name': 'D r. Massy.'}
# None
# {'id': None, 'name': 'Dr. Colas'}
# None
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Lluid.'}
# None
# {'id': None, 'name': 'M r. Lluids'}
# {'id': None, 'name': 'Lluid.'}
# None
# {'id': None, 'name': 'M r. O.'}
# {'id': None, 'name': 'Duke of Rutland.'}
# None
# {'id': None, 'name': 'M r. Maidstone'}
# {'id': None, 'name': 'M r. Lawson.'}
# None
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'Dr. Plott.'}
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'Dr. Waldo.'}
# {'id': None, 'name': 'Waldo.'}
# None
# None
# {'id': None, 'name': 'Dr. Brown'}
# {'id': None, 'name': 'Dr. Waldo.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Newton'}
# None
# {'id': None, 'name': 'Dr. Lavater'}
# {'id': None, 'name': 'M r. Lluid.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Dr. Lavater.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'M r. Lluid.'}
# {'id': None, 'name': 'Dr. Lavater.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'M r. Lluid.'}
# {'id': None, 'name': 'D r. Lavater.'}
# {'id': None, 'name': 'M r. Lluid'}
# {'id': None, 'name': 'Dr. Lavater.'}
# {'id': None, 'name': 'Lluid'}
# {'id': None, 'name': 'M r. Lluid.'}
# {'id': None, 'name': 'D. Lavater.'}
# {'id': None, 'name': 'D r. Lavater.'}
# {'id': None, 'name': 'Dr. Lavater.'}
# {'id': None, 'name': 'D r. Lavater.'}
# {'id': None, 'name': 'M r. Hodges.'}
# {'id': None, 'name': 'M r. Beverland.'}
# {'id': None, 'name': 'Dr. Lister.'}
# None
# {'id': None, 'name': 'M r. Bradyll.'}
# {'id': None, 'name': 'M r. Bradyll.'}
# None
# {'id': None, 'name': 'Mong r.- Masson'}
# {'id': None, 'name': 'M r. Staphorst.'}
# {'id': None, 'name': 'M r. Burnet'}
# {'id': None, 'name': 'M r. Barham.'}
# {'id': None, 'name': 'Dr. Thorpe.'}
# {'id': None, 'name': 'M r. Burnet.'}
# None
# {'id': None, 'name': 'M rs. Alsop.'}
# {'id': None, 'name': 'M rs Id.'}
# {'id': None, 'name': 'Alsop.'}
# {'id': None, 'name': 'D r. Stiegertahl.'}
# {'id': None, 'name': 'M r. Barham'}
# {'id': None, 'name': 'S t. George'}
# {'id': None, 'name': 'Faucett.'}
# {'id': None, 'name': 'Dr. Steigertahl.'}
# {'id': None, 'name': 'Capt and'}
# {'id': None, 'name': 'Pate.'}
# None
# {'id': None, 'name': 'D r. Oldfield'}
# {'id': None, 'name': 'M r. Heathcote'}
# {'id': None, 'name': 'Dr. Kempfer.'}
# None
# {'id': None, 'name': 'M r. Dupuys'}
# {'id': None, 'name': 'M r. Clark.'}
# {'id': None, 'name': 'M r. duprys.'}
# {'id': None, 'name': 'M r. Catesby'}
# None
# {'id': None, 'name': 'Dr. Kempfer.'}
# {'id': None, 'name': 'S t. Petr.'}
# {'id': None, 'name': 'M rs. Isted.'}
# {'id': None, 'name': 'M r. Van milder'}
# {'id': None, 'name': 'M r. Theobalds'}
# None
# {'id': None, 'name': 'Coll. Nicholson.'}
# {'id': None, 'name': 'M r. Elking.'}
# {'id': None, 'name': 'Dr. Boylston.'}
# {'id': None, 'name': 'M r. Andrews'}
# {'id': None, 'name': 'M r. Ranby.'}
# {'id': None, 'name': 'Dr. Schenchzer'}
# None
# None
# None
# {'id': None, 'name': 'Dr. Richardson.'}
# {'id': None, 'name': 'M r. Lockyer'}
# None
# {'id': None, 'name': 'Dr. Schenchezer.'}
# {'id': None, 'name': 'M r. Ranby.'}
# {'id': None, 'name': 'M r. Haseman.'}
# {'id': None, 'name': 'S t. Giler'}
# {'id': None, 'name': 'M r. Smith.'}
# None
# {'id': None, 'name': 'M r. Bell.'}
# {'id': None, 'name': 'M r. Clerk.'}
# None
# {'id': None, 'name': 'Governor Bennet.'}
# {'id': None, 'name': 'M rs. Dering.'}
# {'id': None, 'name': 'M r. Clerk.'}
# None
# None
# None
# {'id': None, 'name': 'S t. Thomas Dereham.'}
# {'id': None, 'name': 'Dr. Wood'}
# {'id': None, 'name': 'M r. Martyn'}
# None
# {'id': None, 'name': 'scheuchzer'}
# {'id': None, 'name': 'M r. Linck'}
# {'id': None, 'name': 'M r. Elking.'}
# {'id': None, 'name': 'M r. Hoaston.'}
# {'id': None, 'name': 'M r. Tollman'}
# {'id': None, 'name': 'M r. Tollman'}
# {'id': None, 'name': 'M rs. Dering'}
# None
# {'id': None, 'name': 'Dr. Krieg'}
# {'id': None, 'name': 'Woodward.'}
# {'id': None, 'name': 'M r. Barrets'}
# {'id': None, 'name': 'M r. Ranby.'}
# {'id': None, 'name': 'M r. Joes.'}
# {'id': None, 'name': 'M r. Clerk.'}
# None
# {'id': None, 'name': 'Lawson.'}
# None
# None
# None
# {'id': None, 'name': 'M r. Maidstone.'}
# {'id': None, 'name': 'Cap t. Staines.'}
# {'id': None, 'name': 'M r. Maidstone.'}
# {'id': None, 'name': 'M r. Bignall.'}
# {'id': None, 'name': 'M r. Green.'}
# {'id': None, 'name': 'M r. Haines.'}
# {'id': None, 'name': 'M r. Maidstone.'}
# {'id': None, 'name': 'S t. Paul'}
# {'id': None, 'name': 'Coll. Johnson'}
# {'id': None, 'name': 'Catesby'}
# {'id': None, 'name': 'M r. Newton.'}
# {'id': None, 'name': 'Dr. Honston.'}
# None
# None
# None
# None
# None
# {'id': None, 'name': 'Dr. Gray'}
# {'id': None, 'name': 'Dr. Mortimer.'}
# None
# {'id': None, 'name': 'M r. Clerk.'}
# None
# {'id': None, 'name': 'S t. Mathew Decker'}
# {'id': None, 'name': 'M r. Bevan'}
# {'id': None, 'name': 'S Jo. Shadwa'}
# {'id': None, 'name': 'Cap t. Win'}
# {'id': None, 'name': 'Walker'}
# {'id': None, 'name': 'M r. Godfreys'}
# None
# None
# {'id': None, 'name': 'Dr. Houston.'}
# {'id': None, 'name': 'M r. Gough.'}
# {'id': None, 'name': 'Lord de la walls'}
# {'id': None, 'name': 'M r. Talbot'}
# {'id': None, 'name': 'r. Barrow.'}
# {'id': None, 'name': 'Dr. Grews'}
# None
# {'id': None, 'name': 'M r. Caldecutt.'}
# {'id': None, 'name': 'M r. James White'}
# {'id': None, 'name': 'Brown'}
# None
# {'id': None, 'name': 'M r. Burton'}
# {'id': None, 'name': 'M r. Ranby.'}
# {'id': None, 'name': 'M r. Mill'}
# {'id': None, 'name': 'Dr. Massy.'}
# {'id': None, 'name': 'Cardinall Gualtueris'}
# {'id': None, 'name': 'M r. Millar.'}
# {'id': None, 'name': 'M r. Edgcomb'}
# {'id': None, 'name': 'M r. Ric'}
# {'id': None, 'name': 'D. p.'}
# None
# {'id': None, 'name': 'M r. James'}
# {'id': None, 'name': 'Christian. Maximilian Spener'}
# {'id': None, 'name': 'M r. Jones.'}
# None
# {'id': None, 'name': 'M r Jones'}
# {'id': None, 'name': 'W m Bradlay'}
# {'id': None, 'name': 'Hugh Jones'}
# {'id': None, 'name': 'Dr. Massy.'}
# {'id': None, 'name': 'M r. Ranby.'}
# {'id': None, 'name': 'Lluid'}
# None
# {'id': None, 'name': 'Lluid'}
# {'id': None, 'name': 'M r. Morton.'}
# None
# None
# {'id': None, 'name': 'Lluid.'}
# None
# {'id': None, 'name': 'M r. Lluid.'}
# None
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'Capt. Craford'}
# None
# {'id': None, 'name': 'M r. Bell.'}
# {'id': None, 'name': 'M r. Bell'}
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'Ms. add.'}
# {'id': None, 'name': 'M r. Lluid'}
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'Lluid.'}
# None
# {'id': None, 'name': 'Heuch.'}
# {'id': None, 'name': 'Heuch'}
# {'id': None, 'name': 'Erhart.'}
# {'id': None, 'name': 'Erhart.'}
# {'id': None, 'name': 'Erhart.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Heuch.'}
# {'id': None, 'name': 'M r. Patrick. Adams.'}
# None
# {'id': None, 'name': 'Cap t. Craford.'}
# None
# {'id': None, 'name': 'M r. Winthorp'}
# None
# {'id': None, 'name': 'M r. Houstoun'}
# {'id': None, 'name': 'M rs. Louther.'}
# {'id': None, 'name': 'M r. Winthorpe'}
# {'id': None, 'name': 'M r. Oglethorp.'}
# {'id': None, 'name': 'M r. Fabre.'}
# {'id': None, 'name': 'M r. Winthorp.'}
# {'id': None, 'name': 'M r. Consett'}
# {'id': None, 'name': 'Dr. Mortemar'}
# {'id': None, 'name': 'M r. Bell.'}
# {'id': None, 'name': 'Cap t. Craford.'}
# {'id': None, 'name': 'M r. Craford'}
# None
# {'id': None, 'name': 'M r. Beerly.'}
# {'id': None, 'name': 'M r. Jenkins.'}
# {'id': None, 'name': 'M r. Clarke.'}
# {'id': None, 'name': 'Cap t. Crayfoot'}
# {'id': None, 'name': 'Cap t. Cray'}
# None
# {'id': None, 'name': 'M r. Adams.'}
# {'id': None, 'name': 'M r. Clarke.'}
# {'id': None, 'name': 'M r. Laurie.'}
# {'id': None, 'name': 'M r. Adams'}
# {'id': None, 'name': 'Cap t. Crayfoot.'}
# {'id': None, 'name': 'Cap t. Blithouse.'}
# None
# {'id': None, 'name': 'M r. Catesby.'}
# {'id': None, 'name': 'Dr. Hampe.'}
# {'id': None, 'name': 'M r. Theobalds.'}
# {'id': None, 'name': 'M r. Copping.'}
# {'id': None, 'name': 'M r. Swymmer.'}
# None
# {'id': None, 'name': 'Cap t. Jenkins.'}
# None
# {'id': None, 'name': 'M r. M'}
# {'id': None, 'name': 'Cap t. Walker.'}
# {'id': None, 'name': 'M r. Burnards'}
# {'id': None, 'name': 'M r. Bernards'}
# {'id': None, 'name': 'James'}
# {'id': None, 'name': 'Cap t. Craycoot'}
# {'id': None, 'name': 'M r. John Morse'}
# {'id': None, 'name': 'M r. Catesby'}
# {'id': None, 'name': 'M r. Payne.'}
# {'id': None, 'name': 'M r. Barret'}
# {'id': None, 'name': 'Capt. Craycoot.'}
# {'id': None, 'name': 'D r. Massy.'}
# None
# {'id': None, 'name': 'M r. Edgcomb'}
# {'id': None, 'name': 'Brown'}
# {'id': None, 'name': 'M r. Hodgson.'}
# {'id': None, 'name': 'Niece sloane'}
# {'id': None, 'name': 'M r. Panlet'}
# {'id': None, 'name': 'S r. Monti'}
# {'id': None, 'name': 'M r. Nichols.'}
# None
# {'id': None, 'name': 'M r. Clerk.'}
# {'id': None, 'name': 'M r. Ames.'}
# {'id': None, 'name': 'Dr. Browning'}
# {'id': None, 'name': 'M rs. Hall'}
# {'id': None, 'name': 'M r. Clerk'}
# {'id': None, 'name': 'M r. Clerk'}
# {'id': None, 'name': 'Dr. Mead'}
# {'id': None, 'name': 'Dr. Stack'}
# {'id': None, 'name': 'Edwards'}
# {'id': None, 'name': 'Duke of Richmond'}
# {'id': None, 'name': 'Stack'}
# {'id': None, 'name': 'Catesby'}
# {'id': None, 'name': 'Dr. Stuart.'}
# {'id': None, 'name': 'Dr. Stuart.'}
# {'id': None, 'name': 'M r. Courten.'}
# {'id': None, 'name': 'Courten.'}
# None
# {'id': None, 'name': 'M r. Edwards'}
# None
# {'id': None, 'name': 'D r. Massy'}
# None
# None
# {'id': None, 'name': 'Scarburgh'}
# {'id': None, 'name': 'M r. Beverland.'}
# {'id': None, 'name': 'Green'}
# None
# {'id': None, 'name': 'Wood'}
# None
# None
# None
# {'id': None, 'name': 'M r. - Martin.'}
# {'id': None, 'name': 'S t. Kilda.'}
# None
# None
# {'id': None, 'name': 'Edwards.'}
# {'id': None, 'name': 'M r. Edwards.'}
# {'id': None, 'name': 'D r. 0. 1. 0. Walraven.'}
# {'id': None, 'name': 'M r. Cunningham.'}
# None
# None
# {'id': None, 'name': 'M r. Martin.'}
# None
# {'id': None, 'name': 'Hern'}
# {'id': None, 'name': 'M r. Petiver.'}
# {'id': None, 'name': 'Dr. Stuart'}
# None
# {'id': None, 'name': 'Dr. Stuart.'}
# None
# {'id': None, 'name': 'M r. Gore.'}
# {'id': None, 'name': 'M r. Courten'}
# {'id': None, 'name': 'Dr. Sherard.'}
# {'id': None, 'name': 'Dr. Sherard'}
# None
# {'id': None, 'name': 'Dr. Richardson'}
# {'id': None, 'name': 'D. from'}
# None
# {'id': None, 'name': 'Cap t. Carr'}
# {'id': None, 'name': 'Cap t. Hatton.'}
# None
# {'id': None, 'name': 'D r. Dolnus'}
# None
# {'id': None, 'name': 'M r. Urry'}
# {'id': None, 'name': 'Dean Hicks'}
# {'id': None, 'name': 'M r. Fuller'}
# None
# None
# None
# {'id': None, 'name': 'S r. Tho. Brown'}
# {'id': None, 'name': 'Dr. Br.'}
# {'id': None, 'name': 'Dr. S. Br.'}
# {'id': None, 'name': 'M r. Robinson'}
# {'id': None, 'name': 'Dr. S.'}
# {'id': None, 'name': 'Dr. Brown.'}
# {'id': None, 'name': 'Dr. Br.'}
# None
# {'id': None, 'name': 'M r. orc'}
# {'id': None, 'name': 'M r. Morton'}
# {'id': None, 'name': 'D r. Brown.'}
# {'id': None, 'name': 'Ld Abbington'}
# None
# {'id': None, 'name': 'M r. Beaumont.'}
# {'id': None, 'name': 'Lord Abbington'}
# {'id': None, 'name': 'Lawson.'}
# {'id': None, 'name': 'May'}
# None
# {'id': None, 'name': 'Krieg.'}
# None
# {'id': None, 'name': 'Lawson.'}
# {'id': None, 'name': 'Lawson.'}
# None
# {'id': None, 'name': 'Mort.'}
# {'id': None, 'name': 'M r. Robertson.'}
# {'id': None, 'name': 'M r. Hicks.'}
# {'id': None, 'name': 'M r. Staphorst.'}
# {'id': None, 'name': 'M r. Lawson'}
# None
# {'id': None, 'name': 'Lawson.'}
# {'id': None, 'name': 'Lawson.'}
# {'id': None, 'name': 'Lawson.'}
# {'id': None, 'name': 'Lawson.'}
# {'id': None, 'name': 'Lawson.'}
# {'id': None, 'name': 'Lawson.'}
# {'id': None, 'name': 'Lawson.'}
# {'id': None, 'name': 'Lawson.'}
# {'id': None, 'name': 'Dr. Krieg'}
# {'id': None, 'name': 'Lawson.'}
# None
# None
# {'id': None, 'name': 'M r. Beverland.'}
# {'id': None, 'name': 'S t. Lucar'}
# {'id': None, 'name': 'S t. Joseph Hodges.'}
# {'id': None, 'name': 'M r. Maidstone.'}
# {'id': None, 'name': 'M r. Barham.'}
# {'id': None, 'name': 'M r. Roberts.'}
# None
# {'id': None, 'name': 'M rs. Alsop.'}
# None
# {'id': None, 'name': 'S r. Robert Child'}
# {'id': None, 'name': 'M r. Williams'}
# {'id': None, 'name': 'Capt. Walker.'}
# None
# {'id': None, 'name': 'Green'}
# {'id': None, 'name': 'M r. Hamilton.'}
# {'id': None, 'name': 'Dr. Musgraw'}
# {'id': None, 'name': 'Dr. Richardson.'}
# {'id': None, 'name': 'M r. Faucett'}
# None
# {'id': None, 'name': 'M r. Jesson'}
# {'id': None, 'name': 'M rs. Colleton'}
# {'id': None, 'name': 'M rs. Colleton'}
# None
# {'id': None, 'name': 'Dr. Kempfer.'}
# None
# {'id': None, 'name': 'M r. Dupuys'}
# None
# {'id': None, 'name': 'M r. Catesby.'}
# {'id': None, 'name': 'M r. Catesby'}
# {'id': None, 'name': 'Dr. Richardson.'}
# {'id': None, 'name': 'M r. Dupuys.'}
# {'id': None, 'name': 'M r. Catesby'}
# {'id': None, 'name': 'M r. Edw'}
# None
# {'id': None, 'name': 'M r. Bell.'}
# {'id': None, 'name': 'Dr. Lewis.'}
# {'id': None, 'name': 'M r. Ranby.'}
# {'id': None, 'name': 'M r. Catesby'}
# {'id': None, 'name': 'Catesby.'}
# {'id': None, 'name': 'M r. Ranby.'}
# {'id': None, 'name': 'M rs. Newport.'}
# {'id': None, 'name': 'M r. Ranby.'}
# {'id': None, 'name': 'M r. Ranby.'}
# None
# None
# None
# {'id': None, 'name': 'M r. Norman'}
# {'id': None, 'name': 'Dr. Oldfield.'}
# None
# {'id': None, 'name': 'M r. Elking.'}
# {'id': None, 'name': 'M r. Shipton.'}
# None
# {'id': None, 'name': 'Dr. Richardson'}
# {'id': None, 'name': 'Lady Ferrers'}
# {'id': None, 'name': 'M r. Elking.'}
# {'id': None, 'name': 'M r. Catesby.'}
# {'id': None, 'name': 'Dr. Massy.'}
# {'id': None, 'name': 'Cap t Fielding.'}
# {'id': None, 'name': 'M r. Heneage.'}
# {'id': None, 'name': 'Dr. Richardson.'}
# {'id': None, 'name': 'M r. Johnson'}
# {'id': None, 'name': 'Dr. Richardson.'}
# None
# {'id': None, 'name': 'M r. Clerk.'}
# None
# {'id': None, 'name': 'M r. Clerk.'}
# None
# None
# None
# {'id': None, 'name': 'M r. Elking'}
# None
# {'id': None, 'name': 'Dr. Brynius'}
# {'id': None, 'name': 'Dr. Richardson.'}
# {'id': None, 'name': 'Dr. Richardson'}
# {'id': None, 'name': 'Lord Westmoreland'}
# {'id': None, 'name': 'M r. Ranby.'}
# None
# {'id': None, 'name': 'M r. Clerk.'}
# None
# {'id': None, 'name': 'M r. Clerk.'}
# {'id': None, 'name': 'Catesby.'}
# None
# {'id': None, 'name': 'Catesby.'}
# {'id': None, 'name': 'Catesby.'}
# {'id': None, 'name': 'M r. Clark'}
# {'id': None, 'name': 'M r. Maidstone.'}
# {'id': None, 'name': 'M r. Dubois.'}
# None
# {'id': None, 'name': 'M r. Edwards'}
# {'id': None, 'name': 'M r. Theobalds.'}
# {'id': None, 'name': 'Catesby.'}
# {'id': None, 'name': 'Duke of Cumberland.'}
# {'id': None, 'name': 'M r. Moubray.'}
# {'id': None, 'name': 'M r. Bell.'}
# {'id': None, 'name': 'M r. Miller.'}
# {'id': None, 'name': 'Cap t. Uring'}
# {'id': None, 'name': 'M r. Houstoun.'}
# {'id': None, 'name': 'M r. Hall.'}
# None
# {'id': None, 'name': 'Dr. Nicolls.'}
# None
# {'id': None, 'name': 'Dampier'}
# {'id': None, 'name': 'Dr. Grews'}
# {'id': None, 'name': 'M r. John Courtney'}
# {'id': None, 'name': 'M r. Millers.'}
# {'id': None, 'name': 'Clerk.'}
# None
# {'id': None, 'name': 'Wald.'}
# {'id': None, 'name': 'M r. Edwards.'}
# {'id': None, 'name': 'M r. Catesby.'}
# None
# {'id': None, 'name': 'M r. Fullers'}
# {'id': None, 'name': 'May.'}
# None
# None
# {'id': None, 'name': 'Governor Collet'}
# {'id': None, 'name': 'M r. Leeds.'}
# {'id': None, 'name': 'D. Cadogan.'}
# {'id': None, 'name': 'M r. Catesby.'}
# {'id': None, 'name': 'M rs. Stanley.'}
# {'id': None, 'name': 'M r. Catesby'}
# {'id': None, 'name': 'M r. Houstoun.'}
# {'id': None, 'name': 'M r. Catesby'}
# {'id': None, 'name': 'M r. Winthorp'}
# None
# {'id': None, 'name': 'Dr. Mortimer.'}
# {'id': None, 'name': 'Capt. Crafort.'}
# None
# None
# {'id': None, 'name': 'M r. Dubois'}
# {'id': None, 'name': 'M r. Ord.'}
# {'id': None, 'name': 'M r. Edwards.'}
# None
# {'id': None, 'name': 'M r. Arstedi.'}
# None
# {'id': None, 'name': 'M r. Hodgson.'}
# {'id': None, 'name': 'Dr. Dering.'}
# {'id': None, 'name': 'Cadogan.'}
# None
# {'id': None, 'name': 'M r. Bell.'}
# {'id': None, 'name': 'M r. Clark.'}
# {'id': None, 'name': 'M r. Laurie.'}
# {'id': None, 'name': 'M r. Perry'}
# {'id': None, 'name': 'Lady Betty Heathcote.'}
# None
# {'id': None, 'name': 'M r. A H Wood.'}
# {'id': None, 'name': 'M r. Cox.'}
# {'id': None, 'name': 'M r. Craycoot'}
# {'id': None, 'name': 'M r. Barham'}
# {'id': None, 'name': 'M r. Swymmer'}
# None
# None
# {'id': None, 'name': 'M r. Clerk'}
# {'id': None, 'name': 'M r. Theobalds'}
# None
# {'id': None, 'name': 'Capt Walker.'}
# {'id': None, 'name': 'Duke of Cumber =land'}
# {'id': None, 'name': 'Tomo Chiche the Indian King'}
# {'id': None, 'name': 'Capt. Walker'}
# {'id': None, 'name': 'M r. Theobalds'}
# {'id': None, 'name': 'Dr. Knight'}
# {'id': None, 'name': 'M r. Bevan'}
# None
# {'id': None, 'name': 'M r. Gordon.'}
# {'id': None, 'name': 'M r. Catesby.'}
# None
# {'id': None, 'name': 'Capt. Craycoot.'}
# {'id': None, 'name': 'Capt. Cole.'}
# None
# {'id': None, 'name': 'M r. Dubois'}
# {'id': None, 'name': 'M r. Collinson.'}
# None
# {'id': None, 'name': 'M r. Edwards'}
# {'id': None, 'name': 'Dr. Mortimer.'}
# {'id': None, 'name': 'Brown'}
# {'id': None, 'name': 'Dr. Massy.'}
# {'id': None, 'name': 'Catesby'}
# {'id': None, 'name': 'Capt Cray'}
# {'id': None, 'name': 'M r. Bell.'}
# None
# None
# {'id': None, 'name': 'M rs. Jane'}
# {'id': None, 'name': 'M r. Edwards'}
# {'id': None, 'name': 'Dr. Parsons'}
# None
# {'id': None, 'name': 'Ld. Abbingdon'}
# None
# {'id': None, 'name': 'M r. Clerk.'}
# None
# {'id': None, 'name': 'Green'}
# {'id': None, 'name': 'M r Winthorp.'}
# None
# None
# None
# {'id': None, 'name': 'M r. Catesby'}
# None
# {'id': None, 'name': 'M r. Potts'}
# None
# {'id': None, 'name': 'M r. Edwards.'}
# None
# {'id': None, 'name': 'M r. given'}
# {'id': None, 'name': 'Amyand'}
# {'id': None, 'name': 'M r. Edwards.'}
# {'id': None, 'name': 'M r. Edwards'}
# {'id': None, 'name': 'M r. Edwards'}
# None
# {'id': None, 'name': 'M r. Edwards.'}
# None
# {'id': None, 'name': 'M r. Bartram'}
# {'id': None, 'name': 'M r. Bartram.'}
# {'id': None, 'name': 'M r. Edwards.'}
# None
# {'id': None, 'name': 'M r. Edwards.'}
# {'id': None, 'name': 'M r. Catesby'}
# {'id': None, 'name': 'M r. Edwards.'}
# None
# {'id': None, 'name': 'M r. Harrison'}
# {'id': None, 'name': 'M r. Edwards'}
# {'id': None, 'name': 'M r. Edwards.'}
# None
# {'id': None, 'name': 'M r. Edwards'}
# None
# {'id': None, 'name': 'M r. Edwards.'}
# {'id': None, 'name': 'Surgeon'}
# {'id': None, 'name': 'Geo Edwards'}
# None
# {'id': None, 'name': 'Lord Fermanaugh'}
# None
# {'id': None, 'name': 'Edwards.'}
# {'id': None, 'name': 'Green'}
# {'id': None, 'name': 'Green'}
# {'id': None, 'name': 'Duke of Richmond'}
# {'id': None, 'name': 'M r. Edwards.'}
# {'id': None, 'name': 'Green'}
# {'id': None, 'name': 'M r. Colebrooke'}
# {'id': None, 'name': 'D. in'}
# {'id': None, 'name': 'Martin'}
# {'id': None, 'name': 'Dr. Richardson.'}
# {'id': None, 'name': 'M r. Borham'}
# {'id': None, 'name': 'M r. Martin.'}
# None
# {'id': None, 'name': 'Martin.'}
# {'id': None, 'name': 'Dr. Richardson'}
# {'id': None, 'name': 'Dr. Richardson'}
# {'id': None, 'name': 'Dr. Richardson'}
# {'id': None, 'name': 'S t. Nicholas Garret'}
# {'id': None, 'name': 'Dr. Waldo'}
# None
# {'id': None, 'name': 'M r. Burnett'}
# None
# {'id': None, 'name': 'Dr. Richardson'}
# {'id': None, 'name': 'Dr. Richardson.'}
# {'id': None, 'name': 'Dr. Richardson.'}
# {'id': None, 'name': 'Dr. Richardson.'}
# {'id': None, 'name': 'Dr. Richardson.'}
# {'id': None, 'name': 'Dr. Richardson.'}
# {'id': None, 'name': 'Dr. Richardson.'}
# {'id': None, 'name': 'Dr. Richardson.'}
# {'id': None, 'name': 'Dr. Richardson.'}
# {'id': None, 'name': 'M r. Harris.'}
# {'id': None, 'name': 'Lady Garrard'}
# {'id': None, 'name': 'Lady Garrard'}
# {'id': None, 'name': 'M r. Shipton.'}
# {'id': None, 'name': 'M r. Shipton.'}
# {'id': None, 'name': 'M r. Clerk.'}
# {'id': None, 'name': 'M r. Clerk.'}
# None
# None
# {'id': None, 'name': 'M r. Clerk.'}
# None
# {'id': None, 'name': 'M r. Clerk.'}
# None
# {'id': None, 'name': 'Gray'}
# {'id': None, 'name': 'Gray'}
# None
# None
# {'id': None, 'name': 'M r. Randy.'}
# {'id': None, 'name': 'M r. Ranby.'}
# {'id': None, 'name': 'Hon ble. Lumley Lloyd'}
# {'id': None, 'name': 'Hon ble. Lumley Lloyd'}
# {'id': None, 'name': 'M r. Maidstone'}
# {'id': None, 'name': 'M r. Maidstone'}
# None
# None
# {'id': None, 'name': 'Mark Annesly Esq'}
# {'id': None, 'name': 'Mark Annesly Esq'}
# {'id': None, 'name': 'M r. Moubray.'}
# {'id': None, 'name': 'M r. Moubray.'}
# {'id': None, 'name': 'Dr. Grews'}
# {'id': None, 'name': 'Dr. Grews'}
# {'id': None, 'name': 'M r. Bell.'}
# {'id': None, 'name': 'M r. Bell.'}
# {'id': None, 'name': 'M r. Petivers'}
# {'id': None, 'name': 'M r. Retivers'}
# {'id': None, 'name': 'M r. Amyand'}
# {'id': None, 'name': 'M r Amyand'}
# {'id': None, 'name': 'M r. Marson'}
# {'id': None, 'name': 'S r. Nicholas'}
# {'id': None, 'name': 'Lady Garrard'}
# {'id': None, 'name': 'my daughter Cadogan'}
# {'id': None, 'name': 'M r. Dogly'}
# {'id': None, 'name': 'M r. W'}
# {'id': None, 'name': 'M r. Clerk.'}
# {'id': None, 'name': 'Capt. Walker.'}
# None
# {'id': None, 'name': 'M rs Deering.'}
# None
# {'id': None, 'name': 'M r. Barrets'}
# None
# {'id': None, 'name': 'M r. Collier.'}
# {'id': None, 'name': 'Capt. Cray coot'}
# None
# None
# {'id': None, 'name': 'Capt. Cray coot'}
# {'id': None, 'name': 'my neice Sloane'}
# {'id': None, 'name': 'M r. Vernons.'}
# {'id': None, 'name': 'Lluid.'}
# {'id': None, 'name': 'Lluid.'}
# None
# {'id': None, 'name': 'Vernon'}

# %% [markdown]
# #### Add catalogue entries

# %%
name_query = """
PREFIX ecrm: <http://erlangen-crm.org/current/>

SELECT ?person ?label

WHERE {
    # ?person rdf:type ecrm:E21_Person .
    # ?person rdfs:label ?label .
}
"""

# Return a dataframe containing all names
names = pd.DataFrame(graph.query(name_query), columns=["person", "label"])
names[0:10]
# Out:
# Empty DataFrame
# Columns: [person, label]
# Index: []

# %%
print(len(graph))
# Out:
# 24574

# %%
graph.serialize(destination='/Users/danielemetilli/Downloads/sloane-graph-fossils-v.ttl', format="turtle");
